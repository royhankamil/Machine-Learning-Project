# %% [markdown]
# # **Preprocessing**

# %% [markdown]
# ### **Eksplorasi Data**

# %% [markdown]
# Pada tahapan ini saya akan melakukan beberapa persiapan dan juga mencoba memeahami isi dari data tersebut mulai dari banyaknya data pada setiap label dan lain lain.

# %%
# menyiapkan library
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import re
import string

# %% [markdown]
# lalu disini saya melakukan importing pada dataset untuk mengetahui isi dari data tersebut

# %%
# melakukan pengambilan data
df = pd.read_csv("TABEL DATA LATIH HATESPEECH RISET.xlsx - Sheet1.csv")

# melihat data
df.head()
# Out:
#           username                                            comment   label
# 0         dxndelin  @amyliarm lingkunganmu keknya punya pemahaman ...  Netral
# 1     __succiduous                           Udah jelek brengsek pula     Ras
# 2  KemenagMempawah  Lucunya penghuni negeri ini selalu di hiasi da...   Agama
# 3    1stKOREANguy1  Yang jelek + miskin udah pasti bukan Kristen ,...     Ras
# 4  newsutdofficial  @MurtadhaOne1 Mereka memanfaatkan kebodohan ka...   Agama

# %% [markdown]
# Lalu kita akan coba telusuri banyaknya data untuk setiap labelnya. Jikalau tidak seimbang maka nantinya akan saya proses lagi. Karena kalau label tidak seimbang, maka akan berpotensi overfitting. Mengapa overfitting ? dikarenakan model akan lebih cenderung belajar pada data yang paling banyak, sehingga dia akan sulit mengenali pada data dengan class yang jumlahnya sedikit.

# %%
# banyaknya data pada setiap class
df.label.value_counts()
# Out:
# label
# Netral    836
# Ras       601
# Agama     563
# Name: count, dtype: int64

# %% [markdown]
# Setelah saya lakukan analisa ternyata keseimbangan datanya sudah cukup bagus

# %% [markdown]
# ### **Seleksi Fitur**

# %% [markdown]
# Pada tahapan ini kita akan mencoba menyeleksi fitur pada data kita. Kita akan menghapus untuk fitur yang tidak diperlukan. Setelah melihat datanya saya bisa menentukan bahwa fitur yang kita perlukan hanya comment dan label saja. Comment yang akan menjadi data x nya nanti dan label sebagai data y nya nanti

# %%
# menghilangkan fitur
df.drop(columns="username", inplace=True)

# mlihat data
df.head()
# Out:
#                                              comment   label
# 0  @amyliarm lingkunganmu keknya punya pemahaman ...  Netral
# 1                           Udah jelek brengsek pula     Ras
# 2  Lucunya penghuni negeri ini selalu di hiasi da...   Agama
# 3  Yang jelek + miskin udah pasti bukan Kristen ,...     Ras
# 4  @MurtadhaOne1 Mereka memanfaatkan kebodohan ka...   Agama

# %% [markdown]
# ### **Cleaning**

# %% [markdown]
# **Nilai yang Hilang**
#
# kita akan mencari apakah ada data yang hilang. Untuk memastikan bahwa data ini tidak ada yang hilang. **Mengapa harus di cek lagi ?** karena jika benar benar ada data yang hilang, maka akan berpotensi **kesalahpahaman oleh model**. Misal pada text terisi Nan (karena tidak ada nilainya) maka model akan mengira kalau text tersebut memiliki text yang berisi "Nan"

# %%
# jumlah nilai hilang jenis Nan
df.isna().sum()
# Out:
# comment    3
# label      4
# dtype: int64

# %% [markdown]
# kita dapat melihta kalau ada data kosong di kolom comment sebanyak 3 data dan data kosong di label ada 4 data. Yang kita lakukan adalah **mengdrop / menghilangkan data yang kosong** ini. Kenapa kok dihilangkan bukan di cari rata rata atau lainnya. Karena data text pada comment itu unik untuk setiap datanya. Maka tidak bisa dilakukan pencarian mean, modus, atau lain lain.

# %%
# melihat data unik pada label
df.label.unique()
# Out:
# array(['Netral', 'Ras', 'Agama', nan], dtype=object)

# %%
# menghilangkan data kosong
df.dropna(inplace=True)

# melihat banyak data kosong
df.isna().sum()
# Out:
# comment    0
# label      0
# dtype: int64

# %% [markdown]
# **Data yang Terduplikasi**
#
# kita akan mencari apakah ada data yang terduplikasi atau tidak. **mengapa kita perlu mencari apakah ada data yang duplikasi** ? karena jika data yang terduplikasi ini dibiarkan maka akan **menimbulkan overfitting** karena model akan **cenderung menghafal** pada data yang terduplikasi. Jikalau model ini menghafal maka yang terjadi dia akan **kesulitan untuk menebak data yang baru**

# %%
# melihat data yang terduplikasi
df[df.comment.duplicated()]
# Out:
#                                                 comment   label
# 143   @VIVAcoid Sudahlah,Dia mnjabat sbg menteri saj...  Netral
# 144   @banjarbase Agama jgn dijadikan tolak ukur lag...  Netral
# 269                     @yonkpaws Jelek klodia ðŸ˜”ðŸ˜”     Ras
# 387   gua kok ngerekam suara gue jelek amat anjir bi...   Agama
# 398   Ini contoh Islam yg ga bener + contoh kristen ...   Agama
# ...                                                 ...     ...
# 1728                                IKN Potret Kemajuan  Netral
# 1730                                IKN Potret Kemajuan  Netral
# 1733                                IKN Potret Kemajuan  Netral
# 1811                                IKN Potret Kemajuan  Netral
# 1999                                IKN Potret Kemajuan  Netral
#
# [61 rows x 2 columns]

# %% [markdown]
# di atas kita dapat melihat kalau **ada data yang terduplikasi**. Maka selanjutnya kita perlu menghilangkan salah satu data yang terduplikasi ini. Kita dapat menggunakan function yang ada di pandas

# %%
# menghilangkan data yang terduplikasi
df.drop_duplicates(inplace=True)

# melihat banyaknya data yang terduplikasi
df[df.comment.duplicated()]
# Out:
#                                                 comment  label
# 387   gua kok ngerekam suara gue jelek amat anjir bi...  Agama
# 458   @RazmanZakaria60 apa sumbangan PAS kepada nega...  Agama
# 477   @Motty_hang yang benci FPI PKI dan kaum munafikun  Agama
# 491   @souIsinlove kpop k nya kafir jahat setan wall...  Agama
# 512   gausah senyum kau didepan ku kntl, jelek kau b...    Ras
# 600   @kompascom Maka, oleh sebab itu bertindaklah s...    Ras
# 1671  @apoycuy Tokoh agama di Papua kecam penyeranga...    Ras

# %% [markdown]
# ### **Train Test Split**

# %% [markdown]
# Pada tahapan ini kita akan melakukan splitting data menjadi data yang digunakan khusus untuk train dan data yang digunakan khusus untuk test. Mengapa hal ini perlu dilakukan, karena agar kita dapat melihat performa model kita melalui data yang baru (data test)

# %%
# akan mengembalikan data yang sudah di split
def Train_Test_Split(x, y, random_seed=None, test_size=0.2):
    n = len(x) # banyak data

    # jika punya seed
    if random_seed:
        np.random.seed(random_seed)
    
    # banyak data test
    test_size = int(test_size * n)

    # menentukan index secara random
    indices = np.random.permutation(n)
    train_indices, test_indices = indices[test_size:], indices[:test_size]

    return x.iloc[train_indices], x.iloc[test_indices], y.iloc[train_indices], y.iloc[test_indices]
# menentukan x dan y nya
x = df["comment"]
y = df["label"]

# splitting pada data kita
X_train, X_test, y_train, y_test  = Train_Test_Split(x, y, random_seed=42)

# melihat isi data train
X_train
# Out:
# 1796    Indonesia Negara Hukum\r\n Assalamuâ€™alaikum\...
# 908     Ã¢â‚¬Å“Tergantung interpretasi masing-masing i...
# 575     Terbukti benar hrus dipercaya benar, tak jelas...
# 1697    menurutku penyakit kita bukan pada pakaian dan...
# 1475    @WagimanDeep212_ Berbalut agama makan duit don...
#                               ...
# 1179    @maman1965 Berusaha menghormati adat istiadat ...
# 1343    @ZacZakirin13 @syazreenaaa Tapi menteri agama ...
# 906     @OposisiCerdas Murtad aja keles susah bgt. Toh...
# 1510    WARTAWAN RASMI LAMAN REFORMASI: TIK TOK KHALID...
# 1175    PENGURUS BARU HMI dari BANDUNG pakai KALUNG SA...
# Name: comment, Length: 1557, dtype: object

# %% [markdown]
# ### **Case Folding**

# %% [markdown]
# Pada tahapan ini kita akan menghilangkan karakter karakter yang **tidak memiliki makna dalam segi bahasa** yang ada pada data comment. Karakter seperti tag, hashtag, link, emoji, dan lain lain. Karena karakter jenis ini terlalu unik maka kita perlu menghilkangkannya. Karakter yang **terlalu unik umumnya tidak memiliki pola**.

# %% [markdown]
# # akan mengembalikan text yang sudah di case
# def case_folding(text):
#     # menghilangkan tag
#     text = re.sub(r"@[A-Za-z0-9_]+", "", text)
#     # menghilangkan hashtag
#     text = re.sub(r"#\w+", "", text)
#     # menghilangkan link
#     text = re.sub(r"https?://\S+", "", text)
#     # menghilangkan newline atau enter
#     text = re.sub(r"\n+", "", text)
#     # menghilangkan \r
#     text = re.sub(r"\r+", "", text)
#     # menghilangkan nomer
#     text = re.sub(r"\d+", "", text)
#
#     # menghilangkan simbol
#     text = text.translate(str.maketrans("", "", string.punctuation))
#
#     # menghilangkan emoji
#     emoji_pattern = re.compile("["
#                                u"\U0001F600-\U0001F64F"
#                                u"\U0001F300-\U0001F5FF"
#                                u"\U0001F680-\U0001F6FF"
#                                u"\U00010000-\U0010ffff"
#                                "]+", flags=re.UNICODE)
#     text = emoji_pattern.sub(r"", text).lower()
#
#     # menghilangkan karakter diluar latin
#     qwerty = "abcdefghijklmnopqrstuvwxyz "
#     text = "".join([letter for letter in text if letter in qwerty])
#
#     # memperkecil huruf
#     return text
#
# # mengimplementasikann untuk setiap doc
# X_train = X_train.apply(case_folding)
# X_train

# %% [markdown]
# ### **Tokenize**

# %% [markdown]
# Pada tahapan ini kita akan melakukan **pemisahan** untuk setiap document nya menjadi **list kata**. Tujuannya adalah kata ini akan menjadi fitur nantinya dalam pembobotan kata

# %%
# akan mengembalikan documen yang sudah di tokenize
def tokenize(text):
    return word_tokenize(text)

# mengimplementasikan untuk setiap doc
X_train = X_train.apply(tokenize)
X_train
# Out:
# 1796    [Indonesia, Negara, Hukum, Assalamuâ€™alaikum,...
# 908     [Ã¢â‚¬Å, “, Tergantung, interpretasi, masing-m...
# 575     [Terbukti, benar, hrus, dipercaya, benar, ,, t...
# 1697    [menurutku, penyakit, kita, bukan, pada, pakai...
# 1475    [@, WagimanDeep212_, Berbalut, agama, makan, d...
#                               ...
# 1179    [@, maman1965, Berusaha, menghormati, adat, is...
# 1343    [@, ZacZakirin13, @, syazreenaaa, Tapi, menter...
# 906     [@, OposisiCerdas, Murtad, aja, keles, susah, ...
# 1510    [WARTAWAN, RASMI, LAMAN, REFORMASI, :, TIK, TO...
# 1175    [PENGURUS, BARU, HMI, dari, BANDUNG, pakai, KA...
# Name: comment, Length: 1557, dtype: object

# %% [markdown]
# ### **Normalize**

# %% [markdown]
# Pada proses ini kita akan mengubah kata yang **tidak baku menjadi kata baku / kata yang umum menjadi kata yang umum**. Seperti singkatan singkatan menjadi kata yang aslinya. Tujuannya adalah agar menjadikan sama makna yang disingkat dengan yang tidak disingkat

# %%
# kata yang harus dinormalize
norm_word = {
    "emg" : "memang",
    "saiz" : "size",
    "cino" : "cina",
    "jowo" : "jawa",
    "kite" : "kita",
    "lg" : "lagi",
    "aj" : "aja",
    "yg" : "yang",
    "pdhl" : "padahal",
    "napa" : "kenapa",
    "dh" : "sudah",
    "udh" : "sudah",
    "tdk" : "tidak",
    "sm" : "sama",
    "ga" : "tidak",
    "bgt" : "banget",
    "mentri" : "menteri",
    "embantu" : "membantu",
    "dlm" : "dalam",
    "bdang" : "bidang",
    "msh" : "masih",
    "ampe" : "sampai",
    "ky" : "kaya",
    "nnya" : "tanya",
    "krn" : "karena",
    "jir" : "anjing",
    "ajg" : "anjing",
    "anjir" : "anjing",
    "gak" : "tidak",
    "ak" : "aku",
    "dasr" : "dasar",
    "lgsg" : "langsung",
    "skrg" : "sekarang",
    "gw" : "gua",
    "w" : "gua",
    "engga" : "tidak",
    "dgn" : "dengan",
    "orng" : "orang",
    "org" : "orang",
    "ni" : "ini",
    "jgn" : "jangan",
    "mbahas" : "bahas",
    "krna" : "karena",
    "ma" : "sama",
    "sblm" : "sebelum",
    "tp" : "tapi",
    "sbg" : "sebagai"
}

# melakukan normalisasi
def normalize(text):
    return [norm_word[word] if word in norm_word else word for word in text]

# mengimplementasikan untuk setiap doc
X_train = X_train.apply(normalize)
X_train
# Out:
# 1796    [Indonesia, Negara, Hukum, Assalamuâ€™alaikum,...
# 908     [Ã¢â‚¬Å, “, Tergantung, interpretasi, masing-m...
# 575     [Terbukti, benar, hrus, dipercaya, benar, ,, t...
# 1697    [menurutku, penyakit, kita, bukan, pada, pakai...
# 1475    [@, WagimanDeep212_, Berbalut, agama, makan, d...
#                               ...
# 1179    [@, maman1965, Berusaha, menghormati, adat, is...
# 1343    [@, ZacZakirin13, @, syazreenaaa, Tapi, menter...
# 906     [@, OposisiCerdas, Murtad, aja, keles, susah, ...
# 1510    [WARTAWAN, RASMI, LAMAN, REFORMASI, :, TIK, TO...
# 1175    [PENGURUS, BARU, HMI, dari, BANDUNG, pakai, KA...
# Name: comment, Length: 1557, dtype: object

# %% [markdown]
# ### **Menghilangkan Stopwords**

# %% [markdown]
# Pada tahapan ini kita akan menyeleksi kata tertentu. Kita akan **menghilangkan kata yang tidak memiliki makna secara independen**. **Mengapa harus dihilangkan ?** dikarenakan nantinya yang akan **dilakukan pembobotan** kata akan memerlukan makna yang independen pada setiap fitur nya. Jika maknanya itu dependen dan terikat pada kata yang lainnya maka akan berbeda beda maknanya. Jika makna beda, maka tidak ada pola nanti datanya. Contoh konjungsi, kata penjelas, dan lain lain.

# %%
# kata yang harus di stop
stopw = stopwords.words("indonesian")

# mengembalikan kata yang sudah di stop
def stopword(text):
    return [word for word in text if word not in stopw and len(word) >=2 ]

# mengimplementasikan untuk setiap doc
X_train = X_train.apply(stopword)
X_train
# Out:
# 1796    [Indonesia, Negara, Hukum, Assalamuâ€™alaikum,...
# 908     [Ã¢â‚¬Å, Tergantung, interpretasi, individu, k...
# 575     [Terbukti, hrus, dipercaya, salah, dipercaya, ...
# 1697    [menurutku, penyakit, pakaian, asesories, akar...
# 1475    [WagimanDeep212_, Berbalut, agama, makan, duit...
#                               ...
# 1179    [maman1965, Berusaha, menghormati, adat, istia...
# 1343    [ZacZakirin13, syazreenaaa, Tapi, menteri, aga...
# 906     [OposisiCerdas, Murtad, aja, keles, susah, ban...
# 1510    [WARTAWAN, RASMI, LAMAN, REFORMASI, TIK, TOK, ...
# 1175    [PENGURUS, BARU, HMI, BANDUNG, pakai, KALUNG, ...
# Name: comment, Length: 1557, dtype: object

# %% [markdown]
# ### **Stemming**

# %% [markdown]
# Pada tahapan ini kita akan melakukan pengubahan kata kata menjadi kata dasarnya. Tujuannya adalah agar memperkecil variasinya sehingga model juga akan memahami bahwa kata yang belum dasar memiliki makna yang sama dengan kata dasarnya. Misal Penyanyi menjadi nyanyi, Pemahaman menjadi paham.

# %%
stemmer = StemmerFactory().create_stemmer()

def stemming(text):
    return [stemmer.stem(word) for word in text]

# mengimplementasikan untuk setiap doc
X_train = X_train.apply(stemming)
X_train
# Out:
# 1796    [indonesia, negara, hukum, assalamu alaikum, u...
# 908     [, gantung, interpretasi, individu, kemari, ru...
# 575     [bukti, hrus, percaya, salah, percaya, salah, ...
# 1697    [turut, sakit, pakai, asesories, akar, budaya,...
# 1475    [wagimandeep212, balut, agama, makan, duit, do...
#                               ...
# 1179    [maman1965, usaha, hormat, adat, istiadat, lok...
# 1343    [zaczakirin13, syazreenaaa, tapi, menteri, aga...
# 906     [oposisicerdas, murtad, aja, les, susah, bange...
# 1510    [wartawan, rasmi, laman, reformasi, tik, tok, ...
# 1175    [urus, baru, hmi, bandung, pakai, kalung, sali...
# Name: comment, Length: 1557, dtype: object

# %% [markdown]
# **Kemunculan Data**
#
# Pada tahapan kita akan mencari kata yang paling sering disebut di setiap class

# %%
# data yang ingin dilabeli
labeled_data = X_train.to_frame()

# melabeli data
labeled_data["label"] = y_train

labeled_data
# Out:
#                                                 comment   label
# 1796  [indonesia, negara, hukum, assalamu alaikum, u...  Netral
# 908   [, gantung, interpretasi, individu, kemari, ru...  Netral
# 575   [bukti, hrus, percaya, salah, percaya, salah, ...   Agama
# 1697  [turut, sakit, pakai, asesories, akar, budaya,...  Netral
# 1475  [wagimandeep212, balut, agama, makan, duit, do...   Agama
# ...                                                 ...     ...
# 1179  [maman1965, usaha, hormat, adat, istiadat, lok...  Netral
# 1343  [zaczakirin13, syazreenaaa, tapi, menteri, aga...  Netral
# 906   [oposisicerdas, murtad, aja, les, susah, bange...   Agama
# 1510  [wartawan, rasmi, laman, reformasi, tik, tok, ...   Agama
# 1175  [urus, baru, hmi, bandung, pakai, kalung, sali...  Netral
#
# [1557 rows x 2 columns]

# %% [markdown]
# kata paling sering untuk class untuk class ras

# %%
from wordcloud.wordcloud import WordCloud

# menampilkan data
def showing(wc):
    plt.figure(figsize=(12,8)) # ukuran
    plt.axis("off") 
    plt.imshow(wc, interpolation="bilinear")
    plt.show

# semua kata
allword = "".join([str(text).replace("'", "") for text in labeled_data.comment[labeled_data.label == "Ras"]])

# menyiapkan  komponen wordcloud
word_cloud = WordCloud(
    height=800,
    width=1200,
    collocations=False,
    colormap="Blues_r"
 ).generate(allword)

showing(word_cloud)

# %% [markdown]
# kata paling sering untuk class untuk class Agama

# %%
# menampilkan data
def showing(wc):
    plt.figure(figsize=(12,8)) # ukuran
    plt.axis("off") 
    plt.imshow(wc, interpolation="bilinear")
    plt.show

# semua kata
allword = "".join([str(text).replace("'", "") for text in labeled_data.comment[labeled_data.label == "Agama"]])

# menyiapkan  komponen wordcloud
word_cloud = WordCloud(
    height=800,
    width=1200,
    collocations=False,
    colormap="Blues_r"
 ).generate(allword)

showing(word_cloud)

# %% [markdown]
# kata paling sering untuk class untuk class netral

# %%
# menampilkan data
def showing(wc):
    plt.figure(figsize=(12,8)) # ukuran
    plt.axis("off") 
    plt.imshow(wc, interpolation="bilinear")
    plt.show

# semua kata
allword = "".join([str(text).replace("'", "") for text in labeled_data.comment[labeled_data.label == "Netral"]])

# menyiapkan  komponen wordcloud
word_cloud = WordCloud(
    height=800,
    width=1200,
    collocations=False,
    colormap="Blues_r"
 ).generate(allword)

showing(word_cloud)

# %% [markdown]
# # **Pembobotan Kata**

# %% [markdown]
# ### **Kalkulasi TF-IDF**

# %% [markdown]
# Pada tahapan ini kita akan melakukan perhitungan dalam **TFIDF** untuk nilai dari pembobotan kata berikut untuk tahapan tahapannya:
# - Untuk tahapan awal kita akan melakukan perhitungan *term frequency* yaitu perhitungan **banyaknya term / jumlah kata** untuk suatu dokumen **dibanding** dengan **banyak kata** yang ada di dokumen tersebut. untuk rumus dari TF atau *term frequency* adalah **TF** = kata *t* diulang di document *d* / banyak kata di document *d*
# - Untuk tahapan selanjutnya adalah kita akan menghitung dari *inverse document frequency* yaitu perhitungan berapa **banyak dokumen** yang didalamnya terdapat **kata *t***. Untuk rumusnya dari IDF atau *inverse document frequency* adalah **IDF** = log10(banyak document / banyak document yang di dalamnya ada kata *t* )
# - Lalu pada tahapan selanjutnya adalah kita akan melakukan perhitungan untuk ***pembobotan suatu kata*** dengan *TF-IDF*  yaitu gabungan *term frequency* dan *inverse document frequency*. Cara menggabungkannya adalah dengan mengkali nilai dari TF dan IDF nya. rumus dari *TF IDF* adalah **TFIDF** = TF * IDF
# - Lalu kita akan menentukan *TF IDF* untuk setiap item
# - Lalu untuk mempermudah hasil analisa akan dilakukan normalisasi untuk nilai tf idf

# %%
# Inisialisasi Class yang akan digunakan untuk kalkulasi TF-IDF
class TFIDFVectorizer:
    # Inisialisasi variable yang dibutuhkan untuk kalkulasi TF-IDF
    def __init__(self) -> None:
        # Inisialisasi variable untuk menampung array teks yang sudah ditokenisasi dalam bentuk dictionary.
        self.documents = {}

        # Inisialisasi variable untuk menampung array TF yang sudah dikalkulasi dengan format {index : {term : value, ...}}
        self.tf = {}

        # Inisialisasi variable untuk menampung array IDF yang sudah dikalkulasi dengan format {key : value}
        self.idf = {}
        self.idf_token = []

        # Inisialisasi variable untuk menampung array TF-IDF yang sudah dikalkulasi dengan format {index : {term : value, ...}}
        self.tfidf = {}

        # Inisialisasi variable untuk menampung hasil tertinggi dan terendah dalam array TFIDF untuk keperluan normalisasi TF-IDF
        self.max_tfidf = 0
        self.min_tfidf = 0

    # Kalkulasi frekuensi kemunculan tiap term didalam dokumen dengan rumus (Number of term appear in the document/total term in the document)
    def CalculateTermFrequence(self):
        for index, document in self.documents.items():
            self.tf[index] = {}
            for term in document:
                if term in self.tf[index]:
                    self.tf[index][term] += 1
                else:
                    self.tf[index][term] = 1
            self.tf[index] = {term: value/sum(self.tf[index].values()) for term, value in self.tf[index].items()}
    
    # Kalkulasi Inverse Document Frequency, yang dimana semakin kecil maka semakin sering muncul dengan rumus log(Total Documents/Number the term appear in all documents)
    def CalculateInverseDocumentFrequency(self):
        documents_length = len(self.documents)
        self.idf_token = set()

        for document in self.documents.values():
            self.idf_token.update(document)

        for token in self.idf_token:
            self.idf[token] = np.log(documents_length/sum(1 for doc in self.documents.values() if token in doc))
        
    # Kalkulasi TFIDF dengan rumus (TERM_ITF*Calculated_IDF_TERM)
    def CalculateTFIDF(self):
        for index, document in self.tf.items():
            self.tfidf[index] = {}
            for word, value in document.items():
                self.tfidf[index][word] = value*self.idf[word]
            
            for token in self.idf_token:
                if token not in self.tfidf[index]:
                    self.tfidf[index][token] = 0
        
        flattened_value = [value for doc in self.tfidf.values() for value in doc.values()]
        self.max_tfidf = max(flattened_value)
        self.min_tfidf = min(flattened_value)
        
        #for index, document in self.tfidf.items():
        #    print(document)
        #     self.tfidf = sorted(document.items(), key=lambda x:x[1])
    

    # Memanggil Semua Fungsi untuk train TFIDF yang akan digunakan di Model, dan digunakan untuk mengconvert (predict text(input)) menjadi Value TF-IDF
    def Train(self, documents = {}):
        self.documents = documents
        self.CalculateTermFrequence()
        self.CalculateInverseDocumentFrequency()
        self.CalculateTFIDF()
        
        return self.tfidf
    
    # Kalkulasi TFIDF Terhadap (predict text(input)) dengan IDF yang sudah dikalkulasi di fungsi train/IDF dari data train untuk menunjukkan keunikan setiapterm pada (predict text(input))
    def CalculatePredictTextTFIDF(self, document):
        tf = {}
        for word in document:
            if word in tf:
                tf[word]+=1
            else:
                tf[word]=1
        tf = {key: value/sum(tf.values()) for key, value in tf.items()}

        tfidf = {}
        for word, value in tf.items():
            if word in self.idf_token:
                tfidf[word] = value*self.idf[word]
        
        for token in self.idf_token:
                if token not in tfidf:
                    tfidf[token] = 0
                    
        return tfidf

# %%
# melakukan implementasi untuk setiap data
dict = X_train.to_dict()
vectorizer = TFIDFVectorizer()
Vectorized_X_train = pd.DataFrame(vectorizer.Train(dict))
print(vectorizer.CalculatePredictTextTFIDF(["indonesia", "negara", "hukum", "assalamualaikum"]))
# Out:
# {'indonesia': 0.897329014035109, 'negara': 0.9217386314260879, 'hukum': 1.238155224758907, '': 0, 'manusi': 0, 'sekala': 0, 'usaha': 0, 'anwar': 0, 'bonaleles': 0, 'tiktok': 0, 'tertib': 0, 'adat': 0, 'mud': 0, 'nightmare': 0, 'kass': 0, 'pke': 0, 'well': 0, 'pantas': 0, 't co nxpgifgiw8': 0, 'skinticfic': 0, 'yo': 0, 'funny': 0, 'sakerautm': 0, 't co wkjoqnhavx': 0, 'dlktatur': 0, 'jem': 0, 'ust': 0, 'kapir': 0, 'eeaalahh': 0, 'mbulukk': 0, 'better': 0, 'ferrykoto': 0, 'keuangannews id': 0, 't co bcjwm4w9jr': 0, 'sampuk': 0, 'bodok': 0, 'beda': 0, 'sex': 0, 'gimmick': 0, 'makin': 0, 't co ckdepkby7n': 0, 'privasi': 0, 'joeallan23': 0, 'tasyabbuh': 0, 'ngga': 0, 'jirat': 0, 'bedain': 0, 'mescid-i': 0, 'oleh': 0, 'hiding': 0, 'irenedyah': 0, 'dap': 0, 'lngsg': 0, 'jaga': 0, 'keilangan': 0, 'gula': 0, 'mungil': 0, 'menghornati': 0, 'lelaki': 0, 'wyuanwca': 0, 'mojokerto': 0, 'auto': 0, 'koto': 0, 'skripsi': 0, 'teken': 0, 'mba': 0, 'sarkum09110094': 0, 'besar': 0, 'adil': 0, 'jokowi': 0, 't co z5jwuv2hob': 0, 'shocknya': 0, 'tubirfess': 0, 'kemeja': 0, 'xikut': 0, 'kalau': 0, 'anti-muslim': 0, 'polri': 0, 'merdeka': 0, 'balanga': 0, 't co ufudl6hcvg': 0, 'laris': 0, 'tiongkok': 0, 't co jcyfvmj3nt': 0, 'sastra': 0, 'rizmaya': 0, 'antri': 0, 'tamil': 0, 'pierrerandy2': 0, 'politiik': 0, 'sunyik': 0, 't co wvznypmvl8': 0, 't co fuknzqgh3l': 0, 'melihara': 0, 'agama ajar': 0, 'ikan': 0, 'promote': 0, 'oligarki': 0, 'tetek': 0, 'istighfar': 0, 'masakin': 0, 'samsudin': 0, 'gagaknew': 0, 'msalah': 0, 'msukkn': 0, 'yuliati29211086': 0, 'hindu': 0, 'jamin': 0, '2-3': 0, 'kabupaten': 0, 'wong': 0, 'direview': 0, 'ras': 0, 'dan': 0, 'youtubenya': 0, 'kali': 0, 'resah': 0, 'kon': 0, 't co 7ioydnzubf': 0, 'gk': 0, 'bod': 0, 'yaqut': 0, 'tunda': 0, 'kemisikinan': 0, 'ikut': 0, 'nutupin': 0, 'behahahahaha': 0, 'wkw': 0, 'kekalen': 0, 'klp': 0, 'sm': 0, 'el': 0, 'korut': 0, 'promosiin': 0, 't co hchutpy3ml': 0, 'ndrewstjan': 0, 'ngopi': 0, 't co kpplg6gyjo': 0, 'layar': 0, 'nyebutin': 0, 't co jphouwhkuh': 0, 'its': 0, 'works': 0, 'gi': 0, 'kasta': 0, 'dongeng': 0, 'seoul': 0, 'stopplandemit': 0, 'mentah': 0, 'kep': 0, 'aemieruls': 0, 't co dofdwiwbr8': 0, 'im': 0, 'waifuan': 0, 'gm': 0, 'puki': 0, 'periksa': 0, 'mbok': 0, 'asesoris': 0, 'duniawi': 0, '77': 0, 'had': 0, 'bang': 0, 'tuju': 0, 'convomf': 0, 'bs': 0, 'invisib85100194': 0, 'outredox': 0, 'ibu': 0, 'version': 0, 'paling': 0, 'tali': 0, 't co t5el0jezcd': 0, 'faktor': 0, 'subhanallah': 0, 'twitter': 0, 'perkara': 0, 'twt': 0, 'selecxtive': 0, 'maman1965': 0, 'sipit': 0, 't co q4k915fibg': 0, 'pahit': 0, 'raja': 0, '30 000': 0, 'seg': 0, 'koleksi': 0, 'bigul': 0, 'bukn': 0, 'dimasukkin': 0, 'sulawesi': 0, 't co 41adgk0ejz': 0, 'multimedia': 0, 'nyerah': 0, 'hari': 0, 'mah': 0, 'jelas2': 0, 'terbit': 0, 'when': 0, 'tita83079013': 0, 'isis': 0, 't co j2oeq7me0k': 0, 'kntl': 0, 'pelit': 0, 'buang': 0, 'konflik': 0, 'tuuhkan': 0, 'tapai': 0, 'chiben': 0, 'alur': 0, 'anggota': 0, 'dianggep': 0, 'bamiyan': 0, 'yang': 0, 'point': 0, 'khajar': 0, 'buat': 0, 'jumianto rk': 0, 't co er4dwk8fqu': 0, 'warwerwor': 0, 'cewe': 0, 'ppt': 0, 'kmrn': 0, 't co zoclqfk7xc': 0, 'badminton': 0, 'dilaporin': 0, 'guess': 0, 't co ypjblmjplq': 0, 'nowplaying': 0, 'owh': 0, 't co vwycrdkbct': 0, 't co cpo1he9r9z': 0, 'pro': 0, 'syara': 0, 'kemenlu': 0, 'sehingga': 0, 'jeannie': 0, 'kriminal': 0, 'bgitu': 0, 'alah': 0, 'buset': 0, 'tjhinfar': 0, 'yazma': 0, 'investasi': 0, 'imageku': 0, 'pinter': 0, 'trima': 0, 'john': 0, 'preman': 0, 'bidang': 0, 'ambil': 0, 'aceh': 0, 'mnrt': 0, 'andra': 0, 't co f6udtihtxf': 0, 'rugi': 0, 'sini': 0, 'becandaan': 0, 'fiya nisaa': 0, 'nonton': 0, 'dindadi': 0, 'belu': 0, 'super': 0, 'mydorkenergy': 0, 'kristian': 0, 't co bv8twzs5pc': 0, 'ancok': 0, 't co ew3chfvtbs': 0, 'ricoo 111': 0, 'receh': 0, 't co 40zdfk6u18': 0, 't co zolc7ywcdg': 0, 'kesiap': 0, 'dok': 0, 'dialog': 0, 'seka': 0, 'kian': 0, 'eclaircakee': 0, 'tenarr': 0, 'bacot': 0, 'hias': 0, 'wife': 0, 't co qbs1zu ...

# %%
import numpy
import math

class KNN:
    def __init__(self) -> None:
        self.xtrain = {}
        self.ytrain = pd.DataFrame()
        self.ytest = {}
        self.distances = {}
        self.neighbor = 1

    def fit(self, xtrain, ytrain):
        self.xtrain = xtrain
        self.ytrain = ytrain

    def predict(self, document):
        self.ytest = document
        for index, doc in self.xtrain.items():
            distance = []
            for term, value in self.ytest.items():
                distance.append((value-doc[term])**2)
            self.distances[index] = sum(distance)
        return self.voting()
    
    def voting(self):
        sorted_distance = min(self.distances.items(), key=lambda x:x[1])
        return y_train.loc[sorted_distance[0]]
    
    # menampilkan akurasi, prrecision, recall, dan f1 score
    def metric(self, y_pred, y_true, label):
    
        n_label = len(label) # banyak label
        
        confusion_matrix = np.zeros((n_label, n_label)) # confusion matriks

        # menghitung masing masing cell
        for i in range(len(y_pred)):
            confusion_matrix[label.index(y_pred[i])][label.index(y_true[i])] += 1
        self.cm = confusion_matrix # menyimpan di object
        print(confusion_matrix)

        # menghitung akurasi model
        accuracy = np.sum([confusion_matrix[i][i] for i in range(n_label)]) / len(y_pred)

        # perhitungan precision
        for i in range(n_label):
            print("\nclass:", label[i])

            # menghitung precision
            precision = confusion_matrix[i][i] / np.sum([confusion_matrix[i][k] for k in range(n_label)])
            self.precision.append(precision)
            print("precision:", precision)

            # menghitung recall
            recall = confusion_matrix[i][i] / np.sum([confusion_matrix[k][i] for k in range(n_label)])
            self.recall.append(recall)
            print("recall:", recall)

            # menghitung f1 score
            f1score = (2 * precision * recall) / (precision + recall)
            self.f1score.append(f1score)
            print(f1score)
            
        print("\naccuracy:", accuracy)
                

knn = KNN()
knn.fit(Vectorized_X_train, y_train)
text = "Ras terkuat di jalan, no counterðŸ¤£"
text = tokenize(text)
text = normalize(text)
text = stopword(text)
text = stemming(text)

text = (vectorizer.CalculatePredictTextTFIDF(text))
knn.predict(text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 76
#      73 text = stemming(text)
#      75 text = (vectorizer.CalculatePredictTextTFIDF(text))
# ---> 76 knn.predict(text)
#
# Cell In[37], line 21, in KNN.predict(self, document)
#      19     distance = []
#      20     for term, value in self.ytest.items():
# ---> 21         distance.append((value-doc[term])**2)
#      22     self.distances[index] = sum(distance)
#      23 return self.voting()
#
# File c:\Python\Python312\Lib\site-packages\pandas\core\series.py:1112, in Series.__getitem__(self, key)
#    1109     return self._values[key]
#    1111 elif key_is_scalar:
# -> 1112     return self._get_value(key)
#    1114 # Convert generator to list before going through hashable part
#    1115 # (We will iterate through the generator there to check for slices)
#    1116 if is_iterator(key):
#
# File c:\Python\Python312\Lib\site-packages\pandas\core\series.py:1211, in Series._get_value(self, label, takeable)
#    1208     new_mgr = self._mgr.get_rows_with_mask(indexer)
#    1209     return self._constructor_from_mgr(new_mgr, axes=new_mgr.axes).__finalize__(self)
# -> 1211 def _get_value(self, label, takeable: bool = False):
#    1212     """
#    1213     Quickly retrieve single value at passed index label.
#    1214
#    (...)
#    1222     scalar value
#    1223     """
#    1224     if takeable:
#
# KeyboardInterrupt:

# %%
test = np.array(["tanah", "itu", "basah"])

test.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 np.array(["tanah", "itu", "basah"]).index("tanah")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
def cleaning(text):
    text = tokenize(text)
    text = normalize(text)
    text = stopword(text)
    text = stemming(text)   
    return text

predict = []

for x in X_test.iloc[:30]:
    x = cleaning(x)
    x = (vectorizer.CalculatePredictTextTFIDF(x))

    predict.append(knn.predict(x))

knn.metric(predict, y_test, np.unique(y_test))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 16
#      12     x = (vectorizer.CalculatePredictTextTFIDF(x))
#      14     predict.append(knn.predict(x))
# ---> 16 knn.metric(predict, y_test, np.unique(y_test))
#
# Cell In[22], line 37, in KNN.metric(self, y_pred, y_true, label)
#      35 # menghitung masing masing cell
#      36 for i in range(len(y_pred)):
# ---> 37     confusion_matrix[y_pred[i]][y_true[i]] += 1
#      38 self.cm = confusion_matrix # menyimpan di object
#      39 print(confusion_matrix)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
knn.metric(predict, y_test.to_numpy()[:30], np.unique(y_test))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 knn.metric(predict, y_test.to_numpy()[:30], np.unique(y_test))
#
# Cell In[37], line 38, in KNN.metric(self, y_pred, y_true, label)
#      36 # menghitung masing masing cell
#      37 for i in range(len(y_pred)):
# ---> 38     confusion_matrix[label.index(y_pred[i])][label.index(y_true[i])] += 1
#      39 self.cm = confusion_matrix # menyimpan di object
#      40 print(confusion_matrix)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %% [markdown]
# ### **Feature Selection**

# %% [markdown]
# Pada tahapan ini kita akan melakukan penyeleksian pada fitur lagi. **Mengapa kita perlu melakukan penyeleksian lagi ?** dikarenakan setelah melakukan perhitungan tf idf, masih ada yang harus diseleksi untuk membuat **performa model** menjadi **lebih baik** lagi. **term yang baik** adalah term yang **nilai tf idf** nya **tidak mendekati nol**, dikarenakan jika nilai tf idf yang mendekati nol, maka term itu sangat sekali jarang muncul dalam suatu dokumen. **Jika semakin jarang muncul** maka banyak item yang nilai tf idf nya nol sehingga data untuk term tersebut **tidak akan memiliki pola**. Oleh karena itu, kita dapat menghapus term tersebut.

# %% [markdown]
# Tetapi sebelum melakukan itu, kita perlu untuk melakukan analisa untuk menemukan *threshold* (nilai tf idf minimal)

# %%
# semua term / feature
terms = Vectorized_X_train.columns

# mencari document frequemcy
document_fre = {}
for term in terms:
    document_fre[term] = 0
    for doc in X_train:
        if term in doc:
            document_fre[term] += 1

document_fre
# Out:
# {'indonesia': 41,
#  'negara': 39,
#  'hukum': 11,
#  'assalamualaikum': 1,
#  'lestari': 6,
#  'waris': 4,
#  'budaya': 75,
#  'benda': 6,
#  'pantun': 2,
#  'apresiasi': 3,
#  'gawe': 1,
#  'untunga': 1,
#  'ba': 5,
#  'ip': 1,
#  'jilat': 4,
#  'tonjol': 1,
#  'um': 2,
#  'eeaalahh': 1,
#  'moyang': 1,
#  'tmp': 1,
#  'bible': 1,
#  'pantas': 1,
#  'bankek': 1,
#  'bendung': 1,
#  'bejat': 1,
#  'silaturahmi': 1,
#  'hafal': 1,
#  'minat': 1,
#  'bai': 1,
#  'berangkat': 1,
#  'okay': 1,
#  'muda': 6,
#  'subhanallah': 1,
#  'pecat': 1,
#  'otai': 1,
#  'ayat': 5,
#  'seoul': 1,
#  'agam': 2,
#  'keji': 5,
#  'injil': 1,
#  'tt': 1,
#  'cucu': 2,
#  'nutupin': 1,
#  'member': 3,
#  'gtkan': 1,
#  'loe': 4,
#  'otonomi': 3,
#  'mayoritas': 3,
#  'tuang': 1,
#  'infrastruktur': 1,
#  'cenderawasih': 3,
#  'nuduhnuduh': 1,
#  'depends': 1,
#  'anwar': 1,
#  'kriminalisasi': 1,
#  'damaimemberdayakan': 1,
#  'nyata': 4,
#  'jelekanehngetik': 1,
#  'toefl': 1,
#  'ilang': 4,
#  'lipstik': 1,
#  'jiplak': 1,
#  'yaudah': 2,
#  'jin': 1,
#  'bod': 1,
#  'merasuah': 1,
#  'mood': 6,
#  'proses': 9,
#  'janji': 1,
#  'if': 1,
#  'internasional': 2,
#  'bekal': 1,
#  'coverin': 1,
#  'heryana': 1,
#  'spesialis': 1,
#  'mew': 1,
#  'ngaji': 3,
#  'eksekusi': 1,
#  'orgnya': 1,
#  'pantai': 1,
#  'lengah': 1,
#  'emakemak': 1,
#  'kyai': 2,
#  'stuju': 1,
#  'faham': 4,
#  'owner': 1,
#  'layan': 6,
#  'novariadi': 1,
#  'salak': 1,
#  'lepas': 3,
#  'kehidupa': 1,
#  'cntik': 1,
#  'bullying': 1,
#  'rugi': 3,
#  'pinginnya': 1,
#  'mes': 3,
#  'nyari': 2,
#  'fandango': 1,
#  'glucella': 1,
#  'ledekin': 1,
#  'nyaman': 2,
#  'ribu': 5,
#  'pola': 2,
#  'penga': 1,
#  'landenin': 1,
#  'subdirektorat': 1,
#  'ruin': 1,
#  'bunga': 1,
#  'si': 34,
#  'kecilpendek': 1,
#  'ngaju': 1,
#  'hati': 17,
#  'bawah': 2,
#  'lengkap': 3,
#  'bongkar': 1,
#  'say': 1,
#  'jijik': 10,
#  'semangat': 3,
#  'topeng': 2,
#  'bismillaah': 1,
#  'dikumpulin': 1,
#  'emak': 1,
#  'perna': 1,
#  'tenangd': 1,
#  'avatar': 1,
#  'salah': 33,
#  'maju': 98,
#  'logika': 4,
#  'papa': 1,
#  'edan': 1,
#  'lada': 1,
#  'maba': 3,
#  'khalayak': 1,
#  'halang': 3,
#  'rastanty': 1,
#  'posisi': 1,
#  'funny': 1,
#  'kdaerah': 1,
#  'hijrah': 1,
#  'embat': 1,
#  'husband': 1,
#  'ahmad': 1,
#  'ngak': 1,
#  'islamphobia': 1,
#  'bantai': 5,
#  'lahan': 6,
#  'yaqut': 2,
#  'per': 3,
#  'turut': 4,
#  'milih': 3,
#  'sanggup': 2,
#  'scene': 1,
#  'polri': 1,
#  'wkoskekekek': 1,
#  'invu': 1,
#  'monyet': 9,
#  'no': 4,
#  'gedung': 1,
#  'cerai': 2,
#  'lokal': 8,
#  'hoiriyeh': 1,
#  'nihil': 1,
#  'flawless': 1,
#  'real': 2,
#  'takpay': 1,
#  'yle': 1,
#  'hidung': 2,
#  'mulia': 1,
#  'tuntut': 1,
#  'tgok': 1,
#  'drdulu': 1,
#  'ugaidi': 1,
#  'bujug': 1,
#  'kaya': 33,
#  'smg': 2,
#  'nggak': 13,
#  'melihara': 1,
#  'koar': 2,
#  'demokrat': 1,
#  'radikal': 4,
#  'enam': 3,
#  'siket': 1,
#  'hk': 1,
#  'chinese': 1,
#  'pokpok': 1,
#  'seputa': 1,
#  'uud': 1,
#  'kemisikinan': 1,
#  'klodia': 1,
#  'kuning': 1,
#  'iring': 9,
#  'idol': 4,
#  'hai': 3,
#  'smith': 1,
#  'tug': 1,
#  'kam': 1,
#  'lmk': 1,
#  'negarapulau': 1,
#  'gunaguna': 1,
#  'kt': 2,
#  'bey': 1,
#  'manggil': 1,
#  'bhi': 1,
#  'couldve': 1,
#  'suami': 2,
#  'kental': 2,
#  'cowok': 4,
#  'jari': 2,
#  'aksi': 10,
#  'player': 1,
#  'hahahha': 1,
#  'kmrn': 1,
#  'massa': 4,
#  'cundang': 1,
#  'etis': 1,
#  'tangan': 8,
#  'harus': 1,
#  'somad': 1,
#  'gofood': 1,
#  'frasa': 1,
#  'bersin': 1,
#  'kkk': 1,
#  'dr': 10,
#  'lo': 28,
#  'ngumpul': 1,
#  'sukses': 5,
#  'struggle': 1,
#  'even': 1,
#  'sebut': 3,
#  'sekolah': 16,
#  'laa': 4,
#  'terima': 4,
#  'mksd': 1,
#  'gulagula': 1,
#  'musium': 1,
#  'butang': 1,
#  'ju': 2,
#  'kalah': 4,
#  'cerita': 6,
#  'haramkofar': 1,
#  'hasut': 1,
#  'doi': 4,
#  'tenang': 1,
#  'sempit': 3,
#  'keplak': 1,
#  'umbar': 1,
#  'ibrani': 2,
#  'makmur': 1,
#  'hibah': 8,
#  'benang': 1,
#  'belit': 1,
#  'kotor': 2,
#  'donasi': 2,
#  'jelek': 197,
#  'gendut': 2,
#  'gelora': 1,
#  'ghosting': 1,
#  'murtad': 2,
#  'ngikut': 2,
#  'punya': 1,
#  'unik': 1,
#  'duluan': 1,
#  'wallahi': 2,
#  'laki': 8,
#  'sudut': 1,
#  'syarat': 2,
#  'ya': 95,
#  'naah': 1,
#  'pks': 2,
#  'gausah': 8,
#  'annoying': 2,
#  'review': 1,
#  'hepi': 1,
#  'iye': 1,
#  'diboongin': 1,
#  'tolonglahjangan': 1,
#  'appnya': 1,
#  'paksa': 4,
#  'garis': 1,
#  'kasus': 1,
#  'pelet': 1,
#  'azan': 1,
#  'batal': 2,
#  'tapai': 1,
#  'mantep': 1,
#  'fascista': 1,
#  'gemblung': 1,
#  'buat': 4,
#  'nanggung': 1,
#  'syara': 1,
#  'ngecropnya': 1,
#  'twitter': 2,
#  'kejut': 3,
#  'surat': 2,
#  'bro': 5,
#  'stop': 2,
#  'pokok': 2,
#  'sgera': 1,
#  'penuh': 3,
#  'jenggot': 2,
#  'perempuan': 9,
#  'banyakkkkk': 1,
#  'area': 1,
#  'pasal': 5,
#  'jan': 4,
#  'unifi': 1,
#  'makasih': 2,
#  'lamar': 1,
#  'sosiologi': 6,
#  'rem': 4,
#  'perintah': 18,
#  'niscaya': 1,
#  'adm': 1,
#  'cah': 1,
#  'sempet': 1,
#  'sosial': 10,
#  'brarti': 1,
#  'bandit': 1,
#  'kemenlu': 1,
#  'ngebakso': 1,
#  'cuapek': 1,
#  'bd': 1,
#  'gilir': 3,
#  'bnyk': 1,
#  'swasta': 3,
#  'klasifikasi': 1,
#  'rikopin': 1,
#  'wamendagri': 2,
#  'wahabi': 2,
#  'nugas': 1,
#  'thats': 1,
#  'banyakada': 1,
#  'aju': 1,
#  'bungkus': 2,
#  'sipit': 1,
#  'prioritas': 2,
#  'pacar': 7,
#  'repnyaaa': 1,
#  'book': 1,
#  'penjajahann': 1,
#  'sendiri': 1,
#  'mmberi': 1,
#  'bohongin': 1,
#  'barusan': 1,
#  'standaard': 1,
#  'nk': 3,
#  'ahahahaahok': 1,
#  'borneo': 2,
#  'cuci': 1,
#  'simbol': 1,
#  'kedok': 5,
#  'video': 1,
#  'bhkan': 1,
#  'cagar': 2,
#  'as': 2,
#  'raya': 5,
#  'disebutny': 1,
#  'himpun': 1,
#  'dipropokasi': 1,
#  'nie': 1,
#  'oooh': 1,
#  'catat': 2,
#  'rame': 2,
#  'wkw': 2,
#  'tata': 1,
#  'kek': 29,
#  'bandung': 1,
#  'ge': 2,
#  'ngga': 12,
#  'selamalamanya': 1,
#  'afiska': 1,
#  'inget': 5,
#  'karna': 14,
#  'sosialisasi': 1,
#  'laman': 1,
#  'asesoris': 1,
#  'et': 1,
#  'jaya': 2,
#  'wastr': 3,
#  'hadir': 3,
#  'ppkn': 5,
#  'hihiw': 1,
#  'ganda': 1,
#  'bonus': 1,
#  'sdm': 1,
#  'penting': 2,
#  'jfr': 1,
#  'lapor': 2,
#  'kat': 6,
#  'kriminal': 1,
#  'injak': 5,
#  'gi': 1,
#  'adl': 1,
#  'karl': 1,
#  'dewasa': 1,
#  'ipin': 1,
#  'setan': 3,
#  'jayapura': 1,
#  'adik': 4,
#  'miracle': 1,
#  'nek': 2,
#  'petik': 3,
#  'diskotik': 1,
#  'wajah': 3,
#  'fakhiri': 3,
#  'yatim': 1,
#  'koramil': 1,
#  'kanye': 1,
#  'buzzerp': 1,
#  'duh': 2,
#  'xpe': 1,
#  'psikis': 1,
#  'korupsi': 3,
#  'marut': 1,
#  'typo': 2,
#  'benerrrrrrrrrrrrrrrr': 1,
#  'syuhada': 1,
#  'egp': 1,
#  'muslim': 12,
#  'boomer': 1,
#  'umroh': 1,
#  'belu': 1,
#  'bom': 3,
#  'serasi': 1,
#  'ka': 6,
#  'ngelit': 1,
#  'separatis': 2,
#  'musuh': 7,
#  'twt': 1,
#  'ngelamar': 1,
#  'butuh': 11,
#  'resto': 1,
#  'masu': 1,
#  'murid': 1,
#  'ngaca': 5,
#  'pede': 2,
#  'mie': 1,
#  'alergi': 1,
#  'bapak': 2,
#  'festival': 1,
#  'keselek': 1,
#  'kuat': 17,
#  'merah': 5,
#  'public': 1,
#  'anjustadz': 1,
#  'abisss': 1,
#  'live': 1,
#  'kultus': 1,
#  'mau': 2,
#  'minum': 1,
#  'hut': 1,
#  'zikir': 1,
#  'bang': 7,
#  'semester': 1,
#  'sara': 1,
#  'nikmat': 1,
#  'warungmlyt': 1,
#  'milik': 5,
#  'batas': 1,
#  'yaman': 2,
#  'ta': 1,
#  'suku': 13,
#  'ikijijik': 1,
#  'nika': 1,
#  'ct': 1,
#  'indo': 8,
#  'pilih': 11,
#  'ngelebar': 1,
#  'belagu': 1,
#  'orientasi': 1,
#  'oii': 1,
#  'identiti': 1,
#  'bk': 1,
#  'gradasi': 1,
#  'myself': 1,
#  'naral': 1,
#  'exfo': 1,
#  'abdul': 1,
#  'qadyani': 1,
#  'khazanah': 1,
#  'sat': 1,
#  'vaksin': 12,
#  'tindas': 2,
#  'bacot': 4,
#  'alir': 4,
#  'misoginis': 1,
#  'salut': 1,
#  'nilep': 2,
#  'kantor': 13,
#  'progam': 1,
#  'akh': 1,
#  'ite': 1,
#  'jiakh': 1,
#  'akademik': 2,
#  'apa': 11,
#  'uu': 7,
#  'kisi': 1,
#  'xboleh': 1,
#  'sempurna': 3,
#  'tenggara': 1,
#  'wakil': 2,
#  'blm': 4,
#  'iyo': 1,
#  'kopong': 1,
#  'son': 1,
#  'pada': 1,
#  'anggur': 5,
#  'kumpul': 1,
#  'matematika': 2,
#  'ikat': 2,
#  'foto': 2,
#  'mbundet': 1,
#  'jidat': 2,
#  'wordexcel': 1,
#  'terimakacii': 1,
#  'hitamputih': 1,
#  'rillo': 1,
#  'tim': 2,
#  'polisi': 2,
#  'iyaaa': 2,
#  'malaikat': 1,
#  'lydia': 1,
#  'jejelin': 1,
#  'primordial': 1,
#  'masakin': 1,
#  'sembah': 2,
#  'mojokerto': 1,
#  'tambah': 2,
#  'tar': 1,
#  'eh': 5,
#  'dagingn': 1,
#  'wkwkw': 2,
#  'mnrt': 1,
#  'gigi': 1,
#  'halah': 2,
#  'terorisme': 1,
#  'kecimpung': 1,
#  'warna': 6,
#  'provokasi': 5,
#  'larang': 8,
#  'loreng': 1,
#  'hedonisme': 1,
#  'isine': 1,
#  'juli': 11,
#  'asai': 4,
#  'case': 2,
#  'trenggalek': 1,
#  'social': 2,
#  'mundur': 2,
#  'bbb': 1,
#  'jaman': 8,
#  'pops': 1,
#  'anus': 2,
#  'bedain': 1,
#  'singapore': 2,
#  'basmi': 2,
#  'kali': 16,
#  'buday': 1,
#  'acara': 5,
#  'ginj': 1,
#  'diperdeb': 1,
#  'diskriminasi': 3,
#  'narasi': 4,
#  'nasbung': 1,
#  'bmr': 2,
#  'kelola': 2,
#  'kui': 1,
#  'edhi': 1,
#  'doank': 1,
#  'timbul': 1,
#  'kabur': 1,
#  'anggap': 3,
#  'dalil': 2,
#  'tambong': 1,
#  'sila': 1,
#  'clear': 1,
#  'siswi': 1,
#  'atribut': 1,
#  'tkt': 3,
#  'hihi': 1,
#  'bantu': 12,
#  'warung': 1,
#  'ngeles': 1,
#  'siaa': 2,
#  'nomor': 1,
#  'akwowkw': 1,
#  'makna': 3,
#  'ladekat': 1,
#  'fair': 1,
#  'kacung': 1,
#  'imigran': 1,
#  'selamat': 14,
#  'divisi': 1,
#  'raslullh': 1,
#  'isis': 1,
#  'tuch': 1,
#  'teeth': 1,
#  'djoko': 1,
#  'sorbantrus': 1,
#  'identitasjembut': 1,
#  'kampret': 1,
#  'patut': 1,
#  'jakarta': 5,
#  'cikgu': 1,
#  'panggil': 6,
#  'angkuh': 1,
#  'vee': 1,
#  'mainmain': 1,
#  'jugak': 2,
#  'otake': 1,
#  'bicara': 5,
#  'numpang': 1,
#  'impor': 3,
#  'percetakanapa': 1,
#  'ambon': 1,
#  'sebenernya': 2,
#  'kobar': 1,
#  'huk': 1,
#  'gede': 2,
#  'bakiak': 1,
#  'duda': 1,
#  'telfon': 1,
#  'wala': 1,
#  'keanekaragaman': 1,
#  'pantang': 1,
#  'kemarin': 3,
#  'keren': 5,
#  'ngurusin': 3,
#  'paksiksa': 1,
#  'popup': 1,
#  'rasul': 1,
#  'mslim': 1,
#  'buta': 3,
#  'sentimen': 3,
#  'sangar': 1,
#  'asli': 11,
#  'nabbb': 1,
#  'kira': 1,
#  'salahkannabi': 1,
#  'iyuhhh': 1,
#  'mulok': 2,
#  'elu': 2,
#  'huhuhu': 1,
#  'rinso': 1,
#  'adzan': 2,
#  'nonton': 4,
#  'sokakta': 1,
#  'urang': 1,
#  'biar': 12,
#  'abang': 2,
#  'perut': 2,
#  'friendly': 1,
#  'doktor': 1,
#  'senang': 7,
#  'taumungkin': 1,
#  'korang': 3,
#  'ibukota': 2,
#  'polres': 1,
#  'hijab': 5,
#  'haishh': 1,
#  'dark': 1,
#  'kpopers': 1,
#  'tuangin': 1,
#  'sinting': 1,
#  'bpk': 2,
#  'emeng': 1,
#  'restuin': 1,
#  'dry': 2,
#  'make': 4,
#  'label': 3,
#  'ngomong': 6,
#  'gua': 42,
#  'gender': 1,
#  'nya': 39,
#  'rumput': 2,
#  'site': 1,
#  'lindung': 4,
#  'beruntus': 1,
#  'biased': 1,
#  'nye': 1,
#  'lawan': 4,
#  'jaipong': 1,
#  'palsu': 1,
#  'jodoh': 1,
#  'bas': 3,
#  'gitu': 14,
#  'isih': 1,
#  'issokkeiii': 1,
#  'foad': 1,
#  'soleh': 2,
#  'konstitusional': 1,
#  'mui': 5,
#  'deketin': 2,
#  'bantah': 1,
#  'nyusahin': 1,
#  'mas': 6,
#  'medsos': 2,
#  'hitung': 2,
#  'ehhehe': 1,
#  'kne': 1,
#  'dfec': 1,
#  'singkir': 1,
#  'naung': 2,
#  'beauty': 2,
#  'teken': 7,
#  'cernabelajar': 1,
#  'jilbab': 1,
#  'ngapain': 3,
#  'air': 3,
#  'guy': 2,
#  'rada': 1,
#  'palestine': 1,
#  'fgdp': 1,
#  'prilaku': 1,
#  'yesus': 2,
#  'dia': 1,
#  'jelasjelas': 2,
#  'balas': 2,
#  'yater': 1,
#  'kepoooo': 1,
#  'tindak': 9,
#  'juang': 3,
#  'kalo': 74,
#  'oke': 5,
#  'yakan': 1,
#  'sore': 3,
#  'kwkw': 1,
#  'hemat': 1,
#  'tantang': 2,
#  'prediksi': 1,
#  'koto': 1,
#  'sikat': 3,
#  'wkwkkwk': 1,
#  'didik': 11,
#  'strip': 1,
#  'satu': 6,
#  'oh': 3,
#  'geng': 1,
#  'kstp': 18,
#  'poca': 1,
#  'choice': 1,
#  'diplajarin': 1,
#  'desember': 1,
#  'seklh': 1,
#  'adam': 1,
#  'tabaruj': 1,
#  'jam': 1,
#  'akulahhh': 1,
#  'pap': 1,
#  'gokar': 1,
#  'adha': 1,
#  'anarkis': 1,
#  'fetish': 1,
#  'versi': 2,
#  'bumn': 1,
#  'rmhnya': 1,
#  'fast': 5,
#  'basing': 1,
#  'whip': 1,
#  'banyak': 5,
#  'kian': 4,
#  'anjjirrr': 1,
#  'garagara': 2,
#  'betang': 1,
#  'abadi': 2,
#  'well': 1,
#  'lempar': 1,
#  'sunderland': 1,
#  'keriting': 5,
#  'rek': 1,
#  'bnr': 1,
#  'jokowi': 11,
#  'kampus': 2,
#  'waloni': 1,
#  'gunung': 10,
#  'waze': 2,
#  'cucuk': 1,
#  'wempi': 2,
#  'usut': 1,
#  'nampak': 6,
#  'yeeaayyyy': 1,
#  'merinding': 1,
#  'lost': 1,
#  'apaa': 1,
#  'log': 1,
#  'oap': 2,
#  'seni': 5,
#  'pertamina': 1,
#  'yellow': 1,
#  'didnt': 1,
#  'upacara': 2,
#  'kab': 1,
#  'susah': 9,
#  'duit': 6,
#  'tida': 1,
#  'kontol': 4,
#  'pkn': 2,
#  'freem': 1,
#  'uda': 2,
#  'ahlak': 2,
#  'bnyakk': 1,
#  'takut': 10,
#  'laku': 25,
#  'kuku': 1,
#  'fokus': 3,
#  'ahahah': 1,
#  'ternyataa': 1,
#  'wawas': 1,
#  'amrik': 1,
#  'hmm': 2,
#  'deklarasi': 1,
#  'lai': 1,
#  'reguler': 1,
#  'kontribusi': 1,
#  'be': 5,
#  'guoblok': 2,
#  'bajar': 1,
#  'bodynya': 1,
#  'nyebut': 1,
#  'bangke': 1,
#  'diajarin': 1,
#  'catboy': 1,
#  'ngaruh': 1,
#  'gerilya': 1,
#  'hantam': 1,
#  'wa': 7,
#  'bi': 1,
#  'purba': 1,
#  'curut': 1,
#  'gituuuu': 1,
#  'oalah': 1,
#  'wadani': 1,
#  'bansernya': 2,
#  'uji': 3,
#  'nak': 14,
#  'cemar': 1,
#  'hidayat': 1,
#  'daftar': 15,
#  'jiwa': 3,
#  'kanvas': 1,
#  'viewers': 1,
#  'gtw': 1,
#  'tongkol': 1,
#  'menmbungkuk': 4,
#  'fase': 1,
#  'peremp': 1,
#  'sikap': 2,
#  'resumereview': 1,
#  'pastu': 2,
#  'hutang': 2,
#  'berfikirnya': 1,
#  'ngedm': 1,
#  'kating': 2,
#  'ponpes': 1,
#  'aura': 2,
#  'wooooo': 1,
#  'kog': 1,
#  'israel': 1,
#  'goes': 1,
#  'kaum': 15,
#  'pki': 22,
#  'terkevoh': 1,
#  'kontra': 1,
#  'to': 5,
#  'ukbing': 1,
#  'bukhari': 2,
#  'ganggu': 1,
#  'resume': 4,
#  'dapet': 4,
#  'akuan': 1,
#  'mat': 1,
#  'harbi': 1,
#  'meromantisasi': 1,
#  'problem': 1,
#  'cuiiehh': 1,
#  'tm': 1,
#  'ank': 1,
#  'keriput': 1,
#  'gresik': 1,
#  'melinjo': 1,
#  'babi': 14,
#  'anut': 4,
#  'tautaunya': 1,
#  'suffering': 1,
#  'gawat': 1,
#  'skdr': 1,
#  'nolongin': 1,
#  'kuliah': 4,
#  'taste': 1,
#  'yoshi': 1,
#  'atheis': 1,
#  'sja': 2,
#  'laknatullah': 1,
#  'kades': 1,
#  'obat': 1,
#  'bornesi': 1,
#  'tiket': 1,
#  'banget': 128,
#  'yaaaa': 1,
#  'pedih': 1,
#  'klub': 1,
#  'mengatasnamakan': 1,
#  'dzalik': 1,
#  'negera': 1,
#  'macai': 1,
#  'sudahlahdia': 1,
#  'blajar': 2,
#  'sampang': 1,
#  'sekuler': 1,
#  'cermin': 2,
#  'ucap': 2,
#  'kapas': 1,
#  'opose': 1,
#  'sol': 1,
#  'mandarin': 1,
#  'coba': 7,
#  'politik': 6,
#  'njingg': 1,
#  'kompak': 1,
#  'bodetabek': 1,
#  'dasrul': 1,
#  'brisik': 1,
#  'takhayul': 2,
#  'agreed': 1,
#  'hubung': 5,
#  'sorry': 1,
#  'saram': 1,
#  'pop': 1,
#  'usak': 2,
#  'job': 1,
#  'periksa': 1,
#  'anjer': 2,
#  'baheulaane': 1,
#  'rian': 1,
#  'rindu': 1,
#  'tanggungjawab': 1,
#  'maming': 1,
#  'sembang': 1,
#  'dianggep': 1,
#  'karakter': 1,
#  'ekstrimis': 1,
#  'renov': 1,
#  'astagaaa': 1,
#  'hadeehhh': 1,
#  'kicik': 1,
#  'nabi': 8,
#  'abrahamik': 1,
#  'asuuuu': 1,
#  'kualitas': 3,
#  'mabuk': 6,
#  'sebab': 2,
#  'kotatmptterserah': 1,
#  'einstein': 1,
#  'cb': 1,
#  'subahanallah': 1,
#  'trima': 1,
#  'grammar': 1,
#  'tahufreemason': 1,
#  'kala': 1,
#  'ftonya': 1,
#  'hadrah': 9,
#  'san': 1,
#  'cantikkk': 1,
#  'muak': 1,
#  'drive': 1,
#  'smp': 5,
#  'tetep': 7,
#  'nila': 1,
#  'sd': 6,
#  'dnger': 1,
#  'darimana': 1,
#  'korban': 4,
#  'sulawesi': 1,
#  'putus': 4,
#  'siapatau': 1,
#  'dhajjall': 1,
#  'utama': 3,
#  'disakitin': 1,
#  'timur': 5,
#  'musim': 1,
#  'islamik': 1,
#  'nasehat': 1,
#  'kopi': 1,
#  'kua': 1,
#  'alam': 1,
#  'akherat': 1,
#  'ampun': 3,
#  'oon': 2,
#  'setengahsetengah': 1,
#  'toleransi': 5,
#  'orangdan': 1,
#  'hate': 1,
#  'dipush': 1,
#  'jung': 1,
#  'buzzerrp': 1,
#  'smoo': 1,
#  'manusiamaupun': 1,
#  'nder': 10,
#  'dayak': 17,
#  'jabrik': 1,
#  ...}

# %% [markdown]
# Saya memutuskan untuk menentukan **threshold** berdasarkan **rata rata nilai tf idf** pada kata yang cukup **sering muncul**

# %%
# menentukan threshold
threshold = np.mean([Vectorized_X_train[c].mean() for c in Vectorized_X_train.columns if document_fre[c] > 4] )

threshold
# Out:
# 0.0006213583278971017

# %% [markdown]
# Lalu setelah itu, saya akan mencari **term** yang **tidak memenuhi threshold** nya agar nantinya **dihapus**

# %%
# term yang tidak memenuhi
nonsense_word = [word for word in Vectorized_X_train.columns if Vectorized_X_train[word].mean() < threshold] 

nonsense_word
# Out:
# ['hukum',
#  'assalamualaikum',
#  'lestari',
#  'waris',
#  'benda',
#  'pantun',
#  'apresiasi',
#  'gawe',
#  'untunga',
#  'ba',
#  'ip',
#  'jilat',
#  'tonjol',
#  'um',
#  'eeaalahh',
#  'moyang',
#  'tmp',
#  'bible',
#  'pantas',
#  'bankek',
#  'bendung',
#  'bejat',
#  'silaturahmi',
#  'hafal',
#  'minat',
#  'bai',
#  'berangkat',
#  'okay',
#  'muda',
#  'subhanallah',
#  'pecat',
#  'otai',
#  'ayat',
#  'seoul',
#  'agam',
#  'keji',
#  'injil',
#  'tt',
#  'cucu',
#  'nutupin',
#  'member',
#  'gtkan',
#  'loe',
#  'otonomi',
#  'mayoritas',
#  'tuang',
#  'infrastruktur',
#  'cenderawasih',
#  'nuduhnuduh',
#  'depends',
#  'anwar',
#  'kriminalisasi',
#  'damaimemberdayakan',
#  'nyata',
#  'jelekanehngetik',
#  'toefl',
#  'ilang',
#  'lipstik',
#  'jiplak',
#  'yaudah',
#  'jin',
#  'bod',
#  'merasuah',
#  'mood',
#  'proses',
#  'janji',
#  'if',
#  'internasional',
#  'bekal',
#  'coverin',
#  'heryana',
#  'spesialis',
#  'mew',
#  'ngaji',
#  'eksekusi',
#  'orgnya',
#  'pantai',
#  'lengah',
#  'emakemak',
#  'kyai',
#  'stuju',
#  'faham',
#  'owner',
#  'layan',
#  'novariadi',
#  'salak',
#  'lepas',
#  'kehidupa',
#  'cntik',
#  'bullying',
#  'rugi',
#  'pinginnya',
#  'mes',
#  'nyari',
#  'fandango',
#  'glucella',
#  'ledekin',
#  'nyaman',
#  'ribu',
#  'pola',
#  'penga',
#  'landenin',
#  'subdirektorat',
#  'ruin',
#  'bunga',
#  'kecilpendek',
#  'ngaju',
#  'bawah',
#  'lengkap',
#  'bongkar',
#  'say',
#  'jijik',
#  'semangat',
#  'topeng',
#  'bismillaah',
#  'dikumpulin',
#  'emak',
#  'perna',
#  'tenangd',
#  'avatar',
#  'logika',
#  'papa',
#  'edan',
#  'lada',
#  'maba',
#  'khalayak',
#  'halang',
#  'rastanty',
#  'posisi',
#  'funny',
#  'kdaerah',
#  'hijrah',
#  'embat',
#  'husband',
#  'ahmad',
#  'ngak',
#  'islamphobia',
#  'bantai',
#  'lahan',
#  'yaqut',
#  'per',
#  'turut',
#  'milih',
#  'sanggup',
#  'scene',
#  'polri',
#  'wkoskekekek',
#  'invu',
#  'monyet',
#  'no',
#  'gedung',
#  'cerai',
#  'lokal',
#  'hoiriyeh',
#  'nihil',
#  'flawless',
#  'real',
#  'takpay',
#  'yle',
#  'hidung',
#  'mulia',
#  'tuntut',
#  'tgok',
#  'drdulu',
#  'ugaidi',
#  'bujug',
#  'smg',
#  'melihara',
#  'koar',
#  'demokrat',
#  'radikal',
#  'enam',
#  'siket',
#  'hk',
#  'chinese',
#  'pokpok',
#  'seputa',
#  'uud',
#  'kemisikinan',
#  'klodia',
#  'kuning',
#  'iring',
#  'idol',
#  'hai',
#  'smith',
#  'tug',
#  'kam',
#  'lmk',
#  'negarapulau',
#  'gunaguna',
#  'kt',
#  'bey',
#  'manggil',
#  'bhi',
#  'couldve',
#  'suami',
#  'kental',
#  'cowok',
#  'jari',
#  'aksi',
#  'player',
#  'hahahha',
#  'kmrn',
#  'massa',
#  'cundang',
#  'etis',
#  'tangan',
#  'harus',
#  'somad',
#  'gofood',
#  'frasa',
#  'bersin',
#  'kkk',
#  'dr',
#  'ngumpul',
#  'sukses',
#  'struggle',
#  'even',
#  'sebut',
#  'laa',
#  'terima',
#  'mksd',
#  'gulagula',
#  'musium',
#  'butang',
#  'ju',
#  'kalah',
#  'cerita',
#  'haramkofar',
#  'hasut',
#  'doi',
#  'tenang',
#  'sempit',
#  'umbar',
#  'ibrani',
#  'makmur',
#  'hibah',
#  'benang',
#  'belit',
#  'kotor',
#  'donasi',
#  'gendut',
#  'gelora',
#  'ghosting',
#  'murtad',
#  'ngikut',
#  'punya',
#  'unik',
#  'duluan',
#  'wallahi',
#  'laki',
#  'sudut',
#  'syarat',
#  'naah',
#  'pks',
#  'gausah',
#  'annoying',
#  'review',
#  'hepi',
#  'iye',
#  'diboongin',
#  'tolonglahjangan',
#  'appnya',
#  'paksa',
#  'garis',
#  'kasus',
#  'pelet',
#  'azan',
#  'batal',
#  'tapai',
#  'mantep',
#  'fascista',
#  'gemblung',
#  'buat',
#  'nanggung',
#  'syara',
#  'ngecropnya',
#  'twitter',
#  'kejut',
#  'surat',
#  'bro',
#  'stop',
#  'pokok',
#  'sgera',
#  'penuh',
#  'jenggot',
#  'perempuan',
#  'banyakkkkk',
#  'area',
#  'pasal',
#  'jan',
#  'unifi',
#  'makasih',
#  'lamar',
#  'sosiologi',
#  'rem',
#  'niscaya',
#  'adm',
#  'cah',
#  'sempet',
#  'sosial',
#  'brarti',
#  'bandit',
#  'kemenlu',
#  'ngebakso',
#  'cuapek',
#  'bd',
#  'gilir',
#  'bnyk',
#  'swasta',
#  'klasifikasi',
#  'rikopin',
#  'wamendagri',
#  'wahabi',
#  'nugas',
#  'thats',
#  'banyakada',
#  'aju',
#  'bungkus',
#  'sipit',
#  'prioritas',
#  'pacar',
#  'repnyaaa',
#  'book',
#  'penjajahann',
#  'sendiri',
#  'mmberi',
#  'bohongin',
#  'barusan',
#  'standaard',
#  'nk',
#  'ahahahaahok',
#  'borneo',
#  'cuci',
#  'simbol',
#  'kedok',
#  'video',
#  'bhkan',
#  'cagar',
#  'as',
#  'raya',
#  'disebutny',
#  'himpun',
#  'dipropokasi',
#  'nie',
#  'oooh',
#  'catat',
#  'rame',
#  'wkw',
#  'tata',
#  'bandung',
#  'ge',
#  'ngga',
#  'selamalamanya',
#  'afiska',
#  'inget',
#  'karna',
#  'sosialisasi',
#  'laman',
#  'asesoris',
#  'et',
#  'jaya',
#  'wastr',
#  'hadir',
#  'ppkn',
#  'hihiw',
#  'ganda',
#  'bonus',
#  'sdm',
#  'penting',
#  'jfr',
#  'lapor',
#  'kat',
#  'kriminal',
#  'injak',
#  'gi',
#  'adl',
#  'karl',
#  'dewasa',
#  'ipin',
#  'setan',
#  'jayapura',
#  'adik',
#  'miracle',
#  'nek',
#  'petik',
#  'diskotik',
#  'wajah',
#  'fakhiri',
#  'yatim',
#  'koramil',
#  'kanye',
#  'buzzerp',
#  'duh',
#  'xpe',
#  'psikis',
#  'korupsi',
#  'marut',
#  'typo',
#  'benerrrrrrrrrrrrrrrr',
#  'syuhada',
#  'egp',
#  'muslim',
#  'boomer',
#  'umroh',
#  'belu',
#  'bom',
#  'serasi',
#  'ka',
#  'ngelit',
#  'separatis',
#  'musuh',
#  'twt',
#  'ngelamar',
#  'butuh',
#  'resto',
#  'masu',
#  'murid',
#  'ngaca',
#  'pede',
#  'mie',
#  'alergi',
#  'bapak',
#  'festival',
#  'keselek',
#  'merah',
#  'public',
#  'anjustadz',
#  'abisss',
#  'live',
#  'kultus',
#  'mau',
#  'minum',
#  'hut',
#  'zikir',
#  'bang',
#  'semester',
#  'sara',
#  'nikmat',
#  'warungmlyt',
#  'milik',
#  'batas',
#  'yaman',
#  'ta',
#  'ikijijik',
#  'nika',
#  'ct',
#  'indo',
#  'pilih',
#  'ngelebar',
#  'belagu',
#  'orientasi',
#  'oii',
#  'identiti',
#  'bk',
#  'gradasi',
#  'myself',
#  'naral',
#  'exfo',
#  'abdul',
#  'qadyani',
#  'khazanah',
#  'sat',
#  'vaksin',
#  'tindas',
#  'bacot',
#  'alir',
#  'misoginis',
#  'salut',
#  'nilep',
#  'kantor',
#  'progam',
#  'akh',
#  'ite',
#  'jiakh',
#  'akademik',
#  'apa',
#  'uu',
#  'kisi',
#  'xboleh',
#  'sempurna',
#  'tenggara',
#  'wakil',
#  'blm',
#  'iyo',
#  'kopong',
#  'son',
#  'pada',
#  'anggur',
#  'kumpul',
#  'matematika',
#  'ikat',
#  'foto',
#  'mbundet',
#  'jidat',
#  'wordexcel',
#  'terimakacii',
#  'hitamputih',
#  'rillo',
#  'tim',
#  'polisi',
#  'iyaaa',
#  'malaikat',
#  'lydia',
#  'jejelin',
#  'primordial',
#  'masakin',
#  'sembah',
#  'mojokerto',
#  'tambah',
#  'tar',
#  'eh',
#  'dagingn',
#  'wkwkw',
#  'mnrt',
#  'gigi',
#  'halah',
#  'terorisme',
#  'kecimpung',
#  'warna',
#  'provokasi',
#  'larang',
#  'loreng',
#  'hedonisme',
#  'isine',
#  'juli',
#  'asai',
#  'case',
#  'trenggalek',
#  'social',
#  'mundur',
#  'bbb',
#  'jaman',
#  'pops',
#  'anus',
#  'bedain',
#  'singapore',
#  'basmi',
#  'kali',
#  'buday',
#  'acara',
#  'ginj',
#  'diperdeb',
#  'diskriminasi',
#  'narasi',
#  'nasbung',
#  'bmr',
#  'kelola',
#  'kui',
#  'edhi',
#  'doank',
#  'timbul',
#  'kabur',
#  'anggap',
#  'dalil',
#  'tambong',
#  'sila',
#  'clear',
#  'siswi',
#  'atribut',
#  'tkt',
#  'hihi',
#  'bantu',
#  'warung',
#  'ngeles',
#  'siaa',
#  'nomor',
#  'akwowkw',
#  'makna',
#  'ladekat',
#  'fair',
#  'kacung',
#  'imigran',
#  'divisi',
#  'raslullh',
#  'isis',
#  'tuch',
#  'teeth',
#  'djoko',
#  'sorbantrus',
#  'identitasjembut',
#  'kampret',
#  'patut',
#  'jakarta',
#  'cikgu',
#  'panggil',
#  'angkuh',
#  'vee',
#  'mainmain',
#  'jugak',
#  'otake',
#  'bicara',
#  'numpang',
#  'impor',
#  'percetakanapa',
#  'ambon',
#  'sebenernya',
#  'kobar',
#  'huk',
#  'gede',
#  'bakiak',
#  'duda',
#  'telfon',
#  'wala',
#  'keanekaragaman',
#  'pantang',
#  'kemarin',
#  'keren',
#  'ngurusin',
#  'paksiksa',
#  'popup',
#  'rasul',
#  'mslim',
#  'buta',
#  'sentimen',
#  'sangar',
#  'nabbb',
#  'kira',
#  'salahkannabi',
#  'iyuhhh',
#  'mulok',
#  'elu',
#  'huhuhu',
#  'rinso',
#  'adzan',
#  'nonton',
#  'sokakta',
#  'urang',
#  'biar',
#  'abang',
#  'perut',
#  'friendly',
#  'doktor',
#  'senang',
#  'taumungkin',
#  'korang',
#  'ibukota',
#  'polres',
#  'hijab',
#  'haishh',
#  'dark',
#  'kpopers',
#  'tuangin',
#  'sinting',
#  'bpk',
#  'emeng',
#  'restuin',
#  'dry',
#  'make',
#  'label',
#  'ngomong',
#  'gender',
#  'rumput',
#  'site',
#  'lindung',
#  'beruntus',
#  'biased',
#  'nye',
#  'lawan',
#  'jaipong',
#  'palsu',
#  'jodoh',
#  'bas',
#  'gitu',
#  'isih',
#  'issokkeiii',
#  'foad',
#  'soleh',
#  'konstitusional',
#  'mui',
#  'deketin',
#  'bantah',
#  'nyusahin',
#  'mas',
#  'medsos',
#  'hitung',
#  'ehhehe',
#  'kne',
#  'dfec',
#  'singkir',
#  'naung',
#  'beauty',
#  'teken',
#  'cernabelajar',
#  'jilbab',
#  'ngapain',
#  'air',
#  'guy',
#  'rada',
#  'palestine',
#  'fgdp',
#  'prilaku',
#  'yesus',
#  'dia',
#  'jelasjelas',
#  'balas',
#  'yater',
#  'kepoooo',
#  'tindak',
#  'juang',
#  'oke',
#  'yakan',
#  'sore',
#  'kwkw',
#  'hemat',
#  'tantang',
#  'prediksi',
#  'koto',
#  'sikat',
#  'wkwkkwk',
#  'didik',
#  'strip',
#  'satu',
#  'oh',
#  'geng',
#  'poca',
#  'choice',
#  'diplajarin',
#  'desember',
#  'seklh',
#  'adam',
#  'tabaruj',
#  'jam',
#  'akulahhh',
#  'pap',
#  'gokar',
#  'adha',
#  'anarkis',
#  'fetish',
#  'versi',
#  'bumn',
#  'rmhnya',
#  'fast',
#  'basing',
#  'whip',
#  'banyak',
#  'kian',
#  'anjjirrr',
#  'garagara',
#  'betang',
#  'abadi',
#  'well',
#  'lempar',
#  'sunderland',
#  'keriting',
#  'rek',
#  'bnr',
#  'jokowi',
#  'kampus',
#  'waloni',
#  'gunung',
#  'waze',
#  'cucuk',
#  'wempi',
#  'usut',
#  'nampak',
#  'yeeaayyyy',
#  'merinding',
#  'lost',
#  'apaa',
#  'log',
#  'oap',
#  'seni',
#  'pertamina',
#  'yellow',
#  'didnt',
#  'upacara',
#  'kab',
#  'susah',
#  'duit',
#  'tida',
#  'kontol',
#  'pkn',
#  'freem',
#  'uda',
#  'ahlak',
#  'bnyakk',
#  'takut',
#  'kuku',
#  'fokus',
#  'ahahah',
#  'ternyataa',
#  'wawas',
#  'amrik',
#  'hmm',
#  'deklarasi',
#  'lai',
#  'reguler',
#  'kontribusi',
#  'be',
#  'guoblok',
#  'bajar',
#  'bodynya',
#  'nyebut',
#  'bangke',
#  'diajarin',
#  'catboy',
#  'ngaruh',
#  'gerilya',
#  'hantam',
#  'wa',
#  'bi',
#  'purba',
#  'curut',
#  'gituuuu',
#  'oalah',
#  'wadani',
#  'bansernya',
#  'uji',
#  'cemar',
#  'hidayat',
#  'jiwa',
#  'kanvas',
#  'viewers',
#  'gtw',
#  'tongkol',
#  'menmbungkuk',
#  'fase',
#  'peremp',
#  'sikap',
#  'resumereview',
#  'pastu',
#  'hutang',
#  'berfikirnya',
#  'ngedm',
#  'kating',
#  'ponpes',
#  'aura',
#  'wooooo',
#  'kog',
#  'israel',
#  'goes',
#  'terkevoh',
#  'kontra',
#  'to',
#  'ukbing',
#  'bukhari',
#  'ganggu',
#  'resume',
#  'dapet',
#  'akuan',
#  'mat',
#  'harbi',
#  'meromantisasi',
#  'problem',
#  'cuiiehh',
#  'tm',
#  'ank',
#  'keriput',
#  'gresik',
#  'melinjo',
#  'anut',
#  'tautaunya',
#  'suffering',
#  'gawat',
#  'skdr',
#  'nolongin',
#  'kuliah',
#  'taste',
#  'yoshi',
#  'atheis',
#  'sja',
#  'laknatullah',
#  'kades',
#  'obat',
#  'bornesi',
#  'tiket',
#  'yaaaa',
#  'pedih',
#  'klub',
#  'mengatasnamakan',
#  'dzalik',
#  'negera',
#  'macai',
#  'sudahlahdia',
#  'blajar',
#  'sampang',
#  'sekuler',
#  'cermin',
#  'ucap',
#  'kapas',
#  'opose',
#  'sol',
#  'mandarin',
#  'coba',
#  'politik',
#  'njingg',
#  'kompak',
#  'bodetabek',
#  'dasrul',
#  'brisik',
#  'takhayul',
#  'agreed',
#  'hubung',
#  'sorry',
#  'saram',
#  'pop',
#  'usak',
#  'job',
#  'periksa',
#  'anjer',
#  'baheulaane',
#  'rian',
#  'rindu',
#  'tanggungjawab',
#  'maming',
#  'sembang',
#  'dianggep',
#  'karakter',
#  'ekstrimis',
#  'renov',
#  'astagaaa',
#  'hadeehhh',
#  'kicik',
#  'nabi',
#  'abrahamik',
#  'asuuuu',
#  'kualitas',
#  'mabuk',
#  'sebab',
#  'kotatmptterserah',
#  'einstein',
#  'cb',
#  'subahanallah',
#  'trima',
#  'grammar',
#  'tahufreemason',
#  'kala',
#  'ftonya',
#  'hadrah',
#  'san',
#  'cantikkk',
#  'muak',
#  'drive',
#  'smp',
#  'tetep',
#  'nila',
#  'sd',
#  'dnger',
#  'darimana',
#  'korban',
#  'sulawesi',
#  'putus',
#  'siapatau',
#  'dhajjall',
#  'utama',
#  'disakitin',
#  'timur',
#  'musim',
#  'islamik',
#  'nasehat',
#  'kopi',
#  'kua',
#  'alam',
#  'akherat',
#  'ampun',
#  'oon',
#  'setengahsetengah',
#  'toleransi',
#  'orangdan',
#  'hate',
#  'dipush',
#  'jung',
#  'buzzerrp',
#  'smoo',
#  'manusiamaupun',
#  'nder',
#  'jabrik',
#  'yutuber',
#  'dok',
#  'lsg',
#  'kntl',
#  'tahan',
#  'kasanah',
#  'pcnya',
#  'pahit',
#  'antar',
#  'bos',
#  'inimah',
#  'kartika',
#  'lgbt',
#  'suntik',
#  'dialek',
#  'tongyg',
#  'power',
#  'tonton',
#  'baikbaik',
#  'terang',
#  'yahya',
#  'via',
#  'mayat',
#  'hektar',
#  'standar',
#  'eropa',
#  'syetannn',
#  'bgtlh',
#  'donatur',
#  'suju',
#  'pawangnga',
#  'besar',
#  ...]

# %% [markdown]
# Setelah itu, kita dapat **menghilangkan** saja untuk term yang tidak memenuhi threshold tadi

# %%
# menghilangkan term / fitur yang tidak memenuhi
Vectorized_X_train.drop(columns=nonsense_word, inplace=True)

Vectorized_X_train
# Out:
#       indonesia    negara    budaya   si  hati     salah  maju  kaya  nggak  \
# 1796   0.098958  0.050159  0.041263  0.0   0.0  0.000000   0.0   0.0    0.0
# 908    0.000000  0.000000  0.000000  0.0   0.0  0.000000   0.0   0.0    0.0
# 575    0.000000  0.000000  0.000000  0.0   0.0  0.174773   0.0   0.0    0.0
# 1697   0.000000  0.000000  0.045848  0.0   0.0  0.000000   0.0   0.0    0.0
# 1475   0.000000  0.000000  0.000000  0.0   0.0  0.000000   0.0   0.0    0.0
# ...         ...       ...       ...  ...   ...       ...   ...   ...    ...
# 1179   0.000000  0.000000  0.000000  0.0   0.0  0.000000   0.0   0.0    0.0
# 1343   0.000000  0.000000  0.000000  0.0   0.0  0.000000   0.0   0.0    0.0
# 906    0.000000  0.000000  0.000000  0.0   0.0  0.000000   0.0   0.0    0.0
# 1510   0.000000  0.000000  0.000000  0.0   0.0  0.000000   0.0   0.0    0.0
# 1175   0.000000  0.000000  0.000000  0.0   0.0  0.000000   0.0   0.0    0.0
#
#        lo  ...  baik  jahat  simak       pas  hidup  tanah  banding  yaa  \
# 1796  0.0  ...   0.0    0.0    0.0  0.000000    0.0    0.0      0.0  0.0
# 908   0.0  ...   0.0    0.0    0.0  0.000000    0.0    0.0      0.0  0.0
# 575   0.0  ...   0.0    0.0    0.0  0.000000    0.0    0.0      0.0  0.0
# 1697  0.0  ...   0.0    0.0    0.0  0.000000    0.0    0.0      0.0  0.0
# 1475  0.0  ...   0.0    0.0    0.0  0.000000    0.0    0.0      0.0  0.0
# ...   ...  ...   ...    ...    ...       ...    ...    ...      ...  ...
# 1179  0.0  ...   0.0    0.0    0.0  0.000000    0.0    0.0      0.0  0.0
# 1343  0.0  ...   0.0    0.0    0.0  0.187363    0.0    0.0      0.0  0.0
# 906   0.0  ...   0.0    0.0    0.0  0.000000    0.0    0.0      0.0  0.0
# 1510  0.0  ...   0.0    0.0    0.0  0.000000    0.0    0.0      0.0  0.0
# 1175  0.0  ...   0.0    0.0    0.0  0.000000    0.0    0.0      0.0  0.0
#
#       udah   lu
# 1796   0.0  0.0
# 908    0.0  0.0
# 575    0.0  0.0
# 1697   0.0  0.0
# 1475   0.0  0.0
# ...    ...  ...
# 1179   0.0  0.0
# 1343   0.0  0.0
# 906    0.0  0.0
# 1510   0.0  0.0
# 1175   0.0  0.0
#
# [1557 rows x 149 columns]

# %% [markdown]
# # **Solusi**

# %% [markdown]
# ### **Inisialisasi Library**

# %% [markdown]
# ##### Disini kita akan menggunakan tkinter untuk mengaplikasikan model KNN kedalam user interface.

# %%
import tkinter

# %% [markdown]
# ### **Filosofi UI**

# %% [markdown]
# #### **FONT**

# %% [markdown]
# **Segoe UI** : Kita hanya menggunakan 1 font untuk konsistensi bentuk teks serta ukuran yang terbilang cukup besar yang berpengaruh ke kemampuan penglihatan yang bisa mempengaruhi literasi pada usia tertentu seperti anak kecil rentang umur (7-12 tahun) dan orang tua (35 tahun) serta user dengan penglihatan yang kurang sempurna, seperti terkena rabun dekat, rabun jauh, silinder, dan sejenisnya.

# %% [markdown]
# #### **WARNA**

# %% [markdown]
# **#0F3E6E (Navy Blue)** Sebagai Background Color: Kita memilih warna tersebut agar semua objek yang berada didalam UI bisa terbaca dengan mudah karena warna yang tidak kontras, tidak terlalu cerah, ataupun terlalu gelap untuk dibandingkan dengan Foreground Color dan Text Color.
#
# **#F0F0F0 (Light Gray)** Sebagai Foreground Color Text Color: Kita memilih warna tersebut karena tidak terlalu cerah, dan mudah dibaca sehingga semua label dan objek didalam UI akan lebih semantic/mudah dimengerti.
#
# **#092745 (Dark Blue)** Sebagai Accent Color : Kita memilih warna tersebut karena lebih gelap, mudah ditangkap mata, dan terlihat lebih mencolok untuk warna teks, sehingga warna berpengaruh kepada teks dan terlihat sebagai highlight.

# %% [markdown]
# #### **Objek**

# %% [markdown]
# **WINDOW** : Kita menggunakan rasio potrait 600x850 (12:17) agar window cukup untuk menampung objek dengan ukuran yang cukup besar.
# **Label Title** : Menggunakan judul yang deskriptif sehingga bisa dimengerti dengan mudah oleh awam maupun profesional, muda maupun tua. Size diukur dengan (x = (maxwidth.pi.2), y=(maxwidth.pi.1,5))
# **Label Input Textbox** : Menggunakan kata kata instruktif yang mudah dipahami.
# **Input Textbox** : Dengan size

# %% [markdown]
# ### **Inisialisasi Konstruksi UI**

# %%
# Class yang akan menampung semua objek di Tkinter
class UI:
    # Fungsi yang digunakan untuk menginisialisasi variabel yang akan digunakan di objek tkinter serta konstruk dari akar window tkinter
    def __init__(self) -> None:
        # Inisialisasi untuk variabel font yang akan digunakan di dalam label Tkinter
        self.Header = ("Segoe UI", 28)
        self.Subheader1 = ("Segoe UI", 28)
        self.Subheader2 = ("Segoe UI", 24)
        self.Subheader3 = ("Segoe UI", 20)
        self.Subheader4 = ("Segoe UI", 12)
        self.button_font = ("Segoe UI", 13)
        
        # Inisialisasi untuk color pallete yang digunakan untuk UI tkinter
        self.background_color = "#0F3E6E"
        self.foreground_color = "#F0F0F0"
        self.accent_color = "#092745"
        
        # Inisialisasi dari window akar Tkinter
        self.root = tkinter.Tk()
        self.root.geometry("600x850")
        self.root.title("Klasifikasi Teks Menggunakan TF-IDF")
        self.root.configure(background=self.background_color)
        self.root.resizable("False", "False")
        self.home()
        self.root.mainloop()

    # Fungsi yang digunakan untuk konstruk page home/beranda
    def home(self):
        # Pelabelan untuk title
        tkinter.Label(master=self.root, text="Prediksi Komentar Rasisme", font=self.Subheader1, background=self.background_color, foreground=self.foreground_color).pack(pady=(54, 0))
        tkinter.Label(master=self.root, text="Menggunakan Algoritma KNN", font=self.Subheader2, background=self.background_color, foreground=self.foreground_color).pack()
        tkinter.Label(master=self.root, text="Dengan Metode TF-IDF ", font=self.Subheader3, background=self.background_color, foreground=self.foreground_color).pack()
        
        # Pelabelan dan konstruk textbox tkinter sebagai input teks algoritma KNN
        tkinter.Label(master=self.root, text="Inputkan Teks Anda Di Bawah:", font=self.Subheader4, background=self.accent_color, foreground=self.foreground_color, padx=85).pack(pady=(27, 0))
        textbox = tkinter.Text(self.root, width=42, height=19, relief="flat", font=self.Subheader4, background=self.accent_color, foreground=self.foreground_color)
        textbox.pack()
        
        # Tombol untuk memanggil fungsi predict, yang dimana menjadi penghubung tkinter dan model KNN
        tkinter.Button(master=self.root, text="Klik untuk memprediksi", font=self.button_font, command=lambda: self.predict(textbox.get("1.0", "end")), relief="groove", width=20, foreground=self.foreground_color, background=self.accent_color, highlightbackground=self.background_color, highlightcolor=self.background_color, activebackground=self.background_color).pack(pady=13)
        
        # Label untuk mewakili hasil class prediksi KNN setelah menekan tombol predict
        self.ClassifyResultTextBox = tkinter.Text(self.root, width=42, height=1, relief="flat", font=self.Subheader4, background=self.accent_color,foreground=self.foreground_color)
        self.ClassifyResultTextBox.insert("1.0", "Prediksi Class : ")
        self.ClassifyResultTextBox.configure(state="disabled")
        self.ClassifyResultTextBox.pack()

    # Fungsi yang digunakan untuk menghubungkan model KNN dan menampilkan hasil dari model KNN kedalam label result/hasil
    def predict(self, text=""):
        self.ClassifyResultTextBox.configure(state="normal")
        self.ClassifyResultTextBox.delete("0.0", "end")
        self.ClassifyResultTextBox.insert("1.0", "Prediksi Class : "+text)
        self.ClassifyResultTextBox.configure(state="disabled")

# %%
tkinter_ui = UI()

# %%
12/17
# Out:
# 0.7058823529411765
