# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from collections import deque
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
df = pd.read_csv("metrics-with-output.csv")
df
# Out:
#                      Time      Timestamp cpu_usage memory_usage  \
# 0     2023-09-08 01:16:00  1694110560000     9.00%        53.5%
# 1     2023-09-08 01:16:05  1694110565000     16.6%        53.3%
# 2     2023-09-08 01:16:10  1694110570000     20.2%        55.3%
# 3     2023-09-08 01:16:15  1694110575000     14.6%        58.0%
# 4     2023-09-08 01:16:20  1694110580000     10.2%        53.5%
# ...                   ...            ...       ...          ...
# 7184  2023-09-08 11:14:40  1694146480000     22.2%        53.5%
# 7185  2023-09-08 11:14:45  1694146485000     27.2%        56.0%
# 7186  2023-09-08 11:14:50  1694146490000     7.20%        54.1%
# 7187  2023-09-08 11:14:55  1694146495000     23.4%        54.6%
# 7188  2023-09-08 11:15:00  1694146500000     31.0%        53.8%
#
#      bandwidth_inbound bandwidth_outbound         tps tps_error response_time  \
# 0            7.46 GB/s          6.45 GB/s     2 req/s   0 req/s        607 ms
# 1            5.85 GB/s          5.27 GB/s  2.20 req/s   0 req/s        2.09 s
# 2            9.06 GB/s          7.96 GB/s  3.20 req/s   0 req/s        3.45 s
# 3            8.41 GB/s          7.21 GB/s  3.20 req/s   0 req/s        2.58 s
# 4            4.88 GB/s          4.30 GB/s  2.60 req/s   0 req/s        862 ms
# ...                ...                ...         ...       ...           ...
# 7184         6.52 GB/s          5.67 GB/s  2.40 req/s   0 req/s        1.51 s
# 7185         7.37 GB/s          6.49 GB/s  2.60 req/s   0 req/s        1.21 s
# 7186         4.76 GB/s          4.02 GB/s  1.40 req/s   0 req/s        285 ms
# 7187         6.75 GB/s          5.90 GB/s  2.40 req/s   0 req/s        804 ms
# 7188         7.76 GB/s          6.92 GB/s  3.20 req/s   0 req/s        2.64 s
#
#       Status
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 7184       0
# 7185       0
# 7186       0
# 7187       0
# 7188       0
#
# [7189 rows x 10 columns]

# %%
# Menampilkan baris pertama dr dataset
df.head()
# Out:
#                   Time      Timestamp cpu_usage memory_usage  \
# 0  2023-09-08 01:16:00  1694110560000     9.00%        53.5%
# 1  2023-09-08 01:16:05  1694110565000     16.6%        53.3%
# 2  2023-09-08 01:16:10  1694110570000     20.2%        55.3%
# 3  2023-09-08 01:16:15  1694110575000     14.6%        58.0%
# 4  2023-09-08 01:16:20  1694110580000     10.2%        53.5%
#
#   bandwidth_inbound bandwidth_outbound         tps tps_error response_time  \
# 0         7.46 GB/s          6.45 GB/s     2 req/s   0 req/s        607 ms
# 1         5.85 GB/s          5.27 GB/s  2.20 req/s   0 req/s        2.09 s
# 2         9.06 GB/s          7.96 GB/s  3.20 req/s   0 req/s        3.45 s
# 3         8.41 GB/s          7.21 GB/s  3.20 req/s   0 req/s        2.58 s
# 4         4.88 GB/s          4.30 GB/s  2.60 req/s   0 req/s        862 ms
#
#    Status
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import matplotlib.pyplot as plt

#Membandingkan jumlah status Healthy dan Unhealthy dengan donut chart
status_counts = df['Status'].value_counts()

colors = ['red','blue']
plt.pie(status_counts, labels=status_counts.index, colors=colors, autopct='%1.1f%%', startangle=90)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Distribution of Status')
plt.show()

# %%
# Preprocessing data: clean and convert to numeric
df['cpu_usage'] = df['cpu_usage'].str.rstrip('%').astype('float') / 100.0
df['memory_usage'] = df['memory_usage'].str.rstrip('%').astype('float') / 100.0

def clean_bandwidth(value):
    if 'GB/s' in value:
        return float(value.replace('GB/s', ''))
    elif 'MB/s' in value:
        return float(value.replace('MB/s', '')) / 1024  # Convert MB/s to GB/s
    else:
        return float(value)

df['bandwidth_inbound'] = df['bandwidth_inbound'].apply(clean_bandwidth)
df['bandwidth_outbound'] = df['bandwidth_outbound'].apply(clean_bandwidth)
df['tps'] = df['tps'].str.rstrip(' req/s').astype('float')
df['tps_error'] = df['tps_error'].str.rstrip(' req/s').astype('float')
df['response_time'] = df['response_time'].replace({' ms': '*1e-3', ' s': '*1'}, regex=True).map(pd.eval).astype('float')

# Drop irrelevant columns (if any)
dataset = df.drop(df.columns[[0, 1]], axis=1)

# Normalize the dataset
scaler = MinMaxScaler()
features = dataset.drop('Status', axis=1)
normalized_features = scaler.fit_transform(features)

# Replace the non-normalized features with the normalized ones in the dataset
normalized_dataset = pd.DataFrame(normalized_features, columns=features.columns)
normalized_dataset['Status'] = dataset['Status'].values  # Add the 'Status' column back
dataset = normalized_dataset
# Display the normalized dataset
print(normalized_dataset.head())
# Out:
#    cpu_usage  memory_usage  bandwidth_inbound  bandwidth_outbound       tps  \
# 0   0.080808      0.187192           0.363939            0.364287  0.269231
# 1   0.157576      0.177340           0.284799            0.297010  0.307692
# 2   0.193939      0.275862           0.442586            0.450379  0.500000
# 3   0.137374      0.408867           0.410635            0.407618  0.500000
# 4   0.092929      0.187192           0.237119            0.241705  0.384615
#
#    tps_error  response_time  Status
# 0        0.0       0.070037       0
# 1        0.0       0.282441       0
# 2        0.0       0.477227       0
# 3        0.0       0.352621       0
# 4        0.0       0.106560       0

# %%
# Info dataset mengenai tipe, jumlah kolom dll
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7189 entries, 0 to 7188
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                7189 non-null   object
#  1   Timestamp           7189 non-null   int64
#  2   cpu_usage           7189 non-null   float64
#  3   memory_usage        7189 non-null   float64
#  4   bandwidth_inbound   7189 non-null   float64
#  5   bandwidth_outbound  7189 non-null   float64
#  6   tps                 7189 non-null   float64
#  7   tps_error           7189 non-null   float64
#  8   response_time       7189 non-null   float64
#  9   Status              7189 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 561.8+ KB

# %%
# Menampilkan dataset setelah proses konversi dan pembersihan data
print(df)
# Out:
#                      Time      Timestamp  cpu_usage  memory_usage  \
# 0     2023-09-08 01:16:00  1694110560000      0.090         0.535
# 1     2023-09-08 01:16:05  1694110565000      0.166         0.533
# 2     2023-09-08 01:16:10  1694110570000      0.202         0.553
# 3     2023-09-08 01:16:15  1694110575000      0.146         0.580
# 4     2023-09-08 01:16:20  1694110580000      0.102         0.535
# ...                   ...            ...        ...           ...
# 7184  2023-09-08 11:14:40  1694146480000      0.222         0.535
# 7185  2023-09-08 11:14:45  1694146485000      0.272         0.560
# 7186  2023-09-08 11:14:50  1694146490000      0.072         0.541
# 7187  2023-09-08 11:14:55  1694146495000      0.234         0.546
# 7188  2023-09-08 11:15:00  1694146500000      0.310         0.538
#
#       bandwidth_inbound  bandwidth_outbound  tps  tps_error  response_time  \
# 0                  7.46                6.45  2.0        0.0          0.607
# 1                  5.85                5.27  2.2        0.0          2.090
# 2                  9.06                7.96  3.2        0.0          3.450
# 3                  8.41                7.21  3.2        0.0          2.580
# 4                  4.88                4.30  2.6        0.0          0.862
# ...                 ...                 ...  ...        ...            ...
# 7184               6.52                5.67  2.4        0.0          1.510
# 7185               7.37                6.49  2.6        0.0          1.210
# 7186               4.76                4.02  1.4        0.0          0.285
# 7187               6.75                5.90  2.4        0.0          0.804
# 7188               7.76                6.92  3.2        0.0          2.640
#
#       Status
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 7184       0
# 7185       0
# 7186       0
# 7187       0
# 7188       0
#
# [7189 rows x 10 columns]

# %%
# Pembersihan/Penghapusan data yang tidak dipakai
dataset = df.drop(df.columns[[0, 1]], axis=1)

dataset.describe()
# Out:
#          cpu_usage  memory_usage  bandwidth_inbound  bandwidth_outbound  \
# count  7189.000000   7189.000000        7189.000000         7189.000000
# mean      0.163090      0.542723           6.318377            5.573617
# std       0.069272      0.019356           3.193037            2.728239
# min       0.010000      0.497000           0.056055            0.060645
# 25%       0.118000      0.533000           3.940000            3.540000
# 50%       0.156000      0.539000           5.910000            5.230000
# 75%       0.198000      0.549000           8.310000            7.260000
# max       1.000000      0.700000          20.400000           17.600000
#
#                tps    tps_error  response_time       Status
# count  7189.000000  7189.000000    7189.000000  7189.000000
# mean      2.490218     0.170817       1.770724     0.132981
# std       0.784028     0.548970       1.024615     0.339578
# min       0.600000     0.000000       0.118000     0.000000
# 25%       2.000000     0.000000       0.952000     0.000000
# 50%       2.400000     0.000000       1.520000     0.000000
# 75%       3.000000     0.000000       2.450000     0.000000
# max       5.800000     4.600000       7.100000     1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# Encode 'Status' column into numeric values
label_encoder = LabelEncoder()
dataset['Status'] = label_encoder.fit_transform(dataset['Status'])

# %%
dataset['Status']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7184    0
# 7185    0
# 7186    0
# 7187    0
# 7188    0
# Name: Status, Length: 7189, dtype: int64

# %%
# Periksa apakah ada data yang hilang
missing_data = dataset.isnull().sum()
if missing_data.any():
    print("Data terdapat missing values yang perlu diimputasi:")
    print(missing_data)
else:
    print("Tidak ada missing values dalam dataset.")
# Out:
# Tidak ada missing values dalam dataset.

# %%
# Split data menjadi features (X) dan target (y)
X = dataset.drop('Status', axis=1)
y = dataset['Status']

# %%
# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=123)

# %%
# Definisikan Environment Class
class Environment:
    def __init__(self, dataset, class_weights, total_epochs):
        self.dataset = dataset
        self.num_samples = len(dataset)
        self.current_sample_idx = None  # Set indeks sampel saat ini ke None saat inisialisasi
        self.class_weights = class_weights  # Bobot kelas
        self.total_epochs = total_epochs  # Total jumlah epoch
        self.current_epoch = 0  # Epoch saat ini, dimulai dari 0

    def reset(self):
        self.current_sample_idx = 0  # Set ulang indeks sampel saat memulai episode baru
        self.current_epoch += 1  # Tambahkan epoch setiap kali reset
        initial_observation = self.dataset.iloc[self.current_sample_idx]  # Ambil observasi awal
        return initial_observation, 0, False

    def step(self, action):
        # Ambil label aktual dan prediksi agen
        actual = self.dataset.iloc[self.current_sample_idx]['Status']  # Menggunakan kolom 'Status' yang ada di dataset
        predicted = action  # Asumsikan 'action' adalah prediksi agen

        # Update indeks sampel
        self.current_sample_idx = (self.current_sample_idx + 1) % self.num_samples
        next_observation = self.dataset.iloc[self.current_sample_idx]
        
        # Hitung reward berdasarkan observasi dan aksi
        reward = self.calculate_reward(
            actual, predicted, self.class_weights, self.current_epoch, self.total_epochs
        )
        
        # Atur done menjadi True jika mencapai akhir episode
        done = self.current_sample_idx == 0
        
        return next_observation, reward, done

    def calculate_reward(self, actual, predicted, class_weights, current_epoch, total_epochs):
        """
        Fungsi reward yang dinamis berdasarkan distribusi kelas dan epoch saat ini.
        
        Parameters:
        - actual: Nilai aktual dari label (0 atau 1).
        - predicted: Prediksi agen (0 atau 1).
        - class_weights: Bobot kelas untuk menangani ketidakseimbangan.
        - current_epoch: Epoch pelatihan saat ini.
        - total_epochs: Total jumlah epoch.
        
        Returns:
        - reward: Nilai reward yang dihitung.
        """
        # Penalty dasar untuk kesalahan
        base_penalty = -1
        base_reward = 1
        
        # Jika prediksi benar
        if predicted == actual:
            if actual == 1:
                # Reward lebih tinggi untuk kelas `1` karena lebih jarang
                reward = base_reward * class_weights[1]
            else:
                # Reward lebih rendah untuk kelas `0` karena lebih sering
                reward = base_reward * class_weights[0]
        else:
            # Jika prediksi salah, berikan penalti
            if predicted == 1:
                # Penalti lebih besar untuk memprediksi `1` dengan salah
                penalty = base_penalty * class_weights[1]
            else:
                # Penalti lebih kecil untuk memprediksi `0` dengan salah
                penalty = base_penalty * class_weights[0]

            # Menggabungkan penalti dengan epoch saat ini
            reward = penalty * (1 + (current_epoch / total_epochs))
        
        return reward

# %%
import tensorflow as tf  # Tambahkan import TensorFlow

class DQNAgent:
    def __init__(self, state_size, action_size, class_weights=None):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.93
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.99
        self.learning_rate = 0.001
        self.class_weights = class_weights
        self.model = self._build_model()

    def custom_loss(y_true, y_pred):
        # Misalnya weight untuk kelas 0 = 0.2, dan kelas 1 = 0.8
        weights = tf.where(tf.equal(y_true, 0), 0.2, 0.8)
        loss = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        return tf.reduce_mean(loss * weights)


    def _build_model(self):
        model = tf.keras.models.Sequential()
        
        # Adding layers with LeakyReLU activation
        model.add(tf.keras.layers.Dense(128, input_dim=self.state_size))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(256))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(128))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(self.action_size, activation='linear'))
        
        model.compile(loss=self.custom_loss, optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        # Separate experiences by label
        experiences_class_0 = [exp for exp in self.memory if exp[3]['Status'] == 0]
        experiences_class_1 = [exp for exp in self.memory if exp[3]['Status'] == 1]

        # Oversample class 0 experiences
        if len(experiences_class_0) < batch_size:
            minibatch = random.sample(experiences_class_0 * (batch_size // len(experiences_class_0)), batch_size)
        else:
            minibatch = random.sample(experiences_class_0, batch_size // 2)
            minibatch += random.sample(experiences_class_1, batch_size // 2)
        
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
# Out:
# WARNING:tensorflow:From c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Parameters
num_actions = 2  # Number of possible actions
num_features = len(dataset.columns) - 1  # Number of features in the dataset (excluding classification)
batch_size = 40
num_episodes = 3000
max_steps = 2000

# %%
# Initialize environment and agent
class_weights = {0:0.7 , 1: 0.3} # Contoh untuk menghitung bobot
env = Environment(dataset, class_weights, num_episodes)
agent = DQNAgent(state_size=num_features, action_size=num_actions, class_weights=class_weights)
# Out:
# WARNING:tensorflow:From c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Training loop
total_reward_all = 0
for episode in range(num_episodes):
    state, _, _ = env.reset()  # Reset the environment and get initial state
    total_reward = 0
    done = False
    while not done:
        action = agent.act(state)
        next_state, reward, done = env.step(action)  # Take action and get next state, reward, and done status
        agent.remember(state, action, reward, next_state, done)  # Remember the experience
        state = next_state  # Update the current state
        total_reward += reward  # Accumulate total reward for the episode
    total_reward_all += total_reward
    print("Episode:", episode+1, "of", num_episodes, "Total Reward:", total_reward)
# Out:
# Episode: 1 of 3000 Total Reward: 1027.4759333333182
# Episode: 2 of 3000 Total Reward: 1052.049133333355
# Episode: 3 of 3000 Total Reward: 1051.6257000000603
# Episode: 4 of 3000 Total Reward: 1003.1881333334214
# Episode: 5 of 3000 Total Reward: 1025.7609999999409
# Episode: 6 of 3000 Total Reward: 1071.3584000000067
# Episode: 7 of 3000 Total Reward: 1111.990566666701
# Episode: 8 of 3000 Total Reward: 1001.4784000000918
# Episode: 9 of 3000 Total Reward: 1105.1419000001345
# Episode: 10 of 3000 Total Reward: 1106.7503333333545
# Episode: 11 of 3000 Total Reward: 1033.1875999999972
# Episode: 12 of 3000 Total Reward: 1031.8012000000524
# Episode: 13 of 3000 Total Reward: 939.2341666667314
# Episode: 14 of 3000 Total Reward: 1166.1273333334611
# Episode: 15 of 3000 Total Reward: 1092.6535000000167
# Episode: 16 of 3000 Total Reward: 1136.249866666697
# Episode: 17 of 3000 Total Reward: 1015.643833333409
# Episode: 18 of 3000 Total Reward: 1083.2938000001234
# Episode: 19 of 3000 Total Reward: 984.7331666666497
# Episode: 20 of 3000 Total Reward: 1069.5293333333582
# Episode: 21 of 3000 Total Reward: 1007.8903000000741
# Episode: 22 of 3000 Total Reward: 1043.590333333393
# Episode: 23 of 3000 Total Reward: 1115.338900000114
# Episode: 24 of 3000 Total Reward: 1088.9120000000032
# Episode: 25 of 3000 Total Reward: 983.1466666666936
# Episode: 26 of 3000 Total Reward: 1113.0302666667694
# Episode: 27 of 3000 Total Reward: 1066.5960000000953
# Episode: 28 of 3000 Total Reward: 1081.1595999999915
# Episode: 29 of 3000 Total Reward: 1008.550833333327
# Episode: 30 of 3000 Total Reward: 1020.0810000000631
# Episode: 31 of 3000 Total Reward: 1006.6464666667923
# Episode: 32 of 3000 Total Reward: 995.2349333334686
# Episode: 33 of 3000 Total Reward: 1025.79139999999
# Episode: 34 of 3000 Total Reward: 1068.6098000000145
# Episode: 35 of 3000 Total Reward: 1062.1778333334153
# Episode: 36 of 3000 Total Reward: 981.5172000001013
# Episode: 37 of 3000 Total Reward: 977.0405666666563
# Episode: 38 of 3000 Total Reward: 1042.9083333333194
# Episode: 39 of 3000 Total Reward: 1065.6240000000314
# Episode: 40 of 3000 Total Reward: 1041.8800000001033
# Episode: 41 of 3000 Total Reward: 1024.5488000001378
# Episode: 42 of 3000 Total Reward: 1044.2208000000073
# Episode: 43 of 3000 Total Reward: 1041.7282000000362
# Episode: 44 of 3000 Total Reward: 978.9330666667349
# Episode: 45 of 3000 Total Reward: 981.5755000000881
# Episode: 46 of 3000 Total Reward: 986.0770666666325
# Episode: 47 of 3000 Total Reward: 1051.1333666666778
# Episode: 48 of 3000 Total Reward: 1099.1032000000948
# Episode: 49 of 3000 Total Reward: 1056.2563000000805
# Episode: 50 of 3000 Total Reward: 1009.6516666667706
# Episode: 51 of 3000 Total Reward: 1013.301499999989
# Episode: 52 of 3000 Total Reward: 1014.7081333333452
# Episode: 53 of 3000 Total Reward: 982.0411000000869
# Episode: 54 of 3000 Total Reward: 1036.1822000001127
# Episode: 55 of 3000 Total Reward: 1005.4058333332908
# Episode: 56 of 3000 Total Reward: 1063.3333333333294
# Episode: 57 of 3000 Total Reward: 943.3254000000371
# Episode: 58 of 3000 Total Reward: 1080.6270000000895
# Episode: 59 of 3000 Total Reward: 1043.9961000001256
# Episode: 60 of 3000 Total Reward: 1033.6179999999727
# Episode: 61 of 3000 Total Reward: 1053.1315666666783
# Episode: 62 of 3000 Total Reward: 1019.6533333334064
# Episode: 63 of 3000 Total Reward: 1052.3707000000916
# Episode: 64 of 3000 Total Reward: 1081.186400000005
# Episode: 65 of 3000 Total Reward: 984.2923333333216
# Episode: 66 of 3000 Total Reward: 1100.4396000000618
# Episode: 67 of 3000 Total Reward: 1032.5925000000873
# Episode: 68 of 3000 Total Reward: 1007.8980000001128
# Episode: 69 of 3000 Total Reward: 988.2207999999929
# Episode: 70 of 3000 Total Reward: 988.0613333333603
# Episode: 71 of 3000 Total Reward: 999.7013333333874
# Episode: 72 of 3000 Total Reward: 1051.6120000000926
# Episode: 73 of 3000 Total Reward: 1023.1523999999548
# Episode: 74 of 3000 Total Reward: 1089.1801333333715
# Episode: 75 of 3000 Total Reward: 1096.5650000000721
# Episode: 76 of 3000 Total Reward: 1035.6810666667777
# Episode: 77 of 3000 Total Reward: 1004.3264333334275
# Episode: 78 of 3000 Total Reward: 1074.2829999999888
# Episode: 79 of 3000 Total Reward: 1001.2539000000094
# Episode: 80 of 3000 Total Reward: 968.6680000000681
# Episode: 81 of 3000 Total Reward: 1048.8449000001035
# Episode: 82 of 3000 Total Reward: 953.5552666666056
# Episode: 83 of 3000 Total Reward: 973.555833333334
# Episode: 84 of 3000 Total Reward: 1010.9676000000281
# Episode: 85 of 3000 Total Reward: 1046.279333333424
# Episode: 86 of 3000 Total Reward: 944.862666666773
# Episode: 87 of 3000 Total Reward: 975.7829000000048
# Episode: 88 of 3000 Total Reward: 1096.5061333333322
# Episode: 89 of 3000 Total Reward: 980.9593000000552
# Episode: 90 of 3000 Total Reward: 1062.2980000000766
# Episode: 91 of 3000 Total Reward: 1048.6891000001492
# Episode: 92 of 3000 Total Reward: 993.8460000000223
# Episode: 93 of 3000 Total Reward: 1007.6137000000101
# Episode: 94 of 3000 Total Reward: 955.3233333334086
# Episode: 95 of 3000 Total Reward: 971.9771666667614
# Episode: 96 of 3000 Total Reward: 985.9111999999889
# Episode: 97 of 3000 Total Reward: 943.1544333333417
# Episode: 98 of 3000 Total Reward: 955.0507333334045
# Episode: 99 of 3000 Total Reward: 975.4356000000591
# Episode: 100 of 3000 Total Reward: 1093.656666666799
# Episode: 101 of 3000 Total Reward: 1001.3251333333393
# Episode: 102 of 3000 Total Reward: 912.7306000000214
# Episode: 103 of 3000 Total Reward: 1062.2889000000791
# Episode: 104 of 3000 Total Reward: 989.4157333334286
# Episode: 105 of 3000 Total Reward: 975.1489999999734
# Episode: 106 of 3000 Total Reward: 1055.4294666666674
# Episode: 107 of 3000 Total Reward: 1069.4022666667338
# Episode: 108 of 3000 Total Reward: 962.2188000001161
# Episode: 109 of 3000 Total Reward: 1003.0219000001533
# Episode: 110 of 3000 Total Reward: 1016.5936666666523
# Episode: 111 of 3000 Total Reward: 1004.7398000000138
# Episode: 112 of 3000 Total Reward: 1111.0285333333852
# Episode: 113 of 3000 Total Reward: 932.0576333334465
# Episode: 114 of 3000 Total Reward: 1044.9325999999908
# Episode: 115 of 3000 Total Reward: 973.5688333333098
# Episode: 116 of 3000 Total Reward: 997.0717333333721
# Episode: 117 of 3000 Total Reward: 1097.4932000001077
# Episode: 118 of 3000 Total Reward: 1054.83560000013
# Episode: 119 of 3000 Total Reward: 976.0433666666798
# Episode: 120 of 3000 Total Reward: 1098.404000000058
# Episode: 121 of 3000 Total Reward: 960.9547000000708
# Episode: 122 of 3000 Total Reward: 1055.2293333334085
# Episode: 123 of 3000 Total Reward: 1013.7479999999706
# Episode: 124 of 3000 Total Reward: 1076.522666666669
# Episode: 125 of 3000 Total Reward: 994.9750000000599
# Episode: 126 of 3000 Total Reward: 1055.4756000000928
# Episode: 127 of 3000 Total Reward: 973.6710000001041
# Episode: 128 of 3000 Total Reward: 999.7815999999883
# Episode: 129 of 3000 Total Reward: 981.0234000000158
# Episode: 130 of 3000 Total Reward: 1043.5080000000817
# Episode: 131 of 3000 Total Reward: 1056.452033333446
# Episode: 132 of 3000 Total Reward: 1015.1563999999621
# Episode: 133 of 3000 Total Reward: 933.1735666666405
# Episode: 134 of 3000 Total Reward: 928.9360666667015
# Episode: 135 of 3000 Total Reward: 975.7005000001105
# Episode: 136 of 3000 Total Reward: 996.9957333334602
# Episode: 137 of 3000 Total Reward: 997.0814333333107
# Episode: 138 of 3000 Total Reward: 1020.0136000000073
# Episode: 139 of 3000 Total Reward: 1015.4829333334052
# Episode: 140 of 3000 Total Reward: 983.4420000000919
# Episode: 141 of 3000 Total Reward: 1085.5729999999787
# Episode: 142 of 3000 Total Reward: 1028.8564000000001
# Episode: 143 of 3000 Total Reward: 1060.4787333333663
# Episode: 144 of 3000 Total Reward: 1009.1896000000843
# Episode: 145 of 3000 Total Reward: 1032.1401666667798
# Episode: 146 of 3000 Total Reward: 992.1127999999942
# Episode: 147 of 3000 Total Reward: 984.8611000000263
# Episode: 148 of 3000 Total Reward: 1077.0818666667035
# Episode: 149 of 3000 Total Reward: 1032.334900000076
# Episode: 150 of 3000 Total Reward: 933.3399999999561
# Episode: 151 of 3000 Total Reward: 982.8709666666916
# Episode: 152 of 3000 Total Reward: 989.4520000000473
# Episode: 153 of 3000 Total Reward: 1034.9613000001134
# Episode: 154 of 3000 Total Reward: 967.1163333334209
# Episode: 155 of 3000 Total Reward: 944.844166666653
# Episode: 156 of 3000 Total Reward: 1051.1184000000226
# Episode: 157 of 3000 Total Reward: 963.5313000000707
# Episode: 158 of 3000 Total Reward: 977.8922000000867
# Episode: 159 of 3000 Total Reward: 1050.6552999999396
# Episode: 160 of 3000 Total Reward: 1045.5853333333382
# Episode: 161 of 3000 Total Reward: 937.2138333333567
# Episode: 162 of 3000 Total Reward: 973.104000000095
# Episode: 163 of 3000 Total Reward: 968.4402666667926
# Episode: 164 of 3000 Total Reward: 985.3366666666751
# Episode: 165 of 3000 Total Reward: 960.7144999999917
# Episode: 166 of 3000 Total Reward: 1047.7388666667118
# Episode: 167 of 3000 Total Reward: 990.1866333334124
# Episode: 168 of 3000 Total Reward: 1040.7600000001362
# Episode: 169 of 3000 Total Reward: 885.300500000022
# Episode: 170 of 3000 Total Reward: 1060.5143333333533
# Episode: 171 of 3000 Total Reward: 1049.769700000079
# Episode: 172 of 3000 Total Reward: 1008.7574666667495
# Episode: 173 of 3000 Total Reward: 1006.7440666666573
# Episode: 174 of 3000 Total Reward: 922.3642000000073
# Episode: 175 of 3000 Total Reward: 1007.1725000000724
# Episode: 176 of 3000 Total Reward: 971.2994666667335
# Episode: 177 of 3000 Total Reward: 1038.9406000001168
# Episode: 178 of 3000 Total Reward: 954.0008000000051
# Episode: 179 of 3000 Total Reward: 983.045766666698
# Episode: 180 of 3000 Total Reward: 981.258000000085
# Episode: 181 of 3000 Total Reward: 1020.7126000000919
# Episode: 182 of 3000 Total Reward: 1016.4660666666416
# Episode: 183 of 3000 Total Reward: 1023.1010000000001
# Episode: 184 of 3000 Total Reward: 1053.0245333333842
# Episode: 185 of 3000 Total Reward: 987.058166666783
# Episode: 186 of 3000 Total Reward: 952.4036000001529
# Episode: 187 of 3000 Total Reward: 939.1070999999889
# Episode: 188 of 3000 Total Reward: 930.7556000000096
# Episode: 189 of 3000 Total Reward: 1054.3075000000888
# Episode: 190 of 3000 Total Reward: 931.0796666667744
# Episode: 191 of 3000 Total Reward: 813.7326666666513
# Episode: 192 of 3000 Total Reward: 1028.9831999999876
# Episode: 193 of 3000 Total Reward: 979.1259000000425
# Episode: 194 of 3000 Total Reward: 915.163133333432
# Episode: 195 of 3000 Total Reward: 944.7650000001289
# Episode: 196 of 3000 Total Reward: 1097.3828000000108
# Episode: 197 of 3000 Total Reward: 962.6037000000345
# Episode: 198 of 3000 Total Reward: 986.2384000000742
# Episode: 199 of 3000 Total Reward: 929.6417666667588
# Episode: 200 of 3000 Total Reward: 889.4866666666396
# Episode: 201 of 3000 Total Reward: 954.7714999999965
# Episode: 202 of 3000 Total Reward: 996.8984000000603
# Episode: 203 of 3000 Total Reward: 1001.5791000000859
# Episode: 204 of 3000 Total Reward: 942.3564000001064
# Episode: 205 of 3000 Total Reward: 962.9253333333237
# Episode: 206 of 3000 Total Reward: 946.9954666666781
# Episode: 207 of 3000 Total Reward: 939.483400000093
# Episode: 208 of 3000 Total Reward: 947.7773333334333
# Episode: 209 of 3000 Total Reward: 1000.0781999999591
# Episode: 210 of 3000 Total Reward: 1019.5329999999763
# Episode: 211 of 3000 Total Reward: 1012.9903666667125
# Episode: 212 of 3000 Total Reward: 940.9201333334441
# Episode: 213 of 3000 Total Reward: 929.6011000001234
# Episode: 214 of 3000 Total Reward: 947.9856666666378
# Episode: 215 of 3000 Total Reward: 956.3530000000073
# Episode: 216 of 3000 Total Reward: 972.8776000000663
# Episode: 217 of 3000 Total Reward: 927.8196666667521
# Episode: 218 of 3000 Total Reward: 1054.7715333333206
# Episode: 219 of 3000 Total Reward: 1017.5989000000017
# Episode: 220 of 3000 Total Reward: 934.488000000024
# Episode: 221 of 3000 Total Reward: 916.4225000000777
# Episode: 222 of 3000 Total Reward: 859.5826000000892
# Episode: 223 of 3000 Total Reward: 978.1061999999919
# Episode: 224 of 3000 Total Reward: 964.633333333356
# Episode: 225 of 3000 Total Reward: 967.1275000000484
# Episode: 226 of 3000 Total Reward: 971.6410000000701
# Episode: 227 of 3000 Total Reward: 972.9988666666193
# Episode: 228 of 3000 Total Reward: 913.9056000000224
# Episode: 229 of 3000 Total Reward: 1011.9947666667168
# Episode: 230 of 3000 Total Reward: 1026.2200000001103
# Episode: 231 of 3000 Total Reward: 997.280400000108
# Episode: 232 of 3000 Total Reward: 950.3231999999748
# Episode: 233 of 3000 Total Reward: 1047.9797666666848
# Episode: 234 of 3000 Total Reward: 896.874400000064
# Episode: 235 of 3000 Total Reward: 964.6516666667635
# Episode: 236 of 3000 Total Reward: 926.2450666666049
# Episode: 237 of 3000 Total Reward: 937.5384000000067
# Episode: 238 of 3000 Total Reward: 890.8218000000197
# Episode: 239 of 3000 Total Reward: 1020.4282000000964
# Episode: 240 of 3000 Total Reward: 980.3640000001205
# Episode: 241 of 3000 Total Reward: 994.4753000000048
# Episode: 242 of 3000 Total Reward: 985.9857333333305
# Episode: 243 of 3000 Total Reward: 871.9321000000465
# Episode: 244 of 3000 Total Reward: 880.6546666667294
# Episode: 245 of 3000 Total Reward: 979.2731666668128
# Episode: 246 of 3000 Total Reward: 1027.5234000000269
# Episode: 247 of 3000 Total Reward: 963.4519333333428
# Episode: 248 of 3000 Total Reward: 950.0040000000746
# Episode: 249 of 3000 Total Reward: 957.718400000094
# Episode: 250 of 3000 Total Reward: 992.7333333333249
# Episode: 251 of 3000 Total Reward: 908.9783666666766
# Episode: 252 of 3000 Total Reward: 885.8760000000653
# Episode: 253 of 3000 Total Reward: 923.9702000000528
# Episode: 254 of 3000 Total Reward: 854.358266666763
# Episode: 255 of 3000 Total Reward: 951.9670000000042
# Episode: 256 of 3000 Total Reward: 953.0130666666955
# Episode: 257 of 3000 Total Reward: 952.3517666667619
# Episode: 258 of 3000 Total Reward: 943.9982000000798
# Episode: 259 of 3000 Total Reward: 944.0595666666417
# Episode: 260 of 3000 Total Reward: 875.0566666666557
# Episode: 261 of 3000 Total Reward: 921.3230000000593
# Episode: 262 of 3000 Total Reward: 950.8469333334596
# Episode: 263 of 3000 Total Reward: 902.7129666667973
# Episode: 264 of 3000 Total Reward: 966.3863999999893
# Episode: 265 of 3000 Total Reward: 910.1071666666733
# Episode: 266 of 3000 Total Reward: 962.215466666744
# Episode: 267 of 3000 Total Reward: 926.3538000000985
# Episode: 268 of 3000 Total Reward: 935.3841333333261
# Episode: 269 of 3000 Total Reward: 952.3102666666389
# Episode: 270 of 3000 Total Reward: 927.8880000000397
# Episode: 271 of 3000 Total Reward: 967.2850666667745
# Episode: 272 of 3000 Total Reward: 974.7053333334626
# Episode: 273 of 3000 Total Reward: 893.092400000015
# Episode: 274 of 3000 Total Reward: 921.5048000000303
# Episode: 275 of 3000 Total Reward: 1010.2525000000743
# Episode: 276 of 3000 Total Reward: 934.2348000000886
# Episode: 277 of 3000 Total Reward: 959.4612333333117
# Episode: 278 of 3000 Total Reward: 950.3801333333276
# Episode: 279 of 3000 Total Reward: 922.2413000000519
# Episode: 280 of 3000 Total Reward: 1015.4760000000927
# Episode: 281 of 3000 Total Reward: 914.9433333334321
# Episode: 282 of 3000 Total Reward: 918.6457999999882
# Episode: 283 of 3000 Total Reward: 905.7948000000041
# Episode: 284 of 3000 Total Reward: 1071.8576000000653
# Episode: 285 of 3000 Total Reward: 977.4350000001107
# Episode: 286 of 3000 Total Reward: 953.0925999999587
# Episode: 287 of 3000 Total Reward: 866.6047999999766
# Episode: 288 of 3000 Total Reward: 917.6536000000398
# Episode: 289 of 3000 Total Reward: 958.0498333334378
# Episode: 290 of 3000 Total Reward: 1007.6510000001357
# Episode: 291 of 3000 Total Reward: 911.5838999999772
# Episode: 292 of 3000 Total Reward: 840.1622666666675
# Episode: 293 of 3000 Total Reward: 869.2909000000635
# Episode: 294 of 3000 Total Reward: 945.5184000000961
# Episode: 295 of 3000 Total Reward: 954.3608333333109
# Episode: 296 of 3000 Total Reward: 921.9781333333265
# Episode: 297 of 3000 Total Reward: 958.8630000000268
# Episode: 298 of 3000 Total Reward: 865.1640000000722
# Episode: 299 of 3000 Total Reward: 895.4761666667513
# Episode: 300 of 3000 Total Reward: 967.279999999995
# Episode: 301 of 3000 Total Reward: 930.3161333333596
# Episode: 302 of 3000 Total Reward: 883.6540666667165
# Episode: 303 of 3000 Total Reward: 963.8924000000717
# Episode: 304 of 3000 Total Reward: 983.8989333332956
# Episode: 305 of 3000 Total Reward: 888.5125000000213
# Episode: 306 of 3000 Total Reward: 953.8908000000434
# Episode: 307 of 3000 Total Reward: 977.0828000001171
# Episode: 308 of 3000 Total Reward: 928.3346666667596
# Episode: 309 of 3000 Total Reward: 909.3577999999736
# Episode: 310 of 3000 Total Reward: 942.4623333333428
# Episode: 311 of 3000 Total Reward: 820.6564666667243
# Episode: 312 of 3000 Total Reward: 959.9832000000833
# Episode: 313 of 3000 Total Reward: 947.0122333332714
# Episode: 314 of 3000 Total Reward: 956.863000000006
# Episode: 315 of 3000 Total Reward: 871.7755000000197
# Episode: 316 of 3000 Total Reward: 921.9588000000924
# Episode: 317 of 3000 Total Reward: 951.8551000001193
# Episode: 318 of 3000 Total Reward: 955.6474000000073
# Episode: 319 of 3000 Total Reward: 970.0688666666637
# Episode: 320 of 3000 Total Reward: 936.3346666667263
# Episode: 321 of 3000 Total Reward: 939.3417000000806
# Episode: 322 of 3000 Total Reward: 873.8908000001302
# Episode: 323 of 3000 Total Reward: 913.9803000000214
# Episode: 324 of 3000 Total Reward: 916.4420000000035
# Episode: 325 of 3000 Total Reward: 1016.902500000077
# Episode: 326 of 3000 Total Reward: 868.5135333334202
# Episode: 327 of 3000 Total Reward: 906.5543999999899
# Episode: 328 of 3000 Total Reward: 932.9810666666754
# Episode: 329 of 3000 Total Reward: 930.9503000000684
# Episode: 330 of 3000 Total Reward: 1007.9180000000725
# Episode: 331 of 3000 Total Reward: 954.9502333334477
# Episode: 332 of 3000 Total Reward: 875.9518666666721
# Episode: 333 of 3000 Total Reward: 925.107600000025
# Episode: 334 of 3000 Total Reward: 893.8609333334276
# Episode: 335 of 3000 Total Reward: 931.624333333422
# Episode: 336 of 3000 Total Reward: 968.3735999999752
# Episode: 337 of 3000 Total Reward: 907.7309333333206
# Episode: 338 of 3000 Total Reward: 891.9345333333848
# Episode: 339 of 3000 Total Reward: 898.842000000059
# Episode: 340 of 3000 Total Reward: 915.8446666668104
# Episode: 341 of 3000 Total Reward: 919.4751333333244
# Episode: 342 of 3000 Total Reward: 868.3448000000027
# Episode: 343 of 3000 Total Reward: 923.4055333333993
# Episode: 344 of 3000 Total Reward: 916.1816000001005
# Episode: 345 of 3000 Total Reward: 835.8714999999916
# Episode: 346 of 3000 Total Reward: 864.4544666666411
# Episode: 347 of 3000 Total Reward: 928.0212000000404
# Episode: 348 of 3000 Total Reward: 958.4592000000973
# Episode: 349 of 3000 Total Reward: 969.1925000001339
# Episode: 350 of 3000 Total Reward: 899.0016666666734
# Episode: 351 of 3000 Total Reward: 902.3451000000292
# Episode: 352 of 3000 Total Reward: 913.7810666667369
# Episode: 353 of 3000 Total Reward: 876.2278333334084
# Episode: 354 of 3000 Total Reward: 986.0755999999722
# Episode: 355 of 3000 Total Reward: 866.9954999999977
# Episode: 356 of 3000 Total Reward: 978.6022666667361
# Episode: 357 of 3000 Total Reward: 902.5911000000824
# Episode: 358 of 3000 Total Reward: 879.845466666766
# Episode: 359 of 3000 Total Reward: 934.6413333333263
# Episode: 360 of 3000 Total Reward: 901.2880000000125
# Episode: 361 of 3000 Total Reward: 892.955100000074
# Episode: 362 of 3000 Total Reward: 929.5704000001009
# Episode: 363 of 3000 Total Reward: 891.7174999999627
# Episode: 364 of 3000 Total Reward: 920.857199999975
# Episode: 365 of 3000 Total Reward: 963.7436666667111
# Episode: 366 of 3000 Total Reward: 863.5204000000973
# Episode: 367 of 3000 Total Reward: 886.2032333334521
# Episode: 368 of 3000 Total Reward: 984.0141333333114
# Episode: 369 of 3000 Total Reward: 887.7674999999927
# Episode: 370 of 3000 Total Reward: 932.8700000000657
# Episode: 371 of 3000 Total Reward: 933.9827666667584
# Episode: 372 of 3000 Total Reward: 961.4251999999772
# Episode: 373 of 3000 Total Reward: 868.1316666666606
# Episode: 374 of 3000 Total Reward: 837.2198000000155
# Episode: 375 of 3000 Total Reward: 979.6875000000871
# Episode: 376 of 3000 Total Reward: 892.3506666667664
# Episode: 377 of 3000 Total Reward: 971.1791999999966
# Episode: 378 of 3000 Total Reward: 864.8216000000239
# Episode: 379 of 3000 Total Reward: 908.9241000000543
# Episode: 380 of 3000 Total Reward: 950.352000000071
# Episode: 381 of 3000 Total Reward: 901.5972999999597
# Episode: 382 of 3000 Total Reward: 955.1917333333554
# Episode: 383 of 3000 Total Reward: 878.3675666667011
# Episode: 384 of 3000 Total Reward: 954.2728000000998
# Episode: 385 of 3000 Total Reward: 893.1595000000843
# Episode: 386 of 3000 Total Reward: 894.3389333333092
# Episode: 387 of 3000 Total Reward: 846.4446000000014
# Episode: 388 of 3000 Total Reward: 860.405066666733
# Episode: 389 of 3000 Total Reward: 894.1050666667528
# Episode: 390 of 3000 Total Reward: 858.0989999999377
# Episode: 391 of 3000 Total Reward: 919.0283333333402
# Episode: 392 of 3000 Total Reward: 888.5744000000183
# Episode: 393 of 3000 Total Reward: 838.5781000000859
# Episode: 394 of 3000 Total Reward: 1012.3187333334372
# Episode: 395 of 3000 Total Reward: 871.1435000000067
# Episode: 396 of 3000 Total Reward: 909.9067999999929
# Episode: 397 of 3000 Total Reward: 856.2826333333816
# Episode: 398 of 3000 Total Reward: 925.837866666741
# Episode: 399 of 3000 Total Reward: 855.9260000001221
# Episode: 400 of 3000 Total Reward: 867.6866666666929
# Episode: 401 of 3000 Total Reward: 908.5953000000063
# Episode: 402 of 3000 Total Reward: 895.0550000000673
# Episode: 403 of 3000 Total Reward: 896.1564000000643
# Episode: 404 of 3000 Total Reward: 884.0753333333288
# Episode: 405 of 3000 Total Reward: 878.057500000006
# Episode: 406 of 3000 Total Reward: 800.8719333334005
# Episode: 407 of 3000 Total Reward: 865.1692000000452
# Episode: 408 of 3000 Total Reward: 865.2888000000988
# Episode: 409 of 3000 Total Reward: 853.7478000000026
# Episode: 410 of 3000 Total Reward: 795.4110000000217
# Episode: 411 of 3000 Total Reward: 864.9510000000753
# Episode: 412 of 3000 Total Reward: 923.104666666764
# Episode: 413 of 3000 Total Reward: 887.283599999981
# Episode: 414 of 3000 Total Reward: 831.1697999999873
# Episode: 415 of 3000 Total Reward: 824.6575000000477
# Episode: 416 of 3000 Total Reward: 824.0738666667206
# Episode: 417 of 3000 Total Reward: 882.2040000001155
# Episode: 418 of 3000 Total Reward: 884.2221333333258
# Episode: 419 of 3000 Total Reward: 895.1658000000093
# Episode: 420 of 3000 Total Reward: 849.4900000000619
# Episode: 421 of 3000 Total Reward: 866.915233333422
# Episode: 422 of 3000 Total Reward: 937.2201333333243
# Episode: 423 of 3000 Total Reward: 906.6629999999772
# Episode: 424 of 3000 Total Reward: 971.7773333333728
# Episode: 425 of 3000 Total Reward: 896.6916666667697
# Episode: 426 of 3000 Total Reward: 962.160800000131
# Episode: 427 of 3000 Total Reward: 963.1504666666763
# Episode: 428 of 3000 Total Reward: 800.4177333333505
# Episode: 429 of 3000 Total Reward: 887.0489000000694
# Episode: 430 of 3000 Total Reward: 870.6516666667472
# Episode: 431 of 3000 Total Reward: 928.4028666666435
# Episode: 432 of 3000 Total Reward: 970.7511999999986
# Episode: 433 of 3000 Total Reward: 897.2565000000556
# Episode: 434 of 3000 Total Reward: 834.5820000000787
# Episode: 435 of 3000 Total Reward: 795.255000000078
# Episode: 436 of 3000 Total Reward: 951.0762666666631
# Episode: 437 of 3000 Total Reward: 966.8465333333489
# Episode: 438 of 3000 Total Reward: 870.5166000000745
# Episode: 439 of 3000 Total Reward: 951.9198666667846
# Episode: 440 of 3000 Total Reward: 833.2279999999596
# Episode: 441 of 3000 Total Reward: 855.078099999977
# Episode: 442 of 3000 Total Reward: 864.5638000000364
# Episode: 443 of 3000 Total Reward: 780.6527666667617
# Episode: 444 of 3000 Total Reward: 865.1916000001274
# Episode: 445 of 3000 Total Reward: 881.5994999999749
# Episode: 446 of 3000 Total Reward: 887.4203999999955
# Episode: 447 of 3000 Total Reward: 925.3503000000695
# Episode: 448 of 3000 Total Reward: 881.6205333334151
# Episode: 449 of 3000 Total Reward: 789.8421999999772
# Episode: 450 of 3000 Total Reward: 921.9200000000018
# Episode: 451 of 3000 Total Reward: 842.7589666666838
# Episode: 452 of 3000 Total Reward: 809.3686666667325
# Episode: 453 of 3000 Total Reward: 872.9035000000948
# Episode: 454 of 3000 Total Reward: 754.0141333333245
# Episode: 455 of 3000 Total Reward: 932.9840000000266
# Episode: 456 of 3000 Total Reward: 865.6504000000474
# Episode: 457 of 3000 Total Reward: 869.3094000000613
# Episode: 458 of 3000 Total Reward: 867.3873333332917
# Episode: 459 of 3000 Total Reward: 916.3746000000214
# Episode: 460 of 3000 Total Reward: 845.0166666666994
# Episode: 461 of 3000 Total Reward: 867.2977000000993
# Episode: 462 of 3000 Total Reward: 865.8888000000738
# Episode: 463 of 3000 Total Reward: 821.890333333311
# Episode: 464 of 3000 Total Reward: 872.3138666666676
# Episode: 465 of 3000 Total Reward: 839.2595000000587
# Episode: 466 of 3000 Total Reward: 853.1762000000839
# Episode: 467 of 3000 Total Reward: 864.1292333332748
# Episode: 468 of 3000 Total Reward: 918.4632000000057
# Episode: 469 of 3000 Total Reward: 792.605200000013
# Episode: 470 of 3000 Total Reward: 887.4896666667534
# Episode: 471 of 3000 Total Reward: 877.6513000001063
# Episode: 472 of 3000 Total Reward: 868.5989333333428
# Episode: 473 of 3000 Total Reward: 953.6365333333312
# Episode: 474 of 3000 Total Reward: 881.2940000000514
# Episode: 475 of 3000 Total Reward: 804.1883333333923
# Episode: 476 of 3000 Total Reward: 901.788799999961
# Episode: 477 of 3000 Total Reward: 799.8695000000231
# Episode: 478 of 3000 Total Reward: 843.164266666666
# Episode: 479 of 3000 Total Reward: 881.2309333334028
# Episode: 480 of 3000 Total Reward: 843.5560000000706
# Episode: 481 of 3000 Total Reward: 882.6394999999924
# Episode: 482 of 3000 Total Reward: 880.1425333333384
# Episode: 483 of 3000 Total Reward: 796.7932000000702
# Episode: 484 of 3000 Total Reward: 825.2161333333856
# Episode: 485 of 3000 Total Reward: 929.3825000001239
# Episode: 486 of 3000 Total Reward: 810.5518000000063
# Episode: 487 of 3000 Total Reward: 831.5614000000255
# Episode: 488 of 3000 Total Reward: 816.4426666667398
# Episode: 489 of 3000 Total Reward: 807.9503000000767
# Episode: 490 of 3000 Total Reward: 818.078333333312
# Episode: 491 of 3000 Total Reward: 859.5474333333179
# Episode: 492 of 3000 Total Reward: 856.9652000000532
# Episode: 493 of 3000 Total Reward: 863.0347666667403
# Episode: 494 of 3000 Total Reward: 799.7194666667657
# Episode: 495 of 3000 Total Reward: 822.6404999999894
# Episode: 496 of 3000 Total Reward: 883.3570666666768
# Episode: 497 of 3000 Total Reward: 815.2171333333979
# Episode: 498 of 3000 Total Reward: 977.4132000001124
# Episode: 499 of 3000 Total Reward: 855.9207999999956
# Episode: 500 of 3000 Total Reward: 922.0499999999842
# Episode: 501 of 3000 Total Reward: 797.1046000000324
# Episode: 502 of 3000 Total Reward: 831.3739333334249
# Episode: 503 of 3000 Total Reward: 780.7836666667642
# Episode: 504 of 3000 Total Reward: 748.9536000000089
# Episode: 505 of 3000 Total Reward: 862.0693333333551
# Episode: 506 of 3000 Total Reward: 882.6907333334013
# Episode: 507 of 3000 Total Reward: 770.095700000065
# Episode: 508 of 3000 Total Reward: 838.5757333333116
# Episode: 509 of 3000 Total Reward: 763.299399999987
# Episode: 510 of 3000 Total Reward: 853.3630000000524
# Episode: 511 of 3000 Total Reward: 829.2069000000743
# Episode: 512 of 3000 Total Reward: 872.8258666667687
# Episode: 513 of 3000 Total Reward: 865.7737999999931
# Episode: 514 of 3000 Total Reward: 766.8925333333342
# Episode: 515 of 3000 Total Reward: 754.4371666667323
# Episode: 516 of 3000 Total Reward: 857.1112000000762
# Episode: 517 of 3000 Total Reward: 874.8456999999581
# Episode: 518 of 3000 Total Reward: 848.286733333307
# Episode: 519 of 3000 Total Reward: 850.3145000000303
# Episode: 520 of 3000 Total Reward: 839.3160000000997
# Episode: 521 of 3000 Total Reward: 761.0957666667503
# Episode: 522 of 3000 Total Reward: 881.104199999975
# Episode: 523 of 3000 Total Reward: 877.8089999999938
# Episode: 524 of 3000 Total Reward: 823.1606666667255
# Episode: 525 of 3000 Total Reward: 816.0025000000695
# Episode: 526 of 3000 Total Reward: 864.1377999999806
# Episode: 527 of 3000 Total Reward: 856.982899999992
# Episode: 528 of 3000 Total Reward: 867.5096000000228
# Episode: 529 of 3000 Total Reward: 810.939033333407
# Episode: 530 of 3000 Total Reward: 841.264666666746
# Episode: 531 of 3000 Total Reward: 869.5525999999961
# Episode: 532 of 3000 Total Reward: 828.5340000000247
# Episode: 533 of 3000 Total Reward: 787.44350000004
# Episode: 534 of 3000 Total Reward: 894.8450000000752
# Episode: 535 of 3000 Total Reward: 857.7706666666302
# Episode: 536 of 3000 Total Reward: 835.7978666666917
# Episode: 537 of 3000 Total Reward: 832.9638000000317
# Episode: 538 of 3000 Total Reward: 823.5864666667594
# Episode: 539 of 3000 Total Reward: 783.0883666667269
# Episode: 540 of 3000 Total Reward: 839.8659999999827
# Episode: 541 of 3000 Total Reward: 849.2652333333377
# Episode: 542 of 3000 Total Reward: 826.5192666667207
# Episode: 543 of 3000 Total Reward: 866.2427000000822
# Episode: 544 of 3000 Total Reward: 774.9202666666168
# Episode: 545 of 3000 Total Reward: 818.5293333333368
# Episode: 546 of 3000 Total Reward: 904.9460000000322
# Episode: 547 of 3000 Total Reward: 805.3156000000781
# Episode: 548 of 3000 Total Reward: 817.9452000001007
# Episode: 549 of 3000 Total Reward: 861.4428000000038
# Episode: 550 of 3000 Total Reward: 940.6199999999941
# Episode: 551 of 3000 Total Reward: 803.053633333376
# Episode: 552 of 3000 Total Reward: 861.3976000000677
# Episode: 553 of 3000 Total Reward: 859.607766666629
# Episode: 554 of 3000 Total Reward: 736.9044000000214
# Episode: 555 of 3000 Total Reward: 765.8789999999988
# Episode: 556 of 3000 Total Reward: 836.5282666667306
# Episode: 557 of 3000 Total Reward: 792.1724000000681
# Episode: 558 of 3000 Total Reward: 760.9643999999946
# Episode: 559 of 3000 Total Reward: 836.3995000000025
# Episode: 560 of 3000 Total Reward: 845.4306666667432
# Episode: 561 of 3000 Total Reward: 774.857000000042
# Episode: 562 of 3000 Total Reward: 830.0919333334386
# Episode: 563 of 3000 Total Reward: 764.721533333339
# Episode: 564 of 3000 Total Reward: 851.7380000000251
# Episode: 565 of 3000 Total Reward: 796.1535000000737
# Episode: 566 of 3000 Total Reward: 894.8968000000895
# Episode: 567 of 3000 Total Reward: 856.2135999999796
# Episode: 568 of 3000 Total Reward: 820.1695999999804
# Episode: 569 of 3000 Total Reward: 904.9788666667267
# Episode: 570 of 3000 Total Reward: 806.106000000054
# Episode: 571 of 3000 Total Reward: 758.5515666667817
# Episode: 572 of 3000 Total Reward: 856.7658666666579
# Episode: 573 of 3000 Total Reward: 786.0953000000072
# Episode: 574 of 3000 Total Reward: 802.0164000000569
# Episode: 575 of 3000 Total Reward: 822.4833333334237
# Episode: 576 of 3000 Total Reward: 866.9991999999946
# Episode: 577 of 3000 Total Reward: 869.4451333333071
# Episode: 578 of 3000 Total Reward: 803.0206666667015
# Episode: 579 of 3000 Total Reward: 858.8201000000956
# Episode: 580 of 3000 Total Reward: 792.4193333334425
# Episode: 581 of 3000 Total Reward: 751.0647666666786
# Episode: 582 of 3000 Total Reward: 826.0526000000191
# Episode: 583 of 3000 Total Reward: 815.2521333333816
# Episode: 584 of 3000 Total Reward: 798.6733333333827
# Episode: 585 of 3000 Total Reward: 821.5369999999764
# Episode: 586 of 3000 Total Reward: 815.5103333333277
# Episode: 587 of 3000 Total Reward: 848.3816666667261
# Episode: 588 of 3000 Total Reward: 814.0388000000785
# Episode: 589 of 3000 Total Reward: 811.0265666667532
# Episode: 590 of 3000 Total Reward: 801.307333333328
# Episode: 591 of 3000 Total Reward: 781.4689000000093
# Episode: 592 of 3000 Total Reward: 854.5229333334166
# Episode: 593 of 3000 Total Reward: 867.3701333334227
# Episode: 594 of 3000 Total Reward: 835.7565999999658
# Episode: 595 of 3000 Total Reward: 800.8214999999742
# Episode: 596 of 3000 Total Reward: 852.4541333333642
# Episode: 597 of 3000 Total Reward: 815.9809000000939
# Episode: 598 of 3000 Total Reward: 875.0456000001076
# Episode: 599 of 3000 Total Reward: 809.8840666666439
# Episode: 600 of 3000 Total Reward: 835.7199999999945
# Episode: 601 of 3000 Total Reward: 723.5685000000522
# Episode: 602 of 3000 Total Reward: 714.5584000000656
# Episode: 603 of 3000 Total Reward: 805.7002999999818
# Episode: 604 of 3000 Total Reward: 794.3006666666573
# Episode: 605 of 3000 Total Reward: 808.5851666666845
# Episode: 606 of 3000 Total Reward: 781.1482000000736
# Episode: 607 of 3000 Total Reward: 831.1304333334094
# Episode: 608 of 3000 Total Reward: 780.689333333327
# Episode: 609 of 3000 Total Reward: 689.6858000000101
# Episode: 610 of 3000 Total Reward: 796.6463333333762
# Episode: 611 of 3000 Total Reward: 792.3064666667217
# Episode: 612 of 3000 Total Reward: 815.1459999999628
# Episode: 613 of 3000 Total Reward: 769.6598333333253
# Episode: 614 of 3000 Total Reward: 842.7187333333651
# Episode: 615 of 3000 Total Reward: 735.409000000073
# Episode: 616 of 3000 Total Reward: 787.6605333333998
# Episode: 617 of 3000 Total Reward: 751.5282999999746
# Episode: 618 of 3000 Total Reward: 788.6190000000009
# Episode: 619 of 3000 Total Reward: 772.1757666667253
# Episode: 620 of 3000 Total Reward: 802.5366666667458
# Episode: 621 of 3000 Total Reward: 865.1514999999436
# Episode: 622 of 3000 Total Reward: 823.3808666666721
# Episode: 623 of 3000 Total Reward: 802.1154000000121
# Episode: 624 of 3000 Total Reward: 865.8360000000874
# Episode: 625 of 3000 Total Reward: 732.0041666667356
# Episode: 626 of 3000 Total Reward: 798.289800000009
# Episode: 627 of 3000 Total Reward: 801.8670999999855
# Episode: 628 of 3000 Total Reward: 820.7422666667153
# Episode: 629 of 3000 Total Reward: 806.866766666724
# Episode: 630 of 3000 Total Reward: 824.039999999971
# Episode: 631 of 3000 Total Reward: 829.637200000026
# Episode: 632 of 3000 Total Reward: 852.8938666666711
# Episode: 633 of 3000 Total Reward: 724.8155000000511
# Episode: 634 of 3000 Total Reward: 750.7526000000722
# Episode: 635 of 3000 Total Reward: 809.6284999999925
# Episode: 636 of 3000 Total Reward: 761.045199999998
# Episode: 637 of 3000 Total Reward: 667.0193666667158
# Episode: 638 of 3000 Total Reward: 868.0648000000547
# Episode: 639 of 3000 Total Reward: 792.4976000001029
# Episode: 640 of 3000 Total Reward: 809.6973333333368
# Episode: 641 of 3000 Total Reward: 724.8255333333468
# Episode: 642 of 3000 Total Reward: 775.8944000000874
# Episode: 643 of 3000 Total Reward: 719.5386000000634
# Episode: 644 of 3000 Total Reward: 764.7062666666452
# Episode: 645 of 3000 Total Reward: 791.9039999999862
# Episode: 646 of 3000 Total Reward: 786.6420000000503
# Episode: 647 of 3000 Total Reward: 796.2053666667182
# Episode: 648 of 3000 Total Reward: 806.6296000001095
# Episode: 649 of 3000 Total Reward: 854.7645666666606
# Episode: 650 of 3000 Total Reward: 742.609999999994
# Episode: 651 of 3000 Total Reward: 773.0948000000608
# Episode: 652 of 3000 Total Reward: 881.2760000001019
# Episode: 653 of 3000 Total Reward: 841.4018333333335
# Episode: 654 of 3000 Total Reward: 809.8739999999787
# Episode: 655 of 3000 Total Reward: 758.6603333333668
# Episode: 656 of 3000 Total Reward: 819.0797333334265
# Episode: 657 of 3000 Total Reward: 783.1423000001017
# Episode: 658 of 3000 Total Reward: 782.6318000000106
# Episode: 659 of 3000 Total Reward: 771.2978000000182
# Episode: 660 of 3000 Total Reward: 706.1000000000384
# Episode: 661 of 3000 Total Reward: 825.2579666667376
# Episode: 662 of 3000 Total Reward: 720.3503333333118
# Episode: 663 of 3000 Total Reward: 777.8542999999897
# Episode: 664 of 3000 Total Reward: 742.0461333333687
# Episode: 665 of 3000 Total Reward: 787.2256666667344
# Episode: 666 of 3000 Total Reward: 731.4292000000775
# Episode: 667 of 3000 Total Reward: 806.7382666666595
# Episode: 668 of 3000 Total Reward: 771.9129333333422
# Episode: 669 of 3000 Total Reward: 809.8190000000716
# Episode: 670 of 3000 Total Reward: 718.4253333334021
# Episode: 671 of 3000 Total Reward: 745.6578999999645
# Episode: 672 of 3000 Total Reward: 791.9287999999716
# Episode: 673 of 3000 Total Reward: 724.3400333333552
# Episode: 674 of 3000 Total Reward: 686.9117333334186
# Episode: 675 of 3000 Total Reward: 710.5950000000656
# Episode: 676 of 3000 Total Reward: 704.7242666666413
# Episode: 677 of 3000 Total Reward: 729.6475333333166
# Episode: 678 of 3000 Total Reward: 724.6370000000489
# Episode: 679 of 3000 Total Reward: 775.3435000000732
# Episode: 680 of 3000 Total Reward: 782.8893333333142
# Episode: 681 of 3000 Total Reward: 791.9492999999925
# Episode: 682 of 3000 Total Reward: 693.2075333333404
# Episode: 683 of 3000 Total Reward: 722.0313333333935
# Episode: 684 of 3000 Total Reward: 810.3724000000886
# Episode: 685 of 3000 Total Reward: 751.3686666666646
# Episode: 686 of 3000 Total Reward: 746.6991333333428
# Episode: 687 of 3000 Total Reward: 812.8714000000438
# Episode: 688 of 3000 Total Reward: 734.0045333334003
# Episode: 689 of 3000 Total Reward: 815.0003999999644
# Episode: 690 of 3000 Total Reward: 746.132999999965
# Episode: 691 of 3000 Total Reward: 818.8855333333663
# Episode: 692 of 3000 Total Reward: 749.2464000000857
# Episode: 693 of 3000 Total Reward: 748.1738000000591
# Episode: 694 of 3000 Total Reward: 813.3295333333111
# Episode: 695 of 3000 Total Reward: 750.0578333333327
# Episode: 696 of 3000 Total Reward: 787.577600000057
# Episode: 697 of 3000 Total Reward: 819.6692000000708
# Episode: 698 of 3000 Total Reward: 765.669733333284
# Episode: 699 of 3000 Total Reward: 700.2601000000079
# Episode: 700 of 3000 Total Reward: 757.1933333333416
# Episode: 701 of 3000 Total Reward: 790.1810000000804
# Episode: 702 of 3000 Total Reward: 791.7028000000874
# Episode: 703 of 3000 Total Reward: 758.8514333333425
# Episode: 704 of 3000 Total Reward: 790.557599999986
# Episode: 705 of 3000 Total Reward: 740.4265000000346
# Episode: 706 of 3000 Total Reward: 721.3322666667066
# Episode: 707 of 3000 Total Reward: 808.0370333332968
# Episode: 708 of 3000 Total Reward: 758.7788000000276
# Episode: 709 of 3000 Total Reward: 718.0063666666557
# Episode: 710 of 3000 Total Reward: 801.3093333333991
# Episode: 711 of 3000 Total Reward: 776.4077000000793
# Episode: 712 of 3000 Total Reward: 796.9485333333297
# Episode: 713 of 3000 Total Reward: 766.4216333333346
# Episode: 714 of 3000 Total Reward: 735.9014000000606
# Episode: 715 of 3000 Total Reward: 681.210666666691
# Episode: 716 of 3000 Total Reward: 792.8936000000863
# Episode: 717 of 3000 Total Reward: 762.6769000000128
# Episode: 718 of 3000 Total Reward: 765.640733333356
# Episode: 719 of 3000 Total Reward: 736.355566666742
# Episode: 720 of 3000 Total Reward: 720.6200000000484
# Episode: 721 of 3000 Total Reward: 699.663099999987
# Episode: 722 of 3000 Total Reward: 769.4350666666509
# Episode: 723 of 3000 Total Reward: 732.4322000000415
# Episode: 724 of 3000 Total Reward: 835.8050666667282
# Episode: 725 of 3000 Total Reward: 677.9475000000859
# Episode: 726 of 3000 Total Reward: 775.1329999999948
# Episode: 727 of 3000 Total Reward: 731.1317333333333
# Episode: 728 of 3000 Total Reward: 775.8488000000602
# Episode: 729 of 3000 Total Reward: 669.506600000066
# Episode: 730 of 3000 Total Reward: 801.244333333326
# Episode: 731 of 3000 Total Reward: 749.6129333333067
# Episode: 732 of 3000 Total Reward: 725.1904000000291
# Episode: 733 of 3000 Total Reward: 688.8583666667474
# Episode: 734 of 3000 Total Reward: 843.4951333334473
# Episode: 735 of 3000 Total Reward: 684.0950000000041
# Episode: 736 of 3000 Total Reward: 783.7181333333501
# Episode: 737 of 3000 Total Reward: 737.2516333333742
# Episode: 738 of 3000 Total Reward: 732.290600000052
# Episode: 739 of 3000 Total Reward: 795.4314333333101
# Episode: 740 of 3000 Total Reward: 759.6579999999938
# Episode: 741 of 3000 Total Reward: 769.0258000000481
# Episode: 742 of 3000 Total Reward: 778.2740666667435
# Episode: 743 of 3000 Total Reward: 677.7474000000711
# Episode: 744 of 3000 Total Reward: 729.5511999999944
# Episode: 745 of 3000 Total Reward: 714.2998333333279
# Episode: 746 of 3000 Total Reward: 744.1430666667345
# Episode: 747 of 3000 Total Reward: 694.4041000000599
# Episode: 748 of 3000 Total Reward: 719.152266666632
# Episode: 749 of 3000 Total Reward: 672.6289333333015
# Episode: 750 of 3000 Total Reward: 714.7000000000243
# Episode: 751 of 3000 Total Reward: 727.8238000000866
# Episode: 752 of 3000 Total Reward: 733.0018666667374
# Episode: 753 of 3000 Total Reward: 763.5315999999822
# Episode: 754 of 3000 Total Reward: 796.8787999999898
# Episode: 755 of 3000 Total Reward: 658.8288333333732
# Episode: 756 of 3000 Total Reward: 615.5784000000582
# Episode: 757 of 3000 Total Reward: 721.0329333333141
# Episode: 758 of 3000 Total Reward: 701.9161999999878
# Episode: 759 of 3000 Total Reward: 697.1865000000004
# Episode: 760 of 3000 Total Reward: 788.056000000078
# Episode: 761 of 3000 Total Reward: 723.1959666667556
# Episode: 762 of 3000 Total Reward: 674.5861999999996
# Episode: 763 of 3000 Total Reward: 734.9718333333536
# Episode: 764 of 3000 Total Reward: 712.130400000035
# Episode: 765 of 3000 Total Reward: 786.2775000000478
# Episode: 766 of 3000 Total Reward: 770.0183999999648
# Episode: 767 of 3000 Total Reward: 663.2718666666354
# Episode: 768 of 3000 Total Reward: 709.9592000000166
# Episode: 769 of 3000 Total Reward: 756.7662000000932
# Episode: 770 of 3000 Total Reward: 760.0380000000608
# Episode: 771 of 3000 Total Reward: 743.3043999999842
# Episode: 772 of 3000 Total Reward: 825.4278666666758
# Episode: 773 of 3000 Total Reward: 673.8290000000494
# Episode: 774 of 3000 Total Reward: 726.6528000000585
# Episode: 775 of 3000 Total Reward: 773.7433333332875
# Episode: 776 of 3000 Total Reward: 798.8770666666805
# Episode: 777 of 3000 Total Reward: 752.3269000000172
# Episode: 778 of 3000 Total Reward: 694.7604000000707
# Episode: 779 of 3000 Total Reward: 697.7990333333934
# Episode: 780 of 3000 Total Reward: 730.5180000000138
# Episode: 781 of 3000 Total Reward: 773.2857999999877
# Episode: 782 of 3000 Total Reward: 611.3816666666883
# Episode: 783 of 3000 Total Reward: 720.4121000000614
# Episode: 784 of 3000 Total Reward: 688.6423999999769
# Episode: 785 of 3000 Total Reward: 698.0656666666875
# Episode: 786 of 3000 Total Reward: 682.7495999999869
# Episode: 787 of 3000 Total Reward: 739.1501333333906
# Episode: 788 of 3000 Total Reward: 774.7298666667461
# Episode: 789 of 3000 Total Reward: 752.3621999999947
# Episode: 790 of 3000 Total Reward: 662.2513333333327
# Episode: 791 of 3000 Total Reward: 709.0960666667122
# Episode: 792 of 3000 Total Reward: 735.5704000000328
# Episode: 793 of 3000 Total Reward: 790.6992666667612
# Episode: 794 of 3000 Total Reward: 789.6696666666799
# Episode: 795 of 3000 Total Reward: 707.740500000014
# Episode: 796 of 3000 Total Reward: 724.1106666667321
# Episode: 797 of 3000 Total Reward: 718.8923000000382
# Episode: 798 of 3000 Total Reward: 700.9311999999821
# Episode: 799 of 3000 Total Reward: 684.7028666666437
# Episode: 800 of 3000 Total Reward: 698.6866666667096
# Episode: 801 of 3000 Total Reward: 741.0649000000566
# Episode: 802 of 3000 Total Reward: 743.9798000001155
# Episode: 803 of 3000 Total Reward: 764.2213666666592
# Episode: 804 of 3000 Total Reward: 731.7007999999935
# Episode: 805 of 3000 Total Reward: 759.3563333333971
# Episode: 806 of 3000 Total Reward: 743.3681333333979
# Episode: 807 of 3000 Total Reward: 667.6478999999974
# Episode: 808 of 3000 Total Reward: 668.7189333332968
# Episode: 809 of 3000 Total Reward: 681.4795000000225
# Episode: 810 of 3000 Total Reward: 785.2630000000893
# Episode: 811 of 3000 Total Reward: 730.4687666667631
# Episode: 812 of 3000 Total Reward: 673.2828000000062
# Episode: 813 of 3000 Total Reward: 717.3018000000134
# Episode: 814 of 3000 Total Reward: 696.6515333333659
# Episode: 815 of 3000 Total Reward: 680.3348333333848
# Episode: 816 of 3000 Total Reward: 733.6695999999793
# Episode: 817 of 3000 Total Reward: 638.9015333333048
# Episode: 818 of 3000 Total Reward: 755.8758000000511
# Episode: 819 of 3000 Total Reward: 712.8179000000661
# Episode: 820 of 3000 Total Reward: 610.6646666666979
# Episode: 821 of 3000 Total Reward: 732.435766666664
# Episode: 822 of 3000 Total Reward: 749.9752000000082
# Episode: 823 of 3000 Total Reward: 714.48426666675
# Episode: 824 of 3000 Total Reward: 718.0784000000552
# Episode: 825 of 3000 Total Reward: 756.9224999999725
# Episode: 826 of 3000 Total Reward: 684.4656666666297
# Episode: 827 of 3000 Total Reward: 698.1693000000273
# Episode: 828 of 3000 Total Reward: 681.9236000000742
# Episode: 829 of 3000 Total Reward: 666.8012666667136
# Episode: 830 of 3000 Total Reward: 721.4106666666476
# Episode: 831 of 3000 Total Reward: 707.9437999999808
# Episode: 832 of 3000 Total Reward: 781.4520000000605
# Episode: 833 of 3000 Total Reward: 700.180033333368
# Episode: 834 of 3000 Total Reward: 760.6239999999781
# Episode: 835 of 3000 Total Reward: 651.1024999999685
# Episode: 836 of 3000 Total Reward: 696.5817333333413
# Episode: 837 of 3000 Total Reward: 699.9371000000647
# Episode: 838 of 3000 Total Reward: 691.9623333333757
# Episode: 839 of 3000 Total Reward: 659.8918999999954
# Episode: 840 of 3000 Total Reward: 764.5000000000161
# Episode: 841 of 3000 Total Reward: 655.1110000000299
# Episode: 842 of 3000 Total Reward: 754.9544000000521
# Episode: 843 of 3000 Total Reward: 661.3207999999693
# Episode: 844 of 3000 Total Reward: 739.1949333333079
# Episode: 845 of 3000 Total Reward: 730.760833333357
# Episode: 846 of 3000 Total Reward: 726.423800000078
# Episode: 847 of 3000 Total Reward: 685.2802000000463
# Episode: 848 of 3000 Total Reward: 597.6418666666538
# Episode: 849 of 3000 Total Reward: 689.6504999999942
# Episode: 850 of 3000 Total Reward: 665.1766666667143
# Episode: 851 of 3000 Total Reward: 767.3662333334083
# Episode: 852 of 3000 Total Reward: 728.2871999999552
# Episode: 853 of 3000 Total Reward: 611.5032333333535
# Episode: 854 of 3000 Total Reward: 773.1484000000187
# Episode: 855 of 3000 Total Reward: 724.797500000074
# Episode: 856 of 3000 Total Reward: 727.2373333334075
# Episode: 857 of 3000 Total Reward: 770.0162999999961
# Episode: 858 of 3000 Total Reward: 636.1029999999753
# Episode: 859 of 3000 Total Reward: 654.9946333333617
# Episode: 860 of 3000 Total Reward: 657.2060000000387
# Episode: 861 of 3000 Total Reward: 742.1876999999736
# Episode: 862 of 3000 Total Reward: 734.7851333333597
# Episode: 863 of 3000 Total Reward: 754.5838333333361
# Episode: 864 of 3000 Total Reward: 605.0472000000431
# Episode: 865 of 3000 Total Reward: 637.1125000000243
# Episode: 866 of 3000 Total Reward: 708.6996000000003
# Episode: 867 of 3000 Total Reward: 707.2860999999996
# Episode: 868 of 3000 Total Reward: 658.6980000000486
# Episode: 869 of 3000 Total Reward: 780.5672000000366
# Episode: 870 of 3000 Total Reward: 670.0770000000829
# Episode: 871 of 3000 Total Reward: 640.6474666666825
# Episode: 872 of 3000 Total Reward: 633.3408000000001
# Episode: 873 of 3000 Total Reward: 723.007200000076
# Episode: 874 of 3000 Total Reward: 643.7107333333618
# Episode: 875 of 3000 Total Reward: 771.8458333333124
# Episode: 876 of 3000 Total Reward: 620.5267999999647
# Episode: 877 of 3000 Total Reward: 682.7889000000351
# Episode: 878 of 3000 Total Reward: 673.1110666666925
# Episode: 879 of 3000 Total Reward: 755.8334000001274
# Episode: 880 of 3000 Total Reward: 723.6493333333267
# Episode: 881 of 3000 Total Reward: 694.7671333333233
# Episode: 882 of 3000 Total Reward: 662.5788000000458
# Episode: 883 of 3000 Total Reward: 678.8303000000557
# Episode: 884 of 3000 Total Reward: 615.603199999997
# Episode: 885 of 3000 Total Reward: 698.6334999999718
# Episode: 886 of 3000 Total Reward: 623.8568000000193
# Episode: 887 of 3000 Total Reward: 625.2482000000632
# Episode: 888 of 3000 Total Reward: 674.9736000000679
# Episode: 889 of 3000 Total Reward: 628.4376333333437
# Episode: 890 of 3000 Total Reward: 724.5326666666764
# Episode: 891 of 3000 Total Reward: 735.5413000000423
# Episode: 892 of 3000 Total Reward: 636.5809333333541
# Episode: 893 of 3000 Total Reward: 732.643699999984
# Episode: 894 of 3000 Total Reward: 788.2275999999965
# Episode: 895 of 3000 Total Reward: 717.7458333333765
# Episode: 896 of 3000 Total Reward: 733.254666666731
# Episode: 897 of 3000 Total Reward: 682.1567000000707
# Episode: 898 of 3000 Total Reward: 758.2233333333314
# Episode: 899 of 3000 Total Reward: 692.2223333333382
# Episode: 900 of 3000 Total Reward: 717.1000000000697
# Episode: 901 of 3000 Total Reward: 666.9994666667137
# Episode: 902 of 3000 Total Reward: 608.1079333333015
# Episode: 903 of 3000 Total Reward: 621.2621999999624
# Episode: 904 of 3000 Total Reward: 699.6720000000236
# Episode: 905 of 3000 Total Reward: 691.1273333334211
# Episode: 906 of 3000 Total Reward: 640.7896000000329
# Episode: 907 of 3000 Total Reward: 693.564666666661
# ...
# Episode: 2713 of 3000 Total Reward: -156.18403333334035
# Episode: 2714 of 3000 Total Reward: -53.422599999990204
# Episode: 2715 of 3000 Total Reward: -49.83449999999738
# Episode: 2716 of 3000 Total Reward: -55.02173333332728
# Episode: 2717 of 3000 Total Reward: -65.5758999999992
# Episode: 2718 of 3000 Total Reward: -176.11860000000217
# Episode: 2719 of 3000 Total Reward: -146.56919999999974
# Episode: 2720 of 3000 Total Reward: -109.54533333333276
# Episode: 2721 of 3000 Total Reward: -44.19899999999797
# Episode: 2722 of 3000 Total Reward: -16.62959999999481
# Episode: 2723 of 3000 Total Reward: -168.81316666666922
# Episode: 2724 of 3000 Total Reward: -57.81199999999777
# Episode: 2725 of 3000 Total Reward: -156.57916666666793
# Episode: 2726 of 3000 Total Reward: -37.56706666666197
# Episode: 2727 of 3000 Total Reward: -166.7107999999938
# Episode: 2728 of 3000 Total Reward: -55.132000000001405
# Episode: 2729 of 3000 Total Reward: -84.27999999999533
# Episode: 2730 of 3000 Total Reward: -115.44699999999754
# Episode: 2731 of 3000 Total Reward: -71.3047999999934
# Episode: 2732 of 3000 Total Reward: -74.26506666666496
# Episode: 2733 of 3000 Total Reward: -168.74130000000142
# Episode: 2734 of 3000 Total Reward: -158.97860000000043
# Episode: 2735 of 3000 Total Reward: 18.16550000000652
# Episode: 2736 of 3000 Total Reward: -19.187999999995316
# Episode: 2737 of 3000 Total Reward: -248.7271000000054
# Episode: 2738 of 3000 Total Reward: -36.73506666666665
# Episode: 2739 of 3000 Total Reward: -22.067499999992965
# Episode: 2740 of 3000 Total Reward: -36.86266666666222
# Episode: 2741 of 3000 Total Reward: -41.47756666666694
# Episode: 2742 of 3000 Total Reward: -101.79400000000136
# Episode: 2743 of 3000 Total Reward: -91.11469999999738
# Episode: 2744 of 3000 Total Reward: -123.53759999999406
# Episode: 2745 of 3000 Total Reward: -53.535999999998914
# Episode: 2746 of 3000 Total Reward: -8.204866666665326
# Episode: 2747 of 3000 Total Reward: -143.09070000000776
# Episode: 2748 of 3000 Total Reward: -56.96239999999684
# Episode: 2749 of 3000 Total Reward: -172.29750000000774
# Episode: 2750 of 3000 Total Reward: -63.80833333333379
# Episode: 2751 of 3000 Total Reward: -74.2535999999977
# Episode: 2752 of 3000 Total Reward: -133.3149333333304
# Episode: 2753 of 3000 Total Reward: -41.550399999990965
# Episode: 2754 of 3000 Total Reward: -116.65519999999914
# Episode: 2755 of 3000 Total Reward: -47.72050000000116
# Episode: 2756 of 3000 Total Reward: -185.34266666667605
# Episode: 2757 of 3000 Total Reward: -135.26269999999636
# Episode: 2758 of 3000 Total Reward: -217.6686666666656
# Episode: 2759 of 3000 Total Reward: -53.30383333333085
# Episode: 2760 of 3000 Total Reward: -94.64799999999254
# Episode: 2761 of 3000 Total Reward: -230.8767333333299
# Episode: 2762 of 3000 Total Reward: -1.3201999999948797
# Episode: 2763 of 3000 Total Reward: -91.52030000000309
# Episode: 2764 of 3000 Total Reward: -128.64266666666683
# Episode: 2765 of 3000 Total Reward: -137.35400000000033
# Episode: 2766 of 3000 Total Reward: -131.02579999999764
# Episode: 2767 of 3000 Total Reward: -116.86623333333364
# Episode: 2768 of 3000 Total Reward: -113.34799999999836
# Episode: 2769 of 3000 Total Reward: -146.5404999999973
# Episode: 2770 of 3000 Total Reward: -139.87266666666483
# Episode: 2771 of 3000 Total Reward: -181.7025000000052
# Episode: 2772 of 3000 Total Reward: -93.12839999999835
# Episode: 2773 of 3000 Total Reward: -264.6740000000086
# Episode: 2774 of 3000 Total Reward: -42.67306666666585
# Episode: 2775 of 3000 Total Reward: -146.46999999999755
# Episode: 2776 of 3000 Total Reward: -46.82666666666419
# Episode: 2777 of 3000 Total Reward: -168.93509999999924
# Episode: 2778 of 3000 Total Reward: -135.67599999999877
# Episode: 2779 of 3000 Total Reward: -116.1158999999976
# Episode: 2780 of 3000 Total Reward: -194.6506666666749
# Episode: 2781 of 3000 Total Reward: -81.87549999999943
# Episode: 2782 of 3000 Total Reward: -79.69779999999696
# Episode: 2783 of 3000 Total Reward: -213.59343333334522
# Episode: 2784 of 3000 Total Reward: -38.51119999999743
# Episode: 2785 of 3000 Total Reward: -225.1026666666653
# Episode: 2786 of 3000 Total Reward: -63.67626666666875
# Episode: 2787 of 3000 Total Reward: -148.717699999994
# Episode: 2788 of 3000 Total Reward: -52.227466666664775
# Episode: 2789 of 3000 Total Reward: -7.213266666666368
# Episode: 2790 of 3000 Total Reward: -150.38500000000133
# Episode: 2791 of 3000 Total Reward: -179.78776666667693
# Episode: 2792 of 3000 Total Reward: -135.93173333333203
# Episode: 2793 of 3000 Total Reward: -136.3561000000006
# Episode: 2794 of 3000 Total Reward: -194.4024000000014
# Episode: 2795 of 3000 Total Reward: -95.88816666666477
# Episode: 2796 of 3000 Total Reward: -176.34959999999913
# Episode: 2797 of 3000 Total Reward: -117.90016666666769
# Episode: 2798 of 3000 Total Reward: -54.17673333333079
# Episode: 2799 of 3000 Total Reward: -169.03130000000792
# Episode: 2800 of 3000 Total Reward: -175.70000000000763
# Episode: 2801 of 3000 Total Reward: -243.86666666666414
# Episode: 2802 of 3000 Total Reward: -80.05579999999794
# Episode: 2803 of 3000 Total Reward: -70.61253333333016
# Episode: 2804 of 3000 Total Reward: -88.62026666665987
# Episode: 2805 of 3000 Total Reward: -76.30149999999902
# Episode: 2806 of 3000 Total Reward: -151.4698666666718
# Episode: 2807 of 3000 Total Reward: -67.05173333332934
# Episode: 2808 of 3000 Total Reward: -182.01280000000475
# Episode: 2809 of 3000 Total Reward: -63.730166666660025
# Episode: 2810 of 3000 Total Reward: -172.212666666667
# Episode: 2811 of 3000 Total Reward: -150.96559999999914
# Episode: 2812 of 3000 Total Reward: -140.138399999998
# Episode: 2813 of 3000 Total Reward: -34.11833333332836
# Episode: 2814 of 3000 Total Reward: -153.11200000000332
# Episode: 2815 of 3000 Total Reward: -195.67066666667156
# Episode: 2816 of 3000 Total Reward: -129.9464000000016
# Episode: 2817 of 3000 Total Reward: -161.54570000000177
# Episode: 2818 of 3000 Total Reward: -111.1413999999999
# Episode: 2819 of 3000 Total Reward: -125.6170999999992
# Episode: 2820 of 3000 Total Reward: -214.68199999999953
# Episode: 2821 of 3000 Total Reward: -131.07369999999807
# Episode: 2822 of 3000 Total Reward: -97.01293333333247
# Episode: 2823 of 3000 Total Reward: -105.559099999998
# Episode: 2824 of 3000 Total Reward: 12.731199999996566
# Episode: 2825 of 3000 Total Reward: -136.28583333333273
# Episode: 2826 of 3000 Total Reward: -241.040600000008
# Episode: 2827 of 3000 Total Reward: -177.49623333333273
# Episode: 2828 of 3000 Total Reward: -97.63066666666617
# Episode: 2829 of 3000 Total Reward: -212.90989999999894
# Episode: 2830 of 3000 Total Reward: -58.70066666665494
# Episode: 2831 of 3000 Total Reward: -184.93843333333902
# Episode: 2832 of 3000 Total Reward: -4.957600000002675
# Episode: 2833 of 3000 Total Reward: -63.79996666665831
# Episode: 2834 of 3000 Total Reward: -119.47446666666195
# Episode: 2835 of 3000 Total Reward: -99.5870000000013
# Episode: 2836 of 3000 Total Reward: -103.40906666666288
# Episode: 2837 of 3000 Total Reward: -261.51893333332856
# Episode: 2838 of 3000 Total Reward: -250.38639999999867
# Episode: 2839 of 3000 Total Reward: -211.29933333333943
# Episode: 2840 of 3000 Total Reward: -161.5026666666702
# Episode: 2841 of 3000 Total Reward: -148.55890000000136
# Episode: 2842 of 3000 Total Reward: -152.07653333334065
# Episode: 2843 of 3000 Total Reward: -74.62109999999593
# Episode: 2844 of 3000 Total Reward: -166.31679999999903
# Episode: 2845 of 3000 Total Reward: -276.5971666666657
# Episode: 2846 of 3000 Total Reward: -110.881999999995
# Episode: 2847 of 3000 Total Reward: -60.58369999999489
# Episode: 2848 of 3000 Total Reward: -199.6136000000056
# Episode: 2849 of 3000 Total Reward: -220.4216666666788
# Episode: 2850 of 3000 Total Reward: -151.31499999999923
# Episode: 2851 of 3000 Total Reward: -228.50086666667457
# Episode: 2852 of 3000 Total Reward: -36.27200000000005
# Episode: 2853 of 3000 Total Reward: -157.67399999999506
# Episode: 2854 of 3000 Total Reward: -127.77340000000231
# Episode: 2855 of 3000 Total Reward: -189.0006666666667
# Episode: 2856 of 3000 Total Reward: 9.036000000009015
# Episode: 2857 of 3000 Total Reward: -176.46770000000578
# Episode: 2858 of 3000 Total Reward: -133.55526666666694
# Episode: 2859 of 3000 Total Reward: -290.62660000000034
# Episode: 2860 of 3000 Total Reward: -137.92466666666644
# Episode: 2861 of 3000 Total Reward: -165.2674666666649
# Episode: 2862 of 3000 Total Reward: -109.61020000000251
# Episode: 2863 of 3000 Total Reward: -166.54303333333004
# Episode: 2864 of 3000 Total Reward: -127.27119999999834
# Episode: 2865 of 3000 Total Reward: -119.69200000000022
# Episode: 2866 of 3000 Total Reward: -133.57806666666465
# Episode: 2867 of 3000 Total Reward: -47.02419999999574
# Episode: 2868 of 3000 Total Reward: -212.25040000000644
# Episode: 2869 of 3000 Total Reward: -197.33766666667913
# Episode: 2870 of 3000 Total Reward: -156.85733333333337
# Episode: 2871 of 3000 Total Reward: -232.1750999999996
# Episode: 2872 of 3000 Total Reward: -115.46799999999551
# Episode: 2873 of 3000 Total Reward: -56.564333333329785
# Episode: 2874 of 3000 Total Reward: -150.16160000000286
# Episode: 2875 of 3000 Total Reward: -185.59166666667537
# Episode: 2876 of 3000 Total Reward: -218.7272000000094
# Episode: 2877 of 3000 Total Reward: -164.0842000000069
# Episode: 2878 of 3000 Total Reward: -95.73173333333308
# Episode: 2879 of 3000 Total Reward: -134.846066666669
# Episode: 2880 of 3000 Total Reward: -130.4999999999944
# Episode: 2881 of 3000 Total Reward: -242.8276999999963
# Episode: 2882 of 3000 Total Reward: -138.7321333333394
# Episode: 2883 of 3000 Total Reward: -231.09920000000335
# Episode: 2884 of 3000 Total Reward: -168.7613333333386
# Episode: 2885 of 3000 Total Reward: -84.0299999999993
# Episode: 2886 of 3000 Total Reward: -52.3849999999953
# Episode: 2887 of 3000 Total Reward: -200.07913333333383
# Episode: 2888 of 3000 Total Reward: -248.81226666666385
# Episode: 2889 of 3000 Total Reward: -229.70299999999875
# Episode: 2890 of 3000 Total Reward: -117.88133333332993
# Episode: 2891 of 3000 Total Reward: -142.62016666666983
# Episode: 2892 of 3000 Total Reward: -197.5740000000035
# Episode: 2893 of 3000 Total Reward: -5.133566666654907
# Episode: 2894 of 3000 Total Reward: -189.5323333333426
# Episode: 2895 of 3000 Total Reward: -144.06149999999653
# Episode: 2896 of 3000 Total Reward: -203.91973333332794
# Episode: 2897 of 3000 Total Reward: -172.1232666666689
# Episode: 2898 of 3000 Total Reward: -181.9540000000011
# Episode: 2899 of 3000 Total Reward: -191.14570000000253
# Episode: 2900 of 3000 Total Reward: -181.76333333334028
# Episode: 2901 of 3000 Total Reward: -143.3550000000029
# Episode: 2902 of 3000 Total Reward: -156.55053333332947
# Episode: 2903 of 3000 Total Reward: -195.2941666666732
# Episode: 2904 of 3000 Total Reward: -128.3608000000004
# Episode: 2905 of 3000 Total Reward: -247.76583333333056
# Episode: 2906 of 3000 Total Reward: -133.58866666666125
# Episode: 2907 of 3000 Total Reward: -207.5789000000005
# Episode: 2908 of 3000 Total Reward: -90.91506666666946
# Episode: 2909 of 3000 Total Reward: -141.41356666666962
# Episode: 2910 of 3000 Total Reward: -83.1079999999916
# Episode: 2911 of 3000 Total Reward: -203.60380000000453
# Episode: 2912 of 3000 Total Reward: -191.75866666666502
# Episode: 2913 of 3000 Total Reward: -157.42380000000043
# Episode: 2914 of 3000 Total Reward: -152.84779999999753
# Episode: 2915 of 3000 Total Reward: -125.98699999999786
# Episode: 2916 of 3000 Total Reward: -111.9467999999953
# Episode: 2917 of 3000 Total Reward: -159.64316666667062
# Episode: 2918 of 3000 Total Reward: -226.61493333334005
# Episode: 2919 of 3000 Total Reward: -172.08000000000715
# Episode: 2920 of 3000 Total Reward: -210.34000000001072
# Episode: 2921 of 3000 Total Reward: -233.1722666666629
# Episode: 2922 of 3000 Total Reward: -64.21699999999879
# Episode: 2923 of 3000 Total Reward: -162.06750000000096
# Episode: 2924 of 3000 Total Reward: -240.19973333333377
# Episode: 2925 of 3000 Total Reward: -77.29499999999896
# Episode: 2926 of 3000 Total Reward: -177.4594666666735
# Episode: 2927 of 3000 Total Reward: -212.39250000000945
# Episode: 2928 of 3000 Total Reward: -166.59280000000243
# Episode: 2929 of 3000 Total Reward: -261.08479999999633
# Episode: 2930 of 3000 Total Reward: -207.08900000000176
# Episode: 2931 of 3000 Total Reward: -226.43590000000253
# Episode: 2932 of 3000 Total Reward: -150.86293333333165
# Episode: 2933 of 3000 Total Reward: -173.5103666666691
# Episode: 2934 of 3000 Total Reward: -119.96920000000051
# Episode: 2935 of 3000 Total Reward: -226.45333333334332
# Episode: 2936 of 3000 Total Reward: -191.86613333334188
# Episode: 2937 of 3000 Total Reward: -161.20640000000483
# Episode: 2938 of 3000 Total Reward: -191.96653333333487
# Episode: 2939 of 3000 Total Reward: -289.1232333333448
# Episode: 2940 of 3000 Total Reward: -179.8760000000007
# Episode: 2941 of 3000 Total Reward: -277.4359000000061
# Episode: 2942 of 3000 Total Reward: -260.4169333333436
# Episode: 2943 of 3000 Total Reward: -263.7831000000004
# Episode: 2944 of 3000 Total Reward: -244.99653333334075
# Episode: 2945 of 3000 Total Reward: -156.3678333333311
# Episode: 2946 of 3000 Total Reward: -199.75720000001232
# Episode: 2947 of 3000 Total Reward: -127.58840000000066
# Episode: 2948 of 3000 Total Reward: -262.75733333334205
# Episode: 2949 of 3000 Total Reward: -151.6836999999995
# Episode: 2950 of 3000 Total Reward: -202.53999999999837
# Episode: 2951 of 3000 Total Reward: -109.74939999999938
# Episode: 2952 of 3000 Total Reward: -278.8376000000085
# Episode: 2953 of 3000 Total Reward: -136.74486666666508
# Episode: 2954 of 3000 Total Reward: -360.34586666666996
# Episode: 2955 of 3000 Total Reward: -174.3519999999986
# Episode: 2956 of 3000 Total Reward: -236.33720000000204
# Episode: 2957 of 3000 Total Reward: -185.50240000000144
# Episode: 2958 of 3000 Total Reward: -179.95420000000126
# Episode: 2959 of 3000 Total Reward: -171.4747666666727
# Episode: 2960 of 3000 Total Reward: -128.16400000000357
# Episode: 2961 of 3000 Total Reward: -196.26020000001162
# Episode: 2962 of 3000 Total Reward: -253.61320000001183
# Episode: 2963 of 3000 Total Reward: -239.2639000000121
# Episode: 2964 of 3000 Total Reward: -181.3511999999995
# Episode: 2965 of 3000 Total Reward: -139.62100000000044
# Episode: 2966 of 3000 Total Reward: -222.3873999999995
# Episode: 2967 of 3000 Total Reward: -321.7120999999984
# Episode: 2968 of 3000 Total Reward: -173.38453333333902
# Episode: 2969 of 3000 Total Reward: -138.52753333333496
# Episode: 2970 of 3000 Total Reward: -217.92500000000348
# Episode: 2971 of 3000 Total Reward: -201.19046666667296
# Episode: 2972 of 3000 Total Reward: -187.70466666666346
# Episode: 2973 of 3000 Total Reward: -238.61609999999445
# Episode: 2974 of 3000 Total Reward: -206.64479999999884
# Episode: 2975 of 3000 Total Reward: -118.36916666665805
# Episode: 2976 of 3000 Total Reward: -195.05519999999996
# Episode: 2977 of 3000 Total Reward: -239.0652000000079
# Episode: 2978 of 3000 Total Reward: -162.44826666667075
# Episode: 2979 of 3000 Total Reward: -217.08970000000525
# Episode: 2980 of 3000 Total Reward: -223.55333333334076
# Episode: 2981 of 3000 Total Reward: -267.47749999999763
# Episode: 2982 of 3000 Total Reward: -239.98639999999946
# Episode: 2983 of 3000 Total Reward: -238.5540333333298
# Episode: 2984 of 3000 Total Reward: -147.90399999999815
# Episode: 2985 of 3000 Total Reward: -111.29300000000254
# Episode: 2986 of 3000 Total Reward: -191.4906000000087
# Episode: 2987 of 3000 Total Reward: -82.83923333333146
# Episode: 2988 of 3000 Total Reward: -99.4587999999949
# Episode: 2989 of 3000 Total Reward: -225.74589999999554
# Episode: 2990 of 3000 Total Reward: -208.6506666666666
# Episode: 2991 of 3000 Total Reward: -187.81249999999986
# Episode: 2992 of 3000 Total Reward: -138.96613333333232
# Episode: 2993 of 3000 Total Reward: -232.6448333333375
# Episode: 2994 of 3000 Total Reward: -227.5560000000056
# Episode: 2995 of 3000 Total Reward: -210.4908333333403
# Episode: 2996 of 3000 Total Reward: -214.51320000000914
# Episode: 2997 of 3000 Total Reward: -136.54929999999763
# Episode: 2998 of 3000 Total Reward: -135.86759999999902
# Episode: 2999 of 3000 Total Reward: -187.97756666666834
# Episode: 3000 of 3000 Total Reward: -235.69999999999095

# %%
# Calculate average reward
average_reward = total_reward_all / num_episodes
print("Average reward:", average_reward)
# Out:
# Average reward: 422.6100505444505

# %%
# Function to predict Status
def predict_status(observation, agent):
    state = observation.values[:-1]  # Menggunakan fitur dari observasi sebagai state
    state = np.reshape(state, (1, len(state)))  # Reshape state menjadi bentuk (1, num_features)
    state = scaler.transform(state)  # Normalisasi state
    action = agent.act(state)  # Prediksi tindakan menggunakan agen
    return action  # Mengembalikan aksi sebagai prediksi Status

# %%
# Contoh prediksi Status berdasarkan observasi ke-10 dari dataset
observation = dataset.iloc[10]  # Ambil observasi ke-10 dari dataset
predicted_status = predict_status(observation, agent)  # Prediksi Status menggunakan fungsi predict_status
actual_status = observation['Status']  # Status yang sebenarnya dari observasi dalam dataset
print("Predicted Status for observation 10:", predicted_status)
print("Actual Status for observation 10:", actual_status)
# Out:
# Predicted Status for observation 10: 1
# Actual Status for observation 10: 0.0
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Fungsi untuk hitung akurasi
def calculate_accuracy(dataset, agent):
    correct_predictions = 0
    total_predictions = len(dataset)

    for index, observation in dataset.iterrows():
        state = observation.values[:-1]  # Menggunakan fitur dari observasi sebagai state
        state = np.reshape(state, (1, len(state)))  # Pastikan state di-reshape ke bentuk (1, num_features)
        predicted_Status = agent.act(state)  # Prediksi Status menggunakan agen
        actual_Status = observation['Status']  # Nilai Status aktual dari dataset
        if predicted_Status == actual_Status:
            correct_predictions += 1

    accuracy = (correct_predictions / total_predictions) * 100
    return accuracy

# %%
# Menggunakan fungsi calculate_accuracy untuk menghitung akurasi
accuracy = calculate_accuracy(dataset, agent)
print("Accuracy:", accuracy, "%")
# Out:
# Accuracy: 51.23104743357908 %

# %%
# Membuat list untuk menyimpan hasil prediksi
predicted_labels = []

# %%
# Loop melalui setiap observasi dalam dataset dan membuat prediksi
for index, observation in dataset.iterrows():
    predicted_status = predict_status(observation, agent)  # Melakukan prediksi Status
    predicted_labels.append(predicted_status)
# Out:
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Membuat DataFrame dari list hasil prediksi
predicted_labels_df = pd.DataFrame(predicted_labels, columns=['Status'])

# %%
# Output hasil prediksi dalam format yang diminta
print(predicted_labels_df)
# Out:
#       Status
# 0          1
# 1          1
# 2          1
# 3          0
# 4          0
# ...      ...
# 7184       1
# 7185       0
# 7186       1
# 7187       0
# 7188       1
#
# [7189 rows x 1 columns]

# %%
# Gabungkan kolom Status dari dataset asli dengan kolom Status dari predicted_labels_df
comparison_df = pd.concat([dataset['Status'], predicted_labels_df['Status']], axis=1)
comparison_df.columns = ['Actual_Status', 'Predicted_Status']

# %%
# Hitung jumlah status yang sama dan yang berbeda
same_status = comparison_df[comparison_df['Actual_Status'] == comparison_df['Predicted_Status']].shape[0]
different_status = comparison_df[comparison_df['Actual_Status'] != comparison_df['Predicted_Status']].shape[0]

# %% [markdown]
# 1

# %%
same_status / len(comparison_df) * 100
# Out:
# 49.32535818611768

# %%
# Buat visualisasi
plt.figure(figsize=(8, 6))
labels = ['Same Status', 'Different Status']
sizes = [same_status, different_status]
colors = ['lightgreen', 'lightcoral']
explode = (0, 0.1)  # Pisahkan "Different Status"
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Comparison of Actual and Predicted Status')
plt.show()

# %%
import matplotlib.pyplot as plt

# Hitung jumlah status 0 dan 1 dari predicted_labels_df
healthy_count = predicted_labels_df[predicted_labels_df['Status'] == 0].shape[0]
unhealthy_count = predicted_labels_df[predicted_labels_df['Status'] == 1].shape[0]

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns


# Menghitung dan menampilkan confusion matrix untuk data validasi
cm_val = confusion_matrix(comparison_df['Actual_Status'], comparison_df['Predicted_Status'])
print("Confusion Matrix - Validation Data")
print(cm_val)

# Menampilkan confusion matrix sebagai heatmap untuk data validasi
plt.figure(figsize=(10, 8))
sns.heatmap(cm_val, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Validation Data')
plt.show()

# Menghitung dan menampilkan classification report untuk data validasi
print("Classification Report - Validation Data")
report_val = classification_report(comparison_df['Actual_Status'], comparison_df['Predicted_Status'])
print(report_val)
# Out:
# Confusion Matrix - Validation Data
# [[3076 3157]
#  [ 486  470]]
# Classification Report - Validation Data
#               precision    recall  f1-score   support
#
#            0       0.86      0.49      0.63      6233
#            1       0.13      0.49      0.21       956
#
#     accuracy                           0.49      7189
#    macro avg       0.50      0.49      0.42      7189
# weighted avg       0.77      0.49      0.57      7189

# %%
# Data untuk plot
status_labels = ['0', '1']
status_counts = [healthy_count, unhealthy_count]

# %%
# Plot batang
plt.bar(status_labels, status_counts, color=['green', 'red'])

# Tambahkan label angka di atas setiap batang
for i in range(len(status_labels)):
    plt.text(i, status_counts[i], str(status_counts[i]), ha='center', va='bottom')

# Label sumbu dan judul
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Jumlah Status 0 dan 1')

# Tampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt
# s
# Hitung jumlah status 0 dan 1 dari predicted_labels_df
healthy_count = predicted_labels_df[predicted_labels_df['Status'] == 0].shape[0]
unhealthy_count = predicted_labels_df[predicted_labels_df['Status'] == 1].shape[0]

# Data untuk plot
status_labels = ['Healthy', 'Unhealthy']
status_counts = [healthy_count, unhealthy_count]
colors = ['lightgreen', 'lightcoral']

# Plot donut chart
plt.figure(figsize=(8, 6))
plt.pie(status_counts, labels=status_labels, colors=colors, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
plt.gca().add_artist(plt.Circle((0, 0), 0.6, fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Jumlah Status Healthy dan Unhealthy setelah DQN')
plt.show()

# %%
# Menampilkan heatmap dari tabel Q
import seaborn as sns

# Dapatkan bobot dari model jaringan saraf
def get_q_table(model, num_actions):
    # Ambil layer ke-2 (indeks 1) dari model, yang merupakan layer pertama setelah input
    first_layer = model.layers[1]
    # Dapatkan bobot dari layer
    weights = first_layer.get_weights()[0]
    # Ubah bobot menjadi format yang sesuai untuk tabel Q
    q_table = weights.reshape((-1, num_actions))
    return q_table

# Fungsi untuk menampilkan heatmap dari tabel Q
def plot_q_table_heatmap(q_table):
    plt.figure(figsize=(10, 6))
    sns.heatmap(q_table, cmap='viridis', annot=True, fmt=".2f", cbar=False)
    plt.xlabel('Actions')
    plt.ylabel('States')
    plt.title('Heatmap of Q Table')
    plt.show()

# Dapatkan tabel Q dari model agen
q_table = get_q_table(agent.model, num_actions)

# Reduksi dimensi state labels menjadi 1-10
state_labels_reduced = ['State {}'.format(i+1) for i in range(10)]

# Ambil subset dari q_table untuk hanya menampilkan 10 state pertama
q_table_subset = q_table[:10]

# Tampilkan heatmap dari tabel Q
plot_q_table_heatmap(q_table_subset)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 24
#      21     plt.show()
#      23 # Dapatkan tabel Q dari model agen
# ---> 24 q_table = get_q_table(agent.model, num_actions)
#      26 # Reduksi dimensi state labels menjadi 1-10
#      27 state_labels_reduced = ['State {}'.format(i+1) for i in range(10)]
#
# Cell In[38], line 9, in get_q_table(model, num_actions)
#       7 first_layer = model.layers[1]
#       8 # Dapatkan bobot dari layer
# ----> 9 weights = first_layer.get_weights()[0]
#      10 # Ubah bobot menjadi format yang sesuai untuk tabel Q
#      11 q_table = weights.reshape((-1, num_actions))
#
# IndexError: list index out of range

# %%
# Pilih state yang ingin divisualisasikan, misalnya state ke-10
state_index = 10

# Dapatkan Q-values untuk state tersebut
q_values = q_table[state_index, :]

# Tentukan actions (dalam kasus Anda, hanya 2 actions)
actions = ['Action 0', 'Action 1']

# Plot barplot dari Q-values
plt.figure(figsize=(10, 6))
sns.barplot(x=actions, y=q_values)
plt.title(f'Q-values for State {state_index}')
plt.xlabel('Actions')
plt.ylabel('Q-value')
plt.show()
