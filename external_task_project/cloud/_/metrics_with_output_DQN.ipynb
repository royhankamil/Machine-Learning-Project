# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from collections import deque
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
df = pd.read_csv("metrics-with-output.csv")
df
# Out:
#                      Time      Timestamp cpu_usage memory_usage  \
# 0     2023-09-08 01:16:00  1694110560000     9.00%        53.5%
# 1     2023-09-08 01:16:05  1694110565000     16.6%        53.3%
# 2     2023-09-08 01:16:10  1694110570000     20.2%        55.3%
# 3     2023-09-08 01:16:15  1694110575000     14.6%        58.0%
# 4     2023-09-08 01:16:20  1694110580000     10.2%        53.5%
# ...                   ...            ...       ...          ...
# 7184  2023-09-08 11:14:40  1694146480000     22.2%        53.5%
# 7185  2023-09-08 11:14:45  1694146485000     27.2%        56.0%
# 7186  2023-09-08 11:14:50  1694146490000     7.20%        54.1%
# 7187  2023-09-08 11:14:55  1694146495000     23.4%        54.6%
# 7188  2023-09-08 11:15:00  1694146500000     31.0%        53.8%
#
#      bandwidth_inbound bandwidth_outbound         tps tps_error response_time  \
# 0            7.46 GB/s          6.45 GB/s     2 req/s   0 req/s        607 ms
# 1            5.85 GB/s          5.27 GB/s  2.20 req/s   0 req/s        2.09 s
# 2            9.06 GB/s          7.96 GB/s  3.20 req/s   0 req/s        3.45 s
# 3            8.41 GB/s          7.21 GB/s  3.20 req/s   0 req/s        2.58 s
# 4            4.88 GB/s          4.30 GB/s  2.60 req/s   0 req/s        862 ms
# ...                ...                ...         ...       ...           ...
# 7184         6.52 GB/s          5.67 GB/s  2.40 req/s   0 req/s        1.51 s
# 7185         7.37 GB/s          6.49 GB/s  2.60 req/s   0 req/s        1.21 s
# 7186         4.76 GB/s          4.02 GB/s  1.40 req/s   0 req/s        285 ms
# 7187         6.75 GB/s          5.90 GB/s  2.40 req/s   0 req/s        804 ms
# 7188         7.76 GB/s          6.92 GB/s  3.20 req/s   0 req/s        2.64 s
#
#       Status
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 7184       0
# 7185       0
# 7186       0
# 7187       0
# 7188       0
#
# [7189 rows x 10 columns]

# %%
# Menampilkan baris pertama dr dataset
df.head()
# Out:
#                   Time      Timestamp cpu_usage memory_usage  \
# 0  2023-09-08 01:16:00  1694110560000     9.00%        53.5%
# 1  2023-09-08 01:16:05  1694110565000     16.6%        53.3%
# 2  2023-09-08 01:16:10  1694110570000     20.2%        55.3%
# 3  2023-09-08 01:16:15  1694110575000     14.6%        58.0%
# 4  2023-09-08 01:16:20  1694110580000     10.2%        53.5%
#
#   bandwidth_inbound bandwidth_outbound         tps tps_error response_time  \
# 0         7.46 GB/s          6.45 GB/s     2 req/s   0 req/s        607 ms
# 1         5.85 GB/s          5.27 GB/s  2.20 req/s   0 req/s        2.09 s
# 2         9.06 GB/s          7.96 GB/s  3.20 req/s   0 req/s        3.45 s
# 3         8.41 GB/s          7.21 GB/s  3.20 req/s   0 req/s        2.58 s
# 4         4.88 GB/s          4.30 GB/s  2.60 req/s   0 req/s        862 ms
#
#    Status
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import matplotlib.pyplot as plt

#Membandingkan jumlah status Healthy dan Unhealthy dengan donut chart
status_counts = df['Status'].value_counts()

colors = ['red','blue']
plt.pie(status_counts, labels=status_counts.index, colors=colors, autopct='%1.1f%%', startangle=90)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Distribution of Status')
plt.show()

# %%
# Preprocessing data: clean and convert to numeric
df['cpu_usage'] = df['cpu_usage'].str.rstrip('%').astype('float') / 100.0
df['memory_usage'] = df['memory_usage'].str.rstrip('%').astype('float') / 100.0

def clean_bandwidth(value):
    if 'GB/s' in value:
        return float(value.replace('GB/s', ''))
    elif 'MB/s' in value:
        return float(value.replace('MB/s', '')) / 1024  # Convert MB/s to GB/s
    else:
        return float(value)

df['bandwidth_inbound'] = df['bandwidth_inbound'].apply(clean_bandwidth)
df['bandwidth_outbound'] = df['bandwidth_outbound'].apply(clean_bandwidth)
df['tps'] = df['tps'].str.rstrip(' req/s').astype('float')
df['tps_error'] = df['tps_error'].str.rstrip(' req/s').astype('float')
df['response_time'] = df['response_time'].replace({' ms': '*1e-3', ' s': '*1'}, regex=True).map(pd.eval).astype('float')

# Drop irrelevant columns (if any)
dataset = df.drop(df.columns[[0, 1]], axis=1)

# Normalize the dataset
scaler = MinMaxScaler()
features = dataset.drop('Status', axis=1)
normalized_features = scaler.fit_transform(features)

# Replace the non-normalized features with the normalized ones in the dataset
normalized_dataset = pd.DataFrame(normalized_features, columns=features.columns)
normalized_dataset['Status'] = dataset['Status'].values  # Add the 'Status' column back

# Display the normalized dataset
print(normalized_dataset.head())
# Out:
#    cpu_usage  memory_usage  bandwidth_inbound  bandwidth_outbound       tps  \
# 0   0.080808      0.187192           0.363939            0.364287  0.269231
# 1   0.157576      0.177340           0.284799            0.297010  0.307692
# 2   0.193939      0.275862           0.442586            0.450379  0.500000
# 3   0.137374      0.408867           0.410635            0.407618  0.500000
# 4   0.092929      0.187192           0.237119            0.241705  0.384615
#
#    tps_error  response_time  Status
# 0        0.0       0.070037       0
# 1        0.0       0.282441       0
# 2        0.0       0.477227       0
# 3        0.0       0.352621       0
# 4        0.0       0.106560       0

# %%
# Info dataset mengenai tipe, jumlah kolom dll
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7189 entries, 0 to 7188
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                7189 non-null   object
#  1   Timestamp           7189 non-null   int64
#  2   cpu_usage           7189 non-null   float64
#  3   memory_usage        7189 non-null   float64
#  4   bandwidth_inbound   7189 non-null   float64
#  5   bandwidth_outbound  7189 non-null   float64
#  6   tps                 7189 non-null   float64
#  7   tps_error           7189 non-null   float64
#  8   response_time       7189 non-null   float64
#  9   Status              7189 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 561.8+ KB

# %%
# Menampilkan dataset setelah proses konversi dan pembersihan data
print(df)
# Out:
#                      Time      Timestamp  cpu_usage  memory_usage  \
# 0     2023-09-08 01:16:00  1694110560000      0.090         0.535
# 1     2023-09-08 01:16:05  1694110565000      0.166         0.533
# 2     2023-09-08 01:16:10  1694110570000      0.202         0.553
# 3     2023-09-08 01:16:15  1694110575000      0.146         0.580
# 4     2023-09-08 01:16:20  1694110580000      0.102         0.535
# ...                   ...            ...        ...           ...
# 7184  2023-09-08 11:14:40  1694146480000      0.222         0.535
# 7185  2023-09-08 11:14:45  1694146485000      0.272         0.560
# 7186  2023-09-08 11:14:50  1694146490000      0.072         0.541
# 7187  2023-09-08 11:14:55  1694146495000      0.234         0.546
# 7188  2023-09-08 11:15:00  1694146500000      0.310         0.538
#
#       bandwidth_inbound  bandwidth_outbound  tps  tps_error  response_time  \
# 0                  7.46                6.45  2.0        0.0          0.607
# 1                  5.85                5.27  2.2        0.0          2.090
# 2                  9.06                7.96  3.2        0.0          3.450
# 3                  8.41                7.21  3.2        0.0          2.580
# 4                  4.88                4.30  2.6        0.0          0.862
# ...                 ...                 ...  ...        ...            ...
# 7184               6.52                5.67  2.4        0.0          1.510
# 7185               7.37                6.49  2.6        0.0          1.210
# 7186               4.76                4.02  1.4        0.0          0.285
# 7187               6.75                5.90  2.4        0.0          0.804
# 7188               7.76                6.92  3.2        0.0          2.640
#
#       Status
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 7184       0
# 7185       0
# 7186       0
# 7187       0
# 7188       0
#
# [7189 rows x 10 columns]

# %%
# Pembersihan/Penghapusan data yang tidak dipakai
dataset = df.drop(df.columns[[0, 1]], axis=1)

dataset.describe()
# Out:
#          cpu_usage  memory_usage  bandwidth_inbound  bandwidth_outbound  \
# count  7189.000000   7189.000000        7189.000000         7189.000000
# mean      0.163090      0.542723           6.318377            5.573617
# std       0.069272      0.019356           3.193037            2.728239
# min       0.010000      0.497000           0.056055            0.060645
# 25%       0.118000      0.533000           3.940000            3.540000
# 50%       0.156000      0.539000           5.910000            5.230000
# 75%       0.198000      0.549000           8.310000            7.260000
# max       1.000000      0.700000          20.400000           17.600000
#
#                tps    tps_error  response_time       Status
# count  7189.000000  7189.000000    7189.000000  7189.000000
# mean      2.490218     0.170817       1.770724     0.132981
# std       0.784028     0.548970       1.024615     0.339578
# min       0.600000     0.000000       0.118000     0.000000
# 25%       2.000000     0.000000       0.952000     0.000000
# 50%       2.400000     0.000000       1.520000     0.000000
# 75%       3.000000     0.000000       2.450000     0.000000
# max       5.800000     4.600000       7.100000     1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# Encode 'Status' column into numeric values
label_encoder = LabelEncoder()
dataset['Status'] = label_encoder.fit_transform(dataset['Status'])

# %%
dataset['Status']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7184    0
# 7185    0
# 7186    0
# 7187    0
# 7188    0
# Name: Status, Length: 7189, dtype: int64

# %%
# Periksa apakah ada data yang hilang
missing_data = dataset.isnull().sum()
if missing_data.any():
    print("Data terdapat missing values yang perlu diimputasi:")
    print(missing_data)
else:
    print("Tidak ada missing values dalam dataset.")
# Out:
# Tidak ada missing values dalam dataset.

# %%
# Split data menjadi features (X) dan target (y)
X = dataset.drop('Status', axis=1)
y = dataset['Status']

# %%
# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=123)

# %%
# Definisikan Environment Class
class Environment:
    def __init__(self, dataset, class_weights, total_epochs):
        self.dataset = dataset
        self.num_samples = len(dataset)
        self.current_sample_idx = None  # Set indeks sampel saat ini ke None saat inisialisasi
        self.class_weights = class_weights  # Bobot kelas
        self.total_epochs = total_epochs  # Total jumlah epoch
        self.current_epoch = 0  # Epoch saat ini, dimulai dari 0

    def reset(self):
        self.current_sample_idx = 0  # Set ulang indeks sampel saat memulai episode baru
        self.current_epoch += 1  # Tambahkan epoch setiap kali reset
        initial_observation = self.dataset.iloc[self.current_sample_idx]  # Ambil observasi awal
        return initial_observation, 0, False

    def step(self, action):
        # Ambil label aktual dan prediksi agen
        actual = self.dataset.iloc[self.current_sample_idx]['Status']  # Menggunakan kolom 'Status' yang ada di dataset
        predicted = action  # Asumsikan 'action' adalah prediksi agen

        # Update indeks sampel
        self.current_sample_idx = (self.current_sample_idx + 1) % self.num_samples
        next_observation = self.dataset.iloc[self.current_sample_idx]
        
        # Hitung reward berdasarkan observasi dan aksi
        reward = self.calculate_reward(
            actual, predicted, self.class_weights, self.current_epoch, self.total_epochs
        )
        
        # Atur done menjadi True jika mencapai akhir episode
        done = self.current_sample_idx == 0
        
        return next_observation, reward, done

    def calculate_reward(self, actual, predicted, class_weights, current_epoch, total_epochs):
        """
        Fungsi reward yang dinamis berdasarkan distribusi kelas dan epoch saat ini.
        
        Parameters:
        - actual: Nilai aktual dari label (0 atau 1).
        - predicted: Prediksi agen (0 atau 1).
        - class_weights: Bobot kelas untuk menangani ketidakseimbangan.
        - current_epoch: Epoch pelatihan saat ini.
        - total_epochs: Total jumlah epoch.
        
        Returns:
        - reward: Nilai reward yang dihitung.
        """
        # Penalty dasar untuk kesalahan
        base_penalty = -1
        base_reward = 1
        
        # Jika prediksi benar
        if predicted == actual:
            if actual == 1:
                # Reward lebih tinggi untuk kelas `1` karena lebih jarang
                reward = base_reward * class_weights[1]
            else:
                # Reward lebih rendah untuk kelas `0` karena lebih sering
                reward = base_reward * class_weights[0]
        else:
            # Jika prediksi salah, berikan penalti
            if predicted == 1:
                # Penalti lebih besar untuk memprediksi `1` dengan salah
                penalty = base_penalty * class_weights[1]
            else:
                # Penalti lebih kecil untuk memprediksi `0` dengan salah
                penalty = base_penalty * class_weights[0]

            # Menggabungkan penalti dengan epoch saat ini
            reward = penalty * (1 + (current_epoch / total_epochs))
        
        return reward

# %%
import tensorflow as tf  # Tambahkan import TensorFlow

class DQNAgent:
    def __init__(self, state_size, action_size, class_weights=None):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_min = 0.1
        self.epsilon_decay = 0.99
        self.learning_rate = 0.001
        self.class_weights = class_weights
        self.model = self._build_model()

    def custom_loss(y_true, y_pred):
        # Misalnya weight untuk kelas 0 = 0.2, dan kelas 1 = 0.8
        weights = tf.where(tf.equal(y_true, 0), 0.2, 0.8)
        loss = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        return tf.reduce_mean(loss * weights)


    def _build_model(self):
        model = tf.keras.models.Sequential()
        
        # Adding layers with LeakyReLU activation
        model.add(tf.keras.layers.Dense(128, input_dim=self.state_size))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(256))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(128))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(self.action_size, activation='linear'))
        
        model.compile(loss=self.custom_loss, optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        # Separate experiences by label
        experiences_class_0 = [exp for exp in self.memory if exp[3]['Status'] == 0]
        experiences_class_1 = [exp for exp in self.memory if exp[3]['Status'] == 1]

        # Oversample class 0 experiences
        if len(experiences_class_0) < batch_size:
            minibatch = random.sample(experiences_class_0 * (batch_size // len(experiences_class_0)), batch_size)
        else:
            minibatch = random.sample(experiences_class_0, batch_size // 2)
            minibatch += random.sample(experiences_class_1, batch_size // 2)
        
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
# Parameters
num_actions = 2  # Number of possible actions
num_features = len(dataset.columns) - 1  # Number of features in the dataset (excluding classification)
batch_size = 40
num_episodes = 3000
max_steps = 2000

# %%
# Initialize environment and agent
class_weights = {0:0.7 , 1: 0.3} # Contoh untuk menghitung bobot
env = Environment(dataset, class_weights, num_episodes)
agent = DQNAgent(state_size=num_features, action_size=num_actions, class_weights=class_weights)

# %%
# Training loop
total_reward_all = 0
for episode in range(num_episodes):
    state, _, _ = env.reset()  # Reset the environment and get initial state
    total_reward = 0
    done = False
    while not done:
        action = agent.act(state)
        next_state, reward, done = env.step(action)  # Take action and get next state, reward, and done status
        agent.remember(state, action, reward, next_state, done)  # Remember the experience
        state = next_state  # Update the current state
        total_reward += reward  # Accumulate total reward for the episode
    total_reward_all += total_reward
    print("Episode:", episode+1, "of", num_episodes, "Total Reward:", total_reward)
# Out:
# Episode: 1 of 3000 Total Reward: 1043.475399999991
# Episode: 2 of 3000 Total Reward: 1052.052866666683
# Episode: 3 of 3000 Total Reward: 1109.6495000000402
# Episode: 4 of 3000 Total Reward: 1113.2300000000944
# Episode: 5 of 3000 Total Reward: 1065.7736666666037
# Episode: 6 of 3000 Total Reward: 1076.3910000000076
# Episode: 7 of 3000 Total Reward: 1057.9630333333605
# Episode: 8 of 3000 Total Reward: 1043.513066666761
# Episode: 9 of 3000 Total Reward: 1040.102600000123
# Episode: 10 of 3000 Total Reward: 1036.6790000000026
# Episode: 11 of 3000 Total Reward: 1037.238933333331
# Episode: 12 of 3000 Total Reward: 1057.8404000000517
# Episode: 13 of 3000 Total Reward: 1000.3498666667481
# Episode: 14 of 3000 Total Reward: 1042.9700666668155
# Episode: 15 of 3000 Total Reward: 989.4230000000218
# Episode: 16 of 3000 Total Reward: 1009.0509333333433
# Episode: 17 of 3000 Total Reward: 910.4313333333996
# Episode: 18 of 3000 Total Reward: 1068.3028000001168
# Episode: 19 of 3000 Total Reward: 1058.8763000000006
# Episode: 20 of 3000 Total Reward: 1034.3980000000156
# Episode: 21 of 3000 Total Reward: 1106.1717000000542
# Episode: 22 of 3000 Total Reward: 1010.5441333333844
# Episode: 23 of 3000 Total Reward: 1040.1786666667917
# Episode: 24 of 3000 Total Reward: 998.5136000000056
# Episode: 25 of 3000 Total Reward: 1069.398333333364
# Episode: 26 of 3000 Total Reward: 1066.043266666764
# Episode: 27 of 3000 Total Reward: 1065.492500000095
# Episode: 28 of 3000 Total Reward: 1111.254800000005
# Episode: 29 of 3000 Total Reward: 1042.6301000000035
# Episode: 30 of 3000 Total Reward: 1010.9900000000612
# Episode: 31 of 3000 Total Reward: 1029.924433333451
# Episode: 32 of 3000 Total Reward: 950.9320000001355
# Episode: 33 of 3000 Total Reward: 1104.2247999999936
# Episode: 34 of 3000 Total Reward: 1093.663066666684
# Episode: 35 of 3000 Total Reward: 1039.1906666667412
# Episode: 36 of 3000 Total Reward: 1040.648000000119
# Episode: 37 of 3000 Total Reward: 1034.1774666666538
# Episode: 38 of 3000 Total Reward: 1135.1414000000134
# Episode: 39 of 3000 Total Reward: 1033.3016000000407
# Episode: 40 of 3000 Total Reward: 984.6360000001039
# Episode: 41 of 3000 Total Reward: 957.2467666667776
# Episode: 42 of 3000 Total Reward: 1080.3496000000025
# Episode: 43 of 3000 Total Reward: 1121.0564333333753
# Episode: 44 of 3000 Total Reward: 1048.4302666667356
# Episode: 45 of 3000 Total Reward: 989.449500000088
# Episode: 46 of 3000 Total Reward: 1052.4726666666497
# Episode: 47 of 3000 Total Reward: 1140.63940000003
# Episode: 48 of 3000 Total Reward: 1020.485600000058
# Episode: 49 of 3000 Total Reward: 1084.2824333334106
# Episode: 50 of 3000 Total Reward: 1103.1033333334358
# Episode: 51 of 3000 Total Reward: 1071.474899999993
# Episode: 52 of 3000 Total Reward: 1091.2073333333515
# Episode: 53 of 3000 Total Reward: 996.320233333423
# Episode: 54 of 3000 Total Reward: 1082.4090000001158
# Episode: 55 of 3000 Total Reward: 1164.4875000000086
# Episode: 56 of 3000 Total Reward: 1071.4154666666714
# Episode: 57 of 3000 Total Reward: 1081.8992000000776
# Episode: 58 of 3000 Total Reward: 1035.4201333334381
# Episode: 59 of 3000 Total Reward: 1076.4130333334429
# Episode: 60 of 3000 Total Reward: 1037.5459999999694
# Episode: 61 of 3000 Total Reward: 995.7432000000077
# Episode: 62 of 3000 Total Reward: 994.217266666737
# Episode: 63 of 3000 Total Reward: 1081.5618000001023
# Episode: 64 of 3000 Total Reward: 1086.2525333333306
# Episode: 65 of 3000 Total Reward: 1018.3486666666628
# Episode: 66 of 3000 Total Reward: 1016.7334000000294
# Episode: 67 of 3000 Total Reward: 971.1480666667491
# Episode: 68 of 3000 Total Reward: 951.571600000109
# Episode: 69 of 3000 Total Reward: 969.9125999999947
# Episode: 70 of 3000 Total Reward: 1059.4090000000303
# Episode: 71 of 3000 Total Reward: 1061.3521666667223
# Episode: 72 of 3000 Total Reward: 1006.4512000000753
# Episode: 73 of 3000 Total Reward: 1005.7460333332845
# Episode: 74 of 3000 Total Reward: 948.094800000017
# Episode: 75 of 3000 Total Reward: 1032.3750000000475
# Episode: 76 of 3000 Total Reward: 1020.7697333334428
# Episode: 77 of 3000 Total Reward: 1056.8808333334239
# Episode: 78 of 3000 Total Reward: 988.6199999999822
# Episode: 79 of 3000 Total Reward: 1086.6515333333546
# Episode: 80 of 3000 Total Reward: 1036.3106666667416
# Episode: 81 of 3000 Total Reward: 1049.0069000001065
# Episode: 82 of 3000 Total Reward: 1075.7005333332884
# Episode: 83 of 3000 Total Reward: 986.3538666666681
# Episode: 84 of 3000 Total Reward: 945.4664000000186
# Episode: 85 of 3000 Total Reward: 996.7721666667586
# Episode: 86 of 3000 Total Reward: 977.7566000001269
# Episode: 87 of 3000 Total Reward: 1068.6993000000016
# Episode: 88 of 3000 Total Reward: 1015.426666666661
# Episode: 89 of 3000 Total Reward: 1050.6802000000614
# Episode: 90 of 3000 Total Reward: 1067.223000000093
# Episode: 91 of 3000 Total Reward: 1044.8104333334868
# Episode: 92 of 3000 Total Reward: 995.8889333333531
# Episode: 93 of 3000 Total Reward: 917.4140000000062
# Episode: 94 of 3000 Total Reward: 1024.4764000000794
# Episode: 95 of 3000 Total Reward: 992.8385000001003
# Episode: 96 of 3000 Total Reward: 1066.9095999999863
# Episode: 97 of 3000 Total Reward: 1068.4089666666857
# Episode: 98 of 3000 Total Reward: 1029.6452666667435
# Episode: 99 of 3000 Total Reward: 1022.0098000000702
# Episode: 100 of 3000 Total Reward: 1043.9666666667983
# Episode: 101 of 3000 Total Reward: 936.0862000000014
# Episode: 102 of 3000 Total Reward: 1004.5364000000304
# Episode: 103 of 3000 Total Reward: 1012.4408666667586
# Episode: 104 of 3000 Total Reward: 994.550933333424
# Episode: 105 of 3000 Total Reward: 1003.3729999999672
# Episode: 106 of 3000 Total Reward: 973.7404666666596
# Episode: 107 of 3000 Total Reward: 925.4263333333913
# Episode: 108 of 3000 Total Reward: 1073.9108000001252
# Episode: 109 of 3000 Total Reward: 988.1426333334705
# Episode: 110 of 3000 Total Reward: 996.8859999999846
# Episode: 111 of 3000 Total Reward: 1040.3059000000144
# Episode: 112 of 3000 Total Reward: 1044.748000000078
# Episode: 113 of 3000 Total Reward: 1009.1725666667796
# Episode: 114 of 3000 Total Reward: 992.6133999999859
# Episode: 115 of 3000 Total Reward: 1062.9181666666454
# Episode: 116 of 3000 Total Reward: 987.6580000000394
# Episode: 117 of 3000 Total Reward: 1025.631300000103
# Episode: 118 of 3000 Total Reward: 1083.4020000001383
# Episode: 119 of 3000 Total Reward: 986.4162333333444
# Episode: 120 of 3000 Total Reward: 1013.9600000000324
# Episode: 121 of 3000 Total Reward: 969.0676333334017
# Episode: 122 of 3000 Total Reward: 982.5986000000847
# Episode: 123 of 3000 Total Reward: 952.292899999973
# Episode: 124 of 3000 Total Reward: 1039.8447999999992
# Episode: 125 of 3000 Total Reward: 953.5625000000562
# Episode: 126 of 3000 Total Reward: 1009.6566000000854
# Episode: 127 of 3000 Total Reward: 1020.2552000001294
# Episode: 128 of 3000 Total Reward: 993.9095999999885
# Episode: 129 of 3000 Total Reward: 1029.0425000000166
# Episode: 130 of 3000 Total Reward: 1039.525333333421
# Episode: 131 of 3000 Total Reward: 968.8538333334448
# Episode: 132 of 3000 Total Reward: 963.0431999999578
# Episode: 133 of 3000 Total Reward: 1024.1375333333144
# Episode: 134 of 3000 Total Reward: 1037.1247333333797
# Episode: 135 of 3000 Total Reward: 1040.0245000001148
# Episode: 136 of 3000 Total Reward: 950.5333333334611
# Episode: 137 of 3000 Total Reward: 1088.6249666666704
# Episode: 138 of 3000 Total Reward: 951.0016000000054
# Episode: 139 of 3000 Total Reward: 1023.538533333406
# Episode: 140 of 3000 Total Reward: 1007.2120000001016
# Episode: 141 of 3000 Total Reward: 1085.3097999999814
# Episode: 142 of 3000 Total Reward: 1038.2221333333353
# Episode: 143 of 3000 Total Reward: 1029.8972000000294
# Episode: 144 of 3000 Total Reward: 1007.8680000000844
# Episode: 145 of 3000 Total Reward: 976.3813333334376
# Episode: 146 of 3000 Total Reward: 1004.5994666666605
# Episode: 147 of 3000 Total Reward: 1017.2727000000303
# Episode: 148 of 3000 Total Reward: 944.309333333383
# Episode: 149 of 3000 Total Reward: 941.7902666667486
# Episode: 150 of 3000 Total Reward: 982.4199999999543
# Episode: 151 of 3000 Total Reward: 1047.8977666666917
# Episode: 152 of 3000 Total Reward: 1013.2677333333777
# Episode: 153 of 3000 Total Reward: 929.2273000001105
# Episode: 154 of 3000 Total Reward: 1038.3380666667683
# Episode: 155 of 3000 Total Reward: 1032.8206666666576
# Episode: 156 of 3000 Total Reward: 942.8824000000075
# Episode: 157 of 3000 Total Reward: 962.787733333408
# Episode: 158 of 3000 Total Reward: 1021.6558666667712
# Episode: 159 of 3000 Total Reward: 952.2401999999415
# Episode: 160 of 3000 Total Reward: 973.4840000000013
# Episode: 161 of 3000 Total Reward: 1013.5215000000239
# Episode: 162 of 3000 Total Reward: 958.9636000000917
# Episode: 163 of 3000 Total Reward: 1000.4889000001191
# Episode: 164 of 3000 Total Reward: 924.789999999999
# Episode: 165 of 3000 Total Reward: 978.1929999999913
# Episode: 166 of 3000 Total Reward: 990.410866666726
# Episode: 167 of 3000 Total Reward: 973.7635666667304
# Episode: 168 of 3000 Total Reward: 994.8024000001427
# Episode: 169 of 3000 Total Reward: 992.3454000000249
# Episode: 170 of 3000 Total Reward: 976.73500000001
# Episode: 171 of 3000 Total Reward: 983.7950000000728
# Episode: 172 of 3000 Total Reward: 1025.1473333334322
# Episode: 173 of 3000 Total Reward: 1043.4821999999992
# Episode: 174 of 3000 Total Reward: 1009.721400000017
# Episode: 175 of 3000 Total Reward: 1013.5575000000736
# Episode: 176 of 3000 Total Reward: 896.8269333333834
# Episode: 177 of 3000 Total Reward: 961.0054000001202
# Episode: 178 of 3000 Total Reward: 917.9980666666695
# Episode: 179 of 3000 Total Reward: 921.502800000024
# Episode: 180 of 3000 Total Reward: 1012.5040000000973
# Episode: 181 of 3000 Total Reward: 968.6250666667504
# Episode: 182 of 3000 Total Reward: 995.472133333302
# Episode: 183 of 3000 Total Reward: 928.2038999999911
# Episode: 184 of 3000 Total Reward: 967.8104000000566
# Episode: 185 of 3000 Total Reward: 1053.9091666667898
# Episode: 186 of 3000 Total Reward: 1033.1210000001329
# Episode: 187 of 3000 Total Reward: 922.8577666666534
# Episode: 188 of 3000 Total Reward: 1024.9113333333428
# Episode: 189 of 3000 Total Reward: 956.1151000000783
# Episode: 190 of 3000 Total Reward: 1046.5250000001126
# Episode: 191 of 3000 Total Reward: 973.1451999999892
# Episode: 192 of 3000 Total Reward: 937.7367999999778
# Episode: 193 of 3000 Total Reward: 1031.393266666711
# Episode: 194 of 3000 Total Reward: 1004.7821333334401
# Episode: 195 of 3000 Total Reward: 986.6165000001332
# Episode: 196 of 3000 Total Reward: 953.5673333333417
# Episode: 197 of 3000 Total Reward: 914.7350333333536
# Episode: 198 of 3000 Total Reward: 891.5026000000668
# Episode: 199 of 3000 Total Reward: 980.0148666667611
# Episode: 200 of 3000 Total Reward: 983.6466666666388
# Episode: 201 of 3000 Total Reward: 931.8183999999927
# Episode: 202 of 3000 Total Reward: 961.5684666667221
# Episode: 203 of 3000 Total Reward: 965.8144666667499
# Episode: 204 of 3000 Total Reward: 966.3292000001115
# Episode: 205 of 3000 Total Reward: 942.6884999999895
# Episode: 206 of 3000 Total Reward: 1035.3482000000174
# Episode: 207 of 3000 Total Reward: 985.9117000000939
# Episode: 208 of 3000 Total Reward: 939.0285333334385
# Episode: 209 of 3000 Total Reward: 974.3707999999534
# Episode: 210 of 3000 Total Reward: 962.1609999999786
# Episode: 211 of 3000 Total Reward: 927.2825333333748
# Episode: 212 of 3000 Total Reward: 1006.3334666667798
# Episode: 213 of 3000 Total Reward: 1000.0435000001478
# Episode: 214 of 3000 Total Reward: 963.3637333333091
# Episode: 215 of 3000 Total Reward: 974.252666666676
# Episode: 216 of 3000 Total Reward: 1004.8352000000767
# Episode: 217 of 3000 Total Reward: 961.8341333334275
# Episode: 218 of 3000 Total Reward: 924.7994666666456
# Episode: 219 of 3000 Total Reward: 886.1532999999941
# Episode: 220 of 3000 Total Reward: 935.6273333333565
# Episode: 221 of 3000 Total Reward: 970.5348666667506
# Episode: 222 of 3000 Total Reward: 919.1800000001164
# Episode: 223 of 3000 Total Reward: 913.5823666666583
# Episode: 224 of 3000 Total Reward: 975.9693333333591
# Episode: 225 of 3000 Total Reward: 1010.9175000000532
# Episode: 226 of 3000 Total Reward: 953.3246000000698
# Episode: 227 of 3000 Total Reward: 1004.9685999999626
# Episode: 228 of 3000 Total Reward: 981.6536000000219
# Episode: 229 of 3000 Total Reward: 936.437600000042
# Episode: 230 of 3000 Total Reward: 939.1423333334404
# Episode: 231 of 3000 Total Reward: 988.2881000000915
# Episode: 232 of 3000 Total Reward: 925.1453333333033
# Episode: 233 of 3000 Total Reward: 1002.9875333333439
# Episode: 234 of 3000 Total Reward: 916.0756000000674
# Episode: 235 of 3000 Total Reward: 949.6020000000982
# Episode: 236 of 3000 Total Reward: 957.2529333332743
# Episode: 237 of 3000 Total Reward: 930.5430000000065
# Episode: 238 of 3000 Total Reward: 984.6306000000305
# Episode: 239 of 3000 Total Reward: 987.5678000000916
# Episode: 240 of 3000 Total Reward: 961.7400000001076
# Episode: 241 of 3000 Total Reward: 987.5595000000131
# Episode: 242 of 3000 Total Reward: 1011.8571999999966
# Episode: 243 of 3000 Total Reward: 959.7951000000553
# Episode: 244 of 3000 Total Reward: 943.7937333334086
# Episode: 245 of 3000 Total Reward: 991.7840000001464
# Episode: 246 of 3000 Total Reward: 991.4656000000216
# Episode: 247 of 3000 Total Reward: 864.6196666666664
# Episode: 248 of 3000 Total Reward: 972.5496000000796
# Episode: 249 of 3000 Total Reward: 967.996300000088
# Episode: 250 of 3000 Total Reward: 903.2333333333218
# Episode: 251 of 3000 Total Reward: 932.4676333333394
# Episode: 252 of 3000 Total Reward: 986.345600000078
# Episode: 253 of 3000 Total Reward: 832.1787666667038
# Episode: 254 of 3000 Total Reward: 915.001733333441
# Episode: 255 of 3000 Total Reward: 993.6045000000116
# Episode: 256 of 3000 Total Reward: 965.833866666698
# Episode: 257 of 3000 Total Reward: 939.6002000000923
# Episode: 258 of 3000 Total Reward: 1031.638400000096
# Episode: 259 of 3000 Total Reward: 922.3775333333052
# Episode: 260 of 3000 Total Reward: 1026.1560000000031
# Episode: 261 of 3000 Total Reward: 944.7493000000547
# Episode: 262 of 3000 Total Reward: 900.4102666667816
# Episode: 263 of 3000 Total Reward: 938.5633333334623
# Episode: 264 of 3000 Total Reward: 978.2399999999951
# Episode: 265 of 3000 Total Reward: 964.6530000000066
# Episode: 266 of 3000 Total Reward: 866.635266666734
# Episode: 267 of 3000 Total Reward: 954.8992000001006
# Episode: 268 of 3000 Total Reward: 953.1970666666571
# Episode: 269 of 3000 Total Reward: 944.9199999999794
# Episode: 270 of 3000 Total Reward: 991.3460000000449
# Episode: 271 of 3000 Total Reward: 966.7846000001049
# Episode: 272 of 3000 Total Reward: 974.7416000001283
# Episode: 273 of 3000 Total Reward: 900.5383000000061
# Episode: 274 of 3000 Total Reward: 966.2764666667023
# Episode: 275 of 3000 Total Reward: 915.2450000000641
# Episode: 276 of 3000 Total Reward: 922.5264000000972
# Episode: 277 of 3000 Total Reward: 971.511033333309
# Episode: 278 of 3000 Total Reward: 890.285866666662
# Episode: 279 of 3000 Total Reward: 932.8923000000565
# Episode: 280 of 3000 Total Reward: 972.3000000000861
# Episode: 281 of 3000 Total Reward: 907.259566666769
# Episode: 282 of 3000 Total Reward: 929.9183999999927
# Episode: 283 of 3000 Total Reward: 918.4362666666731
# Episode: 284 of 3000 Total Reward: 877.1870666667534
# Episode: 285 of 3000 Total Reward: 907.499500000093
# Episode: 286 of 3000 Total Reward: 1006.5055333332966
# Episode: 287 of 3000 Total Reward: 934.4607333333117
# Episode: 288 of 3000 Total Reward: 902.6440000000351
# Episode: 289 of 3000 Total Reward: 901.514400000099
# Episode: 290 of 3000 Total Reward: 1012.8496666667968
# Episode: 291 of 3000 Total Reward: 865.1782999999724
# Episode: 292 of 3000 Total Reward: 995.087333333346
# Episode: 293 of 3000 Total Reward: 967.8573666667403
# Episode: 294 of 3000 Total Reward: 966.106400000096
# Episode: 295 of 3000 Total Reward: 934.203499999974
# Episode: 296 of 3000 Total Reward: 1028.6224000000068
# Episode: 297 of 3000 Total Reward: 960.6451000000226
# Episode: 298 of 3000 Total Reward: 919.6639333334206
# Episode: 299 of 3000 Total Reward: 1033.4429000001273
# Episode: 300 of 3000 Total Reward: 930.4799999999906
# Episode: 301 of 3000 Total Reward: 963.9616000000254

# %%
# Calculate average reward
average_reward = total_reward_all / num_episodes
print("Average reward:", average_reward)
# Out:
# Average reward: -2218.9183683444558

# %%
# Function to predict Status
def predict_status(observation, agent):
    state = observation.values[:-1]  # Menggunakan fitur dari observasi sebagai state
    state = np.reshape(state, (1, len(state)))  # Reshape state menjadi bentuk (1, num_features)
    state = scaler.transform(state)  # Normalisasi state
    action = agent.act(state)  # Prediksi tindakan menggunakan agen
    return action  # Mengembalikan aksi sebagai prediksi Status

# %%
# Contoh prediksi Status berdasarkan observasi ke-10 dari dataset
observation = dataset.iloc[10]  # Ambil observasi ke-10 dari dataset
predicted_status = predict_status(observation, agent)  # Prediksi Status menggunakan fungsi predict_status
actual_status = observation['Status']  # Status yang sebenarnya dari observasi dalam dataset
print("Predicted Status for observation 10:", predicted_status)
print("Actual Status for observation 10:", actual_status)
# Out:
# Predicted Status for observation 10: 0
# Actual Status for observation 10: 0.0
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Fungsi untuk hitung akurasi
def calculate_accuracy(dataset, agent):
    correct_predictions = 0
    total_predictions = len(dataset)

    for index, observation in dataset.iterrows():
        state = observation.values[:-1]  # Menggunakan fitur dari observasi sebagai state
        state = np.reshape(state, (1, len(state)))  # Pastikan state di-reshape ke bentuk (1, num_features)
        predicted_Status = agent.act(state)  # Prediksi Status menggunakan agen
        actual_Status = observation['Status']  # Nilai Status aktual dari dataset
        if predicted_Status == actual_Status:
            correct_predictions += 1

    accuracy = (correct_predictions / total_predictions) * 100
    return accuracy

# %%
# Menggunakan fungsi calculate_accuracy untuk menghitung akurasi
accuracy = calculate_accuracy(dataset, agent)
print("Accuracy:", accuracy, "%")
# Out:
# Accuracy: 50.159966615662825 %

# %%
# Membuat list untuk menyimpan hasil prediksi
predicted_labels = []

# %%
# Loop melalui setiap observasi dalam dataset dan membuat prediksi
for index, observation in dataset.iterrows():
    predicted_status = predict_status(observation, agent)  # Melakukan prediksi Status
    predicted_labels.append(predicted_status)
# Out:
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Membuat DataFrame dari list hasil prediksi
predicted_labels_df = pd.DataFrame(predicted_labels, columns=['Status'])

# %%
# Output hasil prediksi dalam format yang diminta
print(predicted_labels_df)
# Out:
#       Status
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 7184       1
# 7185       1
# 7186       1
# 7187       0
# 7188       0
#
# [7189 rows x 1 columns]

# %%
# Gabungkan kolom Status dari dataset asli dengan kolom Status dari predicted_labels_df
comparison_df = pd.concat([dataset['Status'], predicted_labels_df['Status']], axis=1)
comparison_df.columns = ['Actual_Status', 'Predicted_Status']

# %%
# Hitung jumlah status yang sama dan yang berbeda
same_status = comparison_df[comparison_df['Actual_Status'] == comparison_df['Predicted_Status']].shape[0]
different_status = comparison_df[comparison_df['Actual_Status'] != comparison_df['Predicted_Status']].shape[0]

# %% [markdown]
# 1

# %%
same_status / len(comparison_df) * 100
# Out:
# 50.46598970649604

# %%
# Buat visualisasi
plt.figure(figsize=(8, 6))
labels = ['Same Status', 'Different Status']
sizes = [same_status, different_status]
colors = ['lightgreen', 'lightcoral']
explode = (0, 0.1)  # Pisahkan "Different Status"
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Comparison of Actual and Predicted Status')
plt.show()

# %%
import matplotlib.pyplot as plt

# Hitung jumlah status 0 dan 1 dari predicted_labels_df
healthy_count = predicted_labels_df[predicted_labels_df['Status'] == 0].shape[0]
unhealthy_count = predicted_labels_df[predicted_labels_df['Status'] == 1].shape[0]

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns


# Menghitung dan menampilkan confusion matrix untuk data validasi
cm_val = confusion_matrix(comparison_df['Actual_Status'], comparison_df['Predicted_Status'])
print("Confusion Matrix - Validation Data")
print(cm_val)

# Menampilkan confusion matrix sebagai heatmap untuk data validasi
plt.figure(figsize=(10, 8))
sns.heatmap(cm_val, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Validation Data')
plt.show()

# Menghitung dan menampilkan classification report untuk data validasi
print("Classification Report - Validation Data")
report_val = classification_report(comparison_df['Actual_Status'], comparison_df['Predicted_Status'])
print(report_val)
# Out:
# Confusion Matrix - Validation Data
# [[3127 3106]
#  [ 455  501]]
# Classification Report - Validation Data
#               precision    recall  f1-score   support
#
#            0       0.87      0.50      0.64      6233
#            1       0.14      0.52      0.22       956
#
#     accuracy                           0.50      7189
#    macro avg       0.51      0.51      0.43      7189
# weighted avg       0.78      0.50      0.58      7189

# %%
# Data untuk plot
status_labels = ['0', '1']
status_counts = [healthy_count, unhealthy_count]

# %%
# Plot batang
plt.bar(status_labels, status_counts, color=['green', 'red'])

# Tambahkan label angka di atas setiap batang
for i in range(len(status_labels)):
    plt.text(i, status_counts[i], str(status_counts[i]), ha='center', va='bottom')

# Label sumbu dan judul
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Jumlah Status 0 dan 1')

# Tampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt
# s
# Hitung jumlah status 0 dan 1 dari predicted_labels_df
healthy_count = predicted_labels_df[predicted_labels_df['Status'] == 0].shape[0]
unhealthy_count = predicted_labels_df[predicted_labels_df['Status'] == 1].shape[0]

# Data untuk plot
status_labels = ['Healthy', 'Unhealthy']
status_counts = [healthy_count, unhealthy_count]
colors = ['lightgreen', 'lightcoral']

# Plot donut chart
plt.figure(figsize=(8, 6))
plt.pie(status_counts, labels=status_labels, colors=colors, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
plt.gca().add_artist(plt.Circle((0, 0), 0.6, fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Jumlah Status Healthy dan Unhealthy setelah DQN')
plt.show()

# %%
# Menampilkan heatmap dari tabel Q
import seaborn as sns

# Dapatkan bobot dari model jaringan saraf
def get_q_table(model, num_actions):
    # Ambil layer ke-2 (indeks 1) dari model, yang merupakan layer pertama setelah input
    first_layer = model.layers[1]
    # Dapatkan bobot dari layer
    weights = first_layer.get_weights()[0]
    # Ubah bobot menjadi format yang sesuai untuk tabel Q
    q_table = weights.reshape((-1, num_actions))
    return q_table

# Fungsi untuk menampilkan heatmap dari tabel Q
def plot_q_table_heatmap(q_table):
    plt.figure(figsize=(10, 6))
    sns.heatmap(q_table, cmap='viridis', annot=True, fmt=".2f", cbar=False)
    plt.xlabel('Actions')
    plt.ylabel('States')
    plt.title('Heatmap of Q Table')
    plt.show()

# Dapatkan tabel Q dari model agen
q_table = get_q_table(agent.model, num_actions)

# Reduksi dimensi state labels menjadi 1-10
state_labels_reduced = ['State {}'.format(i+1) for i in range(10)]

# Ambil subset dari q_table untuk hanya menampilkan 10 state pertama
q_table_subset = q_table[:10]

# Tampilkan heatmap dari tabel Q
plot_q_table_heatmap(q_table_subset)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[82], line 24
#      21     plt.show()
#      23 # Dapatkan tabel Q dari model agen
# ---> 24 q_table = get_q_table(agent.model, num_actions)
#      26 # Reduksi dimensi state labels menjadi 1-10
#      27 state_labels_reduced = ['State {}'.format(i+1) for i in range(10)]
#
# Cell In[82], line 9, in get_q_table(model, num_actions)
#       7 first_layer = model.layers[1]
#       8 # Dapatkan bobot dari layer
# ----> 9 weights = first_layer.get_weights()[0]
#      10 # Ubah bobot menjadi format yang sesuai untuk tabel Q
#      11 q_table = weights.reshape((-1, num_actions))
#
# IndexError: list index out of range

# %%
# Pilih state yang ingin divisualisasikan, misalnya state ke-10
state_index = 10

# Dapatkan Q-values untuk state tersebut
q_values = q_table[state_index, :]

# Tentukan actions (dalam kasus Anda, hanya 2 actions)
actions = ['Action 0', 'Action 1']

# Plot barplot dari Q-values
plt.figure(figsize=(10, 6))
sns.barplot(x=actions, y=q_values)
plt.title(f'Q-values for State {state_index}')
plt.xlabel('Actions')
plt.ylabel('Q-value')
plt.show()
