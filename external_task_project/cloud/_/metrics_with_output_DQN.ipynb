# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from collections import deque
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
df = pd.read_csv("metrics-with-output.csv")
df
# Out:
#                      Time      Timestamp cpu_usage memory_usage  \
# 0     2023-09-08 01:16:00  1694110560000     9.00%        53.5%
# 1     2023-09-08 01:16:05  1694110565000     16.6%        53.3%
# 2     2023-09-08 01:16:10  1694110570000     20.2%        55.3%
# 3     2023-09-08 01:16:15  1694110575000     14.6%        58.0%
# 4     2023-09-08 01:16:20  1694110580000     10.2%        53.5%
# ...                   ...            ...       ...          ...
# 7184  2023-09-08 11:14:40  1694146480000     22.2%        53.5%
# 7185  2023-09-08 11:14:45  1694146485000     27.2%        56.0%
# 7186  2023-09-08 11:14:50  1694146490000     7.20%        54.1%
# 7187  2023-09-08 11:14:55  1694146495000     23.4%        54.6%
# 7188  2023-09-08 11:15:00  1694146500000     31.0%        53.8%
#
#      bandwidth_inbound bandwidth_outbound         tps tps_error response_time  \
# 0            7.46 GB/s          6.45 GB/s     2 req/s   0 req/s        607 ms
# 1            5.85 GB/s          5.27 GB/s  2.20 req/s   0 req/s        2.09 s
# 2            9.06 GB/s          7.96 GB/s  3.20 req/s   0 req/s        3.45 s
# 3            8.41 GB/s          7.21 GB/s  3.20 req/s   0 req/s        2.58 s
# 4            4.88 GB/s          4.30 GB/s  2.60 req/s   0 req/s        862 ms
# ...                ...                ...         ...       ...           ...
# 7184         6.52 GB/s          5.67 GB/s  2.40 req/s   0 req/s        1.51 s
# 7185         7.37 GB/s          6.49 GB/s  2.60 req/s   0 req/s        1.21 s
# 7186         4.76 GB/s          4.02 GB/s  1.40 req/s   0 req/s        285 ms
# 7187         6.75 GB/s          5.90 GB/s  2.40 req/s   0 req/s        804 ms
# 7188         7.76 GB/s          6.92 GB/s  3.20 req/s   0 req/s        2.64 s
#
#       Status
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 7184       0
# 7185       0
# 7186       0
# 7187       0
# 7188       0
#
# [7189 rows x 10 columns]

# %%
# Menampilkan baris pertama dr dataset
df.head()
# Out:
#                   Time      Timestamp cpu_usage memory_usage  \
# 0  2023-09-08 01:16:00  1694110560000     9.00%        53.5%
# 1  2023-09-08 01:16:05  1694110565000     16.6%        53.3%
# 2  2023-09-08 01:16:10  1694110570000     20.2%        55.3%
# 3  2023-09-08 01:16:15  1694110575000     14.6%        58.0%
# 4  2023-09-08 01:16:20  1694110580000     10.2%        53.5%
#
#   bandwidth_inbound bandwidth_outbound         tps tps_error response_time  \
# 0         7.46 GB/s          6.45 GB/s     2 req/s   0 req/s        607 ms
# 1         5.85 GB/s          5.27 GB/s  2.20 req/s   0 req/s        2.09 s
# 2         9.06 GB/s          7.96 GB/s  3.20 req/s   0 req/s        3.45 s
# 3         8.41 GB/s          7.21 GB/s  3.20 req/s   0 req/s        2.58 s
# 4         4.88 GB/s          4.30 GB/s  2.60 req/s   0 req/s        862 ms
#
#    Status
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import matplotlib.pyplot as plt

#Membandingkan jumlah status Healthy dan Unhealthy dengan donut chart
status_counts = df['Status'].value_counts()

colors = ['red','blue']
plt.pie(status_counts, labels=status_counts.index, colors=colors, autopct='%1.1f%%', startangle=90)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Distribution of Status')
plt.show()

# %%
# Preprocessing data: clean and convert to numeric
df['cpu_usage'] = df['cpu_usage'].str.rstrip('%').astype('float') / 100.0
df['memory_usage'] = df['memory_usage'].str.rstrip('%').astype('float') / 100.0

def clean_bandwidth(value):
    if 'GB/s' in value:
        return float(value.replace('GB/s', ''))
    elif 'MB/s' in value:
        return float(value.replace('MB/s', '')) / 1024  # Convert MB/s to GB/s
    else:
        return float(value)

df['bandwidth_inbound'] = df['bandwidth_inbound'].apply(clean_bandwidth)
df['bandwidth_outbound'] = df['bandwidth_outbound'].apply(clean_bandwidth)
df['tps'] = df['tps'].str.rstrip(' req/s').astype('float')
df['tps_error'] = df['tps_error'].str.rstrip(' req/s').astype('float')
df['response_time'] = df['response_time'].replace({' ms': '*1e-3', ' s': '*1'}, regex=True).map(pd.eval).astype('float')

# Drop irrelevant columns (if any)
dataset = df.drop(df.columns[[0, 1]], axis=1)

# Normalize the dataset
scaler = MinMaxScaler()
features = dataset.drop('Status', axis=1)
normalized_features = scaler.fit_transform(features)

# Replace the non-normalized features with the normalized ones in the dataset
normalized_dataset = pd.DataFrame(normalized_features, columns=features.columns)
normalized_dataset['Status'] = dataset['Status'].values  # Add the 'Status' column back

# Display the normalized dataset
print(normalized_dataset.head())
# Out:
#    cpu_usage  memory_usage  bandwidth_inbound  bandwidth_outbound       tps  \
# 0   0.080808      0.187192           0.363939            0.364287  0.269231
# 1   0.157576      0.177340           0.284799            0.297010  0.307692
# 2   0.193939      0.275862           0.442586            0.450379  0.500000
# 3   0.137374      0.408867           0.410635            0.407618  0.500000
# 4   0.092929      0.187192           0.237119            0.241705  0.384615
#
#    tps_error  response_time  Status
# 0        0.0       0.070037       0
# 1        0.0       0.282441       0
# 2        0.0       0.477227       0
# 3        0.0       0.352621       0
# 4        0.0       0.106560       0

# %%
# Info dataset mengenai tipe, jumlah kolom dll
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7189 entries, 0 to 7188
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                7189 non-null   object
#  1   Timestamp           7189 non-null   int64
#  2   cpu_usage           7189 non-null   float64
#  3   memory_usage        7189 non-null   float64
#  4   bandwidth_inbound   7189 non-null   float64
#  5   bandwidth_outbound  7189 non-null   float64
#  6   tps                 7189 non-null   float64
#  7   tps_error           7189 non-null   float64
#  8   response_time       7189 non-null   float64
#  9   Status              7189 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 561.8+ KB

# %%
# Menampilkan dataset setelah proses konversi dan pembersihan data
print(df)
# Out:
#                      Time      Timestamp  cpu_usage  memory_usage  \
# 0     2023-09-08 01:16:00  1694110560000      0.090         0.535
# 1     2023-09-08 01:16:05  1694110565000      0.166         0.533
# 2     2023-09-08 01:16:10  1694110570000      0.202         0.553
# 3     2023-09-08 01:16:15  1694110575000      0.146         0.580
# 4     2023-09-08 01:16:20  1694110580000      0.102         0.535
# ...                   ...            ...        ...           ...
# 7184  2023-09-08 11:14:40  1694146480000      0.222         0.535
# 7185  2023-09-08 11:14:45  1694146485000      0.272         0.560
# 7186  2023-09-08 11:14:50  1694146490000      0.072         0.541
# 7187  2023-09-08 11:14:55  1694146495000      0.234         0.546
# 7188  2023-09-08 11:15:00  1694146500000      0.310         0.538
#
#       bandwidth_inbound  bandwidth_outbound  tps  tps_error  response_time  \
# 0                  7.46                6.45  2.0        0.0          0.607
# 1                  5.85                5.27  2.2        0.0          2.090
# 2                  9.06                7.96  3.2        0.0          3.450
# 3                  8.41                7.21  3.2        0.0          2.580
# 4                  4.88                4.30  2.6        0.0          0.862
# ...                 ...                 ...  ...        ...            ...
# 7184               6.52                5.67  2.4        0.0          1.510
# 7185               7.37                6.49  2.6        0.0          1.210
# 7186               4.76                4.02  1.4        0.0          0.285
# 7187               6.75                5.90  2.4        0.0          0.804
# 7188               7.76                6.92  3.2        0.0          2.640
#
#       Status
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 7184       0
# 7185       0
# 7186       0
# 7187       0
# 7188       0
#
# [7189 rows x 10 columns]

# %%
# Pembersihan/Penghapusan data yang tidak dipakai
dataset = df.drop(df.columns[[0, 1]], axis=1)

dataset.describe()
# Out:
#          cpu_usage  memory_usage  bandwidth_inbound  bandwidth_outbound  \
# count  7189.000000   7189.000000        7189.000000         7189.000000
# mean      0.163090      0.542723           6.318377            5.573617
# std       0.069272      0.019356           3.193037            2.728239
# min       0.010000      0.497000           0.056055            0.060645
# 25%       0.118000      0.533000           3.940000            3.540000
# 50%       0.156000      0.539000           5.910000            5.230000
# 75%       0.198000      0.549000           8.310000            7.260000
# max       1.000000      0.700000          20.400000           17.600000
#
#                tps    tps_error  response_time       Status
# count  7189.000000  7189.000000    7189.000000  7189.000000
# mean      2.490218     0.170817       1.770724     0.132981
# std       0.784028     0.548970       1.024615     0.339578
# min       0.600000     0.000000       0.118000     0.000000
# 25%       2.000000     0.000000       0.952000     0.000000
# 50%       2.400000     0.000000       1.520000     0.000000
# 75%       3.000000     0.000000       2.450000     0.000000
# max       5.800000     4.600000       7.100000     1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# Encode 'Status' column into numeric values
label_encoder = LabelEncoder()
dataset['Status'] = label_encoder.fit_transform(dataset['Status'])

# %%
dataset['Status']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7184    0
# 7185    0
# 7186    0
# 7187    0
# 7188    0
# Name: Status, Length: 7189, dtype: int64

# %%
# Periksa apakah ada data yang hilang
missing_data = dataset.isnull().sum()
if missing_data.any():
    print("Data terdapat missing values yang perlu diimputasi:")
    print(missing_data)
else:
    print("Tidak ada missing values dalam dataset.")
# Out:
# Tidak ada missing values dalam dataset.

# %%
# Split data menjadi features (X) dan target (y)
X = dataset.drop('Status', axis=1)
y = dataset['Status']

# %%
# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=123)

# %%
# Definisikan Environment Class
class Environment:
    def __init__(self, dataset):
        self.dataset = dataset
        self.num_samples = len(dataset)
        self.current_sample_idx = None  # Set indeks sampel saat ini ke None saat inisialisasi

    def reset(self):
        self.current_sample_idx = 0  # Set ulang indeks sampel saat memulai episode baru
        return self.dataset.iloc[self.current_sample_idx], 0, False

    def step(self, action):
        self.current_sample_idx = (self.current_sample_idx + 1) % self.num_samples
        next_observation = self.dataset.iloc[self.current_sample_idx]
        reward = self.calculate_reward(next_observation, action)  # Hitung reward berdasarkan observasi dan aksi
        done = self.current_sample_idx == 0  # Atur done menjadi True jika mencapai akhir episode
        return next_observation, reward, done

    def calculate_reward(self, observation, action):
        actual_Status = observation['Status']
        predicted_Status = action
        if predicted_Status == actual_Status:
            if actual_Status == 1:
                reward = 1  # Lower reward for correctly predicting status 1
            else:
                reward = 2  # Higher reward for correctly predicting status 0
        else:
            if actual_Status == 1:
                reward = -2  # Higher penalty for incorrectly predicting status 1
            else:
                reward = -1  # Lower penalty for incorrectly predicting status 0
        return reward

# %%
import tensorflow as tf  # Tambahkan import TensorFlow

class DQNAgent:
    def __init__(self, state_size, action_size, class_weights=None):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_min = 0.1
        self.epsilon_decay = 0.99
        self.learning_rate = 0.001
        self.class_weights = class_weights
        self.model = self._build_model()

    def custom_loss(self, y_true, y_pred):
        weights = tf.where(tf.equal(y_true, 1), self.class_weights[1], self.class_weights[0])  # Bobot lebih besar untuk kelas 1
        loss = tf.keras.losses.mean_squared_error(y_true, y_pred)
        return tf.reduce_mean(loss * weights)


    def _build_model(self):
        model = tf.keras.models.Sequential()
        
        # Adding layers with LeakyReLU activation
        model.add(tf.keras.layers.Dense(128, input_dim=self.state_size))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(256))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(128))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(self.action_size, activation='linear'))
        
        model.compile(loss=self.custom_loss, optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        # Separate experiences by label
        experiences_class_0 = [exp for exp in self.memory if exp[3]['Status'] == 0]
        experiences_class_1 = [exp for exp in self.memory if exp[3]['Status'] == 1]

        # Oversample class 0 experiences
        if len(experiences_class_0) < batch_size:
            minibatch = random.sample(experiences_class_0 * (batch_size // len(experiences_class_0)), batch_size)
        else:
            minibatch = random.sample(experiences_class_0, batch_size // 2)
            minibatch += random.sample(experiences_class_1, batch_size // 2)
        
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
# Parameters
num_actions = 2  # Number of possible actions
num_features = len(dataset.columns) - 1  # Number of features in the dataset (excluding classification)
batch_size = 40
num_episodes = 5000
max_steps = 2000

# %%
# Initialize environment and agent
env = Environment(dataset)
class_weights = {0: 1, 1: (len(y) - sum(y)) / sum(y)}  # Contoh untuk menghitung bobot
agent = DQNAgent(state_size=num_features, action_size=num_actions, class_weights=class_weights)
# Out:
# d:\Python\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# d:\Python\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
# Training loop
total_reward_all = 0
for episode in range(num_episodes):
    state, _, _ = env.reset()  # Reset the environment and get initial state
    total_reward = 0
    done = False
    while not done:
        action = agent.act(state)
        next_state, reward, done = env.step(action)  # Take action and get next state, reward, and done status
        agent.remember(state, action, reward, next_state, done)  # Remember the experience
        state = next_state  # Update the current state
        total_reward += reward  # Accumulate total reward for the episode
    total_reward_all += total_reward
    print("Episode:", episode+1, "of", num_episodes, "Total Reward:", total_reward)
# Out:
# Episode: 1 of 5000 Total Reward: 2367
# Episode: 2 of 5000 Total Reward: 2646
# Episode: 3 of 5000 Total Reward: 2439
# Episode: 4 of 5000 Total Reward: 2640
# Episode: 5 of 5000 Total Reward: 2847
# Episode: 6 of 5000 Total Reward: 2598
# Episode: 7 of 5000 Total Reward: 2919
# Episode: 8 of 5000 Total Reward: 2763
# Episode: 9 of 5000 Total Reward: 2706
# Episode: 10 of 5000 Total Reward: 2676
# Episode: 11 of 5000 Total Reward: 2694
# Episode: 12 of 5000 Total Reward: 2709
# Episode: 13 of 5000 Total Reward: 2583
# Episode: 14 of 5000 Total Reward: 2781
# Episode: 15 of 5000 Total Reward: 2562
# Episode: 16 of 5000 Total Reward: 2457
# Episode: 17 of 5000 Total Reward: 2475
# Episode: 18 of 5000 Total Reward: 2742
# Episode: 19 of 5000 Total Reward: 2520
# Episode: 20 of 5000 Total Reward: 2619
# Episode: 21 of 5000 Total Reward: 2730
# Episode: 22 of 5000 Total Reward: 2706
# Episode: 23 of 5000 Total Reward: 2613
# Episode: 24 of 5000 Total Reward: 2619
# Episode: 25 of 5000 Total Reward: 2367
# Episode: 26 of 5000 Total Reward: 2685
# Episode: 27 of 5000 Total Reward: 2610
# Episode: 28 of 5000 Total Reward: 2616
# Episode: 29 of 5000 Total Reward: 2745
# Episode: 30 of 5000 Total Reward: 2664
# Episode: 31 of 5000 Total Reward: 2718
# Episode: 32 of 5000 Total Reward: 2709
# Episode: 33 of 5000 Total Reward: 2394
# Episode: 34 of 5000 Total Reward: 2646
# Episode: 35 of 5000 Total Reward: 2847
# Episode: 36 of 5000 Total Reward: 2820
# Episode: 37 of 5000 Total Reward: 2604
# Episode: 38 of 5000 Total Reward: 2682
# Episode: 39 of 5000 Total Reward: 2733
# Episode: 40 of 5000 Total Reward: 2571
# Episode: 41 of 5000 Total Reward: 2520
# Episode: 42 of 5000 Total Reward: 2889
# Episode: 43 of 5000 Total Reward: 2541
# Episode: 44 of 5000 Total Reward: 2601
# Episode: 45 of 5000 Total Reward: 2715
# Episode: 46 of 5000 Total Reward: 2622
# Episode: 47 of 5000 Total Reward: 2646
# Episode: 48 of 5000 Total Reward: 2835
# Episode: 49 of 5000 Total Reward: 2667
# Episode: 50 of 5000 Total Reward: 2697
# Episode: 51 of 5000 Total Reward: 2631
# Episode: 52 of 5000 Total Reward: 2625
# Episode: 53 of 5000 Total Reward: 2676
# Episode: 54 of 5000 Total Reward: 2721
# Episode: 55 of 5000 Total Reward: 2925
# Episode: 56 of 5000 Total Reward: 2556
# Episode: 57 of 5000 Total Reward: 2526
# Episode: 58 of 5000 Total Reward: 2754
# Episode: 59 of 5000 Total Reward: 2751
# Episode: 60 of 5000 Total Reward: 2664
# Episode: 61 of 5000 Total Reward: 2874
# Episode: 62 of 5000 Total Reward: 2556
# Episode: 63 of 5000 Total Reward: 2682
# Episode: 64 of 5000 Total Reward: 2691
# Episode: 65 of 5000 Total Reward: 2676
# Episode: 66 of 5000 Total Reward: 2628
# Episode: 67 of 5000 Total Reward: 2370
# Episode: 68 of 5000 Total Reward: 2928
# Episode: 69 of 5000 Total Reward: 2586
# Episode: 70 of 5000 Total Reward: 2619
# Episode: 71 of 5000 Total Reward: 2688
# Episode: 72 of 5000 Total Reward: 2757
# Episode: 73 of 5000 Total Reward: 2535
# Episode: 74 of 5000 Total Reward: 2694
# Episode: 75 of 5000 Total Reward: 2664
# Episode: 76 of 5000 Total Reward: 2511
# Episode: 77 of 5000 Total Reward: 2649
# Episode: 78 of 5000 Total Reward: 2835
# Episode: 79 of 5000 Total Reward: 2628
# Episode: 80 of 5000 Total Reward: 2610
# Episode: 81 of 5000 Total Reward: 2793
# Episode: 82 of 5000 Total Reward: 2658
# Episode: 83 of 5000 Total Reward: 2619
# Episode: 84 of 5000 Total Reward: 2466
# Episode: 85 of 5000 Total Reward: 2493
# Episode: 86 of 5000 Total Reward: 2778
# Episode: 87 of 5000 Total Reward: 2640
# Episode: 88 of 5000 Total Reward: 2760
# Episode: 89 of 5000 Total Reward: 2610
# Episode: 90 of 5000 Total Reward: 2613
# Episode: 91 of 5000 Total Reward: 2688
# Episode: 92 of 5000 Total Reward: 2610
# Episode: 93 of 5000 Total Reward: 2766
# Episode: 94 of 5000 Total Reward: 2466
# Episode: 95 of 5000 Total Reward: 2394
# Episode: 96 of 5000 Total Reward: 2493
# Episode: 97 of 5000 Total Reward: 2538
# Episode: 98 of 5000 Total Reward: 2592
# Episode: 99 of 5000 Total Reward: 2691
# Episode: 100 of 5000 Total Reward: 2586
# Episode: 101 of 5000 Total Reward: 2511
# Episode: 102 of 5000 Total Reward: 2622
# Episode: 103 of 5000 Total Reward: 2631
# Episode: 104 of 5000 Total Reward: 2517
# Episode: 105 of 5000 Total Reward: 2514
# Episode: 106 of 5000 Total Reward: 2604
# Episode: 107 of 5000 Total Reward: 2802
# Episode: 108 of 5000 Total Reward: 2451
# Episode: 109 of 5000 Total Reward: 2616
# Episode: 110 of 5000 Total Reward: 2709
# Episode: 111 of 5000 Total Reward: 2685
# Episode: 112 of 5000 Total Reward: 2601
# Episode: 113 of 5000 Total Reward: 2604
# Episode: 114 of 5000 Total Reward: 2721
# Episode: 115 of 5000 Total Reward: 2745
# Episode: 116 of 5000 Total Reward: 2622
# Episode: 117 of 5000 Total Reward: 2670
# Episode: 118 of 5000 Total Reward: 2592
# Episode: 119 of 5000 Total Reward: 2583
# Episode: 120 of 5000 Total Reward: 2520
# Episode: 121 of 5000 Total Reward: 2634
# Episode: 122 of 5000 Total Reward: 2643
# Episode: 123 of 5000 Total Reward: 2529
# Episode: 124 of 5000 Total Reward: 2643
# Episode: 125 of 5000 Total Reward: 2346
# Episode: 126 of 5000 Total Reward: 2442
# Episode: 127 of 5000 Total Reward: 2844
# Episode: 128 of 5000 Total Reward: 2865
# Episode: 129 of 5000 Total Reward: 2727
# Episode: 130 of 5000 Total Reward: 2307
# Episode: 131 of 5000 Total Reward: 2613
# Episode: 132 of 5000 Total Reward: 2487
# Episode: 133 of 5000 Total Reward: 2628
# Episode: 134 of 5000 Total Reward: 2628
# Episode: 135 of 5000 Total Reward: 2676
# Episode: 136 of 5000 Total Reward: 2391
# Episode: 137 of 5000 Total Reward: 2727
# Episode: 138 of 5000 Total Reward: 2661
# Episode: 139 of 5000 Total Reward: 2874
# Episode: 140 of 5000 Total Reward: 2589
# Episode: 141 of 5000 Total Reward: 2757
# Episode: 142 of 5000 Total Reward: 2592
# Episode: 143 of 5000 Total Reward: 2679
# Episode: 144 of 5000 Total Reward: 2610
# Episode: 145 of 5000 Total Reward: 2559
# Episode: 146 of 5000 Total Reward: 2655
# Episode: 147 of 5000 Total Reward: 2559
# Episode: 148 of 5000 Total Reward: 2583
# Episode: 149 of 5000 Total Reward: 2541
# Episode: 150 of 5000 Total Reward: 2589
# Episode: 151 of 5000 Total Reward: 2349
# Episode: 152 of 5000 Total Reward: 2742
# Episode: 153 of 5000 Total Reward: 2628
# Episode: 154 of 5000 Total Reward: 2631
# Episode: 155 of 5000 Total Reward: 2733
# Episode: 156 of 5000 Total Reward: 2931
# Episode: 157 of 5000 Total Reward: 2766
# Episode: 158 of 5000 Total Reward: 2685
# Episode: 159 of 5000 Total Reward: 2703
# Episode: 160 of 5000 Total Reward: 2784
# Episode: 161 of 5000 Total Reward: 2511
# Episode: 162 of 5000 Total Reward: 2622
# Episode: 163 of 5000 Total Reward: 2691
# Episode: 164 of 5000 Total Reward: 2721
# Episode: 165 of 5000 Total Reward: 2724
# Episode: 166 of 5000 Total Reward: 2679
# Episode: 167 of 5000 Total Reward: 2787
# Episode: 168 of 5000 Total Reward: 2937
# Episode: 169 of 5000 Total Reward: 2550
# Episode: 170 of 5000 Total Reward: 2763
# Episode: 171 of 5000 Total Reward: 2313
# Episode: 172 of 5000 Total Reward: 2541
# Episode: 173 of 5000 Total Reward: 2565
# Episode: 174 of 5000 Total Reward: 2880
# Episode: 175 of 5000 Total Reward: 2820
# Episode: 176 of 5000 Total Reward: 2730
# Episode: 177 of 5000 Total Reward: 2700
# Episode: 178 of 5000 Total Reward: 2487
# Episode: 179 of 5000 Total Reward: 2619
# Episode: 180 of 5000 Total Reward: 2709
# Episode: 181 of 5000 Total Reward: 2490
# Episode: 182 of 5000 Total Reward: 2628
# Episode: 183 of 5000 Total Reward: 2856
# Episode: 184 of 5000 Total Reward: 2580
# Episode: 185 of 5000 Total Reward: 2400
# Episode: 186 of 5000 Total Reward: 2583
# Episode: 187 of 5000 Total Reward: 2703
# Episode: 188 of 5000 Total Reward: 2586
# Episode: 189 of 5000 Total Reward: 2601
# Episode: 190 of 5000 Total Reward: 2520
# Episode: 191 of 5000 Total Reward: 2727
# Episode: 192 of 5000 Total Reward: 2655
# Episode: 193 of 5000 Total Reward: 2730
# Episode: 194 of 5000 Total Reward: 2742
# Episode: 195 of 5000 Total Reward: 2490
# Episode: 196 of 5000 Total Reward: 2652
# Episode: 197 of 5000 Total Reward: 2742
# Episode: 198 of 5000 Total Reward: 2571
# Episode: 199 of 5000 Total Reward: 2514
# Episode: 200 of 5000 Total Reward: 2442
# Episode: 201 of 5000 Total Reward: 2712
# Episode: 202 of 5000 Total Reward: 2649
# Episode: 203 of 5000 Total Reward: 2922
# Episode: 204 of 5000 Total Reward: 2679
# Episode: 205 of 5000 Total Reward: 2688
# Episode: 206 of 5000 Total Reward: 2640
# Episode: 207 of 5000 Total Reward: 2760
# Episode: 208 of 5000 Total Reward: 2727
# Episode: 209 of 5000 Total Reward: 2538
# Episode: 210 of 5000 Total Reward: 2580
# Episode: 211 of 5000 Total Reward: 2700
# Episode: 212 of 5000 Total Reward: 2775
# Episode: 213 of 5000 Total Reward: 2799
# Episode: 214 of 5000 Total Reward: 2625
# Episode: 215 of 5000 Total Reward: 2739
# Episode: 216 of 5000 Total Reward: 2802
# Episode: 217 of 5000 Total Reward: 2778
# Episode: 218 of 5000 Total Reward: 2733
# Episode: 219 of 5000 Total Reward: 2385
# Episode: 220 of 5000 Total Reward: 2598
# Episode: 221 of 5000 Total Reward: 2217
# Episode: 222 of 5000 Total Reward: 2715
# Episode: 223 of 5000 Total Reward: 2712
# Episode: 224 of 5000 Total Reward: 2700
# Episode: 225 of 5000 Total Reward: 2739
# Episode: 226 of 5000 Total Reward: 2592
# Episode: 227 of 5000 Total Reward: 2676
# Episode: 228 of 5000 Total Reward: 2706
# Episode: 229 of 5000 Total Reward: 2469
# Episode: 230 of 5000 Total Reward: 2781
# Episode: 231 of 5000 Total Reward: 2532
# Episode: 232 of 5000 Total Reward: 2796
# Episode: 233 of 5000 Total Reward: 2775
# Episode: 234 of 5000 Total Reward: 2715
# Episode: 235 of 5000 Total Reward: 2760
# Episode: 236 of 5000 Total Reward: 2703
# Episode: 237 of 5000 Total Reward: 2721
# Episode: 238 of 5000 Total Reward: 2616
# Episode: 239 of 5000 Total Reward: 2583
# Episode: 240 of 5000 Total Reward: 2496
# Episode: 241 of 5000 Total Reward: 2424
# Episode: 242 of 5000 Total Reward: 2694
# Episode: 243 of 5000 Total Reward: 2721
# Episode: 244 of 5000 Total Reward: 2625
# Episode: 245 of 5000 Total Reward: 2631
# Episode: 246 of 5000 Total Reward: 2892
# Episode: 247 of 5000 Total Reward: 2481
# Episode: 248 of 5000 Total Reward: 2604
# Episode: 249 of 5000 Total Reward: 2592
# Episode: 250 of 5000 Total Reward: 2418
# Episode: 251 of 5000 Total Reward: 2937
# Episode: 252 of 5000 Total Reward: 2379
# Episode: 253 of 5000 Total Reward: 2736
# Episode: 254 of 5000 Total Reward: 2355
# Episode: 255 of 5000 Total Reward: 2616
# Episode: 256 of 5000 Total Reward: 2520
# Episode: 257 of 5000 Total Reward: 2778
# Episode: 258 of 5000 Total Reward: 2847
# Episode: 259 of 5000 Total Reward: 2676
# Episode: 260 of 5000 Total Reward: 2793
# Episode: 261 of 5000 Total Reward: 2493
# Episode: 262 of 5000 Total Reward: 2634
# Episode: 263 of 5000 Total Reward: 2496
# Episode: 264 of 5000 Total Reward: 2682
# Episode: 265 of 5000 Total Reward: 2748
# Episode: 266 of 5000 Total Reward: 2610
# Episode: 267 of 5000 Total Reward: 2703
# Episode: 268 of 5000 Total Reward: 2622
# Episode: 269 of 5000 Total Reward: 2670
# Episode: 270 of 5000 Total Reward: 2727
# Episode: 271 of 5000 Total Reward: 2673
# Episode: 272 of 5000 Total Reward: 2826
# Episode: 273 of 5000 Total Reward: 2616
# Episode: 274 of 5000 Total Reward: 2799
# Episode: 275 of 5000 Total Reward: 2523
# Episode: 276 of 5000 Total Reward: 2811
# Episode: 277 of 5000 Total Reward: 2910
# Episode: 278 of 5000 Total Reward: 2478
# Episode: 279 of 5000 Total Reward: 2793
# Episode: 280 of 5000 Total Reward: 2547
# Episode: 281 of 5000 Total Reward: 2652
# Episode: 282 of 5000 Total Reward: 2517
# Episode: 283 of 5000 Total Reward: 2721
# Episode: 284 of 5000 Total Reward: 2670
# Episode: 285 of 5000 Total Reward: 2658
# Episode: 286 of 5000 Total Reward: 2610
# Episode: 287 of 5000 Total Reward: 2706
# Episode: 288 of 5000 Total Reward: 2595
# Episode: 289 of 5000 Total Reward: 2784
# Episode: 290 of 5000 Total Reward: 2673
# Episode: 291 of 5000 Total Reward: 2655
# Episode: 292 of 5000 Total Reward: 2919
# Episode: 293 of 5000 Total Reward: 2643
# Episode: 294 of 5000 Total Reward: 2694
# Episode: 295 of 5000 Total Reward: 2745
# Episode: 296 of 5000 Total Reward: 2643
# Episode: 297 of 5000 Total Reward: 2526
# Episode: 298 of 5000 Total Reward: 2511
# Episode: 299 of 5000 Total Reward: 2589
# Episode: 300 of 5000 Total Reward: 2625
# Episode: 301 of 5000 Total Reward: 2613
# Episode: 302 of 5000 Total Reward: 2649
# Episode: 303 of 5000 Total Reward: 2481
# Episode: 304 of 5000 Total Reward: 2196
# Episode: 305 of 5000 Total Reward: 2670
# Episode: 306 of 5000 Total Reward: 2640
# Episode: 307 of 5000 Total Reward: 2610
# Episode: 308 of 5000 Total Reward: 2778
# Episode: 309 of 5000 Total Reward: 2556
# Episode: 310 of 5000 Total Reward: 2757
# Episode: 311 of 5000 Total Reward: 2448
# Episode: 312 of 5000 Total Reward: 2592
# Episode: 313 of 5000 Total Reward: 2529
# Episode: 314 of 5000 Total Reward: 2643
# Episode: 315 of 5000 Total Reward: 2619
# Episode: 316 of 5000 Total Reward: 2853
# Episode: 317 of 5000 Total Reward: 2511
# Episode: 318 of 5000 Total Reward: 2661
# Episode: 319 of 5000 Total Reward: 2604
# Episode: 320 of 5000 Total Reward: 2709
# Episode: 321 of 5000 Total Reward: 2673
# Episode: 322 of 5000 Total Reward: 2349
# Episode: 323 of 5000 Total Reward: 2634
# Episode: 324 of 5000 Total Reward: 2679
# Episode: 325 of 5000 Total Reward: 2547
# Episode: 326 of 5000 Total Reward: 2718
# Episode: 327 of 5000 Total Reward: 2550
# Episode: 328 of 5000 Total Reward: 2529
# Episode: 329 of 5000 Total Reward: 2676
# Episode: 330 of 5000 Total Reward: 2550
# Episode: 331 of 5000 Total Reward: 2469
# Episode: 332 of 5000 Total Reward: 2625
# Episode: 333 of 5000 Total Reward: 2559
# Episode: 334 of 5000 Total Reward: 2307
# Episode: 335 of 5000 Total Reward: 2436
# Episode: 336 of 5000 Total Reward: 2886
# Episode: 337 of 5000 Total Reward: 2712
# Episode: 338 of 5000 Total Reward: 2751
# Episode: 339 of 5000 Total Reward: 2940
# Episode: 340 of 5000 Total Reward: 2532
# Episode: 341 of 5000 Total Reward: 2820
# Episode: 342 of 5000 Total Reward: 2721
# Episode: 343 of 5000 Total Reward: 2619
# Episode: 344 of 5000 Total Reward: 2640
# Episode: 345 of 5000 Total Reward: 2577
# Episode: 346 of 5000 Total Reward: 2769
# Episode: 347 of 5000 Total Reward: 2739
# Episode: 348 of 5000 Total Reward: 2676
# Episode: 349 of 5000 Total Reward: 2517
# Episode: 350 of 5000 Total Reward: 2505
# Episode: 351 of 5000 Total Reward: 2523
# Episode: 352 of 5000 Total Reward: 2607
# Episode: 353 of 5000 Total Reward: 2541
# Episode: 354 of 5000 Total Reward: 2556
# Episode: 355 of 5000 Total Reward: 2595
# Episode: 356 of 5000 Total Reward: 2682
# Episode: 357 of 5000 Total Reward: 2673
# Episode: 358 of 5000 Total Reward: 2634
# Episode: 359 of 5000 Total Reward: 2373
# Episode: 360 of 5000 Total Reward: 2553
# Episode: 361 of 5000 Total Reward: 2757
# Episode: 362 of 5000 Total Reward: 2388
# Episode: 363 of 5000 Total Reward: 2454
# Episode: 364 of 5000 Total Reward: 2685
# Episode: 365 of 5000 Total Reward: 2778
# Episode: 366 of 5000 Total Reward: 2757
# Episode: 367 of 5000 Total Reward: 2637
# Episode: 368 of 5000 Total Reward: 2556
# Episode: 369 of 5000 Total Reward: 2673
# Episode: 370 of 5000 Total Reward: 2586
# Episode: 371 of 5000 Total Reward: 2550
# Episode: 372 of 5000 Total Reward: 2754
# Episode: 373 of 5000 Total Reward: 2841
# Episode: 374 of 5000 Total Reward: 2838
# Episode: 375 of 5000 Total Reward: 2808
# Episode: 376 of 5000 Total Reward: 2763
# Episode: 377 of 5000 Total Reward: 2529
# Episode: 378 of 5000 Total Reward: 2700
# Episode: 379 of 5000 Total Reward: 2562
# Episode: 380 of 5000 Total Reward: 2412
# Episode: 381 of 5000 Total Reward: 2502
# Episode: 382 of 5000 Total Reward: 2793
# Episode: 383 of 5000 Total Reward: 2670
# Episode: 384 of 5000 Total Reward: 2739
# Episode: 385 of 5000 Total Reward: 2454
# Episode: 386 of 5000 Total Reward: 2523
# Episode: 387 of 5000 Total Reward: 2616
# Episode: 388 of 5000 Total Reward: 2541
# Episode: 389 of 5000 Total Reward: 2592
# Episode: 390 of 5000 Total Reward: 2823
# Episode: 391 of 5000 Total Reward: 2859
# Episode: 392 of 5000 Total Reward: 2814
# Episode: 393 of 5000 Total Reward: 2727
# Episode: 394 of 5000 Total Reward: 2655
# Episode: 395 of 5000 Total Reward: 2772
# Episode: 396 of 5000 Total Reward: 2601
# Episode: 397 of 5000 Total Reward: 2583
# Episode: 398 of 5000 Total Reward: 2898
# Episode: 399 of 5000 Total Reward: 2700
# Episode: 400 of 5000 Total Reward: 2571
# Episode: 401 of 5000 Total Reward: 2745
# Episode: 402 of 5000 Total Reward: 2340
# Episode: 403 of 5000 Total Reward: 2556
# Episode: 404 of 5000 Total Reward: 2769
# Episode: 405 of 5000 Total Reward: 2637
# Episode: 406 of 5000 Total Reward: 2589
# Episode: 407 of 5000 Total Reward: 2550
# Episode: 408 of 5000 Total Reward: 2517
# Episode: 409 of 5000 Total Reward: 2550
# Episode: 410 of 5000 Total Reward: 2790
# Episode: 411 of 5000 Total Reward: 2649
# Episode: 412 of 5000 Total Reward: 2550
# Episode: 413 of 5000 Total Reward: 2616
# Episode: 414 of 5000 Total Reward: 2745
# Episode: 415 of 5000 Total Reward: 2610
# Episode: 416 of 5000 Total Reward: 2568
# Episode: 417 of 5000 Total Reward: 2826
# Episode: 418 of 5000 Total Reward: 2553
# Episode: 419 of 5000 Total Reward: 2706
# Episode: 420 of 5000 Total Reward: 2793
# Episode: 421 of 5000 Total Reward: 2397
# Episode: 422 of 5000 Total Reward: 2667
# Episode: 423 of 5000 Total Reward: 2622
# Episode: 424 of 5000 Total Reward: 2622
# Episode: 425 of 5000 Total Reward: 2724
# Episode: 426 of 5000 Total Reward: 2745
# Episode: 427 of 5000 Total Reward: 2763
# Episode: 428 of 5000 Total Reward: 2823
# Episode: 429 of 5000 Total Reward: 2700
# Episode: 430 of 5000 Total Reward: 2499
# Episode: 431 of 5000 Total Reward: 2796
# Episode: 432 of 5000 Total Reward: 2760
# Episode: 433 of 5000 Total Reward: 2547
# Episode: 434 of 5000 Total Reward: 2631
# Episode: 435 of 5000 Total Reward: 2562
# Episode: 436 of 5000 Total Reward: 2688
# Episode: 437 of 5000 Total Reward: 2787
# Episode: 438 of 5000 Total Reward: 2925
# Episode: 439 of 5000 Total Reward: 2670
# Episode: 440 of 5000 Total Reward: 2559
# Episode: 441 of 5000 Total Reward: 2532
# Episode: 442 of 5000 Total Reward: 2736
# Episode: 443 of 5000 Total Reward: 2505
# Episode: 444 of 5000 Total Reward: 2400
# Episode: 445 of 5000 Total Reward: 2709
# Episode: 446 of 5000 Total Reward: 2583
# Episode: 447 of 5000 Total Reward: 2418
# Episode: 448 of 5000 Total Reward: 2829
# Episode: 449 of 5000 Total Reward: 2454
# Episode: 450 of 5000 Total Reward: 2940
# Episode: 451 of 5000 Total Reward: 2541
# Episode: 452 of 5000 Total Reward: 2559
# Episode: 453 of 5000 Total Reward: 2469
# Episode: 454 of 5000 Total Reward: 2343
# Episode: 455 of 5000 Total Reward: 2877
# Episode: 456 of 5000 Total Reward: 2715
# Episode: 457 of 5000 Total Reward: 2388
# Episode: 458 of 5000 Total Reward: 2931
# Episode: 459 of 5000 Total Reward: 2565
# Episode: 460 of 5000 Total Reward: 2388
# Episode: 461 of 5000 Total Reward: 2634
# Episode: 462 of 5000 Total Reward: 2406
# Episode: 463 of 5000 Total Reward: 2586
# Episode: 464 of 5000 Total Reward: 2802
# Episode: 465 of 5000 Total Reward: 2409
# Episode: 466 of 5000 Total Reward: 2523
# Episode: 467 of 5000 Total Reward: 2397
# Episode: 468 of 5000 Total Reward: 2538
# Episode: 469 of 5000 Total Reward: 2673
# Episode: 470 of 5000 Total Reward: 2637
# Episode: 471 of 5000 Total Reward: 2574
# Episode: 472 of 5000 Total Reward: 2724
# Episode: 473 of 5000 Total Reward: 2403
# Episode: 474 of 5000 Total Reward: 2706
# Episode: 475 of 5000 Total Reward: 2535
# Episode: 476 of 5000 Total Reward: 2529
# Episode: 477 of 5000 Total Reward: 2643
# Episode: 478 of 5000 Total Reward: 2700
# Episode: 479 of 5000 Total Reward: 2589
# Episode: 480 of 5000 Total Reward: 2541
# Episode: 481 of 5000 Total Reward: 2409
# Episode: 482 of 5000 Total Reward: 2778
# Episode: 483 of 5000 Total Reward: 2805
# Episode: 484 of 5000 Total Reward: 2577
# Episode: 485 of 5000 Total Reward: 2778
# Episode: 486 of 5000 Total Reward: 2667
# Episode: 487 of 5000 Total Reward: 2607
# Episode: 488 of 5000 Total Reward: 2454
# Episode: 489 of 5000 Total Reward: 2568
# Episode: 490 of 5000 Total Reward: 2577
# Episode: 491 of 5000 Total Reward: 2952
# Episode: 492 of 5000 Total Reward: 2679
# Episode: 493 of 5000 Total Reward: 2574
# Episode: 494 of 5000 Total Reward: 2943
# Episode: 495 of 5000 Total Reward: 2715
# Episode: 496 of 5000 Total Reward: 2607
# Episode: 497 of 5000 Total Reward: 2538
# Episode: 498 of 5000 Total Reward: 2649
# Episode: 499 of 5000 Total Reward: 2448
# Episode: 500 of 5000 Total Reward: 2772
# Episode: 501 of 5000 Total Reward: 2538
# Episode: 502 of 5000 Total Reward: 2625
# Episode: 503 of 5000 Total Reward: 2793
# Episode: 504 of 5000 Total Reward: 2565
# Episode: 505 of 5000 Total Reward: 2409
# Episode: 506 of 5000 Total Reward: 2544
# Episode: 507 of 5000 Total Reward: 2712
# Episode: 508 of 5000 Total Reward: 2532
# Episode: 509 of 5000 Total Reward: 2679
# Episode: 510 of 5000 Total Reward: 2715
# Episode: 511 of 5000 Total Reward: 2730
# Episode: 512 of 5000 Total Reward: 2709
# Episode: 513 of 5000 Total Reward: 2403
# Episode: 514 of 5000 Total Reward: 2436
# Episode: 515 of 5000 Total Reward: 2436
# Episode: 516 of 5000 Total Reward: 2595
# Episode: 517 of 5000 Total Reward: 2709
# Episode: 518 of 5000 Total Reward: 2679
# Episode: 519 of 5000 Total Reward: 2457
# Episode: 520 of 5000 Total Reward: 2499
# Episode: 521 of 5000 Total Reward: 2487
# Episode: 522 of 5000 Total Reward: 2676
# Episode: 523 of 5000 Total Reward: 2700
# Episode: 524 of 5000 Total Reward: 2595
# Episode: 525 of 5000 Total Reward: 2535
# Episode: 526 of 5000 Total Reward: 2715
# Episode: 527 of 5000 Total Reward: 2934
# Episode: 528 of 5000 Total Reward: 2559
# Episode: 529 of 5000 Total Reward: 2922
# Episode: 530 of 5000 Total Reward: 2523
# Episode: 531 of 5000 Total Reward: 2889
# Episode: 532 of 5000 Total Reward: 2613
# Episode: 533 of 5000 Total Reward: 2700
# Episode: 534 of 5000 Total Reward: 2577
# Episode: 535 of 5000 Total Reward: 2733
# Episode: 536 of 5000 Total Reward: 2535
# Episode: 537 of 5000 Total Reward: 2457
# Episode: 538 of 5000 Total Reward: 2763
# Episode: 539 of 5000 Total Reward: 2694
# Episode: 540 of 5000 Total Reward: 2466
# Episode: 541 of 5000 Total Reward: 2517
# Episode: 542 of 5000 Total Reward: 2616
# Episode: 543 of 5000 Total Reward: 2733
# Episode: 544 of 5000 Total Reward: 2358
# Episode: 545 of 5000 Total Reward: 2538
# Episode: 546 of 5000 Total Reward: 2457
# Episode: 547 of 5000 Total Reward: 2481
# Episode: 548 of 5000 Total Reward: 2688
# Episode: 549 of 5000 Total Reward: 2427
# Episode: 550 of 5000 Total Reward: 2823
# Episode: 551 of 5000 Total Reward: 2706
# Episode: 552 of 5000 Total Reward: 2541
# Episode: 553 of 5000 Total Reward: 2490
# Episode: 554 of 5000 Total Reward: 2628
# Episode: 555 of 5000 Total Reward: 2532
# Episode: 556 of 5000 Total Reward: 2610
# Episode: 557 of 5000 Total Reward: 2697
# Episode: 558 of 5000 Total Reward: 2730
# Episode: 559 of 5000 Total Reward: 2664
# Episode: 560 of 5000 Total Reward: 2634
# Episode: 561 of 5000 Total Reward: 2694
# Episode: 562 of 5000 Total Reward: 2559
# Episode: 563 of 5000 Total Reward: 2376
# Episode: 564 of 5000 Total Reward: 2619
# Episode: 565 of 5000 Total Reward: 2655
# Episode: 566 of 5000 Total Reward: 2688
# Episode: 567 of 5000 Total Reward: 2757
# Episode: 568 of 5000 Total Reward: 2529
# Episode: 569 of 5000 Total Reward: 2541
# Episode: 570 of 5000 Total Reward: 2733
# Episode: 571 of 5000 Total Reward: 2520
# Episode: 572 of 5000 Total Reward: 2604
# Episode: 573 of 5000 Total Reward: 2751
# Episode: 574 of 5000 Total Reward: 2763
# Episode: 575 of 5000 Total Reward: 2664
# Episode: 576 of 5000 Total Reward: 2415
# Episode: 577 of 5000 Total Reward: 2637
# Episode: 578 of 5000 Total Reward: 2400
# Episode: 579 of 5000 Total Reward: 2667
# Episode: 580 of 5000 Total Reward: 2712
# Episode: 581 of 5000 Total Reward: 2904
# Episode: 582 of 5000 Total Reward: 2652
# Episode: 583 of 5000 Total Reward: 2313
# Episode: 584 of 5000 Total Reward: 2685
# Episode: 585 of 5000 Total Reward: 2538
# Episode: 586 of 5000 Total Reward: 2487
# Episode: 587 of 5000 Total Reward: 2589
# Episode: 588 of 5000 Total Reward: 2373
# Episode: 589 of 5000 Total Reward: 2682
# Episode: 590 of 5000 Total Reward: 2754
# Episode: 591 of 5000 Total Reward: 2748
# Episode: 592 of 5000 Total Reward: 2682
# Episode: 593 of 5000 Total Reward: 2823
# Episode: 594 of 5000 Total Reward: 2607
# Episode: 595 of 5000 Total Reward: 2775
# Episode: 596 of 5000 Total Reward: 2730
# Episode: 597 of 5000 Total Reward: 2676
# Episode: 598 of 5000 Total Reward: 2679
# Episode: 599 of 5000 Total Reward: 2589
# Episode: 600 of 5000 Total Reward: 2505
# Episode: 601 of 5000 Total Reward: 2538
# Episode: 602 of 5000 Total Reward: 2460
# Episode: 603 of 5000 Total Reward: 2667
# Episode: 604 of 5000 Total Reward: 2664
# Episode: 605 of 5000 Total Reward: 2739
# Episode: 606 of 5000 Total Reward: 2463
# Episode: 607 of 5000 Total Reward: 2745
# Episode: 608 of 5000 Total Reward: 2895
# Episode: 609 of 5000 Total Reward: 2700
# Episode: 610 of 5000 Total Reward: 2574
# Episode: 611 of 5000 Total Reward: 2382
# Episode: 612 of 5000 Total Reward: 2478
# Episode: 613 of 5000 Total Reward: 2685
# Episode: 614 of 5000 Total Reward: 2649
# Episode: 615 of 5000 Total Reward: 2589
# Episode: 616 of 5000 Total Reward: 2733
# Episode: 617 of 5000 Total Reward: 2889
# Episode: 618 of 5000 Total Reward: 2847
# Episode: 619 of 5000 Total Reward: 2412
# Episode: 620 of 5000 Total Reward: 2757
# Episode: 621 of 5000 Total Reward: 2451
# Episode: 622 of 5000 Total Reward: 2961
# Episode: 623 of 5000 Total Reward: 2661
# Episode: 624 of 5000 Total Reward: 2796
# Episode: 625 of 5000 Total Reward: 2661
# Episode: 626 of 5000 Total Reward: 2523
# Episode: 627 of 5000 Total Reward: 2634
# Episode: 628 of 5000 Total Reward: 2442
# Episode: 629 of 5000 Total Reward: 2517
# Episode: 630 of 5000 Total Reward: 2469
# Episode: 631 of 5000 Total Reward: 2616
# Episode: 632 of 5000 Total Reward: 2634
# Episode: 633 of 5000 Total Reward: 2697
# Episode: 634 of 5000 Total Reward: 2883
# Episode: 635 of 5000 Total Reward: 2466
# Episode: 636 of 5000 Total Reward: 2580
# Episode: 637 of 5000 Total Reward: 2628
# Episode: 638 of 5000 Total Reward: 2664
# Episode: 639 of 5000 Total Reward: 2523
# Episode: 640 of 5000 Total Reward: 2706
# Episode: 641 of 5000 Total Reward: 2553
# Episode: 642 of 5000 Total Reward: 2790
# Episode: 643 of 5000 Total Reward: 2712
# Episode: 644 of 5000 Total Reward: 2742
# Episode: 645 of 5000 Total Reward: 2553
# Episode: 646 of 5000 Total Reward: 2622
# Episode: 647 of 5000 Total Reward: 2637
# Episode: 648 of 5000 Total Reward: 2601
# Episode: 649 of 5000 Total Reward: 2490
# Episode: 650 of 5000 Total Reward: 2547
# Episode: 651 of 5000 Total Reward: 2634
# Episode: 652 of 5000 Total Reward: 2703
# Episode: 653 of 5000 Total Reward: 2661
# Episode: 654 of 5000 Total Reward: 2358
# Episode: 655 of 5000 Total Reward: 2502
# Episode: 656 of 5000 Total Reward: 2730
# Episode: 657 of 5000 Total Reward: 2451
# Episode: 658 of 5000 Total Reward: 2517
# Episode: 659 of 5000 Total Reward: 2763
# Episode: 660 of 5000 Total Reward: 2751
# Episode: 661 of 5000 Total Reward: 2694
# Episode: 662 of 5000 Total Reward: 2715
# Episode: 663 of 5000 Total Reward: 2595
# Episode: 664 of 5000 Total Reward: 2637
# Episode: 665 of 5000 Total Reward: 2715
# Episode: 666 of 5000 Total Reward: 2763
# Episode: 667 of 5000 Total Reward: 2640
# Episode: 668 of 5000 Total Reward: 2634
# Episode: 669 of 5000 Total Reward: 2697
# Episode: 670 of 5000 Total Reward: 2577
# Episode: 671 of 5000 Total Reward: 2553
# Episode: 672 of 5000 Total Reward: 2517
# Episode: 673 of 5000 Total Reward: 2742
# Episode: 674 of 5000 Total Reward: 2610
# Episode: 675 of 5000 Total Reward: 2808
# Episode: 676 of 5000 Total Reward: 2541
# Episode: 677 of 5000 Total Reward: 2736
# Episode: 678 of 5000 Total Reward: 2694
# Episode: 679 of 5000 Total Reward: 2667
# Episode: 680 of 5000 Total Reward: 2619
# Episode: 681 of 5000 Total Reward: 2610
# Episode: 682 of 5000 Total Reward: 2718
# Episode: 683 of 5000 Total Reward: 2643
# Episode: 684 of 5000 Total Reward: 2532
# Episode: 685 of 5000 Total Reward: 2502
# Episode: 686 of 5000 Total Reward: 2520
# Episode: 687 of 5000 Total Reward: 2676
# Episode: 688 of 5000 Total Reward: 2793
# Episode: 689 of 5000 Total Reward: 2691
# Episode: 690 of 5000 Total Reward: 2580
# Episode: 691 of 5000 Total Reward: 2937
# Episode: 692 of 5000 Total Reward: 2514
# Episode: 693 of 5000 Total Reward: 2637
# Episode: 694 of 5000 Total Reward: 2709
# Episode: 695 of 5000 Total Reward: 2592
# Episode: 696 of 5000 Total Reward: 2490
# Episode: 697 of 5000 Total Reward: 2847
# Episode: 698 of 5000 Total Reward: 2715
# Episode: 699 of 5000 Total Reward: 2394
# Episode: 700 of 5000 Total Reward: 2679
# Episode: 701 of 5000 Total Reward: 2694
# Episode: 702 of 5000 Total Reward: 2730
# Episode: 703 of 5000 Total Reward: 2691
# Episode: 704 of 5000 Total Reward: 2694
# Episode: 705 of 5000 Total Reward: 2454
# Episode: 706 of 5000 Total Reward: 2682
# Episode: 707 of 5000 Total Reward: 2628
# Episode: 708 of 5000 Total Reward: 2616
# Episode: 709 of 5000 Total Reward: 2880
# Episode: 710 of 5000 Total Reward: 2466
# Episode: 711 of 5000 Total Reward: 2517
# Episode: 712 of 5000 Total Reward: 2781
# Episode: 713 of 5000 Total Reward: 2559
# Episode: 714 of 5000 Total Reward: 2544
# Episode: 715 of 5000 Total Reward: 2382
# Episode: 716 of 5000 Total Reward: 2850
# Episode: 717 of 5000 Total Reward: 2640
# Episode: 718 of 5000 Total Reward: 2691
# Episode: 719 of 5000 Total Reward: 2586
# Episode: 720 of 5000 Total Reward: 2652
# Episode: 721 of 5000 Total Reward: 2649
# Episode: 722 of 5000 Total Reward: 2730
# Episode: 723 of 5000 Total Reward: 2601
# Episode: 724 of 5000 Total Reward: 2436
# Episode: 725 of 5000 Total Reward: 2220
# Episode: 726 of 5000 Total Reward: 2508
# Episode: 727 of 5000 Total Reward: 2721
# Episode: 728 of 5000 Total Reward: 2697
# Episode: 729 of 5000 Total Reward: 2811
# Episode: 730 of 5000 Total Reward: 2559
# Episode: 731 of 5000 Total Reward: 2466
# Episode: 732 of 5000 Total Reward: 2661
# Episode: 733 of 5000 Total Reward: 2358
# Episode: 734 of 5000 Total Reward: 2688
# Episode: 735 of 5000 Total Reward: 2463
# Episode: 736 of 5000 Total Reward: 2523
# Episode: 737 of 5000 Total Reward: 2496
# Episode: 738 of 5000 Total Reward: 2850
# Episode: 739 of 5000 Total Reward: 2931
# Episode: 740 of 5000 Total Reward: 2595
# Episode: 741 of 5000 Total Reward: 2610
# Episode: 742 of 5000 Total Reward: 2640
# Episode: 743 of 5000 Total Reward: 2586
# Episode: 744 of 5000 Total Reward: 2562
# Episode: 745 of 5000 Total Reward: 2811
# Episode: 746 of 5000 Total Reward: 2568
# Episode: 747 of 5000 Total Reward: 2472
# Episode: 748 of 5000 Total Reward: 2598
# Episode: 749 of 5000 Total Reward: 2493
# Episode: 750 of 5000 Total Reward: 2643
# Episode: 751 of 5000 Total Reward: 2697
# Episode: 752 of 5000 Total Reward: 2712
# Episode: 753 of 5000 Total Reward: 2727
# Episode: 754 of 5000 Total Reward: 2532
# Episode: 755 of 5000 Total Reward: 2694
# Episode: 756 of 5000 Total Reward: 2532
# Episode: 757 of 5000 Total Reward: 2814
# Episode: 758 of 5000 Total Reward: 2481
# Episode: 759 of 5000 Total Reward: 2973
# Episode: 760 of 5000 Total Reward: 2640
# Episode: 761 of 5000 Total Reward: 2484
# Episode: 762 of 5000 Total Reward: 2553
# Episode: 763 of 5000 Total Reward: 2733
# Episode: 764 of 5000 Total Reward: 2472
# Episode: 765 of 5000 Total Reward: 2598
# Episode: 766 of 5000 Total Reward: 2724
# Episode: 767 of 5000 Total Reward: 2571
# Episode: 768 of 5000 Total Reward: 2535
# Episode: 769 of 5000 Total Reward: 2451
# Episode: 770 of 5000 Total Reward: 2700
# Episode: 771 of 5000 Total Reward: 2580
# Episode: 772 of 5000 Total Reward: 2781
# Episode: 773 of 5000 Total Reward: 2796
# Episode: 774 of 5000 Total Reward: 2706
# Episode: 775 of 5000 Total Reward: 2652
# Episode: 776 of 5000 Total Reward: 2718
# Episode: 777 of 5000 Total Reward: 2613
# Episode: 778 of 5000 Total Reward: 2742
# Episode: 779 of 5000 Total Reward: 2493
# Episode: 780 of 5000 Total Reward: 2718
# Episode: 781 of 5000 Total Reward: 2475
# Episode: 782 of 5000 Total Reward: 2412
# Episode: 783 of 5000 Total Reward: 2745
# Episode: 784 of 5000 Total Reward: 2721
# Episode: 785 of 5000 Total Reward: 2664
# Episode: 786 of 5000 Total Reward: 2490
# Episode: 787 of 5000 Total Reward: 2892
# Episode: 788 of 5000 Total Reward: 2550
# Episode: 789 of 5000 Total Reward: 2412
# Episode: 790 of 5000 Total Reward: 2442
# Episode: 791 of 5000 Total Reward: 2604
# Episode: 792 of 5000 Total Reward: 2616
# Episode: 793 of 5000 Total Reward: 2622
# Episode: 794 of 5000 Total Reward: 2532
# Episode: 795 of 5000 Total Reward: 2808
# Episode: 796 of 5000 Total Reward: 2742
# Episode: 797 of 5000 Total Reward: 2634
# Episode: 798 of 5000 Total Reward: 2553
# Episode: 799 of 5000 Total Reward: 2499
# Episode: 800 of 5000 Total Reward: 2664
# Episode: 801 of 5000 Total Reward: 2721
# Episode: 802 of 5000 Total Reward: 2685
# Episode: 803 of 5000 Total Reward: 2667
# Episode: 804 of 5000 Total Reward: 2703
# Episode: 805 of 5000 Total Reward: 2694
# Episode: 806 of 5000 Total Reward: 2631
# Episode: 807 of 5000 Total Reward: 2646
# Episode: 808 of 5000 Total Reward: 2589
# Episode: 809 of 5000 Total Reward: 2772
# Episode: 810 of 5000 Total Reward: 2496
# Episode: 811 of 5000 Total Reward: 2598
# Episode: 812 of 5000 Total Reward: 2601
# Episode: 813 of 5000 Total Reward: 2415
# Episode: 814 of 5000 Total Reward: 2574
# Episode: 815 of 5000 Total Reward: 2739
# Episode: 816 of 5000 Total Reward: 2856
# Episode: 817 of 5000 Total Reward: 2628
# Episode: 818 of 5000 Total Reward: 2436
# Episode: 819 of 5000 Total Reward: 2598
# Episode: 820 of 5000 Total Reward: 2601
# Episode: 821 of 5000 Total Reward: 2628
# Episode: 822 of 5000 Total Reward: 2421
# Episode: 823 of 5000 Total Reward: 2700
# Episode: 824 of 5000 Total Reward: 2718
# Episode: 825 of 5000 Total Reward: 2664
# Episode: 826 of 5000 Total Reward: 2574
# Episode: 827 of 5000 Total Reward: 2487
# Episode: 828 of 5000 Total Reward: 2373
# Episode: 829 of 5000 Total Reward: 2670
# Episode: 830 of 5000 Total Reward: 2748
# Episode: 831 of 5000 Total Reward: 2532
# Episode: 832 of 5000 Total Reward: 2727
# Episode: 833 of 5000 Total Reward: 2610
# Episode: 834 of 5000 Total Reward: 2850
# Episode: 835 of 5000 Total Reward: 2529
# Episode: 836 of 5000 Total Reward: 2691
# Episode: 837 of 5000 Total Reward: 2619
# Episode: 838 of 5000 Total Reward: 2640
# Episode: 839 of 5000 Total Reward: 2694
# Episode: 840 of 5000 Total Reward: 2592
# Episode: 841 of 5000 Total Reward: 2814
# Episode: 842 of 5000 Total Reward: 2439
# Episode: 843 of 5000 Total Reward: 2814
# Episode: 844 of 5000 Total Reward: 2745
# Episode: 845 of 5000 Total Reward: 2388
# Episode: 846 of 5000 Total Reward: 2778
# Episode: 847 of 5000 Total Reward: 2463
# Episode: 848 of 5000 Total Reward: 2760
# Episode: 849 of 5000 Total Reward: 2484
# Episode: 850 of 5000 Total Reward: 2736
# Episode: 851 of 5000 Total Reward: 2682
# Episode: 852 of 5000 Total Reward: 2406
# Episode: 853 of 5000 Total Reward: 2457
# Episode: 854 of 5000 Total Reward: 2775
# Episode: 855 of 5000 Total Reward: 2556
# Episode: 856 of 5000 Total Reward: 2739
# Episode: 857 of 5000 Total Reward: 2688
# Episode: 858 of 5000 Total Reward: 2760
# Episode: 859 of 5000 Total Reward: 2892
# Episode: 860 of 5000 Total Reward: 2685
# Episode: 861 of 5000 Total Reward: 2673
# Episode: 862 of 5000 Total Reward: 2496
# Episode: 863 of 5000 Total Reward: 2700
# Episode: 864 of 5000 Total Reward: 2691
# Episode: 865 of 5000 Total Reward: 2544
# Episode: 866 of 5000 Total Reward: 2688
# Episode: 867 of 5000 Total Reward: 2502
# Episode: 868 of 5000 Total Reward: 2616
# Episode: 869 of 5000 Total Reward: 2631
# Episode: 870 of 5000 Total Reward: 2673
# Episode: 871 of 5000 Total Reward: 2559
# Episode: 872 of 5000 Total Reward: 2514
# Episode: 873 of 5000 Total Reward: 2715
# Episode: 874 of 5000 Total Reward: 2553
# Episode: 875 of 5000 Total Reward: 2781
# Episode: 876 of 5000 Total Reward: 2571
# Episode: 877 of 5000 Total Reward: 2625
# Episode: 878 of 5000 Total Reward: 2541
# Episode: 879 of 5000 Total Reward: 2781
# Episode: 880 of 5000 Total Reward: 2631
# Episode: 881 of 5000 Total Reward: 2859
# Episode: 882 of 5000 Total Reward: 2838
# Episode: 883 of 5000 Total Reward: 2796
# Episode: 884 of 5000 Total Reward: 2586
# Episode: 885 of 5000 Total Reward: 2697
# Episode: 886 of 5000 Total Reward: 2616
# Episode: 887 of 5000 Total Reward: 2784
# Episode: 888 of 5000 Total Reward: 2400
# Episode: 889 of 5000 Total Reward: 2805
# Episode: 890 of 5000 Total Reward: 2691
# Episode: 891 of 5000 Total Reward: 2601
# Episode: 892 of 5000 Total Reward: 2646
# Episode: 893 of 5000 Total Reward: 2565
# Episode: 894 of 5000 Total Reward: 2643
# Episode: 895 of 5000 Total Reward: 2619
# Episode: 896 of 5000 Total Reward: 2673
# Episode: 897 of 5000 Total Reward: 2532
# Episode: 898 of 5000 Total Reward: 2601
# Episode: 899 of 5000 Total Reward: 2586
# Episode: 900 of 5000 Total Reward: 2832
# Episode: 901 of 5000 Total Reward: 2604
# Episode: 902 of 5000 Total Reward: 2409
# Episode: 903 of 5000 Total Reward: 2679
# Episode: 904 of 5000 Total Reward: 2496
# Episode: 905 of 5000 Total Reward: 2556
# Episode: 906 of 5000 Total Reward: 2331
# Episode: 907 of 5000 Total Reward: 2850
# Episode: 908 of 5000 Total Reward: 2559
# Episode: 909 of 5000 Total Reward: 2817
# Episode: 910 of 5000 Total Reward: 2820
# Episode: 911 of 5000 Total Reward: 2694
# Episode: 912 of 5000 Total Reward: 2418
# Episode: 913 of 5000 Total Reward: 2505
# Episode: 914 of 5000 Total Reward: 2523
# Episode: 915 of 5000 Total Reward: 2589
# Episode: 916 of 5000 Total Reward: 2499
# Episode: 917 of 5000 Total Reward: 2472
# Episode: 918 of 5000 Total Reward: 2694
# Episode: 919 of 5000 Total Reward: 2430
# Episode: 920 of 5000 Total Reward: 2586
# Episode: 921 of 5000 Total Reward: 2814
# Episode: 922 of 5000 Total Reward: 2541
# Episode: 923 of 5000 Total Reward: 2820
# Episode: 924 of 5000 Total Reward: 2658
# Episode: 925 of 5000 Total Reward: 2670
# Episode: 926 of 5000 Total Reward: 2469
# Episode: 927 of 5000 Total Reward: 2745
# Episode: 928 of 5000 Total Reward: 2655
# Episode: 929 of 5000 Total Reward: 2358
# Episode: 930 of 5000 Total Reward: 2643
# Episode: 931 of 5000 Total Reward: 2556
# Episode: 932 of 5000 Total Reward: 2574
# Episode: 933 of 5000 Total Reward: 2529
# Episode: 934 of 5000 Total Reward: 2649
# Episode: 935 of 5000 Total Reward: 2709
# Episode: 936 of 5000 Total Reward: 2475
# Episode: 937 of 5000 Total Reward: 2526
# Episode: 938 of 5000 Total Reward: 2667
# Episode: 939 of 5000 Total Reward: 2523
# Episode: 940 of 5000 Total Reward: 2550
# Episode: 941 of 5000 Total Reward: 2526
# Episode: 942 of 5000 Total Reward: 2802
# Episode: 943 of 5000 Total Reward: 2718
# Episode: 944 of 5000 Total Reward: 2415
# Episode: 945 of 5000 Total Reward: 2784
# Episode: 946 of 5000 Total Reward: 2940
# Episode: 947 of 5000 Total Reward: 2598
# Episode: 948 of 5000 Total Reward: 2610
# Episode: 949 of 5000 Total Reward: 2880
# Episode: 950 of 5000 Total Reward: 2697
# Episode: 951 of 5000 Total Reward: 2754
# Episode: 952 of 5000 Total Reward: 2400
# Episode: 953 of 5000 Total Reward: 2532
# Episode: 954 of 5000 Total Reward: 2751
# Episode: 955 of 5000 Total Reward: 2610
# Episode: 956 of 5000 Total Reward: 2787
# Episode: 957 of 5000 Total Reward: 2751
# Episode: 958 of 5000 Total Reward: 2589
# Episode: 959 of 5000 Total Reward: 2691
# Episode: 960 of 5000 Total Reward: 2511
# Episode: 961 of 5000 Total Reward: 2643
# Episode: 962 of 5000 Total Reward: 2955
# Episode: 963 of 5000 Total Reward: 2670
# Episode: 964 of 5000 Total Reward: 2448
# Episode: 965 of 5000 Total Reward: 2586
# Episode: 966 of 5000 Total Reward: 2481
# Episode: 967 of 5000 Total Reward: 2598
# Episode: 968 of 5000 Total Reward: 2688
# Episode: 969 of 5000 Total Reward: 2640
# Episode: 970 of 5000 Total Reward: 2817
# Episode: 971 of 5000 Total Reward: 2592
# Episode: 972 of 5000 Total Reward: 2394
# Episode: 973 of 5000 Total Reward: 2751
# Episode: 974 of 5000 Total Reward: 2595
# Episode: 975 of 5000 Total Reward: 2835
# Episode: 976 of 5000 Total Reward: 2865
# Episode: 977 of 5000 Total Reward: 2712
# Episode: 978 of 5000 Total Reward: 2691
# Episode: 979 of 5000 Total Reward: 2460
# Episode: 980 of 5000 Total Reward: 2535
# Episode: 981 of 5000 Total Reward: 2787
# Episode: 982 of 5000 Total Reward: 2700
# Episode: 983 of 5000 Total Reward: 2478
# Episode: 984 of 5000 Total Reward: 2418
# Episode: 985 of 5000 Total Reward: 2811
# Episode: 986 of 5000 Total Reward: 2895
# Episode: 987 of 5000 Total Reward: 2541
# Episode: 988 of 5000 Total Reward: 2601
# Episode: 989 of 5000 Total Reward: 2745
# Episode: 990 of 5000 Total Reward: 2796
# Episode: 991 of 5000 Total Reward: 2598
# Episode: 992 of 5000 Total Reward: 2475
# Episode: 993 of 5000 Total Reward: 2553
# Episode: 994 of 5000 Total Reward: 2610
# Episode: 995 of 5000 Total Reward: 2571
# Episode: 996 of 5000 Total Reward: 2760
# Episode: 997 of 5000 Total Reward: 2622
# Episode: 998 of 5000 Total Reward: 2634
# Episode: 999 of 5000 Total Reward: 2658
# Episode: 1000 of 5000 Total Reward: 2907
# Episode: 1001 of 5000 Total Reward: 2622
# Episode: 1002 of 5000 Total Reward: 2571
# Episode: 1003 of 5000 Total Reward: 2625
# Episode: 1004 of 5000 Total Reward: 2688
# Episode: 1005 of 5000 Total Reward: 2727
# Episode: 1006 of 5000 Total Reward: 2619
# Episode: 1007 of 5000 Total Reward: 2721
# Episode: 1008 of 5000 Total Reward: 2595
# Episode: 1009 of 5000 Total Reward: 2595
# Episode: 1010 of 5000 Total Reward: 2523
# Episode: 1011 of 5000 Total Reward: 2598
# Episode: 1012 of 5000 Total Reward: 2532
# Episode: 1013 of 5000 Total Reward: 2592
# Episode: 1014 of 5000 Total Reward: 2667
# Episode: 1015 of 5000 Total Reward: 2610
# Episode: 1016 of 5000 Total Reward: 2577
# Episode: 1017 of 5000 Total Reward: 2682
# Episode: 1018 of 5000 Total Reward: 2619
# Episode: 1019 of 5000 Total Reward: 2547
# Episode: 1020 of 5000 Total Reward: 2649
# Episode: 1021 of 5000 Total Reward: 2808
# Episode: 1022 of 5000 Total Reward: 2778
# Episode: 1023 of 5000 Total Reward: 2781
# Episode: 1024 of 5000 Total Reward: 2817
# Episode: 1025 of 5000 Total Reward: 2538
# Episode: 1026 of 5000 Total Reward: 2640
# Episode: 1027 of 5000 Total Reward: 2796
# Episode: 1028 of 5000 Total Reward: 2487
# Episode: 1029 of 5000 Total Reward: 2616
# Episode: 1030 of 5000 Total Reward: 2700
# Episode: 1031 of 5000 Total Reward: 2658
# Episode: 1032 of 5000 Total Reward: 2580
# Episode: 1033 of 5000 Total Reward: 2904
# Episode: 1034 of 5000 Total Reward: 2532
# Episode: 1035 of 5000 Total Reward: 2592
# Episode: 1036 of 5000 Total Reward: 2760
# Episode: 1037 of 5000 Total Reward: 2748
# Episode: 1038 of 5000 Total Reward: 2601
# Episode: 1039 of 5000 Total Reward: 2706
# Episode: 1040 of 5000 Total Reward: 2673
# Episode: 1041 of 5000 Total Reward: 2718
# Episode: 1042 of 5000 Total Reward: 2436
# Episode: 1043 of 5000 Total Reward: 2658
# Episode: 1044 of 5000 Total Reward: 2823
# Episode: 1045 of 5000 Total Reward: 2880
# Episode: 1046 of 5000 Total Reward: 2643
# Episode: 1047 of 5000 Total Reward: 2667
# Episode: 1048 of 5000 Total Reward: 2634
# Episode: 1049 of 5000 Total Reward: 2760
# Episode: 1050 of 5000 Total Reward: 2679
# Episode: 1051 of 5000 Total Reward: 2535
# Episode: 1052 of 5000 Total Reward: 2694
# Episode: 1053 of 5000 Total Reward: 2502
# Episode: 1054 of 5000 Total Reward: 2655
# Episode: 1055 of 5000 Total Reward: 2580
# Episode: 1056 of 5000 Total Reward: 2655
# Episode: 1057 of 5000 Total Reward: 2514
# Episode: 1058 of 5000 Total Reward: 2676
# Episode: 1059 of 5000 Total Reward: 2904
# Episode: 1060 of 5000 Total Reward: 2814
# Episode: 1061 of 5000 Total Reward: 2637
# Episode: 1062 of 5000 Total Reward: 2721
# Episode: 1063 of 5000 Total Reward: 2616
# Episode: 1064 of 5000 Total Reward: 2511
# Episode: 1065 of 5000 Total Reward: 2577
# Episode: 1066 of 5000 Total Reward: 2730
# Episode: 1067 of 5000 Total Reward: 2328
# Episode: 1068 of 5000 Total Reward: 2598
# Episode: 1069 of 5000 Total Reward: 2640
# Episode: 1070 of 5000 Total Reward: 2589
# Episode: 1071 of 5000 Total Reward: 2667
# Episode: 1072 of 5000 Total Reward: 2598
# Episode: 1073 of 5000 Total Reward: 2505
# Episode: 1074 of 5000 Total Reward: 2694
# Episode: 1075 of 5000 Total Reward: 2595
# Episode: 1076 of 5000 Total Reward: 2421
# Episode: 1077 of 5000 Total Reward: 2658
# Episode: 1078 of 5000 Total Reward: 2886
# Episode: 1079 of 5000 Total Reward: 2514
# Episode: 1080 of 5000 Total Reward: 2550
# Episode: 1081 of 5000 Total Reward: 2841
# Episode: 1082 of 5000 Total Reward: 2565
# Episode: 1083 of 5000 Total Reward: 2673
# Episode: 1084 of 5000 Total Reward: 2694
# Episode: 1085 of 5000 Total Reward: 2697
# Episode: 1086 of 5000 Total Reward: 2508
# Episode: 1087 of 5000 Total Reward: 2730
# Episode: 1088 of 5000 Total Reward: 2568
# Episode: 1089 of 5000 Total Reward: 2598
# Episode: 1090 of 5000 Total Reward: 2823
# Episode: 1091 of 5000 Total Reward: 2688
# Episode: 1092 of 5000 Total Reward: 2523
# Episode: 1093 of 5000 Total Reward: 2838
# Episode: 1094 of 5000 Total Reward: 2535
# Episode: 1095 of 5000 Total Reward: 2724
# Episode: 1096 of 5000 Total Reward: 2736
# Episode: 1097 of 5000 Total Reward: 2613
# Episode: 1098 of 5000 Total Reward: 2592
# Episode: 1099 of 5000 Total Reward: 2793
# Episode: 1100 of 5000 Total Reward: 2793
# Episode: 1101 of 5000 Total Reward: 2781
# Episode: 1102 of 5000 Total Reward: 2499
# Episode: 1103 of 5000 Total Reward: 2862
# Episode: 1104 of 5000 Total Reward: 2538
# Episode: 1105 of 5000 Total Reward: 2607
# Episode: 1106 of 5000 Total Reward: 2643
# Episode: 1107 of 5000 Total Reward: 2451
# Episode: 1108 of 5000 Total Reward: 2799
# Episode: 1109 of 5000 Total Reward: 2484
# Episode: 1110 of 5000 Total Reward: 2655
# Episode: 1111 of 5000 Total Reward: 2799
# Episode: 1112 of 5000 Total Reward: 2697
# Episode: 1113 of 5000 Total Reward: 2841
# Episode: 1114 of 5000 Total Reward: 2679
# Episode: 1115 of 5000 Total Reward: 2700
# Episode: 1116 of 5000 Total Reward: 2580
# Episode: 1117 of 5000 Total Reward: 2691
# Episode: 1118 of 5000 Total Reward: 2715
# Episode: 1119 of 5000 Total Reward: 2457
# Episode: 1120 of 5000 Total Reward: 2508
# Episode: 1121 of 5000 Total Reward: 2610
# Episode: 1122 of 5000 Total Reward: 2466
# Episode: 1123 of 5000 Total Reward: 2583
# Episode: 1124 of 5000 Total Reward: 2634
# Episode: 1125 of 5000 Total Reward: 2568
# Episode: 1126 of 5000 Total Reward: 2547
# Episode: 1127 of 5000 Total Reward: 2667
# Episode: 1128 of 5000 Total Reward: 2886
# Episode: 1129 of 5000 Total Reward: 2607
# Episode: 1130 of 5000 Total Reward: 2676
# Episode: 1131 of 5000 Total Reward: 2673
# Episode: 1132 of 5000 Total Reward: 2664
# Episode: 1133 of 5000 Total Reward: 2622
# Episode: 1134 of 5000 Total Reward: 2535
# Episode: 1135 of 5000 Total Reward: 2766
# Episode: 1136 of 5000 Total Reward: 2550
# Episode: 1137 of 5000 Total Reward: 2532
# Episode: 1138 of 5000 Total Reward: 2760
# Episode: 1139 of 5000 Total Reward: 2535
# Episode: 1140 of 5000 Total Reward: 2862
# Episode: 1141 of 5000 Total Reward: 2490
# Episode: 1142 of 5000 Total Reward: 2352
# Episode: 1143 of 5000 Total Reward: 2772
# Episode: 1144 of 5000 Total Reward: 2610
# Episode: 1145 of 5000 Total Reward: 2826
# Episode: 1146 of 5000 Total Reward: 2721
# Episode: 1147 of 5000 Total Reward: 2841
# Episode: 1148 of 5000 Total Reward: 2895
# Episode: 1149 of 5000 Total Reward: 2577
# Episode: 1150 of 5000 Total Reward: 2673
# Episode: 1151 of 5000 Total Reward: 2526
# Episode: 1152 of 5000 Total Reward: 2823
# Episode: 1153 of 5000 Total Reward: 2604
# Episode: 1154 of 5000 Total Reward: 2898
# Episode: 1155 of 5000 Total Reward: 2751
# Episode: 1156 of 5000 Total Reward: 2520
# Episode: 1157 of 5000 Total Reward: 2550
# Episode: 1158 of 5000 Total Reward: 2691
# Episode: 1159 of 5000 Total Reward: 2610
# Episode: 1160 of 5000 Total Reward: 2631
# Episode: 1161 of 5000 Total Reward: 2655
# Episode: 1162 of 5000 Total Reward: 2502
# Episode: 1163 of 5000 Total Reward: 2472
# Episode: 1164 of 5000 Total Reward: 2748
# Episode: 1165 of 5000 Total Reward: 2862
# Episode: 1166 of 5000 Total Reward: 2496
# Episode: 1167 of 5000 Total Reward: 2775
# Episode: 1168 of 5000 Total Reward: 2607
# Episode: 1169 of 5000 Total Reward: 2334
# Episode: 1170 of 5000 Total Reward: 2730
# Episode: 1171 of 5000 Total Reward: 2496
# Episode: 1172 of 5000 Total Reward: 2568
# Episode: 1173 of 5000 Total Reward: 2826
# Episode: 1174 of 5000 Total Reward: 2490
# Episode: 1175 of 5000 Total Reward: 2595
# Episode: 1176 of 5000 Total Reward: 2745
# Episode: 1177 of 5000 Total Reward: 2535
# Episode: 1178 of 5000 Total Reward: 2736
# Episode: 1179 of 5000 Total Reward: 2643
# Episode: 1180 of 5000 Total Reward: 2844
# Episode: 1181 of 5000 Total Reward: 2757
# Episode: 1182 of 5000 Total Reward: 2727
# Episode: 1183 of 5000 Total Reward: 2646
# Episode: 1184 of 5000 Total Reward: 2601
# Episode: 1185 of 5000 Total Reward: 2604
# Episode: 1186 of 5000 Total Reward: 2580
# Episode: 1187 of 5000 Total Reward: 2850
# Episode: 1188 of 5000 Total Reward: 2670
# Episode: 1189 of 5000 Total Reward: 2481
# Episode: 1190 of 5000 Total Reward: 2550
# Episode: 1191 of 5000 Total Reward: 2628
# Episode: 1192 of 5000 Total Reward: 2376
# Episode: 1193 of 5000 Total Reward: 2367
# Episode: 1194 of 5000 Total Reward: 2628
# Episode: 1195 of 5000 Total Reward: 2421
# Episode: 1196 of 5000 Total Reward: 2604
# Episode: 1197 of 5000 Total Reward: 2751
# ...
# Episode: 4611 of 5000 Total Reward: 2607
# Episode: 4612 of 5000 Total Reward: 2451
# Episode: 4613 of 5000 Total Reward: 2739
# Episode: 4614 of 5000 Total Reward: 2571
# Episode: 4615 of 5000 Total Reward: 2523
# Episode: 4616 of 5000 Total Reward: 2574
# Episode: 4617 of 5000 Total Reward: 2508
# Episode: 4618 of 5000 Total Reward: 2766
# Episode: 4619 of 5000 Total Reward: 2811
# Episode: 4620 of 5000 Total Reward: 2625
# Episode: 4621 of 5000 Total Reward: 2547
# Episode: 4622 of 5000 Total Reward: 2730
# Episode: 4623 of 5000 Total Reward: 2553
# Episode: 4624 of 5000 Total Reward: 3012
# Episode: 4625 of 5000 Total Reward: 2766
# Episode: 4626 of 5000 Total Reward: 2688
# Episode: 4627 of 5000 Total Reward: 2724
# Episode: 4628 of 5000 Total Reward: 2625
# Episode: 4629 of 5000 Total Reward: 2739
# Episode: 4630 of 5000 Total Reward: 2658
# Episode: 4631 of 5000 Total Reward: 2754
# Episode: 4632 of 5000 Total Reward: 2727
# Episode: 4633 of 5000 Total Reward: 2667
# Episode: 4634 of 5000 Total Reward: 2700
# Episode: 4635 of 5000 Total Reward: 2667
# Episode: 4636 of 5000 Total Reward: 2682
# Episode: 4637 of 5000 Total Reward: 2901
# Episode: 4638 of 5000 Total Reward: 2682
# Episode: 4639 of 5000 Total Reward: 2604
# Episode: 4640 of 5000 Total Reward: 2808
# Episode: 4641 of 5000 Total Reward: 2574
# Episode: 4642 of 5000 Total Reward: 2613
# Episode: 4643 of 5000 Total Reward: 2418
# Episode: 4644 of 5000 Total Reward: 2544
# Episode: 4645 of 5000 Total Reward: 2718
# Episode: 4646 of 5000 Total Reward: 2442
# Episode: 4647 of 5000 Total Reward: 2631
# Episode: 4648 of 5000 Total Reward: 2673
# Episode: 4649 of 5000 Total Reward: 2553
# Episode: 4650 of 5000 Total Reward: 2721
# Episode: 4651 of 5000 Total Reward: 2607
# Episode: 4652 of 5000 Total Reward: 2436
# Episode: 4653 of 5000 Total Reward: 2337
# Episode: 4654 of 5000 Total Reward: 2562
# Episode: 4655 of 5000 Total Reward: 2442
# Episode: 4656 of 5000 Total Reward: 2553
# Episode: 4657 of 5000 Total Reward: 2889
# Episode: 4658 of 5000 Total Reward: 2508
# Episode: 4659 of 5000 Total Reward: 2715
# Episode: 4660 of 5000 Total Reward: 2751
# Episode: 4661 of 5000 Total Reward: 2754
# Episode: 4662 of 5000 Total Reward: 2433
# Episode: 4663 of 5000 Total Reward: 2538
# Episode: 4664 of 5000 Total Reward: 2787
# Episode: 4665 of 5000 Total Reward: 2814
# Episode: 4666 of 5000 Total Reward: 2604
# Episode: 4667 of 5000 Total Reward: 2817
# Episode: 4668 of 5000 Total Reward: 2589
# Episode: 4669 of 5000 Total Reward: 2685
# Episode: 4670 of 5000 Total Reward: 2427
# Episode: 4671 of 5000 Total Reward: 2751
# Episode: 4672 of 5000 Total Reward: 2766
# Episode: 4673 of 5000 Total Reward: 2844
# Episode: 4674 of 5000 Total Reward: 2562
# Episode: 4675 of 5000 Total Reward: 2373
# Episode: 4676 of 5000 Total Reward: 2556
# Episode: 4677 of 5000 Total Reward: 2442
# Episode: 4678 of 5000 Total Reward: 2709
# Episode: 4679 of 5000 Total Reward: 2949
# Episode: 4680 of 5000 Total Reward: 2511
# Episode: 4681 of 5000 Total Reward: 2478
# Episode: 4682 of 5000 Total Reward: 2649
# Episode: 4683 of 5000 Total Reward: 2769
# Episode: 4684 of 5000 Total Reward: 2709
# Episode: 4685 of 5000 Total Reward: 2604
# Episode: 4686 of 5000 Total Reward: 2619
# Episode: 4687 of 5000 Total Reward: 2610
# Episode: 4688 of 5000 Total Reward: 2454
# Episode: 4689 of 5000 Total Reward: 2616
# Episode: 4690 of 5000 Total Reward: 2700
# Episode: 4691 of 5000 Total Reward: 2712
# Episode: 4692 of 5000 Total Reward: 2766
# Episode: 4693 of 5000 Total Reward: 2733
# Episode: 4694 of 5000 Total Reward: 2361
# Episode: 4695 of 5000 Total Reward: 2706
# Episode: 4696 of 5000 Total Reward: 2721
# Episode: 4697 of 5000 Total Reward: 2520
# Episode: 4698 of 5000 Total Reward: 2904
# Episode: 4699 of 5000 Total Reward: 2646
# Episode: 4700 of 5000 Total Reward: 2538
# Episode: 4701 of 5000 Total Reward: 2583
# Episode: 4702 of 5000 Total Reward: 2805
# Episode: 4703 of 5000 Total Reward: 2622
# Episode: 4704 of 5000 Total Reward: 2595
# Episode: 4705 of 5000 Total Reward: 2565
# Episode: 4706 of 5000 Total Reward: 2670
# Episode: 4707 of 5000 Total Reward: 2685
# Episode: 4708 of 5000 Total Reward: 2631
# Episode: 4709 of 5000 Total Reward: 2637
# Episode: 4710 of 5000 Total Reward: 2619
# Episode: 4711 of 5000 Total Reward: 2781
# Episode: 4712 of 5000 Total Reward: 2508
# Episode: 4713 of 5000 Total Reward: 2658
# Episode: 4714 of 5000 Total Reward: 2643
# Episode: 4715 of 5000 Total Reward: 2649
# Episode: 4716 of 5000 Total Reward: 2649
# Episode: 4717 of 5000 Total Reward: 2787
# Episode: 4718 of 5000 Total Reward: 2655
# Episode: 4719 of 5000 Total Reward: 2526
# Episode: 4720 of 5000 Total Reward: 2784
# Episode: 4721 of 5000 Total Reward: 2733
# Episode: 4722 of 5000 Total Reward: 2643
# Episode: 4723 of 5000 Total Reward: 2631
# Episode: 4724 of 5000 Total Reward: 2610
# Episode: 4725 of 5000 Total Reward: 2643
# Episode: 4726 of 5000 Total Reward: 2640
# Episode: 4727 of 5000 Total Reward: 2667
# Episode: 4728 of 5000 Total Reward: 2547
# Episode: 4729 of 5000 Total Reward: 2799
# Episode: 4730 of 5000 Total Reward: 2712
# Episode: 4731 of 5000 Total Reward: 2580
# Episode: 4732 of 5000 Total Reward: 2724
# Episode: 4733 of 5000 Total Reward: 2541
# Episode: 4734 of 5000 Total Reward: 2523
# Episode: 4735 of 5000 Total Reward: 2790
# Episode: 4736 of 5000 Total Reward: 2436
# Episode: 4737 of 5000 Total Reward: 2637
# Episode: 4738 of 5000 Total Reward: 2637
# Episode: 4739 of 5000 Total Reward: 2529
# Episode: 4740 of 5000 Total Reward: 2550
# Episode: 4741 of 5000 Total Reward: 2607
# Episode: 4742 of 5000 Total Reward: 2754
# Episode: 4743 of 5000 Total Reward: 2631
# Episode: 4744 of 5000 Total Reward: 2616
# Episode: 4745 of 5000 Total Reward: 2739
# Episode: 4746 of 5000 Total Reward: 2721
# Episode: 4747 of 5000 Total Reward: 2571
# Episode: 4748 of 5000 Total Reward: 2811
# Episode: 4749 of 5000 Total Reward: 2748
# Episode: 4750 of 5000 Total Reward: 2634
# Episode: 4751 of 5000 Total Reward: 2412
# Episode: 4752 of 5000 Total Reward: 2577
# Episode: 4753 of 5000 Total Reward: 2733
# Episode: 4754 of 5000 Total Reward: 2598
# Episode: 4755 of 5000 Total Reward: 2622
# Episode: 4756 of 5000 Total Reward: 2604
# Episode: 4757 of 5000 Total Reward: 2568
# Episode: 4758 of 5000 Total Reward: 2631
# Episode: 4759 of 5000 Total Reward: 2706
# Episode: 4760 of 5000 Total Reward: 2700
# Episode: 4761 of 5000 Total Reward: 2685
# Episode: 4762 of 5000 Total Reward: 2664
# Episode: 4763 of 5000 Total Reward: 2757
# Episode: 4764 of 5000 Total Reward: 2436
# Episode: 4765 of 5000 Total Reward: 2565
# Episode: 4766 of 5000 Total Reward: 2754
# Episode: 4767 of 5000 Total Reward: 2547
# Episode: 4768 of 5000 Total Reward: 2637
# Episode: 4769 of 5000 Total Reward: 2547
# Episode: 4770 of 5000 Total Reward: 2772
# Episode: 4771 of 5000 Total Reward: 2703
# Episode: 4772 of 5000 Total Reward: 2790
# Episode: 4773 of 5000 Total Reward: 2670
# Episode: 4774 of 5000 Total Reward: 2682
# Episode: 4775 of 5000 Total Reward: 2739
# Episode: 4776 of 5000 Total Reward: 2523
# Episode: 4777 of 5000 Total Reward: 2643
# Episode: 4778 of 5000 Total Reward: 2766
# Episode: 4779 of 5000 Total Reward: 2706
# Episode: 4780 of 5000 Total Reward: 2457
# Episode: 4781 of 5000 Total Reward: 2655
# Episode: 4782 of 5000 Total Reward: 2454
# Episode: 4783 of 5000 Total Reward: 2829
# Episode: 4784 of 5000 Total Reward: 2571
# Episode: 4785 of 5000 Total Reward: 2688
# Episode: 4786 of 5000 Total Reward: 2715
# Episode: 4787 of 5000 Total Reward: 2607
# Episode: 4788 of 5000 Total Reward: 2559
# Episode: 4789 of 5000 Total Reward: 2667
# Episode: 4790 of 5000 Total Reward: 2736
# Episode: 4791 of 5000 Total Reward: 2688
# Episode: 4792 of 5000 Total Reward: 2634
# Episode: 4793 of 5000 Total Reward: 2793
# Episode: 4794 of 5000 Total Reward: 2463
# Episode: 4795 of 5000 Total Reward: 2550
# Episode: 4796 of 5000 Total Reward: 2502
# Episode: 4797 of 5000 Total Reward: 2346
# Episode: 4798 of 5000 Total Reward: 2736
# Episode: 4799 of 5000 Total Reward: 2802
# Episode: 4800 of 5000 Total Reward: 2661
# Episode: 4801 of 5000 Total Reward: 2622
# Episode: 4802 of 5000 Total Reward: 2730
# Episode: 4803 of 5000 Total Reward: 2802
# Episode: 4804 of 5000 Total Reward: 2592
# Episode: 4805 of 5000 Total Reward: 2706
# Episode: 4806 of 5000 Total Reward: 2550
# Episode: 4807 of 5000 Total Reward: 2469
# Episode: 4808 of 5000 Total Reward: 2751
# Episode: 4809 of 5000 Total Reward: 2721
# Episode: 4810 of 5000 Total Reward: 2748
# Episode: 4811 of 5000 Total Reward: 2568
# Episode: 4812 of 5000 Total Reward: 2553
# Episode: 4813 of 5000 Total Reward: 2499
# Episode: 4814 of 5000 Total Reward: 2670
# Episode: 4815 of 5000 Total Reward: 2400
# Episode: 4816 of 5000 Total Reward: 2799
# Episode: 4817 of 5000 Total Reward: 2478
# Episode: 4818 of 5000 Total Reward: 2739
# Episode: 4819 of 5000 Total Reward: 2544
# Episode: 4820 of 5000 Total Reward: 2556
# Episode: 4821 of 5000 Total Reward: 2433
# Episode: 4822 of 5000 Total Reward: 2496
# Episode: 4823 of 5000 Total Reward: 2931
# Episode: 4824 of 5000 Total Reward: 2736
# Episode: 4825 of 5000 Total Reward: 2787
# Episode: 4826 of 5000 Total Reward: 2733
# Episode: 4827 of 5000 Total Reward: 2817
# Episode: 4828 of 5000 Total Reward: 2499
# Episode: 4829 of 5000 Total Reward: 2805
# Episode: 4830 of 5000 Total Reward: 2424
# Episode: 4831 of 5000 Total Reward: 2676
# Episode: 4832 of 5000 Total Reward: 2634
# Episode: 4833 of 5000 Total Reward: 2661
# Episode: 4834 of 5000 Total Reward: 2823
# Episode: 4835 of 5000 Total Reward: 2700
# Episode: 4836 of 5000 Total Reward: 2463
# Episode: 4837 of 5000 Total Reward: 2604
# Episode: 4838 of 5000 Total Reward: 2841
# Episode: 4839 of 5000 Total Reward: 2607
# Episode: 4840 of 5000 Total Reward: 2724
# Episode: 4841 of 5000 Total Reward: 2823
# Episode: 4842 of 5000 Total Reward: 2655
# Episode: 4843 of 5000 Total Reward: 2493
# Episode: 4844 of 5000 Total Reward: 2790
# Episode: 4845 of 5000 Total Reward: 2610
# Episode: 4846 of 5000 Total Reward: 2613
# Episode: 4847 of 5000 Total Reward: 2799
# Episode: 4848 of 5000 Total Reward: 2487
# Episode: 4849 of 5000 Total Reward: 2508
# Episode: 4850 of 5000 Total Reward: 2766
# Episode: 4851 of 5000 Total Reward: 2619
# Episode: 4852 of 5000 Total Reward: 2457
# Episode: 4853 of 5000 Total Reward: 2649
# Episode: 4854 of 5000 Total Reward: 2676
# Episode: 4855 of 5000 Total Reward: 2592
# Episode: 4856 of 5000 Total Reward: 2748
# Episode: 4857 of 5000 Total Reward: 2619
# Episode: 4858 of 5000 Total Reward: 2760
# Episode: 4859 of 5000 Total Reward: 2571
# Episode: 4860 of 5000 Total Reward: 2667
# Episode: 4861 of 5000 Total Reward: 2868
# Episode: 4862 of 5000 Total Reward: 2616
# Episode: 4863 of 5000 Total Reward: 2604
# Episode: 4864 of 5000 Total Reward: 2757
# Episode: 4865 of 5000 Total Reward: 2607
# Episode: 4866 of 5000 Total Reward: 2427
# Episode: 4867 of 5000 Total Reward: 2490
# Episode: 4868 of 5000 Total Reward: 2643
# Episode: 4869 of 5000 Total Reward: 2805
# Episode: 4870 of 5000 Total Reward: 2448
# Episode: 4871 of 5000 Total Reward: 2676
# Episode: 4872 of 5000 Total Reward: 2664
# Episode: 4873 of 5000 Total Reward: 2520
# Episode: 4874 of 5000 Total Reward: 2502
# Episode: 4875 of 5000 Total Reward: 2517
# Episode: 4876 of 5000 Total Reward: 2691
# Episode: 4877 of 5000 Total Reward: 2868
# Episode: 4878 of 5000 Total Reward: 2703
# Episode: 4879 of 5000 Total Reward: 2616
# Episode: 4880 of 5000 Total Reward: 2652
# Episode: 4881 of 5000 Total Reward: 2685
# Episode: 4882 of 5000 Total Reward: 2583
# Episode: 4883 of 5000 Total Reward: 2583
# Episode: 4884 of 5000 Total Reward: 2718
# Episode: 4885 of 5000 Total Reward: 2841
# Episode: 4886 of 5000 Total Reward: 2640
# Episode: 4887 of 5000 Total Reward: 2694
# Episode: 4888 of 5000 Total Reward: 2544
# Episode: 4889 of 5000 Total Reward: 2661
# Episode: 4890 of 5000 Total Reward: 2508
# Episode: 4891 of 5000 Total Reward: 2688
# Episode: 4892 of 5000 Total Reward: 2613
# Episode: 4893 of 5000 Total Reward: 2799
# Episode: 4894 of 5000 Total Reward: 2634
# Episode: 4895 of 5000 Total Reward: 2745
# Episode: 4896 of 5000 Total Reward: 2688
# Episode: 4897 of 5000 Total Reward: 2946
# Episode: 4898 of 5000 Total Reward: 2553
# Episode: 4899 of 5000 Total Reward: 2619
# Episode: 4900 of 5000 Total Reward: 2550
# Episode: 4901 of 5000 Total Reward: 2625
# Episode: 4902 of 5000 Total Reward: 2841
# Episode: 4903 of 5000 Total Reward: 2553
# Episode: 4904 of 5000 Total Reward: 2712
# Episode: 4905 of 5000 Total Reward: 2511
# Episode: 4906 of 5000 Total Reward: 2721
# Episode: 4907 of 5000 Total Reward: 2478
# Episode: 4908 of 5000 Total Reward: 2376
# Episode: 4909 of 5000 Total Reward: 2625
# Episode: 4910 of 5000 Total Reward: 2763
# Episode: 4911 of 5000 Total Reward: 2454
# Episode: 4912 of 5000 Total Reward: 2574
# Episode: 4913 of 5000 Total Reward: 2706
# Episode: 4914 of 5000 Total Reward: 2697
# Episode: 4915 of 5000 Total Reward: 2508
# Episode: 4916 of 5000 Total Reward: 2961
# Episode: 4917 of 5000 Total Reward: 2523
# Episode: 4918 of 5000 Total Reward: 2820
# Episode: 4919 of 5000 Total Reward: 2586
# Episode: 4920 of 5000 Total Reward: 2718
# Episode: 4921 of 5000 Total Reward: 2883
# Episode: 4922 of 5000 Total Reward: 2400
# Episode: 4923 of 5000 Total Reward: 2724
# Episode: 4924 of 5000 Total Reward: 2760
# Episode: 4925 of 5000 Total Reward: 2751
# Episode: 4926 of 5000 Total Reward: 2598
# Episode: 4927 of 5000 Total Reward: 2580
# Episode: 4928 of 5000 Total Reward: 2832
# Episode: 4929 of 5000 Total Reward: 2790
# Episode: 4930 of 5000 Total Reward: 2874
# Episode: 4931 of 5000 Total Reward: 2772
# Episode: 4932 of 5000 Total Reward: 2625
# Episode: 4933 of 5000 Total Reward: 2652
# Episode: 4934 of 5000 Total Reward: 2784
# Episode: 4935 of 5000 Total Reward: 2706
# Episode: 4936 of 5000 Total Reward: 2514
# Episode: 4937 of 5000 Total Reward: 2838
# Episode: 4938 of 5000 Total Reward: 2598
# Episode: 4939 of 5000 Total Reward: 2718
# Episode: 4940 of 5000 Total Reward: 2688
# Episode: 4941 of 5000 Total Reward: 2553
# Episode: 4942 of 5000 Total Reward: 2514
# Episode: 4943 of 5000 Total Reward: 2781
# Episode: 4944 of 5000 Total Reward: 2706
# Episode: 4945 of 5000 Total Reward: 2793
# Episode: 4946 of 5000 Total Reward: 2757
# Episode: 4947 of 5000 Total Reward: 2760
# Episode: 4948 of 5000 Total Reward: 2673
# Episode: 4949 of 5000 Total Reward: 2562
# Episode: 4950 of 5000 Total Reward: 2511
# Episode: 4951 of 5000 Total Reward: 2607
# Episode: 4952 of 5000 Total Reward: 2499
# Episode: 4953 of 5000 Total Reward: 2685
# Episode: 4954 of 5000 Total Reward: 2691
# Episode: 4955 of 5000 Total Reward: 2751
# Episode: 4956 of 5000 Total Reward: 2778
# Episode: 4957 of 5000 Total Reward: 2871
# Episode: 4958 of 5000 Total Reward: 2841
# Episode: 4959 of 5000 Total Reward: 2703
# Episode: 4960 of 5000 Total Reward: 2460
# Episode: 4961 of 5000 Total Reward: 2331
# Episode: 4962 of 5000 Total Reward: 2493
# Episode: 4963 of 5000 Total Reward: 2391
# Episode: 4964 of 5000 Total Reward: 2676
# Episode: 4965 of 5000 Total Reward: 2514
# Episode: 4966 of 5000 Total Reward: 2613
# Episode: 4967 of 5000 Total Reward: 2598
# Episode: 4968 of 5000 Total Reward: 2340
# Episode: 4969 of 5000 Total Reward: 2613
# Episode: 4970 of 5000 Total Reward: 2613
# Episode: 4971 of 5000 Total Reward: 2757
# Episode: 4972 of 5000 Total Reward: 2649
# Episode: 4973 of 5000 Total Reward: 2448
# Episode: 4974 of 5000 Total Reward: 2631
# Episode: 4975 of 5000 Total Reward: 2691
# Episode: 4976 of 5000 Total Reward: 2661
# Episode: 4977 of 5000 Total Reward: 2724
# Episode: 4978 of 5000 Total Reward: 2577
# Episode: 4979 of 5000 Total Reward: 2622
# Episode: 4980 of 5000 Total Reward: 2427
# Episode: 4981 of 5000 Total Reward: 2556
# Episode: 4982 of 5000 Total Reward: 2517
# Episode: 4983 of 5000 Total Reward: 2580
# Episode: 4984 of 5000 Total Reward: 2625
# Episode: 4985 of 5000 Total Reward: 2436
# Episode: 4986 of 5000 Total Reward: 2721
# Episode: 4987 of 5000 Total Reward: 2787
# Episode: 4988 of 5000 Total Reward: 2856
# Episode: 4989 of 5000 Total Reward: 2820
# Episode: 4990 of 5000 Total Reward: 2616
# Episode: 4991 of 5000 Total Reward: 2757
# Episode: 4992 of 5000 Total Reward: 2772
# Episode: 4993 of 5000 Total Reward: 2646
# Episode: 4994 of 5000 Total Reward: 2679
# Episode: 4995 of 5000 Total Reward: 2853
# Episode: 4996 of 5000 Total Reward: 2379
# Episode: 4997 of 5000 Total Reward: 2463
# Episode: 4998 of 5000 Total Reward: 2727
# Episode: 4999 of 5000 Total Reward: 2607
# Episode: 5000 of 5000 Total Reward: 2628

# %%
# Calculate average reward
average_reward = total_reward_all / num_episodes
print("Average reward:", average_reward)
# Out:
# Average reward: 2639.2008

# %%
# Function to predict Status
def predict_status(observation, agent):
    state = observation.values[:-1]  # Menggunakan fitur dari observasi sebagai state
    state = np.reshape(state, (1, len(state)))  # Reshape state menjadi bentuk (1, num_features)
    state = scaler.transform(state)  # Normalisasi state
    action = agent.act(state)  # Prediksi tindakan menggunakan agen
    return action  # Mengembalikan aksi sebagai prediksi Status

# %%
# Contoh prediksi Status berdasarkan observasi ke-10 dari dataset
observation = dataset.iloc[10]  # Ambil observasi ke-10 dari dataset
predicted_status = predict_status(observation, agent)  # Prediksi Status menggunakan fungsi predict_status
actual_status = observation['Status']  # Status yang sebenarnya dari observasi dalam dataset
print("Predicted Status for observation 10:", predicted_status)
print("Actual Status for observation 10:", actual_status)
# Out:
# Predicted Status for observation 10: 1
# Actual Status for observation 10: 0.0
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Fungsi untuk hitung akurasi
def calculate_accuracy(dataset, agent):
    correct_predictions = 0
    total_predictions = len(dataset)

    for index, observation in dataset.iterrows():
        state = observation.values[:-1]  # Menggunakan fitur dari observasi sebagai state
        state = np.reshape(state, (1, len(state)))  # Pastikan state di-reshape ke bentuk (1, num_features)
        predicted_Status = agent.act(state)  # Prediksi Status menggunakan agen
        actual_Status = observation['Status']  # Nilai Status aktual dari dataset
        if predicted_Status == actual_Status:
            correct_predictions += 1

    accuracy = (correct_predictions / total_predictions) * 100
    return accuracy

# %%
# Menggunakan fungsi calculate_accuracy untuk menghitung akurasi
accuracy = calculate_accuracy(dataset, agent)
print("Accuracy:", accuracy, "%")
# Out:
# Accuracy: 49.45054945054945 %

# %%
# Membuat list untuk menyimpan hasil prediksi
predicted_labels = []

# %%
# Loop melalui setiap observasi dalam dataset dan membuat prediksi
for index, observation in dataset.iterrows():
    predicted_status = predict_status(observation, agent)  # Melakukan prediksi Status
    predicted_labels.append(predicted_status)
# Out:
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# d:\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Membuat DataFrame dari list hasil prediksi
predicted_labels_df = pd.DataFrame(predicted_labels, columns=['Status'])

# %%
# Output hasil prediksi dalam format yang diminta
print(predicted_labels_df)
# Out:
#       Status
# 0          0
# 1          0
# 2          0
# 3          1
# 4          1
# ...      ...
# 7184       0
# 7185       0
# 7186       0
# 7187       1
# 7188       1
#
# [7189 rows x 1 columns]

# %%
# Gabungkan kolom Status dari dataset asli dengan kolom Status dari predicted_labels_df
comparison_df = pd.concat([dataset['Status'], predicted_labels_df['Status']], axis=1)
comparison_df.columns = ['Actual_Status', 'Predicted_Status']

# %%
# Hitung jumlah status yang sama dan yang berbeda
same_status = comparison_df[comparison_df['Actual_Status'] == comparison_df['Predicted_Status']].shape[0]
different_status = comparison_df[comparison_df['Actual_Status'] != comparison_df['Predicted_Status']].shape[0]

# %% [markdown]
# 1

# %%
same_status / len(comparison_df) * 100
# Out:
# 49.10279593823898

# %%
# Buat visualisasi
plt.figure(figsize=(8, 6))
labels = ['Same Status', 'Different Status']
sizes = [same_status, different_status]
colors = ['lightgreen', 'lightcoral']
explode = (0, 0.1)  # Pisahkan "Different Status"
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Comparison of Actual and Predicted Status')
plt.show()

# %%
import matplotlib.pyplot as plt

# Hitung jumlah status 0 dan 1 dari predicted_labels_df
healthy_count = predicted_labels_df[predicted_labels_df['Status'] == 0].shape[0]
unhealthy_count = predicted_labels_df[predicted_labels_df['Status'] == 1].shape[0]

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns


# Menghitung dan menampilkan confusion matrix untuk data validasi
cm_val = confusion_matrix(comparison_df['Actual_Status'], comparison_df['Predicted_Status'])
print("Confusion Matrix - Validation Data")
print(cm_val)

# Menampilkan confusion matrix sebagai heatmap untuk data validasi
plt.figure(figsize=(10, 8))
sns.heatmap(cm_val, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Validation Data')
plt.show()

# Menghitung dan menampilkan classification report untuk data validasi
print("Classification Report - Validation Data")
report_val = classification_report(comparison_df['Actual_Status'], comparison_df['Predicted_Status'])
print(report_val)
# Out:
# Confusion Matrix - Validation Data
# [[3040 3193]
#  [ 466  490]]
# Classification Report - Validation Data
#               precision    recall  f1-score   support
#
#            0       0.87      0.49      0.62      6233
#            1       0.13      0.51      0.21       956
#
#     accuracy                           0.49      7189
#    macro avg       0.50      0.50      0.42      7189
# weighted avg       0.77      0.49      0.57      7189

# %%
# Data untuk plot
status_labels = ['0', '1']
status_counts = [healthy_count, unhealthy_count]

# %%
# Plot batang
plt.bar(status_labels, status_counts, color=['green', 'red'])

# Tambahkan label angka di atas setiap batang
for i in range(len(status_labels)):
    plt.text(i, status_counts[i], str(status_counts[i]), ha='center', va='bottom')

# Label sumbu dan judul
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Jumlah Status 0 dan 1')

# Tampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt
# s
# Hitung jumlah status 0 dan 1 dari predicted_labels_df
healthy_count = predicted_labels_df[predicted_labels_df['Status'] == 0].shape[0]
unhealthy_count = predicted_labels_df[predicted_labels_df['Status'] == 1].shape[0]

# Data untuk plot
status_labels = ['Healthy', 'Unhealthy']
status_counts = [healthy_count, unhealthy_count]
colors = ['lightgreen', 'lightcoral']

# Plot donut chart
plt.figure(figsize=(8, 6))
plt.pie(status_counts, labels=status_labels, colors=colors, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
plt.gca().add_artist(plt.Circle((0, 0), 0.6, fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Jumlah Status Healthy dan Unhealthy setelah DQN')
plt.show()

# %%
# Menampilkan heatmap dari tabel Q
import seaborn as sns

# Dapatkan bobot dari model jaringan saraf
def get_q_table(model, num_actions):
    # Ambil layer ke-2 (indeks 1) dari model, yang merupakan layer pertama setelah input
    first_layer = model.layers[1]
    # Dapatkan bobot dari layer
    weights = first_layer.get_weights()[0]
    # Ubah bobot menjadi format yang sesuai untuk tabel Q
    q_table = weights.reshape((-1, num_actions))
    return q_table

# Fungsi untuk menampilkan heatmap dari tabel Q
def plot_q_table_heatmap(q_table):
    plt.figure(figsize=(10, 6))
    sns.heatmap(q_table, cmap='viridis', annot=True, fmt=".2f", cbar=False)
    plt.xlabel('Actions')
    plt.ylabel('States')
    plt.title('Heatmap of Q Table')
    plt.show()

# Dapatkan tabel Q dari model agen
q_table = get_q_table(agent.model, num_actions)

# Reduksi dimensi state labels menjadi 1-10
state_labels_reduced = ['State {}'.format(i+1) for i in range(10)]

# Ambil subset dari q_table untuk hanya menampilkan 10 state pertama
q_table_subset = q_table[:10]

# Tampilkan heatmap dari tabel Q
plot_q_table_heatmap(q_table_subset)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[212], line 24
#      21     plt.show()
#      23 # Dapatkan tabel Q dari model agen
# ---> 24 q_table = get_q_table(agent.model, num_actions)
#      26 # Reduksi dimensi state labels menjadi 1-10
#      27 state_labels_reduced = ['State {}'.format(i+1) for i in range(10)]
#
# Cell In[212], line 9, in get_q_table(model, num_actions)
#       7 first_layer = model.layers[1]
#       8 # Dapatkan bobot dari layer
# ----> 9 weights = first_layer.get_weights()[0]
#      10 # Ubah bobot menjadi format yang sesuai untuk tabel Q
#      11 q_table = weights.reshape((-1, num_actions))
#
# IndexError: list index out of range

# %%
# Pilih state yang ingin divisualisasikan, misalnya state ke-10
state_index = 10

# Dapatkan Q-values untuk state tersebut
q_values = q_table[state_index, :]

# Tentukan actions (dalam kasus Anda, hanya 2 actions)
actions = ['Action 0', 'Action 1']

# Plot barplot dari Q-values
plt.figure(figsize=(10, 6))
sns.barplot(x=actions, y=q_values)
plt.title(f'Q-values for State {state_index}')
plt.xlabel('Actions')
plt.ylabel('Q-value')
plt.show()
