# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from collections import deque
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# Load dataset
df = pd.read_csv("metrics-with-output.csv")
df
# Out:
#                      Time      Timestamp cpu_usage memory_usage  \
# 0     2023-09-08 01:16:00  1694110560000     9.00%        53.5%
# 1     2023-09-08 01:16:05  1694110565000     16.6%        53.3%
# 2     2023-09-08 01:16:10  1694110570000     20.2%        55.3%
# 3     2023-09-08 01:16:15  1694110575000     14.6%        58.0%
# 4     2023-09-08 01:16:20  1694110580000     10.2%        53.5%
# ...                   ...            ...       ...          ...
# 7184  2023-09-08 11:14:40  1694146480000     22.2%        53.5%
# 7185  2023-09-08 11:14:45  1694146485000     27.2%        56.0%
# 7186  2023-09-08 11:14:50  1694146490000     7.20%        54.1%
# 7187  2023-09-08 11:14:55  1694146495000     23.4%        54.6%
# 7188  2023-09-08 11:15:00  1694146500000     31.0%        53.8%
#
#      bandwidth_inbound bandwidth_outbound         tps tps_error response_time  \
# 0            7.46 GB/s          6.45 GB/s     2 req/s   0 req/s        607 ms
# 1            5.85 GB/s          5.27 GB/s  2.20 req/s   0 req/s        2.09 s
# 2            9.06 GB/s          7.96 GB/s  3.20 req/s   0 req/s        3.45 s
# 3            8.41 GB/s          7.21 GB/s  3.20 req/s   0 req/s        2.58 s
# 4            4.88 GB/s          4.30 GB/s  2.60 req/s   0 req/s        862 ms
# ...                ...                ...         ...       ...           ...
# 7184         6.52 GB/s          5.67 GB/s  2.40 req/s   0 req/s        1.51 s
# 7185         7.37 GB/s          6.49 GB/s  2.60 req/s   0 req/s        1.21 s
# 7186         4.76 GB/s          4.02 GB/s  1.40 req/s   0 req/s        285 ms
# 7187         6.75 GB/s          5.90 GB/s  2.40 req/s   0 req/s        804 ms
# 7188         7.76 GB/s          6.92 GB/s  3.20 req/s   0 req/s        2.64 s
#
#       Status
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 7184       0
# 7185       0
# 7186       0
# 7187       0
# 7188       0
#
# [7189 rows x 10 columns]

# %%
# Menampilkan baris pertama dr dataset
df.head()
# Out:
#                   Time      Timestamp cpu_usage memory_usage  \
# 0  2023-09-08 01:16:00  1694110560000     9.00%        53.5%
# 1  2023-09-08 01:16:05  1694110565000     16.6%        53.3%
# 2  2023-09-08 01:16:10  1694110570000     20.2%        55.3%
# 3  2023-09-08 01:16:15  1694110575000     14.6%        58.0%
# 4  2023-09-08 01:16:20  1694110580000     10.2%        53.5%
#
#   bandwidth_inbound bandwidth_outbound         tps tps_error response_time  \
# 0         7.46 GB/s          6.45 GB/s     2 req/s   0 req/s        607 ms
# 1         5.85 GB/s          5.27 GB/s  2.20 req/s   0 req/s        2.09 s
# 2         9.06 GB/s          7.96 GB/s  3.20 req/s   0 req/s        3.45 s
# 3         8.41 GB/s          7.21 GB/s  3.20 req/s   0 req/s        2.58 s
# 4         4.88 GB/s          4.30 GB/s  2.60 req/s   0 req/s        862 ms
#
#    Status
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import matplotlib.pyplot as plt

#Membandingkan jumlah status Healthy dan Unhealthy dengan donut chart
status_counts = df['Status'].value_counts()

colors = ['red','blue']
plt.pie(status_counts, labels=status_counts.index, colors=colors, autopct='%1.1f%%', startangle=90)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Distribution of Status')
plt.show()

# %%
# Preprocessing data: clean and convert to numeric
df['cpu_usage'] = df['cpu_usage'].str.rstrip('%').astype('float') / 100.0
df['memory_usage'] = df['memory_usage'].str.rstrip('%').astype('float') / 100.0

def clean_bandwidth(value):
    if 'GB/s' in value:
        return float(value.replace('GB/s', ''))
    elif 'MB/s' in value:
        return float(value.replace('MB/s', '')) / 1024  # Convert MB/s to GB/s
    else:
        return float(value)

df['bandwidth_inbound'] = df['bandwidth_inbound'].apply(clean_bandwidth)
df['bandwidth_outbound'] = df['bandwidth_outbound'].apply(clean_bandwidth)
df['tps'] = df['tps'].str.rstrip(' req/s').astype('float')
df['tps_error'] = df['tps_error'].str.rstrip(' req/s').astype('float')
df['response_time'] = df['response_time'].replace({' ms': '*1e-3', ' s': '*1'}, regex=True).map(pd.eval).astype('float')

# Drop irrelevant columns (if any)
dataset = df.drop(df.columns[[0, 1]], axis=1)

# Normalize the dataset
scaler = MinMaxScaler()
features = dataset.drop('Status', axis=1)
normalized_features = scaler.fit_transform(features)

# Replace the non-normalized features with the normalized ones in the dataset
normalized_dataset = pd.DataFrame(normalized_features, columns=features.columns)
normalized_dataset['Status'] = dataset['Status'].values  # Add the 'Status' column back

# Display the normalized dataset
print(normalized_dataset.head())
# Out:
#    cpu_usage  memory_usage  bandwidth_inbound  bandwidth_outbound       tps  \
# 0   0.080808      0.187192           0.363939            0.364287  0.269231
# 1   0.157576      0.177340           0.284799            0.297010  0.307692
# 2   0.193939      0.275862           0.442586            0.450379  0.500000
# 3   0.137374      0.408867           0.410635            0.407618  0.500000
# 4   0.092929      0.187192           0.237119            0.241705  0.384615
#
#    tps_error  response_time  Status
# 0        0.0       0.070037       0
# 1        0.0       0.282441       0
# 2        0.0       0.477227       0
# 3        0.0       0.352621       0
# 4        0.0       0.106560       0

# %%
# Info dataset mengenai tipe, jumlah kolom dll
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7189 entries, 0 to 7188
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                7189 non-null   object
#  1   Timestamp           7189 non-null   int64
#  2   cpu_usage           7189 non-null   float64
#  3   memory_usage        7189 non-null   float64
#  4   bandwidth_inbound   7189 non-null   float64
#  5   bandwidth_outbound  7189 non-null   float64
#  6   tps                 7189 non-null   float64
#  7   tps_error           7189 non-null   float64
#  8   response_time       7189 non-null   float64
#  9   Status              7189 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 561.8+ KB

# %%
# Menampilkan dataset setelah proses konversi dan pembersihan data
print(df)
# Out:
#                      Time      Timestamp  cpu_usage  memory_usage  \
# 0     2023-09-08 01:16:00  1694110560000      0.090         0.535
# 1     2023-09-08 01:16:05  1694110565000      0.166         0.533
# 2     2023-09-08 01:16:10  1694110570000      0.202         0.553
# 3     2023-09-08 01:16:15  1694110575000      0.146         0.580
# 4     2023-09-08 01:16:20  1694110580000      0.102         0.535
# ...                   ...            ...        ...           ...
# 7184  2023-09-08 11:14:40  1694146480000      0.222         0.535
# 7185  2023-09-08 11:14:45  1694146485000      0.272         0.560
# 7186  2023-09-08 11:14:50  1694146490000      0.072         0.541
# 7187  2023-09-08 11:14:55  1694146495000      0.234         0.546
# 7188  2023-09-08 11:15:00  1694146500000      0.310         0.538
#
#       bandwidth_inbound  bandwidth_outbound  tps  tps_error  response_time  \
# 0                  7.46                6.45  2.0        0.0          0.607
# 1                  5.85                5.27  2.2        0.0          2.090
# 2                  9.06                7.96  3.2        0.0          3.450
# 3                  8.41                7.21  3.2        0.0          2.580
# 4                  4.88                4.30  2.6        0.0          0.862
# ...                 ...                 ...  ...        ...            ...
# 7184               6.52                5.67  2.4        0.0          1.510
# 7185               7.37                6.49  2.6        0.0          1.210
# 7186               4.76                4.02  1.4        0.0          0.285
# 7187               6.75                5.90  2.4        0.0          0.804
# 7188               7.76                6.92  3.2        0.0          2.640
#
#       Status
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 7184       0
# 7185       0
# 7186       0
# 7187       0
# 7188       0
#
# [7189 rows x 10 columns]

# %%
# Pembersihan/Penghapusan data yang tidak dipakai
dataset = df.drop(df.columns[[0, 1]], axis=1)

dataset.describe()
# Out:
#          cpu_usage  memory_usage  bandwidth_inbound  bandwidth_outbound  \
# count  7189.000000   7189.000000        7189.000000         7189.000000
# mean      0.163090      0.542723           6.318377            5.573617
# std       0.069272      0.019356           3.193037            2.728239
# min       0.010000      0.497000           0.056055            0.060645
# 25%       0.118000      0.533000           3.940000            3.540000
# 50%       0.156000      0.539000           5.910000            5.230000
# 75%       0.198000      0.549000           8.310000            7.260000
# max       1.000000      0.700000          20.400000           17.600000
#
#                tps    tps_error  response_time       Status
# count  7189.000000  7189.000000    7189.000000  7189.000000
# mean      2.490218     0.170817       1.770724     0.132981
# std       0.784028     0.548970       1.024615     0.339578
# min       0.600000     0.000000       0.118000     0.000000
# 25%       2.000000     0.000000       0.952000     0.000000
# 50%       2.400000     0.000000       1.520000     0.000000
# 75%       3.000000     0.000000       2.450000     0.000000
# max       5.800000     4.600000       7.100000     1.000000

# %%
from sklearn.preprocessing import LabelEncoder

# Encode 'Status' column into numeric values
label_encoder = LabelEncoder()
dataset['Status'] = label_encoder.fit_transform(dataset['Status'])

# %%
dataset['Status']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7184    0
# 7185    0
# 7186    0
# 7187    0
# 7188    0
# Name: Status, Length: 7189, dtype: int64

# %%
# Periksa apakah ada data yang hilang
missing_data = dataset.isnull().sum()
if missing_data.any():
    print("Data terdapat missing values yang perlu diimputasi:")
    print(missing_data)
else:
    print("Tidak ada missing values dalam dataset.")
# Out:
# Tidak ada missing values dalam dataset.

# %%
# Split data menjadi features (X) dan target (y)
X = dataset.drop('Status', axis=1)
y = dataset['Status']

# %%
# Normalisasi data
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=123)

# %%
# Definisikan Environment Class
class Environment:
    def __init__(self, dataset, class_weights, total_epochs):
        self.dataset = dataset
        self.num_samples = len(dataset)
        self.current_sample_idx = None  # Set indeks sampel saat ini ke None saat inisialisasi
        self.class_weights = class_weights  # Bobot kelas
        self.total_epochs = total_epochs  # Total jumlah epoch
        self.current_epoch = 0  # Epoch saat ini, dimulai dari 0

    def reset(self):
        self.current_sample_idx = 0  # Set ulang indeks sampel saat memulai episode baru
        self.current_epoch += 1  # Tambahkan epoch setiap kali reset
        initial_observation = self.dataset.iloc[self.current_sample_idx]  # Ambil observasi awal
        return initial_observation, 0, False

    def step(self, action):
        # Ambil label aktual dan prediksi agen
        actual = self.dataset.iloc[self.current_sample_idx]['Status']  # Menggunakan kolom 'Status' yang ada di dataset
        predicted = action  # Asumsikan 'action' adalah prediksi agen

        # Update indeks sampel
        self.current_sample_idx = (self.current_sample_idx + 1) % self.num_samples
        next_observation = self.dataset.iloc[self.current_sample_idx]
        
        # Hitung reward berdasarkan observasi dan aksi
        reward = self.calculate_reward(
            actual, predicted, self.class_weights, self.current_epoch, self.total_epochs
        )
        
        # Atur done menjadi True jika mencapai akhir episode
        done = self.current_sample_idx == 0
        
        return next_observation, reward, done

    def calculate_reward(self, actual, predicted, class_weights, current_epoch, total_epochs):
        """
        Fungsi reward yang dinamis berdasarkan distribusi kelas dan epoch saat ini.
        
        Parameters:
        - actual: Nilai aktual dari label (0 atau 1).
        - predicted: Prediksi agen (0 atau 1).
        - class_weights: Bobot kelas untuk menangani ketidakseimbangan.
        - current_epoch: Epoch pelatihan saat ini.
        - total_epochs: Total jumlah epoch.
        
        Returns:
        - reward: Nilai reward yang dihitung.
        """
        # Penalty dasar untuk kesalahan
        base_penalty = -1
        base_reward = 1
        
        # Jika prediksi benar
        if predicted == actual:
            if actual == 1:
                # Reward lebih tinggi untuk kelas `1` karena lebih jarang
                reward = base_reward * class_weights[1]
            else:
                # Reward lebih rendah untuk kelas `0` karena lebih sering
                reward = base_reward * class_weights[0]
        else:
            # Jika prediksi salah, berikan penalti
            if predicted == 1:
                # Penalti lebih besar untuk memprediksi `1` dengan salah
                penalty = base_penalty * class_weights[1]
            else:
                # Penalti lebih kecil untuk memprediksi `0` dengan salah
                penalty = base_penalty * class_weights[0]

            # Menggabungkan penalti dengan epoch saat ini
            reward = penalty * (1 + (current_epoch / total_epochs))
        
        return reward

# %%
import tensorflow as tf  # Tambahkan import TensorFlow

class DQNAgent:
    def __init__(self, state_size, action_size, class_weights=None):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.93
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.99
        self.learning_rate = 0.001
        self.class_weights = class_weights
        self.model = self._build_model()

    def custom_loss(y_true, y_pred):
        # Misalnya weight untuk kelas 0 = 0.2, dan kelas 1 = 0.8
        weights = tf.where(tf.equal(y_true, 0), 0.2, 0.8)
        loss = tf.keras.losses.binary_crossentropy(y_true, y_pred)
        return tf.reduce_mean(loss * weights)


    def _build_model(self):
        model = tf.keras.models.Sequential()
        
        # Adding layers with LeakyReLU activation
        model.add(tf.keras.layers.Dense(128, input_dim=self.state_size))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(256))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(128))
        model.add(tf.keras.layers.LeakyReLU(alpha=0.01))
        model.add(tf.keras.layers.Dropout(0.2))
        
        model.add(tf.keras.layers.Dense(self.action_size, activation='linear'))
        
        model.compile(loss=self.custom_loss, optimizer=tf.keras.optimizers.Adam(learning_rate=self.learning_rate))
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])

    def replay(self, batch_size):
        # Separate experiences by label
        experiences_class_0 = [exp for exp in self.memory if exp[3]['Status'] == 0]
        experiences_class_1 = [exp for exp in self.memory if exp[3]['Status'] == 1]

        # Oversample class 0 experiences
        if len(experiences_class_0) < batch_size:
            minibatch = random.sample(experiences_class_0 * (batch_size // len(experiences_class_0)), batch_size)
        else:
            minibatch = random.sample(experiences_class_0, batch_size // 2)
            minibatch += random.sample(experiences_class_1, batch_size // 2)
        
        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                target = (reward + self.gamma * np.amax(self.model.predict(next_state)[0]))
            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
# Parameters
num_actions = 2  # Number of possible actions
num_features = len(dataset.columns) - 1  # Number of features in the dataset (excluding classification)
batch_size = 40
num_episodes = 3000
max_steps = 2000

# %%
# Initialize environment and agent
class_weights = {0:0.7 , 1: 0.3} # Contoh untuk menghitung bobot
env = Environment(dataset, class_weights, num_episodes)
agent = DQNAgent(state_size=num_features, action_size=num_actions, class_weights=class_weights)

# %%
# Training loop
total_reward_all = 0
for episode in range(num_episodes):
    state, _, _ = env.reset()  # Reset the environment and get initial state
    total_reward = 0
    done = False
    while not done:
        action = agent.act(state)
        next_state, reward, done = env.step(action)  # Take action and get next state, reward, and done status
        agent.remember(state, action, reward, next_state, done)  # Remember the experience
        state = next_state  # Update the current state
        total_reward += reward  # Accumulate total reward for the episode
    total_reward_all += total_reward
    print("Episode:", episode+1, "of", num_episodes, "Total Reward:", total_reward)
# Out:
# Episode: 1 of 3000 Total Reward: 978.4679666666502
# Episode: 2 of 3000 Total Reward: 1088.0523333333815
# Episode: 3 of 3000 Total Reward: 1018.608200000077
# Episode: 4 of 3000 Total Reward: 1019.1892000001017
# Episode: 5 of 3000 Total Reward: 1006.74549999994
# Episode: 6 of 3000 Total Reward: 1039.3648000000023
# Episode: 7 of 3000 Total Reward: 1071.932700000034
# Episode: 8 of 3000 Total Reward: 1004.5021333334233
# Episode: 9 of 3000 Total Reward: 1115.1425000001257
# Episode: 10 of 3000 Total Reward: 1026.6263333333382
# Episode: 11 of 3000 Total Reward: 1105.360666666698
# Episode: 12 of 3000 Total Reward: 1026.7456000000582
# Episode: 13 of 3000 Total Reward: 1093.4707666667396
# Episode: 14 of 3000 Total Reward: 1083.997600000132
# Episode: 15 of 3000 Total Reward: 1009.4690000000252
# Episode: 16 of 3000 Total Reward: 1077.151200000019
# Episode: 17 of 3000 Total Reward: 1092.824600000079
# Episode: 18 of 3000 Total Reward: 1163.5026000001258
# Episode: 19 of 3000 Total Reward: 1063.9288666666694
# Episode: 20 of 3000 Total Reward: 1021.3320000000134
# Episode: 21 of 3000 Total Reward: 1006.9134000000759
# Episode: 22 of 3000 Total Reward: 996.4957333333989
# Episode: 23 of 3000 Total Reward: 1014.0820666667967
# Episode: 24 of 3000 Total Reward: 1000.6080000000043
# Episode: 25 of 3000 Total Reward: 985.1850000000264
# Episode: 26 of 3000 Total Reward: 1005.790200000094
# Episode: 27 of 3000 Total Reward: 1166.8336000001045
# Episode: 28 of 3000 Total Reward: 1012.9878666666391
# Episode: 29 of 3000 Total Reward: 1098.8466333333545
# Episode: 30 of 3000 Total Reward: 1007.0660000000631
# Episode: 31 of 3000 Total Reward: 1080.0381000001028
# Episode: 32 of 3000 Total Reward: 1014.2104000001477
# Episode: 33 of 3000 Total Reward: 1025.8925999999892
# Episode: 34 of 3000 Total Reward: 1079.5882666666816
# Episode: 35 of 3000 Total Reward: 1056.268833333415
# Episode: 36 of 3000 Total Reward: 951.2652000001095
# Episode: 37 of 3000 Total Reward: 1008.0664666666547
# Episode: 38 of 3000 Total Reward: 1043.831066666656
# Episode: 39 of 3000 Total Reward: 1047.4238000000294
# Episode: 40 of 3000 Total Reward: 1050.980000000102
# Episode: 41 of 3000 Total Reward: 1007.3916333334748
# Episode: 42 of 3000 Total Reward: 1032.1144000000074
# Episode: 43 of 3000 Total Reward: 1035.7654666666913
# Episode: 44 of 3000 Total Reward: 1066.374533333408
# Episode: 45 of 3000 Total Reward: 1120.2505000001206
# Episode: 46 of 3000 Total Reward: 988.2334666666344
# Episode: 47 of 3000 Total Reward: 1015.9124666666638
# Episode: 48 of 3000 Total Reward: 1009.3304000000588
# Episode: 49 of 3000 Total Reward: 1017.1828000000858
# Episode: 50 of 3000 Total Reward: 1050.750000000112
# Episode: 51 of 3000 Total Reward: 979.861199999991
# Episode: 52 of 3000 Total Reward: 991.650933333347
# Episode: 53 of 3000 Total Reward: 1001.3820666667546
# Episode: 54 of 3000 Total Reward: 1032.1606000001102
# Episode: 55 of 3000 Total Reward: 1012.5543333332917
# Episode: 56 of 3000 Total Reward: 1038.1485333333133
# Episode: 57 of 3000 Total Reward: 1111.1405000000896
# Episode: 58 of 3000 Total Reward: 1011.1340000001084
# Episode: 59 of 3000 Total Reward: 1092.5153000001083
# Episode: 60 of 3000 Total Reward: 1016.5639999999704
# Episode: 61 of 3000 Total Reward: 1056.0522666666795
# Episode: 62 of 3000 Total Reward: 1047.7938666667412
# Episode: 63 of 3000 Total Reward: 993.887700000094
# Episode: 64 of 3000 Total Reward: 1040.7853333333164
# Episode: 65 of 3000 Total Reward: 1051.511166666676
# Episode: 66 of 3000 Total Reward: 1063.2658000000367
# Episode: 67 of 3000 Total Reward: 944.6522666667533
# Episode: 68 of 3000 Total Reward: 1040.2697333334456
# Episode: 69 of 3000 Total Reward: 987.2874999999952
# Episode: 70 of 3000 Total Reward: 991.0916666666901
# Episode: 71 of 3000 Total Reward: 1035.8149333333888
# Episode: 72 of 3000 Total Reward: 974.0768000000767
# Episode: 73 of 3000 Total Reward: 1014.831199999956
# Episode: 74 of 3000 Total Reward: 1055.7682000000343
# Episode: 75 of 3000 Total Reward: 1000.2050000000401
# Episode: 76 of 3000 Total Reward: 1002.5012000001135
# Episode: 77 of 3000 Total Reward: 955.8644333334278
# Episode: 78 of 3000 Total Reward: 1016.723999999986
# Episode: 79 of 3000 Total Reward: 1008.351333333343
# Episode: 80 of 3000 Total Reward: 1027.1960000000752
# Episode: 81 of 3000 Total Reward: 955.2320000000889
# Episode: 82 of 3000 Total Reward: 1025.2358666666128
# Episode: 83 of 3000 Total Reward: 1061.1894000000286
# Episode: 84 of 3000 Total Reward: 1000.0544000000268
# Episode: 85 of 3000 Total Reward: 987.6390000000903
# Episode: 86 of 3000 Total Reward: 1053.9290666667753
# Episode: 87 of 3000 Total Reward: 1042.1367000000073
# Episode: 88 of 3000 Total Reward: 964.9045333333249
# Episode: 89 of 3000 Total Reward: 987.5588000000573
# Episode: 90 of 3000 Total Reward: 1096.4720000000837
# Episode: 91 of 3000 Total Reward: 990.5738333334679
# Episode: 92 of 3000 Total Reward: 1068.9684000000339
# Episode: 93 of 3000 Total Reward: 1010.5300000000115
# Episode: 94 of 3000 Total Reward: 992.7463333334082
# Episode: 95 of 3000 Total Reward: 988.5091666667558
# Episode: 96 of 3000 Total Reward: 950.4471999999874
# Episode: 97 of 3000 Total Reward: 1005.8075666666775
# Episode: 98 of 3000 Total Reward: 1016.4264000000816
# Episode: 99 of 3000 Total Reward: 1003.9240000000666
# Episode: 100 of 3000 Total Reward: 1050.7433333334618
# Episode: 101 of 3000 Total Reward: 1054.5237666666847
# Episode: 102 of 3000 Total Reward: 998.611200000032
# Episode: 103 of 3000 Total Reward: 988.111266666755
# Episode: 104 of 3000 Total Reward: 1025.9010666667743
# Episode: 105 of 3000 Total Reward: 1091.5664999999794
# Episode: 106 of 3000 Total Reward: 1022.4188666666632
# Episode: 107 of 3000 Total Reward: 979.4642333333903
# Episode: 108 of 3000 Total Reward: 1006.129600000126
# Episode: 109 of 3000 Total Reward: 1002.673100000139
# Episode: 110 of 3000 Total Reward: 961.6476666666506
# Episode: 111 of 3000 Total Reward: 991.6399000000088
# Episode: 112 of 3000 Total Reward: 1011.6322666667502
# Episode: 113 of 3000 Total Reward: 1030.7865333334355
# Episode: 114 of 3000 Total Reward: 983.3435999999917
# Episode: 115 of 3000 Total Reward: 1063.1481666666507
# Episode: 116 of 3000 Total Reward: 999.1104000000385
# Episode: 117 of 3000 Total Reward: 1059.1890000001033
# Episode: 118 of 3000 Total Reward: 1001.6241333334644
# Episode: 119 of 3000 Total Reward: 982.2099666666721
# Episode: 120 of 3000 Total Reward: 962.396000000026
# Episode: 121 of 3000 Total Reward: 963.8780666667353
# Episode: 122 of 3000 Total Reward: 993.3387333334216
# Episode: 123 of 3000 Total Reward: 1047.2686999999737
# Episode: 124 of 3000 Total Reward: 1022.0349333333319
# Episode: 125 of 3000 Total Reward: 1044.2541666667323
# Episode: 126 of 3000 Total Reward: 1011.1564000000894
# Episode: 127 of 3000 Total Reward: 972.2890666667773
# Episode: 128 of 3000 Total Reward: 919.3607999999882
# Episode: 129 of 3000 Total Reward: 988.148100000013
# Episode: 130 of 3000 Total Reward: 1059.6466666667543
# Episode: 131 of 3000 Total Reward: 1001.3254333334493
# Episode: 132 of 3000 Total Reward: 1045.4995999999649
# Episode: 133 of 3000 Total Reward: 1081.5586999999925
# Episode: 134 of 3000 Total Reward: 1084.3078666667188
# Episode: 135 of 3000 Total Reward: 1018.2495000001072
# Episode: 136 of 3000 Total Reward: 970.8778666667962
# Episode: 137 of 3000 Total Reward: 1009.4467666666387
# Episode: 138 of 3000 Total Reward: 1023.9400000000138
# Episode: 139 of 3000 Total Reward: 1064.9601666667309
# Episode: 140 of 3000 Total Reward: 972.2320000000875
# Episode: 141 of 3000 Total Reward: 971.8245999999771
# Episode: 142 of 3000 Total Reward: 1007.1605999999965
# Episode: 143 of 3000 Total Reward: 968.8485333333618
# Episode: 144 of 3000 Total Reward: 1007.1416000000889
# Episode: 145 of 3000 Total Reward: 956.4780000001067
# Episode: 146 of 3000 Total Reward: 991.0397999999913
# Episode: 147 of 3000 Total Reward: 1014.3613000000316
# Episode: 148 of 3000 Total Reward: 1001.5722666667205
# Episode: 149 of 3000 Total Reward: 1020.3150333334158
# Episode: 150 of 3000 Total Reward: 1054.7249999999626
# Episode: 151 of 3000 Total Reward: 1004.4900666666888
# Episode: 152 of 3000 Total Reward: 1016.1714666667131
# Episode: 153 of 3000 Total Reward: 1013.4972000001092
# Episode: 154 of 3000 Total Reward: 936.7159333334075
# Episode: 155 of 3000 Total Reward: 998.9963333333205
# Episode: 156 of 3000 Total Reward: 986.7612000000099
# Episode: 157 of 3000 Total Reward: 1041.1850333333975
# Episode: 158 of 3000 Total Reward: 1044.91393333343
# Episode: 159 of 3000 Total Reward: 900.1960999999353
# Episode: 160 of 3000 Total Reward: 979.7506666666728
# Episode: 161 of 3000 Total Reward: 967.6968333333572
# Episode: 162 of 3000 Total Reward: 952.4992000000892
# Episode: 163 of 3000 Total Reward: 921.0653666667768
# Episode: 164 of 3000 Total Reward: 973.3148000000036
# Episode: 165 of 3000 Total Reward: 1014.0124999999907
# Episode: 166 of 3000 Total Reward: 1063.718266666714
# Episode: 167 of 3000 Total Reward: 1063.5894333334154
# Episode: 168 of 3000 Total Reward: 988.1328000001533
# Episode: 169 of 3000 Total Reward: 973.0468333333595
# Episode: 170 of 3000 Total Reward: 1022.5226666666819
# Episode: 171 of 3000 Total Reward: 989.1769000000747
# Episode: 172 of 3000 Total Reward: 926.8540000001049
# Episode: 173 of 3000 Total Reward: 881.8698999999838
# Episode: 174 of 3000 Total Reward: 928.5846000000098
# Episode: 175 of 3000 Total Reward: 1029.8841666667402
# Episode: 176 of 3000 Total Reward: 966.9474666667282
# Episode: 177 of 3000 Total Reward: 983.0408000001217
# Episode: 178 of 3000 Total Reward: 1054.929133333341
# Episode: 179 of 3000 Total Reward: 1012.4932666666995
# Episode: 180 of 3000 Total Reward: 1007.4860000000923
# Episode: 181 of 3000 Total Reward: 1003.5059333334327
# Episode: 182 of 3000 Total Reward: 1036.054533333316
# Episode: 183 of 3000 Total Reward: 980.8626999999947
# Episode: 184 of 3000 Total Reward: 933.0376000000543
# Episode: 185 of 3000 Total Reward: 918.54733333345
# Episode: 186 of 3000 Total Reward: 976.0050000001415
# Episode: 187 of 3000 Total Reward: 953.3439666666583
# Episode: 188 of 3000 Total Reward: 896.5837333333379
# Episode: 189 of 3000 Total Reward: 981.0475000000697
# Episode: 190 of 3000 Total Reward: 1027.1386666667804
# Episode: 191 of 3000 Total Reward: 1066.6222666666747
# Episode: 192 of 3000 Total Reward: 1015.5287999999773
# Episode: 193 of 3000 Total Reward: 978.6727333333738
# Episode: 194 of 3000 Total Reward: 974.5211333334372
# Episode: 195 of 3000 Total Reward: 952.2655000001268
# Episode: 196 of 3000 Total Reward: 942.0120000000109
# Episode: 197 of 3000 Total Reward: 985.5361666667027
# Episode: 198 of 3000 Total Reward: 943.6708000000659
# Episode: 199 of 3000 Total Reward: 957.0198666667559
# Episode: 200 of 3000 Total Reward: 913.8866666666404
# Episode: 201 of 3000 Total Reward: 909.1349999999948
# Episode: 202 of 3000 Total Reward: 1027.2889333333976
# Episode: 203 of 3000 Total Reward: 972.3152000000899
# Episode: 204 of 3000 Total Reward: 935.7444000001093
# Episode: 205 of 3000 Total Reward: 995.4628333333258
# Episode: 206 of 3000 Total Reward: 885.1552000000072
# Episode: 207 of 3000 Total Reward: 864.0068000000772
# Episode: 208 of 3000 Total Reward: 947.9714666667672
# Episode: 209 of 3000 Total Reward: 925.7475666666265
# Episode: 210 of 3000 Total Reward: 986.7769999999834
# Episode: 211 of 3000 Total Reward: 939.4711666667032
# Episode: 212 of 3000 Total Reward: 926.9096000000991
# Episode: 213 of 3000 Total Reward: 965.9146000001193
# Episode: 214 of 3000 Total Reward: 954.941533333306
# Episode: 215 of 3000 Total Reward: 930.0233333333389
# Episode: 216 of 3000 Total Reward: 937.3944000000669
# Episode: 217 of 3000 Total Reward: 897.3802333334303
# Episode: 218 of 3000 Total Reward: 1044.6116666666537
# Episode: 219 of 3000 Total Reward: 865.1312999999911
# Episode: 220 of 3000 Total Reward: 945.3440000000277
# Episode: 221 of 3000 Total Reward: 989.8369000000886
# Episode: 222 of 3000 Total Reward: 950.3946000001164
# Episode: 223 of 3000 Total Reward: 980.6676333333261
# Episode: 224 of 3000 Total Reward: 995.6109333333626
# Episode: 225 of 3000 Total Reward: 848.4000000000424
# Episode: 226 of 3000 Total Reward: 955.4281333334026
# Episode: 227 of 3000 Total Reward: 975.3708333332916
# Episode: 228 of 3000 Total Reward: 990.6568000000234
# Episode: 229 of 3000 Total Reward: 992.9108333333787
# Episode: 230 of 3000 Total Reward: 953.7710000000994
# Episode: 231 of 3000 Total Reward: 1029.5201000000989
# Episode: 232 of 3000 Total Reward: 916.7741333333099
# Episode: 233 of 3000 Total Reward: 984.5370666666721
# Episode: 234 of 3000 Total Reward: 836.7122000000612
# Episode: 235 of 3000 Total Reward: 1039.523833333435
# Episode: 236 of 3000 Total Reward: 1015.7554666666106
# Episode: 237 of 3000 Total Reward: 898.1131000000049
# Episode: 238 of 3000 Total Reward: 967.1942666666951
# Episode: 239 of 3000 Total Reward: 917.751400000091
# Episode: 240 of 3000 Total Reward: 1083.6600000001138
# Episode: 241 of 3000 Total Reward: 945.9528333333405
# Episode: 242 of 3000 Total Reward: 979.3325999999907
# Episode: 243 of 3000 Total Reward: 987.2244000000542
# Episode: 244 of 3000 Total Reward: 939.7612000000693
# Episode: 245 of 3000 Total Reward: 974.902000000146
# Episode: 246 of 3000 Total Reward: 936.2762000000206
# Episode: 247 of 3000 Total Reward: 980.538733333343
# Episode: 248 of 3000 Total Reward: 941.8058666667449
# Episode: 249 of 3000 Total Reward: 905.6391000000814
# Episode: 250 of 3000 Total Reward: 960.0999999999921
# Episode: 251 of 3000 Total Reward: 996.0114666666848
# Episode: 252 of 3000 Total Reward: 938.9512000000674
# Episode: 253 of 3000 Total Reward: 1015.2219000000717
# Episode: 254 of 3000 Total Reward: 961.135333333454
# Episode: 255 of 3000 Total Reward: 953.1625000000026
# Episode: 256 of 3000 Total Reward: 934.5197333333628
# Episode: 257 of 3000 Total Reward: 952.2489666667593
# Episode: 258 of 3000 Total Reward: 971.006800000083
# Episode: 259 of 3000 Total Reward: 958.9300666666378
# Episode: 260 of 3000 Total Reward: 973.4973333333247
# Episode: 261 of 3000 Total Reward: 927.2360000000546
# Episode: 262 of 3000 Total Reward: 952.8294666667937
# Episode: 263 of 3000 Total Reward: 950.668533333477
# Episode: 264 of 3000 Total Reward: 928.9783999999931
# Episode: 265 of 3000 Total Reward: 839.8105000000025
# Episode: 266 of 3000 Total Reward: 891.2382000000603
# Episode: 267 of 3000 Total Reward: 1008.3887000001052
# Episode: 268 of 3000 Total Reward: 1020.572799999996
# Episode: 269 of 3000 Total Reward: 961.2069333333077
# Episode: 270 of 3000 Total Reward: 956.2120000000391
# Episode: 271 of 3000 Total Reward: 984.4052000001078
# Episode: 272 of 3000 Total Reward: 1029.400800000138
# Episode: 273 of 3000 Total Reward: 952.6030000000104
# Episode: 274 of 3000 Total Reward: 905.947666666689
# Episode: 275 of 3000 Total Reward: 992.528333333409
# Episode: 276 of 3000 Total Reward: 1001.7620000001
# Episode: 277 of 3000 Total Reward: 1010.0834999999788
# Episode: 278 of 3000 Total Reward: 901.9623333333277
# Episode: 279 of 3000 Total Reward: 881.6324000000521
# Episode: 280 of 3000 Total Reward: 1055.7546666667615
# Episode: 281 of 3000 Total Reward: 901.2948000000907
# Episode: 282 of 3000 Total Reward: 948.5257999999899
# Episode: 283 of 3000 Total Reward: 954.058933333349
# Episode: 284 of 3000 Total Reward: 920.5692000000856
# Episode: 285 of 3000 Total Reward: 936.8675000000998
# Episode: 286 of 3000 Total Reward: 934.1593333332947
# Episode: 287 of 3000 Total Reward: 926.9109333333156
# Episode: 288 of 3000 Total Reward: 998.13040000005
# Episode: 289 of 3000 Total Reward: 850.4432333334336
# Episode: 290 of 3000 Total Reward: 938.2976666667926
# Episode: 291 of 3000 Total Reward: 936.0106999999756
# Episode: 292 of 3000 Total Reward: 936.0945333333393
# Episode: 293 of 3000 Total Reward: 931.9219333334022
# Episode: 294 of 3000 Total Reward: 940.2146000000954
# Episode: 295 of 3000 Total Reward: 915.8691666666383
# Episode: 296 of 3000 Total Reward: 962.0141333333313
# Episode: 297 of 3000 Total Reward: 862.9821000000142
# Episode: 298 of 3000 Total Reward: 874.9122666667495
# Episode: 299 of 3000 Total Reward: 1031.854866666796
# Episode: 300 of 3000 Total Reward: 867.7199999999917
# Episode: 301 of 3000 Total Reward: 900.336200000018
# Episode: 302 of 3000 Total Reward: 851.7984000000461
# Episode: 303 of 3000 Total Reward: 886.9433000000743
# Episode: 304 of 3000 Total Reward: 913.6119999999562
# Episode: 305 of 3000 Total Reward: 833.570666666685
# Episode: 306 of 3000 Total Reward: 936.0638000000356
# Episode: 307 of 3000 Total Reward: 916.6399000001035
# Episode: 308 of 3000 Total Reward: 986.7617333334299
# Episode: 309 of 3000 Total Reward: 926.222999999972
# Episode: 310 of 3000 Total Reward: 1041.560000000023
# Episode: 311 of 3000 Total Reward: 968.8142666667374
# Episode: 312 of 3000 Total Reward: 969.5880000000892
# Episode: 313 of 3000 Total Reward: 851.3099999999457
# Episode: 314 of 3000 Total Reward: 915.496666666674
# Episode: 315 of 3000 Total Reward: 877.8150000000152
# Episode: 316 of 3000 Total Reward: 894.6737333334095
# Episode: 317 of 3000 Total Reward: 921.5131333334477
# Episode: 318 of 3000 Total Reward: 904.7500000000074
# Episode: 319 of 3000 Total Reward: 891.4317999999882
# Episode: 320 of 3000 Total Reward: 897.0680000000543
# Episode: 321 of 3000 Total Reward: 905.667600000077
# Episode: 322 of 3000 Total Reward: 842.4954666667826
# Episode: 323 of 3000 Total Reward: 977.4243333333609
# Episode: 324 of 3000 Total Reward: 912.0488000000057
# Episode: 325 of 3000 Total Reward: 905.479166666734
# Episode: 326 of 3000 Total Reward: 898.5458666667543
# Episode: 327 of 3000 Total Reward: 937.6661999999927
# Episode: 328 of 3000 Total Reward: 890.5925333333407
# Episode: 329 of 3000 Total Reward: 882.735033333403
# Episode: 330 of 3000 Total Reward: 918.0470000000503
# Episode: 331 of 3000 Total Reward: 898.6071333334445
# Episode: 332 of 3000 Total Reward: 939.5817333333387
# Episode: 333 of 3000 Total Reward: 929.7413000000289
# Episode: 334 of 3000 Total Reward: 956.4975333334307
# Episode: 335 of 3000 Total Reward: 895.7260000000759
# Episode: 336 of 3000 Total Reward: 916.6903999999753
# Episode: 337 of 3000 Total Reward: 973.7529333333287
# Episode: 338 of 3000 Total Reward: 817.996666666711
# Episode: 339 of 3000 Total Reward: 965.6839000000839
# Episode: 340 of 3000 Total Reward: 876.3800000001297
# Episode: 341 of 3000 Total Reward: 913.986366666658
# Episode: 342 of 3000 Total Reward: 825.9280000000033
# Episode: 343 of 3000 Total Reward: 955.834700000076
# Episode: 344 of 3000 Total Reward: 899.2848000000996
# Episode: 345 of 3000 Total Reward: 886.2174999999949
# Episode: 346 of 3000 Total Reward: 955.8025333333159
# Episode: 347 of 3000 Total Reward: 850.1579333333664
# Episode: 348 of 3000 Total Reward: 952.0184000000971
# Episode: 349 of 3000 Total Reward: 883.1450333334502
# Episode: 350 of 3000 Total Reward: 954.1366666666721
# Episode: 351 of 3000 Total Reward: 872.2859000000246
# Episode: 352 of 3000 Total Reward: 902.9570666667339
# Episode: 353 of 3000 Total Reward: 867.4749333334142
# Episode: 354 of 3000 Total Reward: 882.6209999999782
# Episode: 355 of 3000 Total Reward: 983.4921666666713
# Episode: 356 of 3000 Total Reward: 856.9624000000549
# Episode: 357 of 3000 Total Reward: 971.1738000000901
# Episode: 358 of 3000 Total Reward: 945.2918000001098
# Episode: 359 of 3000 Total Reward: 821.3452999999919
# Episode: 360 of 3000 Total Reward: 941.1760000000155
# Episode: 361 of 3000 Total Reward: 987.7949666667565
# Episode: 362 of 3000 Total Reward: 909.280800000088
# Episode: 363 of 3000 Total Reward: 864.056299999958
# Episode: 364 of 3000 Total Reward: 833.154533333304
# Episode: 365 of 3000 Total Reward: 922.332333333374
# Episode: 366 of 3000 Total Reward: 892.7404000000954
# Episode: 367 of 3000 Total Reward: 917.001533333452
# Episode: 368 of 3000 Total Reward: 931.4807999999776
# Episode: 369 of 3000 Total Reward: 904.7022999999973
# Episode: 370 of 3000 Total Reward: 834.5533333333907
# Episode: 371 of 3000 Total Reward: 923.3644333334188
# Episode: 372 of 3000 Total Reward: 878.6387999999741
# Episode: 373 of 3000 Total Reward: 871.9966666666613
# Episode: 374 of 3000 Total Reward: 892.8102000000202
# Episode: 375 of 3000 Total Reward: 909.0375000000842
# Episode: 376 of 3000 Total Reward: 870.7114666667592
# Episode: 377 of 3000 Total Reward: 787.6033999999928
# Episode: 378 of 3000 Total Reward: 870.6956000000237
# Episode: 379 of 3000 Total Reward: 849.9426333333828
# Episode: 380 of 3000 Total Reward: 875.9186666667181
# Episode: 381 of 3000 Total Reward: 972.1659999999634
# Episode: 382 of 3000 Total Reward: 936.6569333333566
# Episode: 383 of 3000 Total Reward: 947.2017666667089
# Episode: 384 of 3000 Total Reward: 832.5240000000897
# Episode: 385 of 3000 Total Reward: 866.4033333334244
# Episode: 386 of 3000 Total Reward: 816.4017333333064
# Episode: 387 of 3000 Total Reward: 885.7604000000075
# Episode: 388 of 3000 Total Reward: 908.6596000000743
# Episode: 389 of 3000 Total Reward: 950.4665666667598
# Episode: 390 of 3000 Total Reward: 924.3339999999432
# Episode: 391 of 3000 Total Reward: 896.5330666666711
# Episode: 392 of 3000 Total Reward: 938.7173333333578
# Episode: 393 of 3000 Total Reward: 853.8008000000873
# Episode: 394 of 3000 Total Reward: 865.8046000001023
# Episode: 395 of 3000 Total Reward: 825.8268333333367
# Episode: 396 of 3000 Total Reward: 769.4915999999802
# Episode: 397 of 3000 Total Reward: 797.6209666667104
# Episode: 398 of 3000 Total Reward: 927.8859333334073
# Episode: 399 of 3000 Total Reward: 906.3973000001317
# Episode: 400 of 3000 Total Reward: 815.5000000000211
# Episode: 401 of 3000 Total Reward: 851.443266666668
# Episode: 402 of 3000 Total Reward: 804.9328000000592
# Episode: 403 of 3000 Total Reward: 893.0161333334123
# Episode: 404 of 3000 Total Reward: 856.3785333333203
# Episode: 405 of 3000 Total Reward: 931.8000000000145
# Episode: 406 of 3000 Total Reward: 887.3258666667364
# Episode: 407 of 3000 Total Reward: 889.3223666667138
# Episode: 408 of 3000 Total Reward: 987.3344000001113
# Episode: 409 of 3000 Total Reward: 849.9161666666741
# Episode: 410 of 3000 Total Reward: 832.0123333333605
# Episode: 411 of 3000 Total Reward: 808.8961000000768
# Episode: 412 of 3000 Total Reward: 870.3356000000778
# Episode: 413 of 3000 Total Reward: 802.3826666666395
# Episode: 414 of 3000 Total Reward: 960.965799999998
# Episode: 415 of 3000 Total Reward: 968.4951666667266
# Episode: 416 of 3000 Total Reward: 916.3448000000719
# Episode: 417 of 3000 Total Reward: 868.8843000001307
# Episode: 418 of 3000 Total Reward: 791.5190666666551
# Episode: 419 of 3000 Total Reward: 881.5093666666763
# Episode: 420 of 3000 Total Reward: 883.6740000000676
# Episode: 421 of 3000 Total Reward: 875.3154333334336
# Episode: 422 of 3000 Total Reward: 901.1101333333223
# Episode: 423 of 3000 Total Reward: 864.5197999999754
# Episode: 424 of 3000 Total Reward: 856.8237333333692
# Episode: 425 of 3000 Total Reward: 965.8933333334364
# Episode: 426 of 3000 Total Reward: 845.1826000001115
# Episode: 427 of 3000 Total Reward: 826.3859666666705
# Episode: 428 of 3000 Total Reward: 837.714666666689
# Episode: 429 of 3000 Total Reward: 874.6751000000647
# Episode: 430 of 3000 Total Reward: 872.3253333334059
# Episode: 431 of 3000 Total Reward: 806.3113999999733
# Episode: 432 of 3000 Total Reward: 840.8247999999901
# Episode: 433 of 3000 Total Reward: 877.0296666667175
# Episode: 434 of 3000 Total Reward: 919.5603333334172
# Episode: 435 of 3000 Total Reward: 885.6925000000977
# Episode: 436 of 3000 Total Reward: 937.9773333333262
# Episode: 437 of 3000 Total Reward: 859.1021666666753
# Episode: 438 of 3000 Total Reward: 851.144200000079
# Episode: 439 of 3000 Total Reward: 808.6617333334088
# Episode: 440 of 3000 Total Reward: 898.6133333332972
# Episode: 441 of 3000 Total Reward: 938.6648999999823
# Episode: 442 of 3000 Total Reward: 874.4164666667047
# Episode: 443 of 3000 Total Reward: 842.9351000000904
# Episode: 444 of 3000 Total Reward: 846.2528000001182
# Episode: 445 of 3000 Total Reward: 870.2409999999785
# Episode: 446 of 3000 Total Reward: 823.0714666666547
# Episode: 447 of 3000 Total Reward: 823.2711000000614
# Episode: 448 of 3000 Total Reward: 877.3816000000888
# Episode: 449 of 3000 Total Reward: 900.1553666666465
# Episode: 450 of 3000 Total Reward: 879.3399999999975
# Episode: 451 of 3000 Total Reward: 870.1119666666883
# Episode: 452 of 3000 Total Reward: 918.8529333334218
# Episode: 453 of 3000 Total Reward: 819.4724000000809
# Episode: 454 of 3000 Total Reward: 944.7333333333332
# Episode: 455 of 3000 Total Reward: 757.2935000000061
# Episode: 456 of 3000 Total Reward: 832.397600000045
# Episode: 457 of 3000 Total Reward: 875.8784333334019
# Episode: 458 of 3000 Total Reward: 795.6699333332951
# Episode: 459 of 3000 Total Reward: 887.0337000000286
# Episode: 460 of 3000 Total Reward: 893.6880000000441
# Episode: 461 of 3000 Total Reward: 837.4525333334246
# Episode: 462 of 3000 Total Reward: 809.7636000000552
# Episode: 463 of 3000 Total Reward: 893.4091333333079
# Episode: 464 of 3000 Total Reward: 871.5768000000077
# Episode: 465 of 3000 Total Reward: 983.1880000000781
# Episode: 466 of 3000 Total Reward: 797.5724666667326
# Episode: 467 of 3000 Total Reward: 844.3901333332736
# Episode: 468 of 3000 Total Reward: 870.9968000000048
# Episode: 469 of 3000 Total Reward: 892.5609666666894
# Episode: 470 of 3000 Total Reward: 904.017000000094
# Episode: 471 of 3000 Total Reward: 856.7926000000751
# Episode: 472 of 3000 Total Reward: 903.8714666666717
# Episode: 473 of 3000 Total Reward: 793.8793333333178
# Episode: 474 of 3000 Total Reward: 809.8180000000398
# Episode: 475 of 3000 Total Reward: 920.7091666667317
# Episode: 476 of 3000 Total Reward: 801.9502666666302
# Episode: 477 of 3000 Total Reward: 847.7491000000191
# Episode: 478 of 3000 Total Reward: 813.3160000000006
# Episode: 479 of 3000 Total Reward: 832.2233000000647
# Episode: 480 of 3000 Total Reward: 863.1480000000813
# Episode: 481 of 3000 Total Reward: 847.7736999999921
# Episode: 482 of 3000 Total Reward: 796.0294666666729
# Episode: 483 of 3000 Total Reward: 800.9506000000614
# Episode: 484 of 3000 Total Reward: 891.7816000000637
# Episode: 485 of 3000 Total Reward: 901.5118333334526
# Episode: 486 of 3000 Total Reward: 801.9038000000053
# Episode: 487 of 3000 Total Reward: 791.5062333333522
# Episode: 488 of 3000 Total Reward: 879.2328000000848
# Episode: 489 of 3000 Total Reward: 878.422200000079
# Episode: 490 of 3000 Total Reward: 886.7823333333115
# Episode: 491 of 3000 Total Reward: 874.436133333327
# Episode: 492 of 3000 Total Reward: 842.2096000000586
# Episode: 493 of 3000 Total Reward: 835.3610000000781
# Episode: 494 of 3000 Total Reward: 891.6714666667896
# Episode: 495 of 3000 Total Reward: 825.7889999999911
# Episode: 496 of 3000 Total Reward: 828.9592000000102
# Episode: 497 of 3000 Total Reward: 858.917500000069
# Episode: 498 of 3000 Total Reward: 882.5740000001081
# Episode: 499 of 3000 Total Reward: 899.7358333333306
# Episode: 500 of 3000 Total Reward: 848.0166666666436
# Episode: 501 of 3000 Total Reward: 829.4092000000351
# Episode: 502 of 3000 Total Reward: 840.4034000000912
# Episode: 503 of 3000 Total Reward: 908.2496000001228
# Episode: 504 of 3000 Total Reward: 852.6992000000114
# Episode: 505 of 3000 Total Reward: 849.867333333354
# Episode: 506 of 3000 Total Reward: 840.2233333333917
# Episode: 507 of 3000 Total Reward: 756.707000000054
# Episode: 508 of 3000 Total Reward: 900.7065333333109
# Episode: 509 of 3000 Total Reward: 853.0680666666585
# Episode: 510 of 3000 Total Reward: 819.9290000000523
# Episode: 511 of 3000 Total Reward: 907.932233333417
# Episode: 512 of 3000 Total Reward: 824.9757333334095
# Episode: 513 of 3000 Total Reward: 891.5343999999918
# Episode: 514 of 3000 Total Reward: 897.0371333333494
# Episode: 515 of 3000 Total Reward: 796.7933333334089
# Episode: 516 of 3000 Total Reward: 853.6812000000972
# Episode: 517 of 3000 Total Reward: 864.0529666666298
# Episode: 518 of 3000 Total Reward: 850.2896666666401
# Episode: 519 of 3000 Total Reward: 834.203900000034
# Episode: 520 of 3000 Total Reward: 867.5573333334337
# Episode: 521 of 3000 Total Reward: 884.4200666667923
# Episode: 522 of 3000 Total Reward: 807.51979999998
# Episode: 523 of 3000 Total Reward: 842.4806999999956
# Episode: 524 of 3000 Total Reward: 867.2872000000647
# Episode: 525 of 3000 Total Reward: 884.4825000000867
# Episode: 526 of 3000 Total Reward: 801.7538666666436
# Episode: 527 of 3000 Total Reward: 825.2561666666619
# Episode: 528 of 3000 Total Reward: 905.3400000000233
# Episode: 529 of 3000 Total Reward: 823.1557333334093
# Episode: 530 of 3000 Total Reward: 861.1233333334285
# Episode: 531 of 3000 Total Reward: 882.118999999992
# Episode: 532 of 3000 Total Reward: 818.9842666666872
# Episode: 533 of 3000 Total Reward: 830.3572333333802
# Episode: 534 of 3000 Total Reward: 850.9290000000699
# Episode: 535 of 3000 Total Reward: 760.8156666666359
# Episode: 536 of 3000 Total Reward: 884.1021333333609
# Episode: 537 of 3000 Total Reward: 794.4172000000276
# Episode: 538 of 3000 Total Reward: 823.0570000000888
# Episode: 539 of 3000 Total Reward: 809.3158000000633
# Episode: 540 of 3000 Total Reward: 788.5539999999728
# Episode: 541 of 3000 Total Reward: 843.850466666668
# Episode: 542 of 3000 Total Reward: 839.5436666667306
# Episode: 543 of 3000 Total Reward: 744.790000000075
# Episode: 544 of 3000 Total Reward: 788.3709333332835
# Episode: 545 of 3000 Total Reward: 840.7465000000084
# Episode: 546 of 3000 Total Reward: 919.4212000000228
# Episode: 547 of 3000 Total Reward: 878.3816333334187
# Episode: 548 of 3000 Total Reward: 785.0272000000939
# Episode: 549 of 3000 Total Reward: 734.7686000000051
# Episode: 550 of 3000 Total Reward: 796.874999999984
# Episode: 551 of 3000 Total Reward: 820.2760000000513
# Episode: 552 of 3000 Total Reward: 809.2512000000668
# Episode: 553 of 3000 Total Reward: 782.2205999999676
# Episode: 554 of 3000 Total Reward: 780.6928666666871
# Episode: 555 of 3000 Total Reward: 787.6004999999998
# Episode: 556 of 3000 Total Reward: 906.1978666667318
# Episode: 557 of 3000 Total Reward: 869.4293666667515
# Episode: 558 of 3000 Total Reward: 878.5903999999956
# Episode: 559 of 3000 Total Reward: 818.1014000000033
# Episode: 560 of 3000 Total Reward: 839.9800000000723
# Episode: 561 of 3000 Total Reward: 831.952300000053
# Episode: 562 of 3000 Total Reward: 803.4692666667781
# Episode: 563 of 3000 Total Reward: 864.6678666666733
# Episode: 564 of 3000 Total Reward: 825.7792000000243
# Episode: 565 of 3000 Total Reward: 812.9068333334193
# Episode: 566 of 3000 Total Reward: 837.463066666746
# Episode: 567 of 3000 Total Reward: 741.3322999999768
# Episode: 568 of 3000 Total Reward: 754.4138666666494
# Episode: 569 of 3000 Total Reward: 774.1456333333789
# Episode: 570 of 3000 Total Reward: 838.8730000000769
# Episode: 571 of 3000 Total Reward: 834.2235000001131
# Episode: 572 of 3000 Total Reward: 759.3509333333288
# Episode: 573 of 3000 Total Reward: 862.3860000000037
# Episode: 574 of 3000 Total Reward: 884.3264666667444
# Episode: 575 of 3000 Total Reward: 821.0741666667413
# Episode: 576 of 3000 Total Reward: 860.0151999999933
# Episode: 577 of 3000 Total Reward: 794.9057999999757
# Episode: 578 of 3000 Total Reward: 833.7739333333677
# Episode: 579 of 3000 Total Reward: 787.8636000000823
# Episode: 580 of 3000 Total Reward: 856.2333333334508
# Episode: 581 of 3000 Total Reward: 869.1317666666788
# Episode: 582 of 3000 Total Reward: 851.4988000000247
# Episode: 583 of 3000 Total Reward: 807.2999000000444
# Episode: 584 of 3000 Total Reward: 831.5154666667264
# Episode: 585 of 3000 Total Reward: 805.2249999999777
# Episode: 586 of 3000 Total Reward: 681.9704666666469
# Episode: 587 of 3000 Total Reward: 778.1119333333806
# Episode: 588 of 3000 Total Reward: 840.0772000000754
# Episode: 589 of 3000 Total Reward: 786.4768333334013
# Episode: 590 of 3000 Total Reward: 772.7929999999947
# Episode: 591 of 3000 Total Reward: 853.8029000000078
# Episode: 592 of 3000 Total Reward: 784.3458666667327
# Episode: 593 of 3000 Total Reward: 828.4608666667498
# Episode: 594 of 3000 Total Reward: 900.8253999999636
# Episode: 595 of 3000 Total Reward: 810.8611666666416
# Episode: 596 of 3000 Total Reward: 890.1758666667102
# Episode: 597 of 3000 Total Reward: 777.2198000000869
# Episode: 598 of 3000 Total Reward: 845.5539333334398
# Episode: 599 of 3000 Total Reward: 817.3615999999797
# Episode: 600 of 3000 Total Reward: 783.3799999999907
# Episode: 601 of 3000 Total Reward: 835.0826666667273
# Episode: 602 of 3000 Total Reward: 746.7824666667053
# Episode: 603 of 3000 Total Reward: 814.3083999999789
# Episode: 604 of 3000 Total Reward: 768.3543999999864
# Episode: 605 of 3000 Total Reward: 789.3230000000146
# Episode: 606 of 3000 Total Reward: 819.2286000000748
# Episode: 607 of 3000 Total Reward: 791.0495000000856
# Episode: 608 of 3000 Total Reward: 790.3037333333289
# Episode: 609 of 3000 Total Reward: 818.3742000000165
# Episode: 610 of 3000 Total Reward: 811.6593333333809
# Episode: 611 of 3000 Total Reward: 814.9948666667316
# Episode: 612 of 3000 Total Reward: 758.331199999959
# Episode: 613 of 3000 Total Reward: 867.6251333333335
# Episode: 614 of 3000 Total Reward: 836.9938000000419
# Episode: 615 of 3000 Total Reward: 797.6365000000955
# Episode: 616 of 3000 Total Reward: 715.7120000000557
# Episode: 617 of 3000 Total Reward: 783.371533333311
# Episode: 618 of 3000 Total Reward: 807.3830000000048
# Episode: 619 of 3000 Total Reward: 735.3283666667205
# Episode: 620 of 3000 Total Reward: 848.628666666756
# Episode: 621 of 3000 Total Reward: 825.7965999999525
# Episode: 622 of 3000 Total Reward: 778.3219333333427
# Episode: 623 of 3000 Total Reward: 886.7016333333571
# Episode: 624 of 3000 Total Reward: 847.2504000000853
# Episode: 625 of 3000 Total Reward: 775.6916666667606
# Episode: 626 of 3000 Total Reward: 725.0314000000091
# Episode: 627 of 3000 Total Reward: 777.675799999986
# Episode: 628 of 3000 Total Reward: 781.3606666667108
# Episode: 629 of 3000 Total Reward: 802.5604333333871
# Episode: 630 of 3000 Total Reward: 786.834999999963
# Episode: 631 of 3000 Total Reward: 880.1689666666956
# Episode: 632 of 3000 Total Reward: 793.9965333333316
# Episode: 633 of 3000 Total Reward: 818.1500000000636
# Episode: 634 of 3000 Total Reward: 811.9581333333974
# Episode: 635 of 3000 Total Reward: 805.0358333333305
# Episode: 636 of 3000 Total Reward: 734.8015999999926
# Episode: 637 of 3000 Total Reward: 824.3984000000648
# Episode: 638 of 3000 Total Reward: 870.790666666724
# Episode: 639 of 3000 Total Reward: 787.4337000000897
# Episode: 640 of 3000 Total Reward: 701.9773333333417
# Episode: 641 of 3000 Total Reward: 823.5774000000214
# Episode: 642 of 3000 Total Reward: 764.5422000000661
# Episode: 643 of 3000 Total Reward: 762.5747666667281
# Episode: 644 of 3000 Total Reward: 803.831466666648
# Episode: 645 of 3000 Total Reward: 817.3984999999874
# Episode: 646 of 3000 Total Reward: 804.4198000000438
# Episode: 647 of 3000 Total Reward: 804.7502333333923
# Episode: 648 of 3000 Total Reward: 773.9968000001077
# Episode: 649 of 3000 Total Reward: 782.8970666666553
# Episode: 650 of 3000 Total Reward: 784.4049999999958
# Episode: 651 of 3000 Total Reward: 751.9429000000512
# Episode: 652 of 3000 Total Reward: 788.1909333334121
# Episode: 653 of 3000 Total Reward: 771.9216999999934
# Episode: 654 of 3000 Total Reward: 756.3993999999759
# Episode: 655 of 3000 Total Reward: 707.2020000000264
# Episode: 656 of 3000 Total Reward: 762.8653333334173
# Episode: 657 of 3000 Total Reward: 736.0763000000975
# Episode: 658 of 3000 Total Reward: 737.5562666666783
# Episode: 659 of 3000 Total Reward: 795.7141333333592
# Episode: 660 of 3000 Total Reward: 850.5380000000486
# Episode: 661 of 3000 Total Reward: 785.6360000000667
# Episode: 662 of 3000 Total Reward: 728.8729333333149
# Episode: 663 of 3000 Total Reward: 750.3072999999868
# Episode: 664 of 3000 Total Reward: 815.9978666667216
# Episode: 665 of 3000 Total Reward: 791.9350000000676
# Episode: 666 of 3000 Total Reward: 842.6200000000881
# Episode: 667 of 3000 Total Reward: 787.8044666666548
# Episode: 668 of 3000 Total Reward: 829.4350666666745
# Episode: 669 of 3000 Total Reward: 704.0962000000584
# Episode: 670 of 3000 Total Reward: 656.3656666667152
# Episode: 671 of 3000 Total Reward: 701.8937999999662
# Episode: 672 of 3000 Total Reward: 726.7079999999718
# Episode: 673 of 3000 Total Reward: 778.7016000000244
# Episode: 674 of 3000 Total Reward: 842.8640000001001
# Episode: 675 of 3000 Total Reward: 718.685000000066
# Episode: 676 of 3000 Total Reward: 784.6901333333118
# Episode: 677 of 3000 Total Reward: 813.4697333333288
# Episode: 678 of 3000 Total Reward: 713.7442000000483
# Episode: 679 of 3000 Total Reward: 779.489533333421
# Episode: 680 of 3000 Total Reward: 798.8693333333188
# Episode: 681 of 3000 Total Reward: 809.1774999999903
# Episode: 682 of 3000 Total Reward: 849.7563333333592
# Episode: 683 of 3000 Total Reward: 844.2063000000854
# Episode: 684 of 3000 Total Reward: 688.0536000000573
# Episode: 685 of 3000 Total Reward: 707.1948333333296
# Episode: 686 of 3000 Total Reward: 766.4827333333468
# Episode: 687 of 3000 Total Reward: 782.9477000000477
# Episode: 688 of 3000 Total Reward: 771.0733333333955
# Episode: 689 of 3000 Total Reward: 815.5180999999665
# Episode: 690 of 3000 Total Reward: 781.3529999999757
# Episode: 691 of 3000 Total Reward: 758.7221666667002
# Episode: 692 of 3000 Total Reward: 763.238266666756
# Episode: 693 of 3000 Total Reward: 774.1008000000538
# Episode: 694 of 3000 Total Reward: 777.2170666666465
# Episode: 695 of 3000 Total Reward: 721.5094999999975
# Episode: 696 of 3000 Total Reward: 779.7240000000621
# Episode: 697 of 3000 Total Reward: 818.7398666667461
# Episode: 698 of 3000 Total Reward: 765.4375333332837
# Episode: 699 of 3000 Total Reward: 756.129800000009
# Episode: 700 of 3000 Total Reward: 766.1133333333473
# Episode: 701 of 3000 Total Reward: 808.4242000000818
# Episode: 702 of 3000 Total Reward: 648.1088000000456
# Episode: 703 of 3000 Total Reward: 859.6471000000136
# Episode: 704 of 3000 Total Reward: 748.7559999999817
# Episode: 705 of 3000 Total Reward: 804.3745000000421
# Episode: 706 of 3000 Total Reward: 731.6730000000609
# Episode: 707 of 3000 Total Reward: 813.0204999999692
# Episode: 708 of 3000 Total Reward: 813.9560000000249
# Episode: 709 of 3000 Total Reward: 662.3830666666558
# Episode: 710 of 3000 Total Reward: 774.6586666667271
# Episode: 711 of 3000 Total Reward: 742.7678000000501
# Episode: 712 of 3000 Total Reward: 689.82853333333
# Episode: 713 of 3000 Total Reward: 804.9628666666737
# Episode: 714 of 3000 Total Reward: 696.5710000000503
# Episode: 715 of 3000 Total Reward: 755.3348333333664
# Episode: 716 of 3000 Total Reward: 747.2181333334331
# Episode: 717 of 3000 Total Reward: 675.8692000000062
# Episode: 718 of 3000 Total Reward: 774.8478000000175
# Episode: 719 of 3000 Total Reward: 674.6994333333996
# Episode: 720 of 3000 Total Reward: 713.9800000000416
# Episode: 721 of 3000 Total Reward: 672.6683333333169
# Episode: 722 of 3000 Total Reward: 818.8127333333272
# Episode: 723 of 3000 Total Reward: 745.2998000000488
# Episode: 724 of 3000 Total Reward: 711.8138666667145
# Episode: 725 of 3000 Total Reward: 690.5366666667463
# Episode: 726 of 3000 Total Reward: 782.1337999999952
# Episode: 727 of 3000 Total Reward: 716.9927666666593
# Episode: 728 of 3000 Total Reward: 761.4938666667207
# Episode: 729 of 3000 Total Reward: 772.9836000000836
# Episode: 730 of 3000 Total Reward: 851.2813333333289
# Episode: 731 of 3000 Total Reward: 794.1957999999793
# Episode: 732 of 3000 Total Reward: 796.118800000038
# Episode: 733 of 3000 Total Reward: 784.6735000000888
# Episode: 734 of 3000 Total Reward: 732.041600000077
# Episode: 735 of 3000 Total Reward: 753.1020000000037
# Episode: 736 of 3000 Total Reward: 696.2365333333405
# Episode: 737 of 3000 Total Reward: 765.4337000000393
# Episode: 738 of 3000 Total Reward: 741.5784000000783
# Episode: 739 of 3000 Total Reward: 741.1551999999768
# Episode: 740 of 3000 Total Reward: 741.1153333333231
# Episode: 741 of 3000 Total Reward: 726.0491000000376
# Episode: 742 of 3000 Total Reward: 800.0548666667444
# Episode: 743 of 3000 Total Reward: 701.7628333333901
# Episode: 744 of 3000 Total Reward: 731.2207999999964
# Episode: 745 of 3000 Total Reward: 758.0745000000051
# Episode: 746 of 3000 Total Reward: 723.8251333334034
# Episode: 747 of 3000 Total Reward: 715.3792000000653
# Episode: 748 of 3000 Total Reward: 759.6954666666312
# Episode: 749 of 3000 Total Reward: 678.9784666666338
# Episode: 750 of 3000 Total Reward: 746.5750000000301
# Episode: 751 of 3000 Total Reward: 759.2547000000841
# Episode: 752 of 3000 Total Reward: 723.2973333334288
# Episode: 753 of 3000 Total Reward: 745.4813999999839
# Episode: 754 of 3000 Total Reward: 636.21159999997
# Episode: 755 of 3000 Total Reward: 695.099000000051
# Episode: 756 of 3000 Total Reward: 721.7592000000756
# Episode: 757 of 3000 Total Reward: 730.5787333333133
# Episode: 758 of 3000 Total Reward: 739.6343333333266
# Episode: 759 of 3000 Total Reward: 698.9708000000057
# Episode: 760 of 3000 Total Reward: 735.6213333333981
# Episode: 761 of 3000 Total Reward: 738.9502333334028
# Episode: 762 of 3000 Total Reward: 687.3989999999951
# Episode: 763 of 3000 Total Reward: 694.8435333333541
# Episode: 764 of 3000 Total Reward: 703.7670666667024
# Episode: 765 of 3000 Total Reward: 724.7805000000498
# Episode: 766 of 3000 Total Reward: 732.4947999999616
# Episode: 767 of 3000 Total Reward: 754.3764999999725
# Episode: 768 of 3000 Total Reward: 752.8792000000235
# Episode: 769 of 3000 Total Reward: 692.5119666667282
# Episode: 770 of 3000 Total Reward: 713.0606666667089
# Episode: 771 of 3000 Total Reward: 683.1386999999796
# Episode: 772 of 3000 Total Reward: 783.4649333333334
# Episode: 773 of 3000 Total Reward: 660.7321000000492
# Episode: 774 of 3000 Total Reward: 665.2286000000363
# Episode: 775 of 3000 Total Reward: 773.9941666666247
# Episode: 776 of 3000 Total Reward: 809.5066666666801
# Episode: 777 of 3000 Total Reward: 768.223300000023
# Episode: 778 of 3000 Total Reward: 709.6016666667338
# Episode: 779 of 3000 Total Reward: 831.6663666667623
# Episode: 780 of 3000 Total Reward: 728.2960000000111
# Episode: 781 of 3000 Total Reward: 715.5155333333162
# Episode: 782 of 3000 Total Reward: 752.2775333333691
# Episode: 783 of 3000 Total Reward: 774.084000000065
# Episode: 784 of 3000 Total Reward: 742.3586666666349
# Episode: 785 of 3000 Total Reward: 757.6971666666938
# Episode: 786 of 3000 Total Reward: 693.6839999999918
# Episode: 787 of 3000 Total Reward: 787.4817666667215
# Episode: 788 of 3000 Total Reward: 665.0918666667042
# Episode: 789 of 3000 Total Reward: 698.8379999999947
# Episode: 790 of 3000 Total Reward: 712.4403333333374
# Episode: 791 of 3000 Total Reward: 677.664533333388
# Episode: 792 of 3000 Total Reward: 650.2080000000044
# Episode: 793 of 3000 Total Reward: 714.7473000000828
# Episode: 794 of 3000 Total Reward: 712.8827333333444
# Episode: 795 of 3000 Total Reward: 661.0430000000184
# Episode: 796 of 3000 Total Reward: 731.8288000000769
# Episode: 797 of 3000 Total Reward: 750.4161333333859
# Episode: 798 of 3000 Total Reward: 726.7399999999764
# Episode: 799 of 3000 Total Reward: 699.3807666666465
# Episode: 800 of 3000 Total Reward: 655.5133333333631
# Episode: 801 of 3000 Total Reward: 703.9969000000468
# Episode: 802 of 3000 Total Reward: 759.9472000000942
# Episode: 803 of 3000 Total Reward: 640.8530333333267
# Episode: 804 of 3000 Total Reward: 720.0139999999966
# Episode: 805 of 3000 Total Reward: 707.5066666667195
# Episode: 806 of 3000 Total Reward: 805.5234000001019
# Episode: 807 of 3000 Total Reward: 783.0534999999979
# Episode: 808 of 3000 Total Reward: 727.2002666666382
# Episode: 809 of 3000 Total Reward: 723.636833333361
# Episode: 810 of 3000 Total Reward: 747.2120000000812
# Episode: 811 of 3000 Total Reward: 724.0903000000812
# Episode: 812 of 3000 Total Reward: 738.1592000000078
# Episode: 813 of 3000 Total Reward: 718.8167000000049
# Episode: 814 of 3000 Total Reward: 702.4887333333734
# Episode: 815 of 3000 Total Reward: 747.6051666667422
# Episode: 816 of 3000 Total Reward: 596.3959999999921
# Episode: 817 of 3000 Total Reward: 589.5714333332982
# Episode: 818 of 3000 Total Reward: 691.5956000000393
# Episode: 819 of 3000 Total Reward: 704.0434000000671
# Episode: 820 of 3000 Total Reward: 658.2953333333769
# Episode: 821 of 3000 Total Reward: 718.3433333333304
# Episode: 822 of 3000 Total Reward: 708.180199999995
# Episode: 823 of 3000 Total Reward: 717.4019666667375
# Episode: 824 of 3000 Total Reward: 694.359200000065
# Episode: 825 of 3000 Total Reward: 730.739999999969
# Episode: 826 of 3000 Total Reward: 623.0316666666279
# Episode: 827 of 3000 Total Reward: 752.3442333333633
# Episode: 828 of 3000 Total Reward: 609.5332000000749
# Episode: 829 of 3000 Total Reward: 640.7011333333649
# Episode: 830 of 3000 Total Reward: 684.1933333333143
# Episode: 831 of 3000 Total Reward: 664.6558999999864
# Episode: 832 of 3000 Total Reward: 749.0146666667157
# Episode: 833 of 3000 Total Reward: 697.1233000000342
# Episode: 834 of 3000 Total Reward: 737.1481999999818
# Episode: 835 of 3000 Total Reward: 691.4743333333126
# Episode: 836 of 3000 Total Reward: 692.7114666666725
# Episode: 837 of 3000 Total Reward: 694.3747000000642
# Episode: 838 of 3000 Total Reward: 701.3142666667383
# Episode: 839 of 3000 Total Reward: 683.8147999999944
# Episode: 840 of 3000 Total Reward: 642.6399999999863
# Episode: 841 of 3000 Total Reward: 672.9047000000304
# Episode: 842 of 3000 Total Reward: 670.1976000000404
# Episode: 843 of 3000 Total Reward: 658.4050999999631
# Episode: 844 of 3000 Total Reward: 679.6654666666409
# Episode: 845 of 3000 Total Reward: 669.8595000000284
# Episode: 846 of 3000 Total Reward: 665.937800000078
# Episode: 847 of 3000 Total Reward: 673.6873000000215
# Episode: 848 of 3000 Total Reward: 643.6098666666478
# Episode: 849 of 3000 Total Reward: 631.2922999999835
# Episode: 850 of 3000 Total Reward: 673.6616666667103
# Episode: 851 of 3000 Total Reward: 719.5083666667291
# Episode: 852 of 3000 Total Reward: 715.5039999999697
# Episode: 853 of 3000 Total Reward: 737.4597333333439
# Episode: 854 of 3000 Total Reward: 701.3908000000075
# Episode: 855 of 3000 Total Reward: 649.7940000000568
# Episode: 856 of 3000 Total Reward: 681.5837333333905
# Episode: 857 of 3000 Total Reward: 743.0450333333278
# Episode: 858 of 3000 Total Reward: 655.2499999999765
# Episode: 859 of 3000 Total Reward: 637.1621000000248
# Episode: 860 of 3000 Total Reward: 665.8266666666873
# Episode: 861 of 3000 Total Reward: 703.255799999972
# Episode: 862 of 3000 Total Reward: 659.4294000000239
# Episode: 863 of 3000 Total Reward: 645.2634333333178
# Episode: 864 of 3000 Total Reward: 742.4760000000583
# Episode: 865 of 3000 Total Reward: 671.1400000000631
# Episode: 866 of 3000 Total Reward: 725.901666666661
# Episode: 867 of 3000 Total Reward: 705.251299999997
# Episode: 868 of 3000 Total Reward: 652.1066666667147
# Episode: 869 of 3000 Total Reward: 581.6973666666397
# Episode: 870 of 3000 Total Reward: 663.7440000000684
# Episode: 871 of 3000 Total Reward: 628.4571000000071
# Episode: 872 of 3000 Total Reward: 723.8925333333393
# Episode: 873 of 3000 Total Reward: 650.4306000000462
# Episode: 874 of 3000 Total Reward: 681.9263333333529
# Episode: 875 of 3000 Total Reward: 657.1124999999894
# Episode: 876 of 3000 Total Reward: 643.9427999999702
# Episode: 877 of 3000 Total Reward: 698.2042333333787
# Episode: 878 of 3000 Total Reward: 683.06700000001
# Episode: 879 of 3000 Total Reward: 621.2344000000323
# Episode: 880 of 3000 Total Reward: 669.0999999999982
# Episode: 881 of 3000 Total Reward: 724.8197333333366
# Episode: 882 of 3000 Total Reward: 584.4652000000314
# Episode: 883 of 3000 Total Reward: 661.3314000000538
# Episode: 884 of 3000 Total Reward: 682.9109333333249
# Episode: 885 of 3000 Total Reward: 700.99349999997
# Episode: 886 of 3000 Total Reward: 703.27380000003
# Episode: 887 of 3000 Total Reward: 675.1858333334155
# Episode: 888 of 3000 Total Reward: 659.0456000000705
# Episode: 889 of 3000 Total Reward: 701.9424000000071
# Episode: 890 of 3000 Total Reward: 643.3533333333327
# Episode: 891 of 3000 Total Reward: 593.4632000000249
# Episode: 892 of 3000 Total Reward: 614.7343999999924
# Episode: 893 of 3000 Total Reward: 737.441766666644
# Episode: 894 of 3000 Total Reward: 615.1487999999744
# Episode: 895 of 3000 Total Reward: 735.1778333333795
# Episode: 896 of 3000 Total Reward: 637.9197333333913
# Episode: 897 of 3000 Total Reward: 676.9075000000589
# Episode: 898 of 3000 Total Reward: 659.9262666666549
# Episode: 899 of 3000 Total Reward: 602.1313333333198
# Episode: 900 of 3000 Total Reward: 713.9600000000671
# Episode: 901 of 3000 Total Reward: 628.0317333333803
# Episode: 902 of 3000 Total Reward: 736.9920666666437
# Episode: 903 of 3000 Total Reward: 669.5697999999649
# Episode: 904 of 3000 Total Reward: 609.5360000000065
# Episode: 905 of 3000 Total Reward: 591.0651666667176
# Episode: 906 of 3000 Total Reward: 679.4438000000769
# Episode: 907 of 3000 Total Reward: 688.9599999999804
# ...
# Episode: 2713 of 3000 Total Reward: -30.33579999999526
# Episode: 2714 of 3000 Total Reward: -45.46153333332877
# Episode: 2715 of 3000 Total Reward: -5.236499999997159
# Episode: 2716 of 3000 Total Reward: -28.108133333325878
# Episode: 2717 of 3000 Total Reward: -106.64010000000171
# Episode: 2718 of 3000 Total Reward: -131.2567999999984
# Episode: 2719 of 3000 Total Reward: -11.37919999999589
# Episode: 2720 of 3000 Total Reward: -75.22266666666631
# Episode: 2721 of 3000 Total Reward: -209.9348000000062
# Episode: 2722 of 3000 Total Reward: -87.51373333332992
# Episode: 2723 of 3000 Total Reward: -68.11523333332639
# Episode: 2724 of 3000 Total Reward: -173.41519999999747
# Episode: 2725 of 3000 Total Reward: -35.15083333332935
# Episode: 2726 of 3000 Total Reward: -59.928199999998974
# Episode: 2727 of 3000 Total Reward: -83.80279999999298
# Episode: 2728 of 3000 Total Reward: -34.94879999999751
# Episode: 2729 of 3000 Total Reward: -48.094899999991284
# Episode: 2730 of 3000 Total Reward: -105.7979999999949
# Episode: 2731 of 3000 Total Reward: -136.6024999999923
# Episode: 2732 of 3000 Total Reward: -132.83920000000572
# Episode: 2733 of 3000 Total Reward: -180.93400000000062
# Episode: 2734 of 3000 Total Reward: -85.65093333333299
# Episode: 2735 of 3000 Total Reward: -72.9766666666659
# Episode: 2736 of 3000 Total Reward: -90.14479999999196
# Episode: 2737 of 3000 Total Reward: -105.85100000000004
# Episode: 2738 of 3000 Total Reward: -156.7138000000016
# Episode: 2739 of 3000 Total Reward: -167.10519999999931
# Episode: 2740 of 3000 Total Reward: -190.33266666667828
# Episode: 2741 of 3000 Total Reward: -94.60416666666642
# Episode: 2742 of 3000 Total Reward: -189.28339999999423
# Episode: 2743 of 3000 Total Reward: -94.5603333333292
# Episode: 2744 of 3000 Total Reward: -97.89733333333069
# Episode: 2745 of 3000 Total Reward: -50.09149999999861
# Episode: 2746 of 3000 Total Reward: -163.76100000000335
# Episode: 2747 of 3000 Total Reward: -141.96296666666848
# Episode: 2748 of 3000 Total Reward: -95.57279999999655
# Episode: 2749 of 3000 Total Reward: -126.38516666666459
# Episode: 2750 of 3000 Total Reward: -94.82500000000013
# Episode: 2751 of 3000 Total Reward: -126.55009999999925
# Episode: 2752 of 3000 Total Reward: -82.49946666666528
# Episode: 2753 of 3000 Total Reward: -92.60013333332392
# Episode: 2754 of 3000 Total Reward: -148.90740000000307
# Episode: 2755 of 3000 Total Reward: -192.60700000000872
# Episode: 2756 of 3000 Total Reward: -99.12146666666429
# Episode: 2757 of 3000 Total Reward: -88.96989999999465
# Episode: 2758 of 3000 Total Reward: -67.01159999999847
# Episode: 2759 of 3000 Total Reward: -76.94979999999934
# Episode: 2760 of 3000 Total Reward: -96.26799999999623
# Episode: 2761 of 3000 Total Reward: -89.22963333332918
# Episode: 2762 of 3000 Total Reward: -130.29279999999576
# Episode: 2763 of 3000 Total Reward: -44.17850000000553
# Episode: 2764 of 3000 Total Reward: -88.11253333333528
# Episode: 2765 of 3000 Total Reward: -134.85633333333232
# Episode: 2766 of 3000 Total Reward: -106.91219999999248
# Episode: 2767 of 3000 Total Reward: -146.11869999999823
# Episode: 2768 of 3000 Total Reward: -210.89359999999706
# Episode: 2769 of 3000 Total Reward: -138.60169999999624
# Episode: 2770 of 3000 Total Reward: -66.54533333332763
# Episode: 2771 of 3000 Total Reward: -114.1849000000003
# Episode: 2772 of 3000 Total Reward: -94.17160000000082
# Episode: 2773 of 3000 Total Reward: -175.0278333333417
# Episode: 2774 of 3000 Total Reward: -79.58413333332535
# Episode: 2775 of 3000 Total Reward: -139.03499999999596
# Episode: 2776 of 3000 Total Reward: -220.12586666666752
# Episode: 2777 of 3000 Total Reward: -119.75136666666134
# Episode: 2778 of 3000 Total Reward: -132.6755999999985
# Episode: 2779 of 3000 Total Reward: -151.32233333333366
# Episode: 2780 of 3000 Total Reward: -154.45733333333797
# Episode: 2781 of 3000 Total Reward: -196.1154000000066
# Episode: 2782 of 3000 Total Reward: -91.36699999999742
# Episode: 2783 of 3000 Total Reward: -106.91749999999556
# Episode: 2784 of 3000 Total Reward: -110.4327999999991
# Episode: 2785 of 3000 Total Reward: -118.31950000000033
# Episode: 2786 of 3000 Total Reward: -165.972333333334
# Episode: 2787 of 3000 Total Reward: -22.475399999997446
# Episode: 2788 of 3000 Total Reward: -77.05999999999916
# Episode: 2789 of 3000 Total Reward: -79.24879999999776
# Episode: 2790 of 3000 Total Reward: -114.91999999999366
# Episode: 2791 of 3000 Total Reward: -49.458033333322874
# Episode: 2792 of 3000 Total Reward: -149.51573333333064
# Episode: 2793 of 3000 Total Reward: -61.574000000001405
# Episode: 2794 of 3000 Total Reward: -62.89886666666801
# Episode: 2795 of 3000 Total Reward: -187.36616666667018
# Episode: 2796 of 3000 Total Reward: -238.0627999999996
# Episode: 2797 of 3000 Total Reward: -33.01589999999894
# Episode: 2798 of 3000 Total Reward: -174.84100000000737
# Episode: 2799 of 3000 Total Reward: -128.34499999999474
# Episode: 2800 of 3000 Total Reward: -134.63333333332713
# Episode: 2801 of 3000 Total Reward: -94.78533333333394
# Episode: 2802 of 3000 Total Reward: -137.61499999999987
# Episode: 2803 of 3000 Total Reward: -81.27669999999317
# Episode: 2804 of 3000 Total Reward: -113.17293333332357
# Episode: 2805 of 3000 Total Reward: -94.76100000000069
# Episode: 2806 of 3000 Total Reward: -146.7643333333386
# Episode: 2807 of 3000 Total Reward: -95.18616666665659
# Episode: 2808 of 3000 Total Reward: -84.0015999999898
# Episode: 2809 of 3000 Total Reward: -53.797566666664736
# Episode: 2810 of 3000 Total Reward: -112.33033333333351
# Episode: 2811 of 3000 Total Reward: -119.61990000000098
# Episode: 2812 of 3000 Total Reward: -175.4185333333331
# Episode: 2813 of 3000 Total Reward: -150.71876666666125
# Episode: 2814 of 3000 Total Reward: -175.3346000000039
# Episode: 2815 of 3000 Total Reward: -261.24700000001235
# Episode: 2816 of 3000 Total Reward: -169.1202666666681
# Episode: 2817 of 3000 Total Reward: -160.1749000000083
# Episode: 2818 of 3000 Total Reward: -114.56606666666708
# Episode: 2819 of 3000 Total Reward: -134.81196666666457
# Episode: 2820 of 3000 Total Reward: -200.57999999999072
# Episode: 2821 of 3000 Total Reward: -173.12809999999826
# Episode: 2822 of 3000 Total Reward: -181.87546666666714
# Episode: 2823 of 3000 Total Reward: -104.13639999999609
# Episode: 2824 of 3000 Total Reward: -179.39413333334534
# Episode: 2825 of 3000 Total Reward: -138.2316666666655
# Episode: 2826 of 3000 Total Reward: -76.88999999999598
# Episode: 2827 of 3000 Total Reward: -75.86476666666746
# Episode: 2828 of 3000 Total Reward: -198.29546666666562
# Episode: 2829 of 3000 Total Reward: -153.06539999999694
# Episode: 2830 of 3000 Total Reward: -286.69700000000154
# Episode: 2831 of 3000 Total Reward: 11.606933333333467
# Episode: 2832 of 3000 Total Reward: -149.80880000000732
# Episode: 2833 of 3000 Total Reward: -116.94806666666402
# Episode: 2834 of 3000 Total Reward: -137.07093333333208
# Episode: 2835 of 3000 Total Reward: -251.28549999999663
# Episode: 2836 of 3000 Total Reward: -263.94906666665815
# Episode: 2837 of 3000 Total Reward: -133.74453333333088
# Episode: 2838 of 3000 Total Reward: -98.51959999999166
# Episode: 2839 of 3000 Total Reward: -181.70326666667248
# Episode: 2840 of 3000 Total Reward: -195.95733333334073
# Episode: 2841 of 3000 Total Reward: -155.60840000000152
# Episode: 2842 of 3000 Total Reward: -278.95926666667776
# Episode: 2843 of 3000 Total Reward: -242.5079666666808
# Episode: 2844 of 3000 Total Reward: -203.3075999999968
# Episode: 2845 of 3000 Total Reward: -253.2694999999967
# Episode: 2846 of 3000 Total Reward: -102.50253333332903
# Episode: 2847 of 3000 Total Reward: -177.9872000000018
# Episode: 2848 of 3000 Total Reward: -171.6392000000056
# Episode: 2849 of 3000 Total Reward: -135.23840000000277
# Episode: 2850 of 3000 Total Reward: -124.18499999999516
# Episode: 2851 of 3000 Total Reward: -171.50280000000163
# Episode: 2852 of 3000 Total Reward: -275.5791999999968
# Episode: 2853 of 3000 Total Reward: -180.0486000000008
# Episode: 2854 of 3000 Total Reward: -135.2490666666691
# Episode: 2855 of 3000 Total Reward: -108.67583333333134
# Episode: 2856 of 3000 Total Reward: -223.08480000000242
# Episode: 2857 of 3000 Total Reward: -219.03870000000686
# Episode: 2858 of 3000 Total Reward: -189.37073333333737
# Episode: 2859 of 3000 Total Reward: -116.6945999999945
# Episode: 2860 of 3000 Total Reward: -263.52666666667574
# Episode: 2861 of 3000 Total Reward: -161.7690333333305
# Episode: 2862 of 3000 Total Reward: -84.49439999999854
# Episode: 2863 of 3000 Total Reward: -0.35330000000145434
# Episode: 2864 of 3000 Total Reward: -141.54319999999623
# Episode: 2865 of 3000 Total Reward: -156.47800000000376
# Episode: 2866 of 3000 Total Reward: -219.80506666666864
# Episode: 2867 of 3000 Total Reward: -171.13460000000686
# Episode: 2868 of 3000 Total Reward: -204.0744000000123
# Episode: 2869 of 3000 Total Reward: -175.5643000000091
# Episode: 2870 of 3000 Total Reward: -163.39699999999934
# Episode: 2871 of 3000 Total Reward: -36.74670000000112
# Episode: 2872 of 3000 Total Reward: -186.72080000000366
# Episode: 2873 of 3000 Total Reward: -201.6593333333318
# Episode: 2874 of 3000 Total Reward: -158.04080000000488
# Episode: 2875 of 3000 Total Reward: -263.5583333333641
# Episode: 2876 of 3000 Total Reward: -137.2249333333338
# Episode: 2877 of 3000 Total Reward: -271.0189000000027
# Episode: 2878 of 3000 Total Reward: -206.26773333333233
# Episode: 2879 of 3000 Total Reward: -158.00323333332946
# Episode: 2880 of 3000 Total Reward: -129.91599999999949
# Episode: 2881 of 3000 Total Reward: -250.5792666666608
# Episode: 2882 of 3000 Total Reward: -109.6231999999989
# Episode: 2883 of 3000 Total Reward: -227.73290000000986
# Episode: 2884 of 3000 Total Reward: -252.54706666667457
# Episode: 2885 of 3000 Total Reward: -207.89816666667537
# Episode: 2886 of 3000 Total Reward: -183.28540000000393
# Episode: 2887 of 3000 Total Reward: -168.2298000000003
# Episode: 2888 of 3000 Total Reward: -144.46666666666718
# Episode: 2889 of 3000 Total Reward: -219.34770000000037
# Episode: 2890 of 3000 Total Reward: -167.56566666666936
# Episode: 2891 of 3000 Total Reward: -145.99456666667137
# Episode: 2892 of 3000 Total Reward: -176.17560000000466
# Episode: 2893 of 3000 Total Reward: -166.40703333333593
# Episode: 2894 of 3000 Total Reward: -160.77013333334295
# Episode: 2895 of 3000 Total Reward: -172.4219999999979
# Episode: 2896 of 3000 Total Reward: -250.71653333333123
# Episode: 2897 of 3000 Total Reward: -116.79706666666209
# Episode: 2898 of 3000 Total Reward: -260.10940000000016
# Episode: 2899 of 3000 Total Reward: -173.2217666666709
# Episode: 2900 of 3000 Total Reward: -266.7733333333411
# Episode: 2901 of 3000 Total Reward: -177.67580000000754
# Episode: 2902 of 3000 Total Reward: -83.39606666666378
# Episode: 2903 of 3000 Total Reward: -142.5212000000002
# Episode: 2904 of 3000 Total Reward: -183.33119999999934
# Episode: 2905 of 3000 Total Reward: -176.78833333333168
# Episode: 2906 of 3000 Total Reward: -128.93619999999703
# Episode: 2907 of 3000 Total Reward: -230.8115000000011
# Episode: 2908 of 3000 Total Reward: -210.19880000000654
# Episode: 2909 of 3000 Total Reward: -246.7581666666794
# Episode: 2910 of 3000 Total Reward: -46.945999999988416
# Episode: 2911 of 3000 Total Reward: -240.91900000001
# Episode: 2912 of 3000 Total Reward: -136.60720000000015
# Episode: 2913 of 3000 Total Reward: -155.13379999999495
# Episode: 2914 of 3000 Total Reward: -105.91319999999202
# Episode: 2915 of 3000 Total Reward: -214.88600000000108
# Episode: 2916 of 3000 Total Reward: -235.45280000000184
# Episode: 2917 of 3000 Total Reward: -170.1301333333391
# Episode: 2918 of 3000 Total Reward: -155.93973333333918
# Episode: 2919 of 3000 Total Reward: -268.91340000001225
# Episode: 2920 of 3000 Total Reward: -283.8053333333411
# Episode: 2921 of 3000 Total Reward: -83.67813333333274
# Episode: 2922 of 3000 Total Reward: -147.43079999999867
# Episode: 2923 of 3000 Total Reward: -106.08843333333174
# Episode: 2924 of 3000 Total Reward: -341.5196000000041
# Episode: 2925 of 3000 Total Reward: -250.5125000000039
# Episode: 2926 of 3000 Total Reward: -122.92586666666826
# Episode: 2927 of 3000 Total Reward: -146.29376666666602
# Episode: 2928 of 3000 Total Reward: -207.35440000000165
# Episode: 2929 of 3000 Total Reward: -21.15863333332918
# Episode: 2930 of 3000 Total Reward: -136.52366666666842
# Episode: 2931 of 3000 Total Reward: -149.18330000000117
# Episode: 2932 of 3000 Total Reward: -155.19439999999722
# Episode: 2933 of 3000 Total Reward: -131.88456666666258
# Episode: 2934 of 3000 Total Reward: -270.61000000000536
# Episode: 2935 of 3000 Total Reward: -224.73566666667637
# Episode: 2936 of 3000 Total Reward: -175.13466666666866
# Episode: 2937 of 3000 Total Reward: -239.9541000000126
# Episode: 2938 of 3000 Total Reward: -164.13186666666542
# Episode: 2939 of 3000 Total Reward: -100.33213333333141
# Episode: 2940 of 3000 Total Reward: -110.43399999999377
# Episode: 2941 of 3000 Total Reward: -182.69216666666546
# Episode: 2942 of 3000 Total Reward: -280.8865333333379
# Episode: 2943 of 3000 Total Reward: -175.887799999999
# Episode: 2944 of 3000 Total Reward: -246.2488000000084
# Episode: 2945 of 3000 Total Reward: -229.61500000001007
# Episode: 2946 of 3000 Total Reward: -159.46420000000379
# Episode: 2947 of 3000 Total Reward: -202.44919999999766
# Episode: 2948 of 3000 Total Reward: -190.75720000000067
# Episode: 2949 of 3000 Total Reward: -105.67039999999592
# Episode: 2950 of 3000 Total Reward: -219.979999999999
# Episode: 2951 of 3000 Total Reward: -179.35666666667117
# Episode: 2952 of 3000 Total Reward: -179.40000000000663
# Episode: 2953 of 3000 Total Reward: -214.45163333334213
# Episode: 2954 of 3000 Total Reward: -166.61373333333762
# Episode: 2955 of 3000 Total Reward: -172.7159999999985
# Episode: 2956 of 3000 Total Reward: -187.4985333333321
# Episode: 2957 of 3000 Total Reward: -109.39479999998892
# Episode: 2958 of 3000 Total Reward: -156.57199999999847
# Episode: 2959 of 3000 Total Reward: -174.06656666667055
# Episode: 2960 of 3000 Total Reward: -161.6946666666702
# Episode: 2961 of 3000 Total Reward: -141.70460000000307
# Episode: 2962 of 3000 Total Reward: -168.78306666667405
# Episode: 2963 of 3000 Total Reward: -101.46103333332856
# Episode: 2964 of 3000 Total Reward: -276.9524000000004
# Episode: 2965 of 3000 Total Reward: -127.93533333333511
# Episode: 2966 of 3000 Total Reward: -222.4522666666662
# Episode: 2967 of 3000 Total Reward: -110.61379999999757
# Episode: 2968 of 3000 Total Reward: -209.93840000000515
# Episode: 2969 of 3000 Total Reward: -117.42259999999916
# Episode: 2970 of 3000 Total Reward: -220.83500000000853
# Episode: 2971 of 3000 Total Reward: -108.70753333332478
# Episode: 2972 of 3000 Total Reward: -239.45053333332814
# Episode: 2973 of 3000 Total Reward: -334.8325000000121
# Episode: 2974 of 3000 Total Reward: -170.89126666666482
# Episode: 2975 of 3000 Total Reward: -277.6725000000043
# Episode: 2976 of 3000 Total Reward: -237.7368000000018
# Episode: 2977 of 3000 Total Reward: -171.61546666667314
# Episode: 2978 of 3000 Total Reward: -225.27566666667843
# Episode: 2979 of 3000 Total Reward: -142.81849999999926
# Episode: 2980 of 3000 Total Reward: -260.0566666666757
# Episode: 2981 of 3000 Total Reward: -202.78389999999823
# Episode: 2982 of 3000 Total Reward: -294.3146000000051
# Episode: 2983 of 3000 Total Reward: -118.57049999999566
# Episode: 2984 of 3000 Total Reward: -251.7759999999991
# Episode: 2985 of 3000 Total Reward: -134.24800000000673
# Episode: 2986 of 3000 Total Reward: -161.5559333333419
# Episode: 2987 of 3000 Total Reward: -249.1594000000037
# Episode: 2988 of 3000 Total Reward: -301.3304000000007
# Episode: 2989 of 3000 Total Reward: -198.2770666666656
# Episode: 2990 of 3000 Total Reward: -152.318666666667
# Episode: 2991 of 3000 Total Reward: -198.9241999999989
# Episode: 2992 of 3000 Total Reward: -68.01146666666108
# Episode: 2993 of 3000 Total Reward: -218.51940000000386
# Episode: 2994 of 3000 Total Reward: -237.43420000000478
# Episode: 2995 of 3000 Total Reward: -206.38266666667639
# Episode: 2996 of 3000 Total Reward: -239.6956000000107
# Episode: 2997 of 3000 Total Reward: -140.34750000000008
# Episode: 2998 of 3000 Total Reward: -251.05213333332804
# Episode: 2999 of 3000 Total Reward: -191.38110000000074
# Episode: 3000 of 3000 Total Reward: -300.8000000000042

# %%
# Calculate average reward
average_reward = total_reward_all / num_episodes
print("Average reward:", average_reward)
# Out:
# Average reward: 419.318372522229

# %%
# Function to predict Status
def predict_status(observation, agent):
    state = observation.values[:-1]  # Menggunakan fitur dari observasi sebagai state
    state = np.reshape(state, (1, len(state)))  # Reshape state menjadi bentuk (1, num_features)
    state = scaler.transform(state)  # Normalisasi state
    action = agent.act(state)  # Prediksi tindakan menggunakan agen
    return action  # Mengembalikan aksi sebagai prediksi Status

# %%
# Contoh prediksi Status berdasarkan observasi ke-10 dari dataset
observation = dataset.iloc[10]  # Ambil observasi ke-10 dari dataset
predicted_status = predict_status(observation, agent)  # Prediksi Status menggunakan fungsi predict_status
actual_status = observation['Status']  # Status yang sebenarnya dari observasi dalam dataset
print("Predicted Status for observation 10:", predicted_status)
print("Actual Status for observation 10:", actual_status)
# Out:
# Predicted Status for observation 10: 0
# Actual Status for observation 10: 0.0
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Fungsi untuk hitung akurasi
def calculate_accuracy(dataset, agent):
    correct_predictions = 0
    total_predictions = len(dataset)

    for index, observation in dataset.iterrows():
        state = observation.values[:-1]  # Menggunakan fitur dari observasi sebagai state
        state = np.reshape(state, (1, len(state)))  # Pastikan state di-reshape ke bentuk (1, num_features)
        predicted_Status = agent.act(state)  # Prediksi Status menggunakan agen
        actual_Status = observation['Status']  # Nilai Status aktual dari dataset
        if predicted_Status == actual_Status:
            correct_predictions += 1

    accuracy = (correct_predictions / total_predictions) * 100
    return accuracy

# %%
# Menggunakan fungsi calculate_accuracy untuk menghitung akurasi
accuracy = calculate_accuracy(dataset, agent)
print("Accuracy:", accuracy, "%")
# Out:
# Accuracy: 49.38099874808736 %

# %%
# Membuat list untuk menyimpan hasil prediksi
predicted_labels = []

# %%
# Loop melalui setiap observasi dalam dataset dan membuat prediksi
for index, observation in dataset.iterrows():
    predicted_status = predict_status(observation, agent)  # Melakukan prediksi Status
    predicted_labels.append(predicted_status)
# Out:
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\Rizal\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Membuat DataFrame dari list hasil prediksi
predicted_labels_df = pd.DataFrame(predicted_labels, columns=['Status'])

# %%
# Output hasil prediksi dalam format yang diminta
print(predicted_labels_df)
# Out:
#       Status
# 0          0
# 1          1
# 2          0
# 3          1
# 4          1
# ...      ...
# 7184       1
# 7185       1
# 7186       1
# 7187       1
# 7188       0
#
# [7189 rows x 1 columns]

# %%
# Gabungkan kolom Status dari dataset asli dengan kolom Status dari predicted_labels_df
comparison_df = pd.concat([dataset['Status'], predicted_labels_df['Status']], axis=1)
comparison_df.columns = ['Actual_Status', 'Predicted_Status']

# %%
# Hitung jumlah status yang sama dan yang berbeda
same_status = comparison_df[comparison_df['Actual_Status'] == comparison_df['Predicted_Status']].shape[0]
different_status = comparison_df[comparison_df['Actual_Status'] != comparison_df['Predicted_Status']].shape[0]

# %% [markdown]
# 1

# %%
same_status / len(comparison_df) * 100
# Out:
# 50.11823619418556

# %%
# Buat visualisasi
plt.figure(figsize=(8, 6))
labels = ['Same Status', 'Different Status']
sizes = [same_status, different_status]
colors = ['lightgreen', 'lightcoral']
explode = (0, 0.1)  # Pisahkan "Different Status"
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.gca().add_artist(plt.Circle((0,0),0.70,fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Comparison of Actual and Predicted Status')
plt.show()

# %%
import matplotlib.pyplot as plt

# Hitung jumlah status 0 dan 1 dari predicted_labels_df
healthy_count = predicted_labels_df[predicted_labels_df['Status'] == 0].shape[0]
unhealthy_count = predicted_labels_df[predicted_labels_df['Status'] == 1].shape[0]

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns


# Menghitung dan menampilkan confusion matrix untuk data validasi
cm_val = confusion_matrix(comparison_df['Actual_Status'], comparison_df['Predicted_Status'])
print("Confusion Matrix - Validation Data")
print(cm_val)

# Menampilkan confusion matrix sebagai heatmap untuk data validasi
plt.figure(figsize=(10, 8))
sns.heatmap(cm_val, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Validation Data')
plt.show()

# Menghitung dan menampilkan classification report untuk data validasi
print("Classification Report - Validation Data")
report_val = classification_report(comparison_df['Actual_Status'], comparison_df['Predicted_Status'])
print(report_val)
# Out:
# Confusion Matrix - Validation Data
# [[3131 3102]
#  [ 484  472]]
# Classification Report - Validation Data
#               precision    recall  f1-score   support
#
#            0       0.87      0.50      0.64      6233
#            1       0.13      0.49      0.21       956
#
#     accuracy                           0.50      7189
#    macro avg       0.50      0.50      0.42      7189
# weighted avg       0.77      0.50      0.58      7189

# %%
# Data untuk plot
status_labels = ['0', '1']
status_counts = [healthy_count, unhealthy_count]

# %%
# Plot batang
plt.bar(status_labels, status_counts, color=['green', 'red'])

# Tambahkan label angka di atas setiap batang
for i in range(len(status_labels)):
    plt.text(i, status_counts[i], str(status_counts[i]), ha='center', va='bottom')

# Label sumbu dan judul
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Jumlah Status 0 dan 1')

# Tampilkan plot
plt.show()

# %%
import matplotlib.pyplot as plt
# s
# Hitung jumlah status 0 dan 1 dari predicted_labels_df
healthy_count = predicted_labels_df[predicted_labels_df['Status'] == 0].shape[0]
unhealthy_count = predicted_labels_df[predicted_labels_df['Status'] == 1].shape[0]

# Data untuk plot
status_labels = ['Healthy', 'Unhealthy']
status_counts = [healthy_count, unhealthy_count]
colors = ['lightgreen', 'lightcoral']

# Plot donut chart
plt.figure(figsize=(8, 6))
plt.pie(status_counts, labels=status_labels, colors=colors, autopct='%1.1f%%', startangle=90, wedgeprops=dict(width=0.4))
plt.gca().add_artist(plt.Circle((0, 0), 0.6, fc='white'))  # Menambahkan lingkaran tengah untuk membuat donut chart
plt.axis('equal')  # Memastikan lingkaran berukuran sama sehingga terlihat seperti donut
plt.title('Jumlah Status Healthy dan Unhealthy setelah DQN')
plt.show()

# %%
# Menampilkan heatmap dari tabel Q
import seaborn as sns

# Dapatkan bobot dari model jaringan saraf
def get_q_table(model, num_actions):
    # Ambil layer ke-2 (indeks 1) dari model, yang merupakan layer pertama setelah input
    first_layer = model.layers[1]
    # Dapatkan bobot dari layer
    weights = first_layer.get_weights()[0]
    # Ubah bobot menjadi format yang sesuai untuk tabel Q
    q_table = weights.reshape((-1, num_actions))
    return q_table

# Fungsi untuk menampilkan heatmap dari tabel Q
def plot_q_table_heatmap(q_table):
    plt.figure(figsize=(10, 6))
    sns.heatmap(q_table, cmap='viridis', annot=True, fmt=".2f", cbar=False)
    plt.xlabel('Actions')
    plt.ylabel('States')
    plt.title('Heatmap of Q Table')
    plt.show()

# Dapatkan tabel Q dari model agen
q_table = get_q_table(agent.model, num_actions)

# Reduksi dimensi state labels menjadi 1-10
state_labels_reduced = ['State {}'.format(i+1) for i in range(10)]

# Ambil subset dari q_table untuk hanya menampilkan 10 state pertama
q_table_subset = q_table[:10]

# Tampilkan heatmap dari tabel Q
plot_q_table_heatmap(q_table_subset)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[158], line 24
#      21     plt.show()
#      23 # Dapatkan tabel Q dari model agen
# ---> 24 q_table = get_q_table(agent.model, num_actions)
#      26 # Reduksi dimensi state labels menjadi 1-10
#      27 state_labels_reduced = ['State {}'.format(i+1) for i in range(10)]
#
# Cell In[158], line 9, in get_q_table(model, num_actions)
#       7 first_layer = model.layers[1]
#       8 # Dapatkan bobot dari layer
# ----> 9 weights = first_layer.get_weights()[0]
#      10 # Ubah bobot menjadi format yang sesuai untuk tabel Q
#      11 q_table = weights.reshape((-1, num_actions))
#
# IndexError: list index out of range

# %%
# Pilih state yang ingin divisualisasikan, misalnya state ke-10
state_index = 10

# Dapatkan Q-values untuk state tersebut
q_values = q_table[state_index, :]

# Tentukan actions (dalam kasus Anda, hanya 2 actions)
actions = ['Action 0', 'Action 1']

# Plot barplot dari Q-values
plt.figure(figsize=(10, 6))
sns.barplot(x=actions, y=q_values)
plt.title(f'Q-values for State {state_index}')
plt.xlabel('Actions')
plt.ylabel('Q-value')
plt.show()
