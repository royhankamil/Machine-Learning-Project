# %%
import numpy as np

# %%
    

ways_probabilities = {"c4" : {"c13" : 20, "a1" : 25, "c7" : 25},
                      "c13" : {"c4" : 20, "a1" : 20, "c12" : 20},
                      "c12" : {"c13" : 20, "b2" : 15 , "c10" : 20},
                      "c10" : {"c12" : 20, "c3" : 15, "b3" : 10},
                      "b3" : {"c10" : 10, "c11" : 25},
                      "c11" : {"b3" : 25, "c3" : 15, "c9" : 15},
                      "c9" : {"c11" : 15, "c3" : 25, "b1" : 15},
                      "b1" : {"c9" : 15, "c5" : 15, "c14" : 15},
                      "c14" : {"b1" : 15, "c6" : 20, "c8" : 25},
                      "c8" : {"c14" : 25, "c6" : 15, "c2" : 25},
                      "c2" : {"c8" : 25, "c1" : 25},
                      "c1" : {"c2" : 25, "c6" : 25, "a1" : 20, "c7" : 20},
                      "c7" : {"c1" : 20, "a1" : 25, "c4" : 25},
                      "b2" : {"a1" : 10, "c12" : 15, "c3" : 10, "c5" : 15},
                      "c3" : {"c10" : 15, "b2" : 10, "c5" : 25, "c9" : 25, "c11" : 15},
                      "c5" : {"c3" : 25, "b2" : 15, "c6" : 10, "b1" : 15},
                      "c6" : {"c5" : 10, "a1" : 25, "c1" : 25, "c8" : 15, "c14" : 20},
                      "a1" : {"c7" : 25, "c4" : 25, "c13" : 20, "b2" : 10, "c6" : 25, "c1" : 20}
                    }

def count_distance(my_way):
    distance = []
    for ind in range(len(my_way) - 1):
        distance.append(ways_probabilities[my_way[ind]][my_way[ind+1]])
        
    return sum(distance)

max_steps = 8
start = "c14"
target = "b3"
all_probabilities_way = [[start, i] for i in ways_probabilities[start]]

for i in range(max_steps - 1):
    print(i)
    clone_probability = []
    for way in all_probabilities_way:
        if way[-1] == target:
            clone_probability.append(way)
            continue
        
        for next_step in ways_probabilities[way[-1]]:
            now_way = way[:]
            print("n", now_way)
            now_way.append(next_step)
            if next_step not in way and now_way not in all_probabilities_way:
                print(next_step)
                clone_probability.append(now_way)
    all_probabilities_way = clone_probability

# len(all_probabilities_way), all_probabilities_way
to_target_way = [x for x in all_probabilities_way if x[-1] == target]
target_way_w_dist = [(x, count_distance(x)) for x in all_probabilities_way]

"minimal distance ", target_way_w_dist[np.argmin([i[1] for i in target_way_w_dist])][0]
# Out:
# 0
# n ['c14', 'b1']
# c9
# n ['c14', 'b1']
# c5
# n ['c14', 'b1']
# n ['c14', 'c6']
# c5
# n ['c14', 'c6']
# a1
# n ['c14', 'c6']
# c1
# n ['c14', 'c6']
# c8
# n ['c14', 'c6']
# n ['c14', 'c8']
# n ['c14', 'c8']
# c6
# n ['c14', 'c8']
# c2
# 1
# n ['c14', 'b1', 'c9']
# c11
# n ['c14', 'b1', 'c9']
# c3
# n ['c14', 'b1', 'c9']
# n ['c14', 'b1', 'c5']
# c3
# n ['c14', 'b1', 'c5']
# b2
# n ['c14', 'b1', 'c5']
# c6
# n ['c14', 'b1', 'c5']
# n ['c14', 'c6', 'c5']
# c3
# n ['c14', 'c6', 'c5']
# b2
# n ['c14', 'c6', 'c5']
# n ['c14', 'c6', 'c5']
# b1
# n ['c14', 'c6', 'a1']
# c7
# n ['c14', 'c6', 'a1']
# c4
# n ['c14', 'c6', 'a1']
# c13
# n ['c14', 'c6', 'a1']
# b2
# n ['c14', 'c6', 'a1']
# n ['c14', 'c6', 'a1']
# c1
# n ['c14', 'c6', 'c1']
# c2
# n ['c14', 'c6', 'c1']
# n ['c14', 'c6', 'c1']
# a1
# n ['c14', 'c6', 'c1']
# c7
# n ['c14', 'c6', 'c8']
# n ['c14', 'c6', 'c8']
# n ['c14', 'c6', 'c8']
# c2
# n ['c14', 'c8', 'c6']
# c5
# n ['c14', 'c8', 'c6']
# a1
# n ['c14', 'c8', 'c6']
# c1
# n ['c14', 'c8', 'c6']
# n ['c14', 'c8', 'c6']
# n ['c14', 'c8', 'c2']
# n ['c14', 'c8', 'c2']
# c1
# 2
# n ['c14', 'b1', 'c9', 'c11']
# b3
# n ['c14', 'b1', 'c9', 'c11']
# c3
# n ['c14', 'b1', 'c9', 'c11']
# n ['c14', 'b1', 'c9', 'c3']
# c10
# n ['c14', 'b1', 'c9', 'c3']
# b2
# n ['c14', 'b1', 'c9', 'c3']
# c5
# n ['c14', 'b1', 'c9', 'c3']
# n ['c14', 'b1', 'c9', 'c3']
# c11
# n ['c14', 'b1', 'c5', 'c3']
# c10
# n ['c14', 'b1', 'c5', 'c3']
# b2
# n ['c14', 'b1', 'c5', 'c3']
# n ['c14', 'b1', 'c5', 'c3']
# c9
# n ['c14', 'b1', 'c5', 'c3']
# c11
# n ['c14', 'b1', 'c5', 'b2']
# a1
# n ['c14', 'b1', 'c5', 'b2']
# c12
# n ['c14', 'b1', 'c5', 'b2']
# c3
# n ['c14', 'b1', 'c5', 'b2']
# n ['c14', 'b1', 'c5', 'c6']
# n ['c14', 'b1', 'c5', 'c6']
# a1
# n ['c14', 'b1', 'c5', 'c6']
# c1
# n ['c14', 'b1', 'c5', 'c6']
# c8
# n ['c14', 'b1', 'c5', 'c6']
# n ['c14', 'c6', 'c5', 'c3']
# c10
# n ['c14', 'c6', 'c5', 'c3']
# b2
# n ['c14', 'c6', 'c5', 'c3']
# n ['c14', 'c6', 'c5', 'c3']
# c9
# n ['c14', 'c6', 'c5', 'c3']
# c11
# n ['c14', 'c6', 'c5', 'b2']
# a1
# n ['c14', 'c6', 'c5', 'b2']
# c12
# n ['c14', 'c6', 'c5', 'b2']
# c3
# n ['c14', 'c6', 'c5', 'b2']
# n ['c14', 'c6', 'c5', 'b1']
# c9
# n ['c14', 'c6', 'c5', 'b1']
# n ['c14', 'c6', 'c5', 'b1']
# n ['c14', 'c6', 'a1', 'c7']
# c1
# n ['c14', 'c6', 'a1', 'c7']
# n ['c14', 'c6', 'a1', 'c7']
# c4
# n ['c14', 'c6', 'a1', 'c4']
# c13
# n ['c14', 'c6', 'a1', 'c4']
# n ['c14', 'c6', 'a1', 'c4']
# c7
# n ['c14', 'c6', 'a1', 'c13']
# c4
# n ['c14', 'c6', 'a1', 'c13']
# n ['c14', 'c6', 'a1', 'c13']
# c12
# n ['c14', 'c6', 'a1', 'b2']
# n ['c14', 'c6', 'a1', 'b2']
# c12
# n ['c14', 'c6', 'a1', 'b2']
# c3
# n ['c14', 'c6', 'a1', 'b2']
# c5
# n ['c14', 'c6', 'a1', 'c1']
# c2
# n ['c14', 'c6', 'a1', 'c1']
# n ['c14', 'c6', 'a1', 'c1']
# n ['c14', 'c6', 'a1', 'c1']
# c7
# n ['c14', 'c6', 'c1', 'c2']
# c8
# n ['c14', 'c6', 'c1', 'c2']
# n ['c14', 'c6', 'c1', 'a1']
# c7
# n ['c14', 'c6', 'c1', 'a1']
# c4
# n ['c14', 'c6', 'c1', 'a1']
# c13
# n ['c14', 'c6', 'c1', 'a1']
# b2
# n ['c14', 'c6', 'c1', 'a1']
# n ['c14', 'c6', 'c1', 'a1']
# n ['c14', 'c6', 'c1', 'c7']
# n ['c14', 'c6', 'c1', 'c7']
# a1
# n ['c14', 'c6', 'c1', 'c7']
# c4
# n ['c14', 'c6', 'c8', 'c2']
# n ['c14', 'c6', 'c8', 'c2']
# c1
# n ['c14', 'c8', 'c6', 'c5']
# c3
# n ['c14', 'c8', 'c6', 'c5']
# b2
# n ['c14', 'c8', 'c6', 'c5']
# n ['c14', 'c8', 'c6', 'c5']
# b1
# n ['c14', 'c8', 'c6', 'a1']
# c7
# n ['c14', 'c8', 'c6', 'a1']
# c4
# n ['c14', 'c8', 'c6', 'a1']
# c13
# n ['c14', 'c8', 'c6', 'a1']
# b2
# n ['c14', 'c8', 'c6', 'a1']
# n ['c14', 'c8', 'c6', 'a1']
# c1
# n ['c14', 'c8', 'c6', 'c1']
# c2
# n ['c14', 'c8', 'c6', 'c1']
# n ['c14', 'c8', 'c6', 'c1']
# a1
# n ['c14', 'c8', 'c6', 'c1']
# c7
# n ['c14', 'c8', 'c2', 'c1']
# n ['c14', 'c8', 'c2', 'c1']
# c6
# n ['c14', 'c8', 'c2', 'c1']
# a1
# n ['c14', 'c8', 'c2', 'c1']
# c7
# 3
# n ['c14', 'b1', 'c9', 'c11', 'c3']
# c10
# n ['c14', 'b1', 'c9', 'c11', 'c3']
# b2
# n ['c14', 'b1', 'c9', 'c11', 'c3']
# c5
# n ['c14', 'b1', 'c9', 'c11', 'c3']
# n ['c14', 'b1', 'c9', 'c11', 'c3']
# n ['c14', 'b1', 'c9', 'c3', 'c10']
# c12
# n ['c14', 'b1', 'c9', 'c3', 'c10']
# n ['c14', 'b1', 'c9', 'c3', 'c10']
# b3
# n ['c14', 'b1', 'c9', 'c3', 'b2']
# a1
# n ['c14', 'b1', 'c9', 'c3', 'b2']
# c12
# n ['c14', 'b1', 'c9', 'c3', 'b2']
# n ['c14', 'b1', 'c9', 'c3', 'b2']
# c5
# n ['c14', 'b1', 'c9', 'c3', 'c5']
# n ['c14', 'b1', 'c9', 'c3', 'c5']
# b2
# n ['c14', 'b1', 'c9', 'c3', 'c5']
# c6
# n ['c14', 'b1', 'c9', 'c3', 'c5']
# n ['c14', 'b1', 'c9', 'c3', 'c11']
# b3
# n ['c14', 'b1', 'c9', 'c3', 'c11']
# n ['c14', 'b1', 'c9', 'c3', 'c11']
# n ['c14', 'b1', 'c5', 'c3', 'c10']
# c12
# n ['c14', 'b1', 'c5', 'c3', 'c10']
# n ['c14', 'b1', 'c5', 'c3', 'c10']
# b3
# n ['c14', 'b1', 'c5', 'c3', 'b2']
# a1
# n ['c14', 'b1', 'c5', 'c3', 'b2']
# c12
# n ['c14', 'b1', 'c5', 'c3', 'b2']
# n ['c14', 'b1', 'c5', 'c3', 'b2']
# n ['c14', 'b1', 'c5', 'c3', 'c9']
# c11
# n ['c14', 'b1', 'c5', 'c3', 'c9']
# n ['c14', 'b1', 'c5', 'c3', 'c9']
# n ['c14', 'b1', 'c5', 'c3', 'c11']
# b3
# n ['c14', 'b1', 'c5', 'c3', 'c11']
# n ['c14', 'b1', 'c5', 'c3', 'c11']
# c9
# n ['c14', 'b1', 'c5', 'b2', 'a1']
# c7
# n ['c14', 'b1', 'c5', 'b2', 'a1']
# c4
# n ['c14', 'b1', 'c5', 'b2', 'a1']
# c13
# n ['c14', 'b1', 'c5', 'b2', 'a1']
# n ['c14', 'b1', 'c5', 'b2', 'a1']
# c6
# n ['c14', 'b1', 'c5', 'b2', 'a1']
# c1
# n ['c14', 'b1', 'c5', 'b2', 'c12']
# c13
# n ['c14', 'b1', 'c5', 'b2', 'c12']
# n ['c14', 'b1', 'c5', 'b2', 'c12']
# c10
# n ['c14', 'b1', 'c5', 'b2', 'c3']
# c10
# n ['c14', 'b1', 'c5', 'b2', 'c3']
# n ['c14', 'b1', 'c5', 'b2', 'c3']
# n ['c14', 'b1', 'c5', 'b2', 'c3']
# c9
# n ['c14', 'b1', 'c5', 'b2', 'c3']
# c11
# n ['c14', 'b1', 'c5', 'c6', 'a1']
# c7
# n ['c14', 'b1', 'c5', 'c6', 'a1']
# c4
# n ['c14', 'b1', 'c5', 'c6', 'a1']
# c13
# n ['c14', 'b1', 'c5', 'c6', 'a1']
# b2
# n ['c14', 'b1', 'c5', 'c6', 'a1']
# n ['c14', 'b1', 'c5', 'c6', 'a1']
# c1
# n ['c14', 'b1', 'c5', 'c6', 'c1']
# c2
# n ['c14', 'b1', 'c5', 'c6', 'c1']
# n ['c14', 'b1', 'c5', 'c6', 'c1']
# a1
# n ['c14', 'b1', 'c5', 'c6', 'c1']
# c7
# n ['c14', 'b1', 'c5', 'c6', 'c8']
# n ['c14', 'b1', 'c5', 'c6', 'c8']
# n ['c14', 'b1', 'c5', 'c6', 'c8']
# c2
# n ['c14', 'c6', 'c5', 'c3', 'c10']
# c12
# n ['c14', 'c6', 'c5', 'c3', 'c10']
# n ['c14', 'c6', 'c5', 'c3', 'c10']
# b3
# n ['c14', 'c6', 'c5', 'c3', 'b2']
# a1
# n ['c14', 'c6', 'c5', 'c3', 'b2']
# c12
# n ['c14', 'c6', 'c5', 'c3', 'b2']
# n ['c14', 'c6', 'c5', 'c3', 'b2']
# n ['c14', 'c6', 'c5', 'c3', 'c9']
# c11
# n ['c14', 'c6', 'c5', 'c3', 'c9']
# n ['c14', 'c6', 'c5', 'c3', 'c9']
# b1
# n ['c14', 'c6', 'c5', 'c3', 'c11']
# b3
# n ['c14', 'c6', 'c5', 'c3', 'c11']
# n ['c14', 'c6', 'c5', 'c3', 'c11']
# c9
# n ['c14', 'c6', 'c5', 'b2', 'a1']
# c7
# n ['c14', 'c6', 'c5', 'b2', 'a1']
# c4
# n ['c14', 'c6', 'c5', 'b2', 'a1']
# c13
# n ['c14', 'c6', 'c5', 'b2', 'a1']
# n ['c14', 'c6', 'c5', 'b2', 'a1']
# n ['c14', 'c6', 'c5', 'b2', 'a1']
# c1
# n ['c14', 'c6', 'c5', 'b2', 'c12']
# c13
# n ['c14', 'c6', 'c5', 'b2', 'c12']
# n ['c14', 'c6', 'c5', 'b2', 'c12']
# c10
# n ['c14', 'c6', 'c5', 'b2', 'c3']
# c10
# n ['c14', 'c6', 'c5', 'b2', 'c3']
# n ['c14', 'c6', 'c5', 'b2', 'c3']
# n ['c14', 'c6', 'c5', 'b2', 'c3']
# c9
# n ['c14', 'c6', 'c5', 'b2', 'c3']
# c11
# n ['c14', 'c6', 'c5', 'b1', 'c9']
# c11
# n ['c14', 'c6', 'c5', 'b1', 'c9']
# c3
# n ['c14', 'c6', 'c5', 'b1', 'c9']
# n ['c14', 'c6', 'a1', 'c7', 'c1']
# c2
# n ['c14', 'c6', 'a1', 'c7', 'c1']
# n ['c14', 'c6', 'a1', 'c7', 'c1']
# n ['c14', 'c6', 'a1', 'c7', 'c1']
# n ['c14', 'c6', 'a1', 'c7', 'c4']
# c13
# n ['c14', 'c6', 'a1', 'c7', 'c4']
# n ['c14', 'c6', 'a1', 'c7', 'c4']
# n ['c14', 'c6', 'a1', 'c4', 'c13']
# n ['c14', 'c6', 'a1', 'c4', 'c13']
# n ['c14', 'c6', 'a1', 'c4', 'c13']
# c12
# n ['c14', 'c6', 'a1', 'c4', 'c7']
# c1
# n ['c14', 'c6', 'a1', 'c4', 'c7']
# n ['c14', 'c6', 'a1', 'c4', 'c7']
# n ['c14', 'c6', 'a1', 'c13', 'c4']
# n ['c14', 'c6', 'a1', 'c13', 'c4']
# n ['c14', 'c6', 'a1', 'c13', 'c4']
# c7
# n ['c14', 'c6', 'a1', 'c13', 'c12']
# n ['c14', 'c6', 'a1', 'c13', 'c12']
# b2
# n ['c14', 'c6', 'a1', 'c13', 'c12']
# c10
# n ['c14', 'c6', 'a1', 'b2', 'c12']
# c13
# n ['c14', 'c6', 'a1', 'b2', 'c12']
# n ['c14', 'c6', 'a1', 'b2', 'c12']
# c10
# n ['c14', 'c6', 'a1', 'b2', 'c3']
# c10
# n ['c14', 'c6', 'a1', 'b2', 'c3']
# n ['c14', 'c6', 'a1', 'b2', 'c3']
# c5
# n ['c14', 'c6', 'a1', 'b2', 'c3']
# c9
# n ['c14', 'c6', 'a1', 'b2', 'c3']
# c11
# n ['c14', 'c6', 'a1', 'b2', 'c5']
# c3
# n ['c14', 'c6', 'a1', 'b2', 'c5']
# n ['c14', 'c6', 'a1', 'b2', 'c5']
# n ['c14', 'c6', 'a1', 'b2', 'c5']
# b1
# n ['c14', 'c6', 'a1', 'c1', 'c2']
# c8
# n ['c14', 'c6', 'a1', 'c1', 'c2']
# n ['c14', 'c6', 'a1', 'c1', 'c7']
# n ['c14', 'c6', 'a1', 'c1', 'c7']
# n ['c14', 'c6', 'a1', 'c1', 'c7']
# c4
# n ['c14', 'c6', 'c1', 'c2', 'c8']
# n ['c14', 'c6', 'c1', 'c2', 'c8']
# n ['c14', 'c6', 'c1', 'c2', 'c8']
# n ['c14', 'c6', 'c1', 'a1', 'c7']
# n ['c14', 'c6', 'c1', 'a1', 'c7']
# n ['c14', 'c6', 'c1', 'a1', 'c7']
# c4
# n ['c14', 'c6', 'c1', 'a1', 'c4']
# c13
# n ['c14', 'c6', 'c1', 'a1', 'c4']
# n ['c14', 'c6', 'c1', 'a1', 'c4']
# c7
# n ['c14', 'c6', 'c1', 'a1', 'c13']
# c4
# n ['c14', 'c6', 'c1', 'a1', 'c13']
# n ['c14', 'c6', 'c1', 'a1', 'c13']
# c12
# n ['c14', 'c6', 'c1', 'a1', 'b2']
# n ['c14', 'c6', 'c1', 'a1', 'b2']
# c12
# n ['c14', 'c6', 'c1', 'a1', 'b2']
# c3
# n ['c14', 'c6', 'c1', 'a1', 'b2']
# c5
# n ['c14', 'c6', 'c1', 'c7', 'a1']
# n ['c14', 'c6', 'c1', 'c7', 'a1']
# c4
# n ['c14', 'c6', 'c1', 'c7', 'a1']
# c13
# n ['c14', 'c6', 'c1', 'c7', 'a1']
# b2
# n ['c14', 'c6', 'c1', 'c7', 'a1']
# n ['c14', 'c6', 'c1', 'c7', 'a1']
# n ['c14', 'c6', 'c1', 'c7', 'c4']
# c13
# n ['c14', 'c6', 'c1', 'c7', 'c4']
# a1
# n ['c14', 'c6', 'c1', 'c7', 'c4']
# n ['c14', 'c6', 'c8', 'c2', 'c1']
# n ['c14', 'c6', 'c8', 'c2', 'c1']
# n ['c14', 'c6', 'c8', 'c2', 'c1']
# a1
# n ['c14', 'c6', 'c8', 'c2', 'c1']
# c7
# n ['c14', 'c8', 'c6', 'c5', 'c3']
# c10
# n ['c14', 'c8', 'c6', 'c5', 'c3']
# b2
# n ['c14', 'c8', 'c6', 'c5', 'c3']
# n ['c14', 'c8', 'c6', 'c5', 'c3']
# c9
# n ['c14', 'c8', 'c6', 'c5', 'c3']
# c11
# n ['c14', 'c8', 'c6', 'c5', 'b2']
# a1
# n ['c14', 'c8', 'c6', 'c5', 'b2']
# c12
# n ['c14', 'c8', 'c6', 'c5', 'b2']
# c3
# n ['c14', 'c8', 'c6', 'c5', 'b2']
# n ['c14', 'c8', 'c6', 'c5', 'b1']
# c9
# n ['c14', 'c8', 'c6', 'c5', 'b1']
# n ['c14', 'c8', 'c6', 'c5', 'b1']
# n ['c14', 'c8', 'c6', 'a1', 'c7']
# c1
# n ['c14', 'c8', 'c6', 'a1', 'c7']
# n ['c14', 'c8', 'c6', 'a1', 'c7']
# c4
# n ['c14', 'c8', 'c6', 'a1', 'c4']
# c13
# n ['c14', 'c8', 'c6', 'a1', 'c4']
# n ['c14', 'c8', 'c6', 'a1', 'c4']
# c7
# n ['c14', 'c8', 'c6', 'a1', 'c13']
# c4
# n ['c14', 'c8', 'c6', 'a1', 'c13']
# n ['c14', 'c8', 'c6', 'a1', 'c13']
# c12
# n ['c14', 'c8', 'c6', 'a1', 'b2']
# n ['c14', 'c8', 'c6', 'a1', 'b2']
# c12
# n ['c14', 'c8', 'c6', 'a1', 'b2']
# c3
# n ['c14', 'c8', 'c6', 'a1', 'b2']
# c5
# n ['c14', 'c8', 'c6', 'a1', 'c1']
# c2
# n ['c14', 'c8', 'c6', 'a1', 'c1']
# n ['c14', 'c8', 'c6', 'a1', 'c1']
# n ['c14', 'c8', 'c6', 'a1', 'c1']
# c7
# n ['c14', 'c8', 'c6', 'c1', 'c2']
# n ['c14', 'c8', 'c6', 'c1', 'c2']
# n ['c14', 'c8', 'c6', 'c1', 'a1']
# c7
# n ['c14', 'c8', 'c6', 'c1', 'a1']
# c4
# n ['c14', 'c8', 'c6', 'c1', 'a1']
# c13
# n ['c14', 'c8', 'c6', 'c1', 'a1']
# b2
# n ['c14', 'c8', 'c6', 'c1', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'c7']
# n ['c14', 'c8', 'c6', 'c1', 'c7']
# a1
# n ['c14', 'c8', 'c6', 'c1', 'c7']
# c4
# n ['c14', 'c8', 'c2', 'c1', 'c6']
# c5
# n ['c14', 'c8', 'c2', 'c1', 'c6']
# a1
# n ['c14', 'c8', 'c2', 'c1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'a1']
# c7
# n ['c14', 'c8', 'c2', 'c1', 'a1']
# c4
# n ['c14', 'c8', 'c2', 'c1', 'a1']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'a1']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'a1']
# c6
# n ['c14', 'c8', 'c2', 'c1', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c7']
# n ['c14', 'c8', 'c2', 'c1', 'c7']
# a1
# n ['c14', 'c8', 'c2', 'c1', 'c7']
# c4
# 4
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c10']
# c12
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c10']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c10']
# b3
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2']
# a1
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2']
# c12
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2']
# c5
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5']
# b2
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5']
# c6
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5']
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12']
# c13
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12']
# b2
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1']
# c7
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1']
# c4
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1']
# c13
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1']
# c6
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1']
# c1
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c12']
# c13
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c12']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c12']
# c10
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c5']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c5']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c5']
# c6
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c5']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2']
# a1
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2']
# c12
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6']
# a1
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6']
# c1
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6']
# c8
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6']
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12']
# c13
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12']
# b2
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1']
# c7
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1']
# c4
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1']
# c13
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1']
# c6
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1']
# c1
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'c12']
# c13
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'c12']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'c12']
# c10
# n ['c14', 'b1', 'c5', 'c3', 'c9', 'c11']
# b3
# n ['c14', 'b1', 'c5', 'c3', 'c9', 'c11']
# n ['c14', 'b1', 'c5', 'c3', 'c9', 'c11']
# n ['c14', 'b1', 'c5', 'c3', 'c11', 'c9']
# n ['c14', 'b1', 'c5', 'c3', 'c11', 'c9']
# n ['c14', 'b1', 'c5', 'c3', 'c11', 'c9']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7']
# c1
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7']
# c4
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c4']
# c13
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c4']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c4']
# c7
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c13']
# c4
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c13']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c13']
# c12
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6']
# c1
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6']
# c8
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1']
# c2
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1']
# c6
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1']
# c7
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13']
# c4
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13']
# a1
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13']
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c10']
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c10']
# c3
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c10']
# b3
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c10']
# c12
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c10']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c10']
# b3
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c9']
# c11
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c9']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c9']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c11']
# b3
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c11']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c11']
# c9
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7']
# c1
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7']
# c4
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c4']
# c13
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c4']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c4']
# c7
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c13']
# c4
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c13']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c13']
# c12
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2']
# c12
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2']
# c3
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c1']
# c2
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c1']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c1']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c1']
# c7
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c2']
# c8
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c2']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1']
# c7
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1']
# c4
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1']
# c13
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1']
# b2
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7']
# a1
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7']
# c4
# n ['c14', 'b1', 'c5', 'c6', 'c8', 'c2']
# n ['c14', 'b1', 'c5', 'c6', 'c8', 'c2']
# c1
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12']
# c13
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12']
# b2
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1']
# c7
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1']
# c4
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1']
# c13
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1']
# c1
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'c12']
# c13
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'c12']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'c12']
# c10
# n ['c14', 'c6', 'c5', 'c3', 'c9', 'c11']
# b3
# n ['c14', 'c6', 'c5', 'c3', 'c9', 'c11']
# n ['c14', 'c6', 'c5', 'c3', 'c9', 'c11']
# n ['c14', 'c6', 'c5', 'c3', 'c9', 'b1']
# n ['c14', 'c6', 'c5', 'c3', 'c9', 'b1']
# n ['c14', 'c6', 'c5', 'c3', 'c9', 'b1']
# n ['c14', 'c6', 'c5', 'c3', 'c11', 'c9']
# n ['c14', 'c6', 'c5', 'c3', 'c11', 'c9']
# n ['c14', 'c6', 'c5', 'c3', 'c11', 'c9']
# b1
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7']
# c1
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7']
# c4
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c4']
# c13
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c4']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c4']
# c7
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c13']
# c4
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c13']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c13']
# c12
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c1']
# c2
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c1']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c1']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c1']
# c7
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13']
# c4
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13']
# a1
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13']
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c10']
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c10']
# c3
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c10']
# b3
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c10']
# c12
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c10']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c10']
# b3
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c9']
# c11
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c9']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c9']
# b1
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c11']
# b3
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c11']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c11']
# c9
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c11']
# b3
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c11']
# c3
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c11']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3']
# c10
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3']
# b2
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3']
# c11
# n ['c14', 'c6', 'a1', 'c7', 'c1', 'c2']
# c8
# n ['c14', 'c6', 'a1', 'c7', 'c1', 'c2']
# n ['c14', 'c6', 'a1', 'c7', 'c4', 'c13']
# n ['c14', 'c6', 'a1', 'c7', 'c4', 'c13']
# n ['c14', 'c6', 'a1', 'c7', 'c4', 'c13']
# c12
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12']
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12']
# b2
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12']
# c10
# n ['c14', 'c6', 'a1', 'c4', 'c7', 'c1']
# c2
# n ['c14', 'c6', 'a1', 'c4', 'c7', 'c1']
# n ['c14', 'c6', 'a1', 'c4', 'c7', 'c1']
# n ['c14', 'c6', 'a1', 'c4', 'c7', 'c1']
# n ['c14', 'c6', 'a1', 'c13', 'c4', 'c7']
# c1
# n ['c14', 'c6', 'a1', 'c13', 'c4', 'c7']
# n ['c14', 'c6', 'a1', 'c13', 'c4', 'c7']
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2']
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2']
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2']
# c3
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2']
# c5
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'c10']
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'c10']
# c3
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'c10']
# b3
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c13']
# c4
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c13']
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c13']
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c10']
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c10']
# c3
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c10']
# b3
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c10']
# c12
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c10']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c10']
# b3
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c5']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c5']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c5']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c5']
# b1
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c9']
# c11
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c9']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c9']
# b1
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c11']
# b3
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c11']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c11']
# c9
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3']
# c10
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3']
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3']
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3']
# c9
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3']
# c11
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'b1']
# c9
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'b1']
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'b1']
# n ['c14', 'c6', 'a1', 'c1', 'c2', 'c8']
# n ['c14', 'c6', 'a1', 'c1', 'c2', 'c8']
# n ['c14', 'c6', 'a1', 'c1', 'c2', 'c8']
# n ['c14', 'c6', 'a1', 'c1', 'c7', 'c4']
# c13
# n ['c14', 'c6', 'a1', 'c1', 'c7', 'c4']
# n ['c14', 'c6', 'a1', 'c1', 'c7', 'c4']
# n ['c14', 'c6', 'c1', 'a1', 'c7', 'c4']
# c13
# n ['c14', 'c6', 'c1', 'a1', 'c7', 'c4']
# n ['c14', 'c6', 'c1', 'a1', 'c7', 'c4']
# n ['c14', 'c6', 'c1', 'a1', 'c4', 'c13']
# n ['c14', 'c6', 'c1', 'a1', 'c4', 'c13']
# n ['c14', 'c6', 'c1', 'a1', 'c4', 'c13']
# c12
# n ['c14', 'c6', 'c1', 'a1', 'c4', 'c7']
# n ['c14', 'c6', 'c1', 'a1', 'c4', 'c7']
# n ['c14', 'c6', 'c1', 'a1', 'c4', 'c7']
# n ['c14', 'c6', 'c1', 'a1', 'c13', 'c4']
# n ['c14', 'c6', 'c1', 'a1', 'c13', 'c4']
# n ['c14', 'c6', 'c1', 'a1', 'c13', 'c4']
# c7
# n ['c14', 'c6', 'c1', 'a1', 'c13', 'c12']
# n ['c14', 'c6', 'c1', 'a1', 'c13', 'c12']
# b2
# n ['c14', 'c6', 'c1', 'a1', 'c13', 'c12']
# c10
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c12']
# c13
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c12']
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c12']
# c10
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c3']
# c10
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c3']
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c3']
# c5
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c3']
# c9
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c3']
# c11
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c5']
# c3
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c5']
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c5']
# n ['c14', 'c6', 'c1', 'a1', 'b2', 'c5']
# b1
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'c4']
# c13
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'c4']
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'c4']
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'c13']
# c4
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'c13']
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'c13']
# c12
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'b2']
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'b2']
# c12
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'b2']
# c3
# n ['c14', 'c6', 'c1', 'c7', 'a1', 'b2']
# c5
# n ['c14', 'c6', 'c1', 'c7', 'c4', 'c13']
# n ['c14', 'c6', 'c1', 'c7', 'c4', 'c13']
# a1
# n ['c14', 'c6', 'c1', 'c7', 'c4', 'c13']
# c12
# n ['c14', 'c6', 'c1', 'c7', 'c4', 'a1']
# n ['c14', 'c6', 'c1', 'c7', 'c4', 'a1']
# n ['c14', 'c6', 'c1', 'c7', 'c4', 'a1']
# c13
# n ['c14', 'c6', 'c1', 'c7', 'c4', 'a1']
# b2
# n ['c14', 'c6', 'c1', 'c7', 'c4', 'a1']
# n ['c14', 'c6', 'c1', 'c7', 'c4', 'a1']
# n ['c14', 'c6', 'c8', 'c2', 'c1', 'a1']
# c7
# n ['c14', 'c6', 'c8', 'c2', 'c1', 'a1']
# c4
# n ['c14', 'c6', 'c8', 'c2', 'c1', 'a1']
# c13
# n ['c14', 'c6', 'c8', 'c2', 'c1', 'a1']
# b2
# n ['c14', 'c6', 'c8', 'c2', 'c1', 'a1']
# n ['c14', 'c6', 'c8', 'c2', 'c1', 'a1']
# n ['c14', 'c6', 'c8', 'c2', 'c1', 'c7']
# n ['c14', 'c6', 'c8', 'c2', 'c1', 'c7']
# a1
# n ['c14', 'c6', 'c8', 'c2', 'c1', 'c7']
# c4
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'c10']
# c12
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'c10']
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'c10']
# b3
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'b2']
# a1
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'b2']
# c12
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'b2']
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'b2']
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'c9']
# c11
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'c9']
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'c9']
# b1
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'c11']
# b3
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'c11']
# n ['c14', 'c8', 'c6', 'c5', 'c3', 'c11']
# c9
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'a1']
# c7
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'a1']
# c4
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'a1']
# c13
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'a1']
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'a1']
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'a1']
# c1
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'c12']
# c13
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'c12']
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'c12']
# c10
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'c3']
# c10
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'c3']
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'c3']
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'c3']
# c9
# n ['c14', 'c8', 'c6', 'c5', 'b2', 'c3']
# c11
# n ['c14', 'c8', 'c6', 'c5', 'b1', 'c9']
# c11
# n ['c14', 'c8', 'c6', 'c5', 'b1', 'c9']
# c3
# n ['c14', 'c8', 'c6', 'c5', 'b1', 'c9']
# n ['c14', 'c8', 'c6', 'a1', 'c7', 'c1']
# c2
# n ['c14', 'c8', 'c6', 'a1', 'c7', 'c1']
# n ['c14', 'c8', 'c6', 'a1', 'c7', 'c1']
# n ['c14', 'c8', 'c6', 'a1', 'c7', 'c1']
# n ['c14', 'c8', 'c6', 'a1', 'c7', 'c4']
# c13
# n ['c14', 'c8', 'c6', 'a1', 'c7', 'c4']
# n ['c14', 'c8', 'c6', 'a1', 'c7', 'c4']
# n ['c14', 'c8', 'c6', 'a1', 'c4', 'c13']
# n ['c14', 'c8', 'c6', 'a1', 'c4', 'c13']
# n ['c14', 'c8', 'c6', 'a1', 'c4', 'c13']
# c12
# n ['c14', 'c8', 'c6', 'a1', 'c4', 'c7']
# c1
# n ['c14', 'c8', 'c6', 'a1', 'c4', 'c7']
# n ['c14', 'c8', 'c6', 'a1', 'c4', 'c7']
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c4']
# c7
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12']
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12']
# b2
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12']
# c10
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12']
# c13
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12']
# c10
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3']
# c10
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3']
# c5
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3']
# c9
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3']
# c11
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5']
# c3
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5']
# b1
# n ['c14', 'c8', 'c6', 'a1', 'c1', 'c2']
# n ['c14', 'c8', 'c6', 'a1', 'c1', 'c2']
# n ['c14', 'c8', 'c6', 'a1', 'c1', 'c7']
# n ['c14', 'c8', 'c6', 'a1', 'c1', 'c7']
# n ['c14', 'c8', 'c6', 'a1', 'c1', 'c7']
# c4
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c7']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c7']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c7']
# c4
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c4']
# c13
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c4']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c4']
# c7
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13']
# c4
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13']
# c12
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2']
# c12
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2']
# c3
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2']
# c5
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1']
# c4
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1']
# c13
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1']
# b2
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4']
# c13
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4']
# a1
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5']
# b1
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1']
# c7
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1']
# c4
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c7']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c7']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c7']
# c4
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c4']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c4']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c4']
# c7
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13']
# c4
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2']
# c5
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6']
# c5
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1']
# c4
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1']
# c6
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4']
# a1
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4']
# 5
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c10', 'c12']
# c13
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c10', 'c12']
# b2
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c10', 'c12']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'a1']
# c7
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'a1']
# c4
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'a1']
# c13
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'a1']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'a1']
# c6
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'a1']
# c1
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'c12']
# c13
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'c12']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'c12']
# c10
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'c5']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'c5']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'c5']
# c6
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'b2', 'c5']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5', 'b2']
# a1
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5', 'b2']
# c12
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5', 'b2']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5', 'b2']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5', 'c6']
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5', 'c6']
# a1
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5', 'c6']
# c1
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5', 'c6']
# c8
# n ['c14', 'b1', 'c9', 'c11', 'c3', 'c5', 'c6']
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12', 'c13']
# c4
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12', 'c13']
# a1
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12', 'c13']
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12', 'b2']
# a1
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12', 'b2']
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12', 'b2']
# n ['c14', 'b1', 'c9', 'c3', 'c10', 'c12', 'b2']
# c5
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c7']
# c1
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c7']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c7']
# c4
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c4']
# c13
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c4']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c4']
# c7
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c13']
# c4
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c13']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c13']
# c12
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c6']
# c5
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c6']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c6']
# c1
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c6']
# c8
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c6']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c1']
# c2
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c1']
# c6
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c1']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'a1', 'c1']
# c7
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c12', 'c13']
# c4
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c12', 'c13']
# a1
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c12', 'c13']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c12', 'c10']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c12', 'c10']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c12', 'c10']
# b3
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c5', 'c6']
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c5', 'c6']
# a1
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c5', 'c6']
# c1
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c5', 'c6']
# c8
# n ['c14', 'b1', 'c9', 'c3', 'b2', 'c5', 'c6']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2', 'a1']
# c7
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2', 'a1']
# c4
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2', 'a1']
# c13
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2', 'a1']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2', 'a1']
# c6
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2', 'a1']
# c1
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2', 'c12']
# c13
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2', 'c12']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'b2', 'c12']
# c10
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'a1']
# c7
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'a1']
# c4
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'a1']
# c13
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'a1']
# b2
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'a1']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'a1']
# c1
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'c1']
# c2
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'c1']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'c1']
# a1
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'c1']
# c7
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'c8']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'c8']
# n ['c14', 'b1', 'c9', 'c3', 'c5', 'c6', 'c8']
# c2
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12', 'c13']
# c4
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12', 'c13']
# a1
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12', 'c13']
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12', 'b2']
# a1
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12', 'b2']
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12', 'b2']
# n ['c14', 'b1', 'c5', 'c3', 'c10', 'c12', 'b2']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c7']
# c1
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c7']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c7']
# c4
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c4']
# c13
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c4']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c4']
# c7
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c13']
# c4
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c13']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c13']
# c12
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c6']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c6']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c6']
# c1
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c6']
# c8
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c6']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c1']
# c2
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c1']
# c6
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c1']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c1']
# c7
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'c12', 'c13']
# c4
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'c12', 'c13']
# a1
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'c12', 'c13']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'c12', 'c10']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'c12', 'c10']
# n ['c14', 'b1', 'c5', 'c3', 'b2', 'c12', 'c10']
# b3
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7', 'c1']
# c2
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7', 'c1']
# c6
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7', 'c1']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7', 'c1']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7', 'c4']
# c13
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7', 'c4']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c7', 'c4']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c4', 'c13']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c4', 'c13']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c4', 'c13']
# c12
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c4', 'c7']
# c1
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c4', 'c7']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c4', 'c7']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c13', 'c4']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c13', 'c4']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c13', 'c4']
# c7
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c13', 'c12']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c13', 'c12']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c13', 'c12']
# c10
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6', 'c1']
# c2
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6', 'c1']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6', 'c1']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6', 'c1']
# c7
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6', 'c8']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6', 'c8']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c6', 'c8']
# c2
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c2']
# c8
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c2']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c6']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c6']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c6']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c6']
# c8
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c6']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c7']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c7']
# n ['c14', 'b1', 'c5', 'b2', 'a1', 'c1', 'c7']
# c4
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13', 'c4']
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13', 'c4']
# a1
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13', 'c4']
# c7
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13', 'a1']
# c7
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13', 'a1']
# c4
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13', 'a1']
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13', 'a1']
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13', 'a1']
# c6
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c13', 'a1']
# c1
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c10', 'c3']
# c9
# n ['c14', 'b1', 'c5', 'b2', 'c12', 'c10', 'c3']
# c11
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c10', 'c12']
# c13
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c10', 'c12']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c10', 'c12']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c9', 'c11']
# b3
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c9', 'c11']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c9', 'c11']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c11', 'c9']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c11', 'c9']
# n ['c14', 'b1', 'c5', 'b2', 'c3', 'c11', 'c9']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7', 'c1']
# c2
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7', 'c1']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7', 'c1']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7', 'c1']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7', 'c4']
# c13
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7', 'c4']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c7', 'c4']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c4', 'c13']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c4', 'c13']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c4', 'c13']
# c12
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c4', 'c7']
# c1
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c4', 'c7']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c4', 'c7']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c13', 'c4']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c13', 'c4']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c13', 'c4']
# c7
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c13', 'c12']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c13', 'c12']
# b2
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c13', 'c12']
# c10
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2', 'c12']
# c13
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2', 'c12']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2', 'c12']
# c10
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2', 'c3']
# c10
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2', 'c3']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2', 'c3']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2', 'c3']
# c9
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'b2', 'c3']
# c11
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c1', 'c2']
# c8
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c1', 'c2']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c1', 'c7']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c1', 'c7']
# n ['c14', 'b1', 'c5', 'c6', 'a1', 'c1', 'c7']
# c4
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c2', 'c8']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c2', 'c8']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c2', 'c8']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'c7']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'c7']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'c7']
# c4
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'c4']
# c13
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'c4']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'c4']
# c7
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'c13']
# c4
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'c13']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'c13']
# c12
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'b2']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'b2']
# c12
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'b2']
# c3
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'a1', 'b2']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7', 'a1']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7', 'a1']
# c4
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7', 'a1']
# c13
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7', 'a1']
# b2
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7', 'a1']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7', 'a1']
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7', 'c4']
# c13
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7', 'c4']
# a1
# n ['c14', 'b1', 'c5', 'c6', 'c1', 'c7', 'c4']
# n ['c14', 'b1', 'c5', 'c6', 'c8', 'c2', 'c1']
# n ['c14', 'b1', 'c5', 'c6', 'c8', 'c2', 'c1']
# n ['c14', 'b1', 'c5', 'c6', 'c8', 'c2', 'c1']
# a1
# n ['c14', 'b1', 'c5', 'c6', 'c8', 'c2', 'c1']
# c7
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12', 'c13']
# c4
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12', 'c13']
# a1
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12', 'c13']
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12', 'b2']
# a1
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12', 'b2']
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12', 'b2']
# n ['c14', 'c6', 'c5', 'c3', 'c10', 'c12', 'b2']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c7']
# c1
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c7']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c7']
# c4
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c4']
# c13
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c4']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c4']
# c7
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c13']
# c4
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c13']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c13']
# c12
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c1']
# c2
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c1']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c1']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'a1', 'c1']
# c7
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'c12', 'c13']
# c4
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'c12', 'c13']
# a1
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'c12', 'c13']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'c12', 'c10']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'c12', 'c10']
# n ['c14', 'c6', 'c5', 'c3', 'b2', 'c12', 'c10']
# b3
# n ['c14', 'c6', 'c5', 'c3', 'c11', 'c9', 'b1']
# n ['c14', 'c6', 'c5', 'c3', 'c11', 'c9', 'b1']
# n ['c14', 'c6', 'c5', 'c3', 'c11', 'c9', 'b1']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7', 'c1']
# c2
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7', 'c1']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7', 'c1']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7', 'c1']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7', 'c4']
# c13
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7', 'c4']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c7', 'c4']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c4', 'c13']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c4', 'c13']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c4', 'c13']
# c12
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c4', 'c7']
# c1
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c4', 'c7']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c4', 'c7']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c13', 'c4']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c13', 'c4']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c13', 'c4']
# c7
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c13', 'c12']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c13', 'c12']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c13', 'c12']
# c10
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c1', 'c2']
# c8
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c1', 'c2']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c1', 'c7']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c1', 'c7']
# n ['c14', 'c6', 'c5', 'b2', 'a1', 'c1', 'c7']
# c4
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13', 'c4']
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13', 'c4']
# a1
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13', 'c4']
# c7
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13', 'a1']
# c7
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13', 'a1']
# c4
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13', 'a1']
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13', 'a1']
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13', 'a1']
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c13', 'a1']
# c1
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c10', 'c3']
# c9
# n ['c14', 'c6', 'c5', 'b2', 'c12', 'c10', 'c3']
# c11
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c10', 'c12']
# c13
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c10', 'c12']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c10', 'c12']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c9', 'c11']
# b3
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c9', 'c11']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c9', 'c11']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c9', 'b1']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c9', 'b1']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c9', 'b1']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c11', 'c9']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c11', 'c9']
# n ['c14', 'c6', 'c5', 'b2', 'c3', 'c11', 'c9']
# b1
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c11', 'c3']
# c10
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c11', 'c3']
# b2
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c11', 'c3']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c11', 'c3']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c11', 'c3']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'c10']
# c12
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'c10']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'c10']
# b3
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'b2']
# a1
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'b2']
# c12
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'b2']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'b2']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'c11']
# b3
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'c11']
# n ['c14', 'c6', 'c5', 'b1', 'c9', 'c3', 'c11']
# n ['c14', 'c6', 'a1', 'c7', 'c1', 'c2', 'c8']
# n ['c14', 'c6', 'a1', 'c7', 'c1', 'c2', 'c8']
# n ['c14', 'c6', 'a1', 'c7', 'c1', 'c2', 'c8']
# n ['c14', 'c6', 'a1', 'c7', 'c4', 'c13', 'c12']
# n ['c14', 'c6', 'a1', 'c7', 'c4', 'c13', 'c12']
# b2
# n ['c14', 'c6', 'a1', 'c7', 'c4', 'c13', 'c12']
# c10
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12', 'b2']
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12', 'b2']
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12', 'b2']
# c3
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12', 'b2']
# c5
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12', 'c10']
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12', 'c10']
# c3
# n ['c14', 'c6', 'a1', 'c4', 'c13', 'c12', 'c10']
# b3
# n ['c14', 'c6', 'a1', 'c4', 'c7', 'c1', 'c2']
# c8
# n ['c14', 'c6', 'a1', 'c4', 'c7', 'c1', 'c2']
# n ['c14', 'c6', 'a1', 'c13', 'c4', 'c7', 'c1']
# c2
# n ['c14', 'c6', 'a1', 'c13', 'c4', 'c7', 'c1']
# n ['c14', 'c6', 'a1', 'c13', 'c4', 'c7', 'c1']
# n ['c14', 'c6', 'a1', 'c13', 'c4', 'c7', 'c1']
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2', 'c3']
# c10
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2', 'c3']
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2', 'c3']
# c5
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2', 'c3']
# c9
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2', 'c3']
# c11
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2', 'c5']
# c3
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2', 'c5']
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2', 'c5']
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'b2', 'c5']
# b1
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# b2
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# c5
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# c9
# n ['c14', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# c11
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c13', 'c4']
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c13', 'c4']
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c13', 'c4']
# c7
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# c5
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# c9
# n ['c14', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# c11
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c10', 'c12']
# c13
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c10', 'c12']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c10', 'c12']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c5', 'b1']
# c9
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c5', 'b1']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c5', 'b1']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c9', 'c11']
# b3
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c9', 'c11']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c9', 'c11']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c9', 'b1']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c9', 'b1']
# c5
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c9', 'b1']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c11', 'c9']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c11', 'c9']
# n ['c14', 'c6', 'a1', 'b2', 'c3', 'c11', 'c9']
# b1
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3', 'c10']
# c12
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3', 'c10']
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3', 'c10']
# b3
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3', 'c9']
# c11
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3', 'c9']
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3', 'c9']
# b1
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3', 'c11']
# b3
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3', 'c11']
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'c3', 'c11']
# c9
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'b1', 'c9']
# c11
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'b1', 'c9']
# c3
# n ['c14', 'c6', 'a1', 'b2', 'c5', 'b1', 'c9']
# n ['c14', 'c6', 'a1', 'c1', 'c7', 'c4', 'c13']
# n ['c14', 'c6', 'a1', 'c1', 'c7', 'c4', 'c13']
# n ['c14', 'c6', 'a1', 'c1', 'c7', 'c4', 'c13']
# c12
# n ['c14', 'c6', 'c1', 'a1', 'c7', 'c4', 'c13']
# n ['c14', 'c6', 'c1', 'a1', 'c7', 'c4', 'c13']
# n ['c14', 'c6', 'c1', 'a1', 'c7', 'c4', 'c13']
# c12
# n ['c14', 'c6', 'c1', 'a1', 'c4', 'c13', 'c12']
# n ['c14', 'c6', 'c1', 'a1', 'c4', 'c13', 'c12']
# b2
# n ['c14', 'c6', 'c1', 'a1', 'c4', 'c13', 'c12']
# c10
# n ['c14', 'c6', 'c1', 'a1', 'c13', 'c4', 'c7']
# ...
# c5
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'b2', 'c3']
# c9
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'b2', 'c3']
# c11
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'b2', 'c5']
# c3
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'b2', 'c5']
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'b2', 'c5']
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'b2', 'c5']
# b1
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# b2
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# c5
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# c9
# n ['c14', 'c8', 'c6', 'a1', 'c13', 'c12', 'c10', 'c3']
# c11
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12', 'c13', 'c4']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12', 'c13', 'c4']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12', 'c13', 'c4']
# c7
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# c5
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# c9
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c12', 'c10', 'c3']
# c11
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c10', 'c12']
# c13
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c10', 'c12']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c10', 'c12']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c5', 'b1']
# c9
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c5', 'b1']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c5', 'b1']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c9', 'c11']
# b3
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c9', 'c11']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c9', 'c11']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c9', 'b1']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c9', 'b1']
# c5
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c9', 'b1']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c11', 'c9']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c11', 'c9']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c3', 'c11', 'c9']
# b1
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'c3', 'c10']
# c12
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'c3', 'c10']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'c3', 'c10']
# b3
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'c3', 'c9']
# c11
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'c3', 'c9']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'c3', 'c9']
# b1
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'c3', 'c11']
# b3
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'c3', 'c11']
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'c3', 'c11']
# c9
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'b1', 'c9']
# c11
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'b1', 'c9']
# c3
# n ['c14', 'c8', 'c6', 'a1', 'b2', 'c5', 'b1', 'c9']
# n ['c14', 'c8', 'c6', 'a1', 'c1', 'c7', 'c4', 'c13']
# n ['c14', 'c8', 'c6', 'a1', 'c1', 'c7', 'c4', 'c13']
# n ['c14', 'c8', 'c6', 'a1', 'c1', 'c7', 'c4', 'c13']
# c12
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c7', 'c4', 'c13']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c7', 'c4', 'c13']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c7', 'c4', 'c13']
# c12
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c4', 'c13', 'c12']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c4', 'c13', 'c12']
# b2
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c4', 'c13', 'c12']
# c10
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c4', 'c7']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c4', 'c7']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c4', 'c7']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c12', 'b2']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c12', 'b2']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c12', 'b2']
# c3
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c12', 'b2']
# c5
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c12', 'c10']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c12', 'c10']
# c3
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'c13', 'c12', 'c10']
# b3
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c12', 'c13']
# c4
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c12', 'c13']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c12', 'c13']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c12', 'c10']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c12', 'c10']
# c3
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c12', 'c10']
# b3
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c10']
# c12
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c10']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c10']
# b3
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c5']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c5']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c5']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c5']
# b1
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c9']
# c11
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c9']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c9']
# b1
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c11']
# b3
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c11']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c3', 'c11']
# c9
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c5', 'c3']
# c10
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c5', 'c3']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c5', 'c3']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c5', 'c3']
# c9
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c5', 'c3']
# c11
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c5', 'b1']
# c9
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c5', 'b1']
# n ['c14', 'c8', 'c6', 'c1', 'a1', 'b2', 'c5', 'b1']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'c4', 'c13']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'c4', 'c13']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'c4', 'c13']
# c12
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'c13', 'c12']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'c13', 'c12']
# b2
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'c13', 'c12']
# c10
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c12']
# c13
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c12']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c12']
# c10
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c3']
# c10
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c3']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c3']
# c5
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c3']
# c9
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c3']
# c11
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c5']
# c3
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c5']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c5']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'a1', 'b2', 'c5']
# b1
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'c13', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'c13', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'c13', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'c13', 'a1']
# b2
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'c13', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'c13', 'a1']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'c13', 'c12']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'c13', 'c12']
# b2
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'c13', 'c12']
# c10
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'a1', 'c13']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'a1', 'c13']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'a1', 'c13']
# c12
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'a1', 'b2']
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'a1', 'b2']
# c12
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'a1', 'b2']
# c3
# n ['c14', 'c8', 'c6', 'c1', 'c7', 'c4', 'a1', 'b2']
# c5
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'c10']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'c10']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'c10']
# b3
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'b2']
# a1
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'b2']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'b2']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'b2']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'c9']
# c11
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'c9']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'c9']
# b1
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'c11']
# b3
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'c11']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'c3', 'c11']
# c9
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'a1']
# c7
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'a1']
# c4
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'a1']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'c12']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'c12']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'c12']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'c3']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'c3']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'c3']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'c3']
# c9
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b2', 'c3']
# c11
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b1', 'c9']
# c11
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b1', 'c9']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'c5', 'b1', 'c9']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c7', 'c4']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c7', 'c4']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c7', 'c4']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c4', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c4', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c4', 'c13']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c4', 'c7']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c4', 'c7']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c4', 'c7']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c13', 'c4']
# c7
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c13', 'c12']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c13', 'c12']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'c13', 'c12']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c12']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c12']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c12']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c3']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c3']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c3']
# c5
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c3']
# c9
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c3']
# c11
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c5']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c5']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c5']
# n ['c14', 'c8', 'c2', 'c1', 'c6', 'a1', 'b2', 'c5']
# b1
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c7', 'c4', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c7', 'c4', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c7', 'c4', 'c13']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c4', 'c13', 'c12']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c4', 'c13', 'c12']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c4', 'c13', 'c12']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c4', 'c7']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c4', 'c7']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c4', 'c7']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c12', 'b2']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c12', 'b2']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c12', 'b2']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c12', 'b2']
# c5
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c12', 'c10']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c12', 'c10']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c13', 'c12', 'c10']
# b3
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c12', 'c13']
# c4
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c12', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c12', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c12', 'c10']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c12', 'c10']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c12', 'c10']
# b3
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c10']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c10']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c10']
# b3
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c5']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c5']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c5']
# c6
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c5']
# b1
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c9']
# c11
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c9']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c9']
# b1
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c11']
# b3
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c11']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c3', 'c11']
# c9
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c3']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c3']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c3']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c3']
# c9
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c3']
# c11
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'b1']
# c9
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'b1']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'b2', 'c5', 'b1']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'c3']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'c3']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'c3']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'c3']
# c9
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'c3']
# c11
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'b2']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'b2']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'b2']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'b2']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'b1']
# c9
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'b1']
# n ['c14', 'c8', 'c2', 'c1', 'a1', 'c6', 'c5', 'b1']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c4', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c4', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c4', 'c13']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c13', 'c4']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c13', 'c12']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c13', 'c12']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c13', 'c12']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c12']
# c13
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c12']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c12']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c3']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c3']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c3']
# c5
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c3']
# c9
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c3']
# c11
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c5']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c5']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c5']
# c6
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'b2', 'c5']
# b1
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c6', 'c5']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c6', 'c5']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c6', 'c5']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'a1', 'c6', 'c5']
# b1
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'c13', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'c13', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'c13', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'c13', 'a1']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'c13', 'a1']
# c6
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'c13', 'a1']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'c13', 'c12']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'c13', 'c12']
# b2
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'c13', 'c12']
# c10
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'c13']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'c13']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'b2']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'b2']
# c12
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'b2']
# c3
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'b2']
# c5
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'c6']
# c5
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'c6']
# n ['c14', 'c8', 'c2', 'c1', 'c7', 'c4', 'a1', 'c6']
# ('minimal distance ', ['c14', 'b1', 'c9', 'c11', 'b3'])

# %%
distance = []
my_way = ['c14', 'b1', 'c5', 'c3', 'b2', 'a1', 'c1']
for ind in range(len(my_way) - 1):
    distance.append(ways_probabilities[my_way[ind]][my_way[ind+1]])
    
distance
# Out:
# [15, 15, 25, 10, 10, 20]
